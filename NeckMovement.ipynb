# %% [markdown]
# # Install and Import Dependencies

# %%
pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.10.21)
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: absl-py in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: jaxlib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.10.5)
# Requirement already satisfied: numpy<2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# video feed
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Camera Feed', frame)
    
    if cv2.waitKey(10) & 0xFF == ord('x'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Make Detections

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Video Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Determining Joints

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            for id, lm in enumerate(landmarks):
                landmark_name = mp_pose.PoseLandmark(id).name   # get landmark name
                print(f"{landmark_name}: "
                      f"x={lm.x:.4f}, y={lm.y:.4f}, z={lm.z:.4f}, visibility={lm.visibility:.4f} \n")

        except:
            pass
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Camera Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# NOSE: x=0.5604, y=0.4754, z=-1.2251, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.5968, y=0.3955, z=-1.1440, visibility=0.9992
#
# LEFT_EYE: x=0.6201, y=0.3960, z=-1.1441, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6424, y=0.3969, z=-1.1444, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5152, y=0.4009, z=-1.1515, visibility=0.9994
#
# RIGHT_EYE: x=0.4870, y=0.4041, z=-1.1508, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4624, y=0.4079, z=-1.1513, visibility=0.9996
#
# LEFT_EAR: x=0.6791, y=0.4422, z=-0.6166, visibility=0.9992
#
# RIGHT_EAR: x=0.4298, y=0.4558, z=-0.6334, visibility=0.9997
#
# MOUTH_LEFT: x=0.6104, y=0.5605, z=-1.0280, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5142, y=0.5644, z=-1.0326, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8565, y=0.8163, z=-0.2371, visibility=0.9953
#
# RIGHT_SHOULDER: x=0.2804, y=0.8150, z=-0.4173, visibility=0.9976
#
# LEFT_ELBOW: x=1.0306, y=0.9672, z=-0.2358, visibility=0.3193
#
# RIGHT_ELBOW: x=0.1033, y=1.0963, z=-0.6651, visibility=0.4204
#
# LEFT_WRIST: x=1.1977, y=1.4926, z=-0.7247, visibility=0.1606
#
# RIGHT_WRIST: x=0.0588, y=1.6432, z=-1.5994, visibility=0.2763
#
# LEFT_PINKY: x=1.2577, y=1.5859, z=-0.8566, visibility=0.1832
#
# RIGHT_PINKY: x=0.0157, y=1.7669, z=-1.8237, visibility=0.3137
#
# LEFT_INDEX: x=1.2059, y=1.5752, z=-0.9494, visibility=0.2703
#
# RIGHT_INDEX: x=0.0878, y=1.7383, z=-1.9187, visibility=0.4300
#
# LEFT_THUMB: x=1.1676, y=1.5561, z=-0.7921, visibility=0.2560
#
# RIGHT_THUMB: x=0.1161, y=1.6999, z=-1.6732, visibility=0.4012
#
# LEFT_HIP: x=0.7563, y=1.8085, z=-0.0353, visibility=0.0006
#
# RIGHT_HIP: x=0.3769, y=1.8153, z=0.0421, visibility=0.0006
#
# LEFT_KNEE: x=0.7573, y=2.6613, z=-0.2647, visibility=0.0015
#
# RIGHT_KNEE: x=0.4071, y=2.6564, z=-0.2770, visibility=0.0007
#
# LEFT_ANKLE: x=0.7744, y=3.4452, z=0.2540, visibility=0.0001
#
# RIGHT_ANKLE: x=0.4265, y=3.4458, z=-0.0363, visibility=0.0000
#
# LEFT_HEEL: x=0.7854, y=3.5655, z=0.2555, visibility=0.0001
#
# RIGHT_HEEL: x=0.4226, y=3.5677, z=-0.0438, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7177, y=3.6710, z=-0.5594, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.4792, y=3.6761, z=-0.9203, visibility=0.0001
#
# NOSE: x=0.5634, y=0.4775, z=-1.3200, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6018, y=0.3984, z=-1.2384, visibility=0.9992
#
# LEFT_EYE: x=0.6247, y=0.3985, z=-1.2388, visibility=0.9991
#
# LEFT_EYE_OUTER: x=0.6463, y=0.3998, z=-1.2393, visibility=0.9990
#
# RIGHT_EYE_INNER: x=0.5211, y=0.4041, z=-1.2482, visibility=0.9994
#
# RIGHT_EYE: x=0.4938, y=0.4075, z=-1.2476, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4694, y=0.4117, z=-1.2481, visibility=0.9995
#
# LEFT_EAR: x=0.6804, y=0.4420, z=-0.6629, visibility=0.9991
#
# RIGHT_EAR: x=0.4385, y=0.4553, z=-0.6931, visibility=0.9996
#
# MOUTH_LEFT: x=0.6130, y=0.5614, z=-1.0975, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5180, y=0.5660, z=-1.1073, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8572, y=0.8147, z=-0.2637, visibility=0.9947
#
# RIGHT_SHOULDER: x=0.2806, y=0.8129, z=-0.3888, visibility=0.9968
#
# LEFT_ELBOW: x=1.0146, y=0.9582, z=-0.5385, visibility=0.3202
#
# RIGHT_ELBOW: x=0.0976, y=1.0606, z=-0.6659, visibility=0.4248
#
# LEFT_WRIST: x=1.1896, y=1.2442, z=-1.3314, visibility=0.1635
#
# RIGHT_WRIST: x=0.0604, y=1.3292, z=-1.6315, visibility=0.2753
#
# LEFT_PINKY: x=1.2377, y=1.2913, z=-1.5163, visibility=0.1855
#
# RIGHT_PINKY: x=0.0339, y=1.3945, z=-1.8628, visibility=0.3095
#
# LEFT_INDEX: x=1.1855, y=1.2537, z=-1.5693, visibility=0.2718
#
# RIGHT_INDEX: x=0.1022, y=1.1865, z=-1.9213, visibility=0.4240
#
# LEFT_THUMB: x=1.1539, y=1.2499, z=-1.3906, visibility=0.2574
#
# RIGHT_THUMB: x=0.1298, y=1.1295, z=-1.6910, visibility=0.3957
#
# LEFT_HIP: x=0.7522, y=1.8081, z=-0.0400, visibility=0.0007
#
# RIGHT_HIP: x=0.3761, y=1.8115, z=0.0470, visibility=0.0006
#
# LEFT_KNEE: x=0.7491, y=2.6377, z=-0.3569, visibility=0.0020
#
# RIGHT_KNEE: x=0.4050, y=2.6138, z=-0.4458, visibility=0.0009
#
# LEFT_ANKLE: x=0.7597, y=3.4082, z=0.0947, visibility=0.0001
#
# RIGHT_ANKLE: x=0.4104, y=3.4090, z=-0.2880, visibility=0.0000
#
# LEFT_HEEL: x=0.7690, y=3.5231, z=0.0895, visibility=0.0001
#
# RIGHT_HEEL: x=0.4052, y=3.5311, z=-0.3046, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6961, y=3.6348, z=-0.7426, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.4552, y=3.6356, z=-1.1938, visibility=0.0001
#
# NOSE: x=0.5638, y=0.4775, z=-1.4051, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6021, y=0.3986, z=-1.3171, visibility=0.9992
#
# LEFT_EYE: x=0.6249, y=0.3986, z=-1.3176, visibility=0.9991
#
# LEFT_EYE_OUTER: x=0.6462, y=0.3998, z=-1.3180, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5220, y=0.4043, z=-1.3289, visibility=0.9993
#
# RIGHT_EYE: x=0.4953, y=0.4077, z=-1.3284, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4711, y=0.4120, z=-1.3289, visibility=0.9995
#
# LEFT_EAR: x=0.6798, y=0.4397, z=-0.7124, visibility=0.9992
#
# RIGHT_EAR: x=0.4417, y=0.4536, z=-0.7561, visibility=0.9996
#
# MOUTH_LEFT: x=0.6133, y=0.5613, z=-1.1720, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5188, y=0.5661, z=-1.1864, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8583, y=0.8143, z=-0.2787, visibility=0.9944
#
# RIGHT_SHOULDER: x=0.2804, y=0.8129, z=-0.4015, visibility=0.9959
#
# LEFT_ELBOW: x=1.1271, y=1.1091, z=-0.4806, visibility=0.3219
#
# RIGHT_ELBOW: x=0.0977, y=1.0417, z=-0.7277, visibility=0.4194
#
# LEFT_WRIST: x=1.2176, y=1.2731, z=-1.1698, visibility=0.1682
#
# RIGHT_WRIST: x=0.0626, y=1.2619, z=-1.6465, visibility=0.2641
#
# LEFT_PINKY: x=1.2671, y=1.3215, z=-1.3185, visibility=0.1882
#
# RIGHT_PINKY: x=0.0469, y=1.3182, z=-1.8645, visibility=0.2956
#
# LEFT_INDEX: x=1.2203, y=1.2870, z=-1.3831, visibility=0.2736
#
# RIGHT_INDEX: x=0.1065, y=1.1417, z=-1.9100, visibility=0.4055
#
# LEFT_THUMB: x=1.1871, y=1.2819, z=-1.2294, visibility=0.2585
#
# RIGHT_THUMB: x=0.1332, y=1.0886, z=-1.6970, visibility=0.3789
#
# LEFT_HIP: x=0.7523, y=1.8086, z=-0.0460, visibility=0.0007
#
# RIGHT_HIP: x=0.3761, y=1.8114, z=0.0531, visibility=0.0007
#
# LEFT_KNEE: x=0.7423, y=2.6278, z=-0.3468, visibility=0.0026
#
# RIGHT_KNEE: x=0.4026, y=2.5976, z=-0.4653, visibility=0.0012
#
# LEFT_ANKLE: x=0.7480, y=3.3942, z=0.1433, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3991, y=3.3929, z=-0.2371, visibility=0.0000
#
# LEFT_HEEL: x=0.7573, y=3.5095, z=0.1411, visibility=0.0001
#
# RIGHT_HEEL: x=0.3931, y=3.5164, z=-0.2476, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6818, y=3.6230, z=-0.7072, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4435, y=3.6207, z=-1.1669, visibility=0.0002
#
# NOSE: x=0.5641, y=0.4775, z=-1.4253, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6024, y=0.3987, z=-1.3367, visibility=0.9992
#
# LEFT_EYE: x=0.6252, y=0.3986, z=-1.3371, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6462, y=0.3998, z=-1.3376, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5227, y=0.4045, z=-1.3485, visibility=0.9993
#
# RIGHT_EYE: x=0.4963, y=0.4080, z=-1.3481, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4722, y=0.4124, z=-1.3486, visibility=0.9995
#
# LEFT_EAR: x=0.6794, y=0.4381, z=-0.7287, visibility=0.9992
#
# RIGHT_EAR: x=0.4435, y=0.4525, z=-0.7738, visibility=0.9996
#
# MOUTH_LEFT: x=0.6136, y=0.5613, z=-1.1917, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5194, y=0.5662, z=-1.2062, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8593, y=0.8140, z=-0.2864, visibility=0.9942
#
# RIGHT_SHOULDER: x=0.2802, y=0.8129, z=-0.4105, visibility=0.9951
#
# LEFT_ELBOW: x=1.1450, y=1.1486, z=-0.4599, visibility=0.3228
#
# RIGHT_ELBOW: x=0.0976, y=1.0356, z=-0.7438, visibility=0.4142
#
# LEFT_WRIST: x=1.2249, y=1.3022, z=-1.1383, visibility=0.1714
#
# RIGHT_WRIST: x=0.0630, y=1.2654, z=-1.6712, visibility=0.2538
#
# LEFT_PINKY: x=1.2754, y=1.3561, z=-1.2859, visibility=0.1898
#
# RIGHT_PINKY: x=0.0498, y=1.3235, z=-1.8863, visibility=0.2831
#
# LEFT_INDEX: x=1.2297, y=1.3221, z=-1.3549, visibility=0.2744
#
# RIGHT_INDEX: x=0.1088, y=1.1361, z=-1.9177, visibility=0.3890
#
# LEFT_THUMB: x=1.1958, y=1.3148, z=-1.1993, visibility=0.2588
#
# RIGHT_THUMB: x=0.1355, y=1.0833, z=-1.7196, visibility=0.3638
#
# LEFT_HIP: x=0.7524, y=1.8089, z=-0.0487, visibility=0.0008
#
# RIGHT_HIP: x=0.3760, y=1.8112, z=0.0559, visibility=0.0008
#
# LEFT_KNEE: x=0.7394, y=2.6240, z=-0.3435, visibility=0.0031
#
# RIGHT_KNEE: x=0.4011, y=2.5927, z=-0.4693, visibility=0.0015
#
# LEFT_ANKLE: x=0.7441, y=3.3894, z=0.1601, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3948, y=3.3876, z=-0.2296, visibility=0.0000
#
# LEFT_HEEL: x=0.7534, y=3.5050, z=0.1585, visibility=0.0001
#
# RIGHT_HEEL: x=0.3887, y=3.5116, z=-0.2391, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6774, y=3.6189, z=-0.7001, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4395, y=3.6156, z=-1.1663, visibility=0.0002
#
# NOSE: x=0.5651, y=0.4773, z=-1.4066, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6034, y=0.3984, z=-1.3179, visibility=0.9992
#
# LEFT_EYE: x=0.6259, y=0.3981, z=-1.3183, visibility=0.9991
#
# LEFT_EYE_OUTER: x=0.6467, y=0.3993, z=-1.3188, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5239, y=0.4045, z=-1.3284, visibility=0.9993
#
# RIGHT_EYE: x=0.4981, y=0.4080, z=-1.3279, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4742, y=0.4124, z=-1.3283, visibility=0.9995
#
# LEFT_EAR: x=0.6794, y=0.4356, z=-0.7180, visibility=0.9992
#
# RIGHT_EAR: x=0.4457, y=0.4513, z=-0.7554, visibility=0.9996
#
# MOUTH_LEFT: x=0.6142, y=0.5607, z=-1.1780, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5214, y=0.5660, z=-1.1896, visibility=0.9996
#
# LEFT_SHOULDER: x=0.8595, y=0.8128, z=-0.2834, visibility=0.9943
#
# RIGHT_SHOULDER: x=0.2803, y=0.8125, z=-0.4109, visibility=0.9949
#
# LEFT_ELBOW: x=1.1419, y=1.1551, z=-0.4152, visibility=0.3256
#
# RIGHT_ELBOW: x=0.0976, y=1.0298, z=-0.7488, visibility=0.4222
#
# LEFT_WRIST: x=1.2280, y=1.3310, z=-1.0307, visibility=0.1736
#
# RIGHT_WRIST: x=0.0641, y=1.2898, z=-1.7294, visibility=0.2518
#
# LEFT_PINKY: x=1.2821, y=1.3944, z=-1.1671, visibility=0.1897
#
# RIGHT_PINKY: x=0.0516, y=1.3560, z=-1.9518, visibility=0.2773
#
# LEFT_INDEX: x=1.2363, y=1.3670, z=-1.2401, visibility=0.2736
#
# RIGHT_INDEX: x=0.1083, y=1.2727, z=-1.9988, visibility=0.3814
#
# LEFT_THUMB: x=1.2013, y=1.3566, z=-1.0913, visibility=0.2579
#
# RIGHT_THUMB: x=0.1399, y=1.0875, z=-1.7854, visibility=0.3570
#
# LEFT_HIP: x=0.7535, y=1.8037, z=-0.0562, visibility=0.0008
#
# RIGHT_HIP: x=0.3765, y=1.8046, z=0.0634, visibility=0.0008
#
# LEFT_KNEE: x=0.7403, y=2.6201, z=-0.3729, visibility=0.0032
#
# RIGHT_KNEE: x=0.4011, y=2.5942, z=-0.4317, visibility=0.0016
#
# LEFT_ANKLE: x=0.7449, y=3.3864, z=0.1381, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3958, y=3.3810, z=-0.1942, visibility=0.0000
#
# LEFT_HEEL: x=0.7545, y=3.5025, z=0.1355, visibility=0.0001
#
# RIGHT_HEEL: x=0.3902, y=3.5019, z=-0.2034, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6777, y=3.6109, z=-0.7467, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4399, y=3.6068, z=-1.1215, visibility=0.0002
#
# NOSE: x=0.5649, y=0.4762, z=-1.3873, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6032, y=0.3969, z=-1.2986, visibility=0.9992
#
# LEFT_EYE: x=0.6259, y=0.3959, z=-1.2989, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6466, y=0.3964, z=-1.2993, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5238, y=0.4040, z=-1.3076, visibility=0.9993
#
# RIGHT_EYE: x=0.4980, y=0.4077, z=-1.3070, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4741, y=0.4122, z=-1.3075, visibility=0.9995
#
# LEFT_EAR: x=0.6793, y=0.4317, z=-0.7072, visibility=0.9992
#
# RIGHT_EAR: x=0.4460, y=0.4501, z=-0.7422, visibility=0.9996
#
# MOUTH_LEFT: x=0.6142, y=0.5594, z=-1.1612, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5214, y=0.5652, z=-1.1710, visibility=0.9996
#
# LEFT_SHOULDER: x=0.8598, y=0.8118, z=-0.2823, visibility=0.9942
#
# RIGHT_SHOULDER: x=0.2803, y=0.8116, z=-0.3770, visibility=0.9943
#
# LEFT_ELBOW: x=1.1740, y=1.1292, z=-0.7071, visibility=0.3449
#
# RIGHT_ELBOW: x=0.0978, y=1.0282, z=-0.6335, visibility=0.4279
#
# LEFT_WRIST: x=1.2274, y=1.0965, z=-1.5925, visibility=0.2038
#
# RIGHT_WRIST: x=0.0605, y=1.2736, z=-1.3697, visibility=0.2468
#
# LEFT_PINKY: x=1.2815, y=1.0851, z=-1.7667, visibility=0.2125
#
# RIGHT_PINKY: x=0.0506, y=1.3374, z=-1.5405, visibility=0.2691
#
# LEFT_INDEX: x=1.2351, y=1.0528, z=-1.7684, visibility=0.2959
#
# RIGHT_INDEX: x=0.1135, y=1.1440, z=-1.5594, visibility=0.3703
#
# LEFT_THUMB: x=1.2010, y=1.0720, z=-1.6322, visibility=0.2781
#
# RIGHT_THUMB: x=0.1415, y=1.0818, z=-1.4083, visibility=0.3474
#
# LEFT_HIP: x=0.7546, y=1.8027, z=-0.0742, visibility=0.0010
#
# RIGHT_HIP: x=0.3772, y=1.8030, z=0.0817, visibility=0.0009
#
# LEFT_KNEE: x=0.7406, y=2.6152, z=-0.4048, visibility=0.0036
#
# RIGHT_KNEE: x=0.4012, y=2.5854, z=-0.4190, visibility=0.0017
#
# LEFT_ANKLE: x=0.7454, y=3.3791, z=0.0960, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3964, y=3.3690, z=-0.1907, visibility=0.0000
#
# LEFT_HEEL: x=0.7554, y=3.4941, z=0.0940, visibility=0.0001
#
# RIGHT_HEEL: x=0.3898, y=3.4903, z=-0.1996, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6786, y=3.6065, z=-0.7836, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4423, y=3.5982, z=-1.1212, visibility=0.0002
#
# NOSE: x=0.5642, y=0.4762, z=-1.3868, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6029, y=0.3968, z=-1.3017, visibility=0.9993
#
# LEFT_EYE: x=0.6258, y=0.3954, z=-1.3021, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6464, y=0.3956, z=-1.3024, visibility=0.9992
#
# RIGHT_EYE_INNER: x=0.5230, y=0.4041, z=-1.3055, visibility=0.9994
#
# RIGHT_EYE: x=0.4975, y=0.4077, z=-1.3049, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4740, y=0.4123, z=-1.3054, visibility=0.9995
#
# LEFT_EAR: x=0.6792, y=0.4292, z=-0.7151, visibility=0.9993
#
# RIGHT_EAR: x=0.4459, y=0.4494, z=-0.7348, visibility=0.9996
#
# MOUTH_LEFT: x=0.6142, y=0.5588, z=-1.1619, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5212, y=0.5651, z=-1.1657, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8612, y=0.8112, z=-0.2865, visibility=0.9942
#
# RIGHT_SHOULDER: x=0.2803, y=0.8116, z=-0.3451, visibility=0.9940
#
# LEFT_ELBOW: x=1.1761, y=1.1446, z=-0.6473, visibility=0.3527
#
# RIGHT_ELBOW: x=0.0954, y=1.0303, z=-0.5581, visibility=0.4280
#
# LEFT_WRIST: x=1.2301, y=1.1405, z=-1.4610, visibility=0.2186
#
# RIGHT_WRIST: x=0.0574, y=1.2800, z=-1.3039, visibility=0.2403
#
# LEFT_PINKY: x=1.2809, y=1.1470, z=-1.6189, visibility=0.2228
#
# RIGHT_PINKY: x=0.0503, y=1.3488, z=-1.4722, visibility=0.2602
#
# LEFT_INDEX: x=1.2345, y=1.1120, z=-1.6380, visibility=0.3060
#
# RIGHT_INDEX: x=0.1150, y=1.1267, z=-1.4984, visibility=0.3585
#
# LEFT_THUMB: x=1.1999, y=1.1232, z=-1.5049, visibility=0.2872
#
# RIGHT_THUMB: x=0.1413, y=1.0793, z=-1.3460, visibility=0.3374
#
# LEFT_HIP: x=0.7554, y=1.8040, z=-0.0841, visibility=0.0010
#
# RIGHT_HIP: x=0.3771, y=1.8031, z=0.0919, visibility=0.0010
#
# LEFT_KNEE: x=0.7395, y=2.6153, z=-0.4254, visibility=0.0038
#
# RIGHT_KNEE: x=0.3991, y=2.5825, z=-0.4226, visibility=0.0018
#
# LEFT_ANKLE: x=0.7408, y=3.3804, z=0.0760, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3887, y=3.3695, z=-0.1976, visibility=0.0001
#
# LEFT_HEEL: x=0.7513, y=3.4960, z=0.0739, visibility=0.0001
#
# RIGHT_HEEL: x=0.3805, y=3.4926, z=-0.2067, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6707, y=3.6095, z=-0.8154, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4380, y=3.6014, z=-1.1430, visibility=0.0002
#
# NOSE: x=0.5646, y=0.4768, z=-1.2872, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6034, y=0.3975, z=-1.1991, visibility=0.9993
#
# LEFT_EYE: x=0.6264, y=0.3961, z=-1.1995, visibility=0.9993
#
# LEFT_EYE_OUTER: x=0.6469, y=0.3964, z=-1.2000, visibility=0.9992
#
# RIGHT_EYE_INNER: x=0.5234, y=0.4045, z=-1.2114, visibility=0.9994
#
# RIGHT_EYE: x=0.4977, y=0.4081, z=-1.2108, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4741, y=0.4125, z=-1.2112, visibility=0.9995
#
# LEFT_EAR: x=0.6793, y=0.4293, z=-0.5919, visibility=0.9994
#
# RIGHT_EAR: x=0.4459, y=0.4493, z=-0.6458, visibility=0.9996
#
# MOUTH_LEFT: x=0.6144, y=0.5589, z=-1.0519, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5213, y=0.5653, z=-1.0691, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8612, y=0.8112, z=-0.1890, visibility=0.9945
#
# RIGHT_SHOULDER: x=0.2804, y=0.8115, z=-0.3217, visibility=0.9940
#
# LEFT_ELBOW: x=1.1589, y=1.1712, z=-0.5928, visibility=0.3522
#
# RIGHT_ELBOW: x=0.0971, y=1.0189, z=-0.9392, visibility=0.4364
#
# LEFT_WRIST: x=1.1777, y=1.2552, z=-1.3671, visibility=0.2207
#
# RIGHT_WRIST: x=0.0854, y=1.0465, z=-2.1907, visibility=0.2645
#
# LEFT_PINKY: x=1.2183, y=1.3125, z=-1.6035, visibility=0.2272
#
# RIGHT_PINKY: x=0.1017, y=1.1001, z=-2.4362, visibility=0.2815
#
# LEFT_INDEX: x=1.1717, y=1.2558, z=-1.5344, visibility=0.3118
#
# RIGHT_INDEX: x=0.1573, y=0.9617, z=-2.4168, visibility=0.3791
#
# LEFT_THUMB: x=1.1421, y=1.2478, z=-1.4746, visibility=0.2909
#
# RIGHT_THUMB: x=0.1693, y=0.9441, z=-2.2258, visibility=0.3562
#
# LEFT_HIP: x=0.7455, y=1.8037, z=-0.0678, visibility=0.0011
#
# RIGHT_HIP: x=0.3717, y=1.7976, z=0.0752, visibility=0.0010
#
# LEFT_KNEE: x=0.7225, y=2.6070, z=-0.4041, visibility=0.0047
#
# RIGHT_KNEE: x=0.3854, y=2.5663, z=-0.4895, visibility=0.0024
#
# LEFT_ANKLE: x=0.7240, y=3.3745, z=0.0626, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3792, y=3.3625, z=-0.3355, visibility=0.0001
#
# LEFT_HEEL: x=0.7305, y=3.4906, z=0.0549, visibility=0.0001
#
# RIGHT_HEEL: x=0.3742, y=3.4855, z=-0.3541, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6638, y=3.5986, z=-0.8005, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4174, y=3.5912, z=-1.2550, visibility=0.0002
#
# NOSE: x=0.5647, y=0.4773, z=-1.2952, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6035, y=0.3975, z=-1.2081, visibility=0.9993
#
# LEFT_EYE: x=0.6265, y=0.3961, z=-1.2085, visibility=0.9993
#
# LEFT_EYE_OUTER: x=0.6470, y=0.3964, z=-1.2089, visibility=0.9993
#
# RIGHT_EYE_INNER: x=0.5234, y=0.4049, z=-1.2188, visibility=0.9994
#
# RIGHT_EYE: x=0.4976, y=0.4086, z=-1.2183, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4741, y=0.4132, z=-1.2187, visibility=0.9995
#
# LEFT_EAR: x=0.6792, y=0.4290, z=-0.6054, visibility=0.9994
#
# RIGHT_EAR: x=0.4459, y=0.4494, z=-0.6534, visibility=0.9997
#
# MOUTH_LEFT: x=0.6145, y=0.5590, z=-1.0642, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5213, y=0.5658, z=-1.0790, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8612, y=0.8111, z=-0.1918, visibility=0.9946
#
# RIGHT_SHOULDER: x=0.2814, y=0.8133, z=-0.3357, visibility=0.9938
#
# LEFT_ELBOW: x=1.1550, y=1.1656, z=-0.6061, visibility=0.3631
#
# RIGHT_ELBOW: x=0.0987, y=1.0103, z=-1.1234, visibility=0.4504
#
# LEFT_WRIST: x=1.1871, y=1.2140, z=-1.4015, visibility=0.2430
#
# RIGHT_WRIST: x=0.0991, y=0.9184, z=-2.3797, visibility=0.2988
#
# LEFT_PINKY: x=1.2212, y=1.2390, z=-1.5526, visibility=0.2478
#
# RIGHT_PINKY: x=0.1000, y=0.9517, z=-2.6199, visibility=0.3090
#
# LEFT_INDEX: x=1.1844, y=1.1871, z=-1.5533, visibility=0.3337
#
# RIGHT_INDEX: x=0.1654, y=0.8495, z=-2.5756, visibility=0.4044
#
# LEFT_THUMB: x=1.1547, y=1.1949, z=-1.4466, visibility=0.3104
#
# RIGHT_THUMB: x=0.1737, y=0.8510, z=-2.4055, visibility=0.3800
#
# LEFT_HIP: x=0.7425, y=1.8063, z=-0.0567, visibility=0.0013
#
# RIGHT_HIP: x=0.3702, y=1.7971, z=0.0638, visibility=0.0012
#
# LEFT_KNEE: x=0.7034, y=2.6036, z=-0.3816, visibility=0.0066
#
# RIGHT_KNEE: x=0.3730, y=2.5580, z=-0.4810, visibility=0.0035
#
# LEFT_ANKLE: x=0.6940, y=3.3708, z=0.0813, visibility=0.0002
#
# RIGHT_ANKLE: x=0.3551, y=3.3596, z=-0.3029, visibility=0.0001
#
# LEFT_HEEL: x=0.6977, y=3.4861, z=0.0770, visibility=0.0001
#
# RIGHT_HEEL: x=0.3496, y=3.4824, z=-0.3186, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6366, y=3.5937, z=-0.7772, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.3863, y=3.5888, z=-1.2129, visibility=0.0003
#
# NOSE: x=0.5647, y=0.4774, z=-1.2974, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6034, y=0.3975, z=-1.2110, visibility=0.9994
#
# LEFT_EYE: x=0.6264, y=0.3960, z=-1.2114, visibility=0.9994
#
# LEFT_EYE_OUTER: x=0.6469, y=0.3962, z=-1.2119, visibility=0.9993
#
# RIGHT_EYE_INNER: x=0.5233, y=0.4049, z=-1.2216, visibility=0.9995
#
# RIGHT_EYE: x=0.4975, y=0.4086, z=-1.2209, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4740, y=0.4132, z=-1.2213, visibility=0.9996
#
# LEFT_EAR: x=0.6789, y=0.4281, z=-0.6172, visibility=0.9994
#
# RIGHT_EAR: x=0.4458, y=0.4494, z=-0.6582, visibility=0.9997
#
# MOUTH_LEFT: x=0.6145, y=0.5591, z=-1.0710, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5213, y=0.5659, z=-1.0843, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8620, y=0.8111, z=-0.2042, visibility=0.9946
#
# RIGHT_SHOULDER: x=0.2814, y=0.8153, z=-0.3434, visibility=0.9934
#
# LEFT_ELBOW: x=1.1807, y=1.1526, z=-0.7765, visibility=0.3755
#
# RIGHT_ELBOW: x=0.0994, y=1.0135, z=-1.0465, visibility=0.4585
#
# LEFT_WRIST: x=1.1998, y=1.0460, z=-1.6358, visibility=0.2730
#
# RIGHT_WRIST: x=0.0971, y=0.9657, z=-2.0815, visibility=0.3151
#
# LEFT_PINKY: x=1.2218, y=1.0118, z=-1.7783, visibility=0.2717
#
# RIGHT_PINKY: x=0.1022, y=0.9841, z=-2.2794, visibility=0.3179
#
# LEFT_INDEX: x=1.1877, y=0.9707, z=-1.7402, visibility=0.3568
#
# RIGHT_INDEX: x=0.1681, y=0.8917, z=-2.2369, visibility=0.4115
#
# LEFT_THUMB: x=1.1595, y=0.9995, z=-1.6560, visibility=0.3306
#
# RIGHT_THUMB: x=0.1760, y=0.8870, z=-2.0973, visibility=0.3859
#
# LEFT_HIP: x=0.7439, y=1.8097, z=-0.0625, visibility=0.0015
#
# RIGHT_HIP: x=0.3740, y=1.8008, z=0.0692, visibility=0.0014
#
# LEFT_KNEE: x=0.7074, y=2.6050, z=-0.3772, visibility=0.0093
#
# RIGHT_KNEE: x=0.3762, y=2.5598, z=-0.3748, visibility=0.0046
#
# LEFT_ANKLE: x=0.7019, y=3.3728, z=0.0959, visibility=0.0003
#
# RIGHT_ANKLE: x=0.3559, y=3.3611, z=-0.1718, visibility=0.0001
#
# LEFT_HEEL: x=0.7074, y=3.4883, z=0.0919, visibility=0.0001
#
# RIGHT_HEEL: x=0.3512, y=3.4842, z=-0.1834, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6432, y=3.5962, z=-0.7729, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.3947, y=3.5901, z=-1.0547, visibility=0.0004
#
# NOSE: x=0.5647, y=0.4771, z=-1.3393, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6036, y=0.3970, z=-1.2538, visibility=0.9994
#
# LEFT_EYE: x=0.6268, y=0.3954, z=-1.2539, visibility=0.9994
#
# LEFT_EYE_OUTER: x=0.6474, y=0.3956, z=-1.2540, visibility=0.9993
#
# RIGHT_EYE_INNER: x=0.5233, y=0.4043, z=-1.2617, visibility=0.9995
#
# RIGHT_EYE: x=0.4973, y=0.4080, z=-1.2611, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4739, y=0.4126, z=-1.2616, visibility=0.9996
#
# LEFT_EAR: x=0.6795, y=0.4273, z=-0.6697, visibility=0.9995
#
# RIGHT_EAR: x=0.4457, y=0.4482, z=-0.6992, visibility=0.9997
#
# MOUTH_LEFT: x=0.6146, y=0.5588, z=-1.1159, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5213, y=0.5658, z=-1.1268, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8618, y=0.8108, z=-0.2617, visibility=0.9944
#
# RIGHT_SHOULDER: x=0.2822, y=0.8144, z=-0.3625, visibility=0.9929
#
# LEFT_ELBOW: x=1.2114, y=1.1239, z=-0.9423, visibility=0.3953
#
# RIGHT_ELBOW: x=0.0901, y=1.0128, z=-1.0304, visibility=0.4643
#
# LEFT_WRIST: x=1.2160, y=0.8231, z=-1.8349, visibility=0.3162
#
# RIGHT_WRIST: x=0.0736, y=1.0589, z=-1.6546, visibility=0.3165
#
# LEFT_PINKY: x=1.2287, y=0.7257, z=-1.9923, visibility=0.3055
#
# RIGHT_PINKY: x=0.0413, y=1.1164, z=-1.7890, visibility=0.3156
#
# LEFT_INDEX: x=1.1960, y=0.6950, z=-1.9203, visibility=0.3873
#
# RIGHT_INDEX: x=0.1249, y=0.9798, z=-1.7627, visibility=0.4084
#
# LEFT_THUMB: x=1.1660, y=0.7482, z=-1.8456, visibility=0.3602
#
# RIGHT_THUMB: x=0.1437, y=0.9572, z=-1.6726, visibility=0.3839
#
# LEFT_HIP: x=0.7441, y=1.8102, z=-0.0694, visibility=0.0017
#
# RIGHT_HIP: x=0.3763, y=1.8010, z=0.0764, visibility=0.0016
#
# LEFT_KNEE: x=0.7102, y=2.6079, z=-0.3767, visibility=0.0097
#
# RIGHT_KNEE: x=0.3766, y=2.5629, z=-0.3380, visibility=0.0046
#
# LEFT_ANKLE: x=0.7043, y=3.3730, z=0.1038, visibility=0.0003
#
# RIGHT_ANKLE: x=0.3599, y=3.3636, z=-0.1184, visibility=0.0001
#
# LEFT_HEEL: x=0.7111, y=3.4897, z=0.1007, visibility=0.0002
#
# RIGHT_HEEL: x=0.3560, y=3.4864, z=-0.1259, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6408, y=3.5994, z=-0.7597, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.3987, y=3.5924, z=-1.0072, visibility=0.0004
#
# NOSE: x=0.5649, y=0.4770, z=-1.3420, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6041, y=0.3970, z=-1.2541, visibility=0.9995
#
# LEFT_EYE: x=0.6273, y=0.3954, z=-1.2542, visibility=0.9994
#
# LEFT_EYE_OUTER: x=0.6479, y=0.3956, z=-1.2542, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5233, y=0.4042, z=-1.2627, visibility=0.9995
#
# RIGHT_EYE: x=0.4973, y=0.4078, z=-1.2621, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4739, y=0.4123, z=-1.2626, visibility=0.9996
#
# LEFT_EAR: x=0.6795, y=0.4273, z=-0.6694, visibility=0.9995
#
# RIGHT_EAR: x=0.4457, y=0.4476, z=-0.7037, visibility=0.9997
#
# MOUTH_LEFT: x=0.6146, y=0.5588, z=-1.1196, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5212, y=0.5658, z=-1.1326, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8600, y=0.8110, z=-0.2848, visibility=0.9939
#
# RIGHT_SHOULDER: x=0.2827, y=0.8145, z=-0.4075, visibility=0.9924
#
# LEFT_ELBOW: x=1.2389, y=1.0593, z=-1.0380, visibility=0.4185
#
# RIGHT_ELBOW: x=0.0805, y=1.0136, z=-1.0539, visibility=0.4725
#
# LEFT_WRIST: x=1.2141, y=0.6354, z=-1.8534, visibility=0.3621
#
# RIGHT_WRIST: x=0.0474, y=1.1028, z=-1.9186, visibility=0.3225
#
# LEFT_PINKY: x=1.2222, y=0.4955, z=-2.0105, visibility=0.3415
#
# RIGHT_PINKY: x=0.0265, y=1.1445, z=-2.0699, visibility=0.3175
#
# LEFT_INDEX: x=1.1087, y=0.3313, z=-1.9049, visibility=0.4184
#
# RIGHT_INDEX: x=0.1100, y=0.9965, z=-2.0135, visibility=0.4096
#
# LEFT_THUMB: x=1.0767, y=0.3937, z=-1.8499, visibility=0.3915
#
# RIGHT_THUMB: x=0.1438, y=0.9670, z=-1.9343, visibility=0.3863
#
# LEFT_HIP: x=0.7454, y=1.8119, z=-0.0690, visibility=0.0021
#
# RIGHT_HIP: x=0.3796, y=1.8020, z=0.0761, visibility=0.0019
#
# LEFT_KNEE: x=0.7120, y=2.6188, z=-0.3544, visibility=0.0102
#
# RIGHT_KNEE: x=0.3772, y=2.5725, z=-0.3470, visibility=0.0045
#
# LEFT_ANKLE: x=0.7054, y=3.3775, z=0.1218, visibility=0.0003
#
# RIGHT_ANKLE: x=0.3624, y=3.3649, z=-0.1252, visibility=0.0001
#
# LEFT_HEEL: x=0.7129, y=3.4907, z=0.1207, visibility=0.0002
#
# RIGHT_HEEL: x=0.3590, y=3.4880, z=-0.1321, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6384, y=3.6063, z=-0.7147, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.4016, y=3.5940, z=-1.0119, visibility=0.0004
#
# NOSE: x=0.5648, y=0.4775, z=-1.4430, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6039, y=0.3970, z=-1.3477, visibility=0.9995
#
# LEFT_EYE: x=0.6272, y=0.3954, z=-1.3482, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6476, y=0.3955, z=-1.3483, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5230, y=0.4044, z=-1.3592, visibility=0.9995
#
# RIGHT_EYE: x=0.4967, y=0.4080, z=-1.3589, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4735, y=0.4126, z=-1.3595, visibility=0.9996
#
# LEFT_EAR: x=0.6790, y=0.4271, z=-0.7016, visibility=0.9995
#
# RIGHT_EAR: x=0.4453, y=0.4478, z=-0.7472, visibility=0.9997
#
# MOUTH_LEFT: x=0.6146, y=0.5594, z=-1.1946, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5211, y=0.5667, z=-1.2108, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8620, y=0.8109, z=-0.2777, visibility=0.9938
#
# RIGHT_SHOULDER: x=0.2826, y=0.8192, z=-0.4242, visibility=0.9920
#
# LEFT_ELBOW: x=1.2307, y=1.1404, z=-0.4801, visibility=0.4172
#
# RIGHT_ELBOW: x=0.0842, y=1.0142, z=-1.1452, visibility=0.4756
#
# LEFT_WRIST: x=1.2601, y=1.2115, z=-1.0355, visibility=0.3535
#
# RIGHT_WRIST: x=0.0807, y=0.9985, z=-2.3198, visibility=0.3248
#
# LEFT_PINKY: x=1.3038, y=1.2566, z=-1.1294, visibility=0.3327
#
# RIGHT_PINKY: x=0.0781, y=1.0744, z=-2.5417, visibility=0.3174
#
# LEFT_INDEX: x=1.2585, y=1.2119, z=-1.1788, visibility=0.4097
#
# RIGHT_INDEX: x=0.1473, y=0.9543, z=-2.5104, visibility=0.4073
#
# LEFT_THUMB: x=1.2216, y=1.2077, z=-1.0804, visibility=0.3820
#
# RIGHT_THUMB: x=0.1623, y=0.9368, z=-2.3472, visibility=0.3831
#
# LEFT_HIP: x=0.7483, y=1.8180, z=-0.0693, visibility=0.0021
#
# RIGHT_HIP: x=0.3801, y=1.8083, z=0.0762, visibility=0.0020
#
# LEFT_KNEE: x=0.7134, y=2.6128, z=-0.3206, visibility=0.0125
#
# RIGHT_KNEE: x=0.3809, y=2.5734, z=-0.3508, visibility=0.0056
#
# LEFT_ANKLE: x=0.7074, y=3.3769, z=0.2494, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3653, y=3.3661, z=-0.0564, visibility=0.0001
#
# LEFT_HEEL: x=0.7152, y=3.4915, z=0.2520, visibility=0.0002
#
# RIGHT_HEEL: x=0.3634, y=3.4884, z=-0.0585, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6400, y=3.6066, z=-0.6298, visibility=0.0004
#
# RIGHT_FOOT_INDEX: x=0.4023, y=3.5945, z=-0.9878, visibility=0.0005
#
# NOSE: x=0.5652, y=0.4775, z=-1.4443, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6040, y=0.3970, z=-1.3455, visibility=0.9995
#
# LEFT_EYE: x=0.6273, y=0.3954, z=-1.3458, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6477, y=0.3955, z=-1.3459, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5231, y=0.4044, z=-1.3586, visibility=0.9996
#
# RIGHT_EYE: x=0.4967, y=0.4081, z=-1.3583, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4735, y=0.4127, z=-1.3589, visibility=0.9996
#
# LEFT_EAR: x=0.6793, y=0.4271, z=-0.6978, visibility=0.9996
#
# RIGHT_EAR: x=0.4452, y=0.4479, z=-0.7481, visibility=0.9997
#
# MOUTH_LEFT: x=0.6151, y=0.5596, z=-1.1959, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5215, y=0.5669, z=-1.2139, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8627, y=0.8116, z=-0.2399, visibility=0.9936
#
# RIGHT_SHOULDER: x=0.2825, y=0.8212, z=-0.4480, visibility=0.9917
#
# LEFT_ELBOW: x=1.2201, y=1.1367, z=-0.5438, visibility=0.4287
#
# RIGHT_ELBOW: x=0.0858, y=1.0156, z=-1.1553, visibility=0.4860
#
# LEFT_WRIST: x=1.2670, y=1.0970, z=-1.1980, visibility=0.3735
#
# RIGHT_WRIST: x=0.0898, y=1.0140, z=-2.2135, visibility=0.3293
#
# LEFT_PINKY: x=1.3070, y=1.0850, z=-1.3346, visibility=0.3463
#
# RIGHT_PINKY: x=0.0873, y=1.0993, z=-2.4140, visibility=0.3177
#
# LEFT_INDEX: x=1.2668, y=1.0582, z=-1.3554, visibility=0.4229
#
# RIGHT_INDEX: x=0.1611, y=0.9420, z=-2.3802, visibility=0.4058
#
# LEFT_THUMB: x=1.2307, y=1.0823, z=-1.2445, visibility=0.3934
#
# RIGHT_THUMB: x=0.1715, y=0.9279, z=-2.2359, visibility=0.3812
#
# LEFT_HIP: x=0.7506, y=1.8245, z=-0.0691, visibility=0.0024
#
# RIGHT_HIP: x=0.3809, y=1.8166, z=0.0760, visibility=0.0023
#
# LEFT_KNEE: x=0.7130, y=2.6124, z=-0.3080, visibility=0.0144
#
# RIGHT_KNEE: x=0.3808, y=2.5741, z=-0.3125, visibility=0.0062
#
# LEFT_ANKLE: x=0.7047, y=3.3773, z=0.2656, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3661, y=3.3668, z=-0.0055, visibility=0.0002
#
# LEFT_HEEL: x=0.7122, y=3.4920, z=0.2700, visibility=0.0002
#
# RIGHT_HEEL: x=0.3626, y=3.4887, z=-0.0063, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6403, y=3.6072, z=-0.5902, visibility=0.0005
#
# RIGHT_FOOT_INDEX: x=0.4044, y=3.5984, z=-0.9232, visibility=0.0006
#
# NOSE: x=0.5654, y=0.4776, z=-1.4415, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6041, y=0.3970, z=-1.3418, visibility=0.9995
#
# LEFT_EYE: x=0.6274, y=0.3954, z=-1.3421, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6478, y=0.3955, z=-1.3422, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5231, y=0.4044, z=-1.3555, visibility=0.9996
#
# RIGHT_EYE: x=0.4967, y=0.4081, z=-1.3551, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4735, y=0.4128, z=-1.3557, visibility=0.9996
#
# LEFT_EAR: x=0.6795, y=0.4272, z=-0.6949, visibility=0.9996
#
# RIGHT_EAR: x=0.4452, y=0.4481, z=-0.7464, visibility=0.9998
#
# MOUTH_LEFT: x=0.6155, y=0.5597, z=-1.1934, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5219, y=0.5671, z=-1.2119, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8633, y=0.8120, z=-0.2220, visibility=0.9934
#
# RIGHT_SHOULDER: x=0.2825, y=0.8228, z=-0.4548, visibility=0.9914
#
# LEFT_ELBOW: x=1.2162, y=1.1343, z=-0.5691, visibility=0.4395
#
# RIGHT_ELBOW: x=0.0873, y=1.0167, z=-1.1715, visibility=0.4962
#
# LEFT_WRIST: x=1.2712, y=1.0586, z=-1.2640, visibility=0.3913
#
# RIGHT_WRIST: x=0.0947, y=1.0172, z=-2.2282, visibility=0.3341
#
# LEFT_PINKY: x=1.3100, y=1.0351, z=-1.3957, visibility=0.3583
#
# RIGHT_PINKY: x=0.0936, y=1.0989, z=-2.4277, visibility=0.3184
#
# LEFT_INDEX: x=1.2717, y=1.0072, z=-1.3955, visibility=0.4344
#
# RIGHT_INDEX: x=0.1666, y=0.9388, z=-2.3897, visibility=0.4048
#
# LEFT_THUMB: x=1.2359, y=1.0366, z=-1.3009, visibility=0.4033
#
# RIGHT_THUMB: x=0.1760, y=0.9255, z=-2.2488, visibility=0.3796
#
# LEFT_HIP: x=0.7528, y=1.8284, z=-0.0690, visibility=0.0027
#
# RIGHT_HIP: x=0.3821, y=1.8215, z=0.0758, visibility=0.0026
#
# LEFT_KNEE: x=0.7131, y=2.6118, z=-0.3049, visibility=0.0164
#
# RIGHT_KNEE: x=0.3811, y=2.5743, z=-0.3039, visibility=0.0069
#
# LEFT_ANKLE: x=0.7040, y=3.3776, z=0.2640, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3673, y=3.3678, z=-0.0037, visibility=0.0002
#
# LEFT_HEEL: x=0.7115, y=3.4923, z=0.2685, visibility=0.0002
#
# RIGHT_HEEL: x=0.3632, y=3.4893, z=-0.0052, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6412, y=3.6077, z=-0.5850, visibility=0.0005
#
# RIGHT_FOOT_INDEX: x=0.4063, y=3.6017, z=-0.9170, visibility=0.0007
#
# NOSE: x=0.5654, y=0.4751, z=-1.3735, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6041, y=0.3952, z=-1.2728, visibility=0.9995
#
# LEFT_EYE: x=0.6274, y=0.3939, z=-1.2731, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6478, y=0.3942, z=-1.2733, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5231, y=0.4018, z=-1.2875, visibility=0.9996
#
# RIGHT_EYE: x=0.4966, y=0.4050, z=-1.2873, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4734, y=0.4094, z=-1.2879, visibility=0.9997
#
# LEFT_EAR: x=0.6793, y=0.4268, z=-0.6525, visibility=0.9996
#
# RIGHT_EAR: x=0.4451, y=0.4460, z=-0.7139, visibility=0.9998
#
# MOUTH_LEFT: x=0.6154, y=0.5585, z=-1.1400, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5218, y=0.5651, z=-1.1606, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8629, y=0.8121, z=-0.1958, visibility=0.9934
#
# RIGHT_SHOULDER: x=0.2827, y=0.8226, z=-0.4478, visibility=0.9912
#
# LEFT_ELBOW: x=1.2108, y=1.1312, z=-0.3940, visibility=0.4530
#
# RIGHT_ELBOW: x=0.0884, y=1.0174, z=-1.1489, visibility=0.5053
#
# LEFT_WRIST: x=1.2840, y=1.0813, z=-0.9494, visibility=0.4109
#
# RIGHT_WRIST: x=0.0940, y=1.0242, z=-2.2699, visibility=0.3492
#
# LEFT_PINKY: x=1.3283, y=1.0758, z=-1.0455, visibility=0.3743
#
# RIGHT_PINKY: x=0.0926, y=1.1066, z=-2.4837, visibility=0.3310
#
# LEFT_INDEX: x=1.2933, y=1.0437, z=-1.0688, visibility=0.4512
#
# RIGHT_INDEX: x=0.1688, y=0.9400, z=-2.4592, visibility=0.4171
#
# LEFT_THUMB: x=1.2576, y=1.0670, z=-0.9856, visibility=0.4197
#
# RIGHT_THUMB: x=0.1782, y=0.9280, z=-2.2992, visibility=0.3917
#
# LEFT_HIP: x=0.7522, y=1.8282, z=-0.0579, visibility=0.0029
#
# RIGHT_HIP: x=0.3814, y=1.8211, z=0.0646, visibility=0.0027
#
# LEFT_KNEE: x=0.7113, y=2.6114, z=-0.3079, visibility=0.0167
#
# RIGHT_KNEE: x=0.3793, y=2.5756, z=-0.3146, visibility=0.0070
#
# LEFT_ANKLE: x=0.7012, y=3.3776, z=0.2566, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3655, y=3.3687, z=-0.0225, visibility=0.0002
#
# LEFT_HEEL: x=0.7079, y=3.4921, z=0.2605, visibility=0.0002
#
# RIGHT_HEEL: x=0.3599, y=3.4897, z=-0.0216, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6419, y=3.6053, z=-0.6041, visibility=0.0005
#
# RIGHT_FOOT_INDEX: x=0.4019, y=3.6024, z=-0.9465, visibility=0.0007
#
# NOSE: x=0.5654, y=0.4743, z=-1.3046, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6042, y=0.3947, z=-1.2067, visibility=0.9996
#
# LEFT_EYE: x=0.6275, y=0.3935, z=-1.2069, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6479, y=0.3937, z=-1.2072, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5231, y=0.4011, z=-1.2243, visibility=0.9996
#
# RIGHT_EYE: x=0.4966, y=0.4043, z=-1.2241, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4734, y=0.4087, z=-1.2247, visibility=0.9997
#
# LEFT_EAR: x=0.6793, y=0.4266, z=-0.5904, visibility=0.9996
#
# RIGHT_EAR: x=0.4452, y=0.4455, z=-0.6677, visibility=0.9998
#
# MOUTH_LEFT: x=0.6154, y=0.5578, z=-1.0697, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5218, y=0.5640, z=-1.0951, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8627, y=0.8127, z=-0.1818, visibility=0.9928
#
# RIGHT_SHOULDER: x=0.2841, y=0.8225, z=-0.4137, visibility=0.9905
#
# LEFT_ELBOW: x=1.2091, y=1.1291, z=-0.9307, visibility=0.4587
#
# RIGHT_ELBOW: x=0.0916, y=1.0128, z=-1.1887, visibility=0.5074
#
# LEFT_WRIST: x=1.2144, y=0.8600, z=-1.8762, visibility=0.4333
#
# RIGHT_WRIST: x=0.0932, y=0.9730, z=-2.2527, visibility=0.3631
#
# LEFT_PINKY: x=1.2261, y=0.7630, z=-2.0306, visibility=0.3941
#
# RIGHT_PINKY: x=0.0908, y=0.9484, z=-2.4498, visibility=0.3396
#
# LEFT_INDEX: x=1.1890, y=0.7256, z=-1.9300, visibility=0.4692
#
# RIGHT_INDEX: x=0.1621, y=0.8756, z=-2.3771, visibility=0.4240
#
# LEFT_THUMB: x=1.1615, y=0.7803, z=-1.8731, visibility=0.4359
#
# RIGHT_THUMB: x=0.1781, y=0.8761, z=-2.2603, visibility=0.3980
#
# LEFT_HIP: x=0.7500, y=1.8293, z=-0.0486, visibility=0.0030
#
# RIGHT_HIP: x=0.3814, y=1.8217, z=0.0551, visibility=0.0029
#
# LEFT_KNEE: x=0.7098, y=2.6112, z=-0.3812, visibility=0.0176
#
# RIGHT_KNEE: x=0.3762, y=2.5759, z=-0.4573, visibility=0.0073
#
# LEFT_ANKLE: x=0.7007, y=3.3775, z=0.0367, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3661, y=3.3705, z=-0.3115, visibility=0.0002
#
# LEFT_HEEL: x=0.7073, y=3.4911, z=0.0329, visibility=0.0003
#
# RIGHT_HEEL: x=0.3607, y=3.4928, z=-0.3278, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6400, y=3.6056, z=-0.7487, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4003, y=3.6029, z=-1.1663, visibility=0.0008
#
# NOSE: x=0.5661, y=0.4729, z=-1.3022, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6045, y=0.3937, z=-1.2049, visibility=0.9996
#
# LEFT_EYE: x=0.6277, y=0.3924, z=-1.2051, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6480, y=0.3923, z=-1.2051, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5233, y=0.4006, z=-1.2199, visibility=0.9996
#
# RIGHT_EYE: x=0.4967, y=0.4040, z=-1.2196, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4735, y=0.4085, z=-1.2202, visibility=0.9997
#
# LEFT_EAR: x=0.6794, y=0.4259, z=-0.5991, visibility=0.9997
#
# RIGHT_EAR: x=0.4454, y=0.4455, z=-0.6650, visibility=0.9998
#
# MOUTH_LEFT: x=0.6164, y=0.5559, z=-1.0729, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5225, y=0.5632, z=-1.0948, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8630, y=0.8126, z=-0.2041, visibility=0.9919
#
# RIGHT_SHOULDER: x=0.2854, y=0.8251, z=-0.4192, visibility=0.9900
#
# LEFT_ELBOW: x=1.2326, y=1.0781, z=-1.0717, visibility=0.4708
#
# RIGHT_ELBOW: x=0.0944, y=1.0078, z=-1.2225, visibility=0.5123
#
# LEFT_WRIST: x=1.2065, y=0.6455, z=-1.9482, visibility=0.4603
#
# RIGHT_WRIST: x=0.0913, y=0.9976, z=-2.2326, visibility=0.3725
#
# LEFT_PINKY: x=1.1686, y=0.3882, z=-2.0999, visibility=0.4146
#
# RIGHT_PINKY: x=0.0893, y=0.9822, z=-2.4175, visibility=0.3439
#
# LEFT_INDEX: x=1.1031, y=0.3484, z=-1.9793, visibility=0.4864
#
# RIGHT_INDEX: x=0.1595, y=0.8986, z=-2.3426, visibility=0.4273
#
# LEFT_THUMB: x=1.0777, y=0.4112, z=-1.9385, visibility=0.4530
#
# RIGHT_THUMB: x=0.1725, y=0.8927, z=-2.2390, visibility=0.4015
#
# LEFT_HIP: x=0.7547, y=1.8291, z=-0.0489, visibility=0.0031
#
# RIGHT_HIP: x=0.3897, y=1.8216, z=0.0554, visibility=0.0030
#
# LEFT_KNEE: x=0.7117, y=2.6127, z=-0.3690, visibility=0.0177
#
# RIGHT_KNEE: x=0.3770, y=2.5767, z=-0.4177, visibility=0.0072
#
# LEFT_ANKLE: x=0.7028, y=3.3777, z=0.0449, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3715, y=3.3711, z=-0.2608, visibility=0.0002
#
# LEFT_HEEL: x=0.7101, y=3.4909, z=0.0353, visibility=0.0002
#
# RIGHT_HEEL: x=0.3679, y=3.4930, z=-0.2715, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6402, y=3.6061, z=-0.6868, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4070, y=3.6034, z=-1.0542, visibility=0.0008
#
# NOSE: x=0.5670, y=0.4727, z=-1.3125, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6052, y=0.3937, z=-1.2162, visibility=0.9996
#
# LEFT_EYE: x=0.6281, y=0.3924, z=-1.2164, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6483, y=0.3923, z=-1.2165, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5240, y=0.4006, z=-1.2302, visibility=0.9996
#
# RIGHT_EYE: x=0.4974, y=0.4039, z=-1.2299, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4740, y=0.4084, z=-1.2305, visibility=0.9997
#
# LEFT_EAR: x=0.6793, y=0.4260, z=-0.6065, visibility=0.9997
#
# RIGHT_EAR: x=0.4458, y=0.4455, z=-0.6874, visibility=0.9998
#
# MOUTH_LEFT: x=0.6169, y=0.5557, z=-1.0818, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5231, y=0.5630, z=-1.0990, visibility=0.9998
#
# LEFT_SHOULDER: x=0.8629, y=0.8123, z=-0.2213, visibility=0.9914
#
# RIGHT_SHOULDER: x=0.2853, y=0.8251, z=-0.4335, visibility=0.9893
#
# LEFT_ELBOW: x=1.2364, y=1.0727, z=-0.9719, visibility=0.4792
#
# RIGHT_ELBOW: x=0.0945, y=1.0077, z=-1.1667, visibility=0.5101
#
# LEFT_WRIST: x=1.2190, y=0.7706, z=-1.8632, visibility=0.4781
#
# RIGHT_WRIST: x=0.0849, y=1.0103, z=-2.1780, visibility=0.3696
#
# LEFT_PINKY: x=1.1982, y=0.6522, z=-2.0211, visibility=0.4285
#
# RIGHT_PINKY: x=0.0813, y=1.0004, z=-2.3398, visibility=0.3402
#
# LEFT_INDEX: x=1.1518, y=0.6157, z=-1.9411, visibility=0.4988
#
# RIGHT_INDEX: x=0.1591, y=0.9150, z=-2.2659, visibility=0.4226
#
# LEFT_THUMB: x=1.1271, y=0.6661, z=-1.8709, visibility=0.4663
#
# RIGHT_THUMB: x=0.1700, y=0.9149, z=-2.1775, visibility=0.3976
#
# LEFT_HIP: x=0.7552, y=1.8229, z=-0.0480, visibility=0.0031
#
# RIGHT_HIP: x=0.3934, y=1.8175, z=0.0544, visibility=0.0031
#
# LEFT_KNEE: x=0.7119, y=2.6083, z=-0.3319, visibility=0.0174
#
# RIGHT_KNEE: x=0.3808, y=2.5739, z=-0.4132, visibility=0.0070
#
# LEFT_ANKLE: x=0.7031, y=3.3703, z=0.1115, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3726, y=3.3655, z=-0.2485, visibility=0.0002
#
# LEFT_HEEL: x=0.7105, y=3.4797, z=0.1098, visibility=0.0002
#
# RIGHT_HEEL: x=0.3686, y=3.4858, z=-0.2606, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6393, y=3.6006, z=-0.6280, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4083, y=3.5957, z=-1.0287, visibility=0.0008
#
# NOSE: x=0.5670, y=0.4723, z=-1.2772, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6055, y=0.3932, z=-1.1828, visibility=0.9996
#
# LEFT_EYE: x=0.6284, y=0.3920, z=-1.1830, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6486, y=0.3917, z=-1.1830, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5240, y=0.4002, z=-1.1957, visibility=0.9997
#
# RIGHT_EYE: x=0.4973, y=0.4033, z=-1.1954, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4740, y=0.4077, z=-1.1960, visibility=0.9997
#
# LEFT_EAR: x=0.6795, y=0.4253, z=-0.5963, visibility=0.9997
#
# RIGHT_EAR: x=0.4459, y=0.4439, z=-0.6592, visibility=0.9998
#
# MOUTH_LEFT: x=0.6169, y=0.5550, z=-1.0554, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5231, y=0.5624, z=-1.0732, visibility=0.9998
#
# LEFT_SHOULDER: x=0.8634, y=0.8124, z=-0.2277, visibility=0.9902
#
# RIGHT_SHOULDER: x=0.2852, y=0.8246, z=-0.4232, visibility=0.9886
#
# LEFT_ELBOW: x=1.2342, y=1.0640, z=-1.0850, visibility=0.4856
#
# RIGHT_ELBOW: x=0.0936, y=1.0142, z=-1.1894, visibility=0.5083
#
# LEFT_WRIST: x=1.1928, y=0.5959, z=-1.9096, visibility=0.4984
#
# RIGHT_WRIST: x=0.0799, y=1.0129, z=-2.2061, visibility=0.3734
#
# LEFT_PINKY: x=1.1397, y=0.3514, z=-2.0581, visibility=0.4440
#
# RIGHT_PINKY: x=0.0754, y=1.0180, z=-2.3798, visibility=0.3421
#
# LEFT_INDEX: x=1.1079, y=0.3241, z=-1.9316, visibility=0.5114
#
# RIGHT_INDEX: x=0.1554, y=0.9115, z=-2.2975, visibility=0.4238
#
# LEFT_THUMB: x=1.0596, y=0.3866, z=-1.8964, visibility=0.4789
#
# RIGHT_THUMB: x=0.1664, y=0.9212, z=-2.2113, visibility=0.3988
#
# LEFT_HIP: x=0.7546, y=1.8250, z=-0.0481, visibility=0.0031
#
# RIGHT_HIP: x=0.3931, y=1.8179, z=0.0546, visibility=0.0031
#
# LEFT_KNEE: x=0.7103, y=2.6111, z=-0.3666, visibility=0.0175
#
# RIGHT_KNEE: x=0.3753, y=2.5746, z=-0.4112, visibility=0.0070
#
# LEFT_ANKLE: x=0.6985, y=3.3704, z=0.0625, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3688, y=3.3661, z=-0.2369, visibility=0.0002
#
# LEFT_HEEL: x=0.7059, y=3.4803, z=0.0606, visibility=0.0002
#
# RIGHT_HEEL: x=0.3662, y=3.4864, z=-0.2485, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6288, y=3.6012, z=-0.6960, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4021, y=3.5964, z=-1.0436, visibility=0.0007
#
# NOSE: x=0.5670, y=0.4719, z=-1.2512, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6055, y=0.3926, z=-1.1569, visibility=0.9996
#
# LEFT_EYE: x=0.6284, y=0.3914, z=-1.1571, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6487, y=0.3911, z=-1.1572, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5238, y=0.3994, z=-1.1697, visibility=0.9997
#
# RIGHT_EYE: x=0.4970, y=0.4025, z=-1.1694, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4739, y=0.4066, z=-1.1700, visibility=0.9997
#
# LEFT_EAR: x=0.6797, y=0.4250, z=-0.5747, visibility=0.9997
#
# RIGHT_EAR: x=0.4459, y=0.4428, z=-0.6316, visibility=0.9998
#
# MOUTH_LEFT: x=0.6169, y=0.5545, z=-1.0303, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5230, y=0.5617, z=-1.0485, visibility=0.9998
#
# LEFT_SHOULDER: x=0.8634, y=0.8123, z=-0.2223, visibility=0.9893
#
# RIGHT_SHOULDER: x=0.2854, y=0.8241, z=-0.4042, visibility=0.9879
#
# LEFT_ELBOW: x=1.2307, y=1.0668, z=-1.0598, visibility=0.4897
#
# RIGHT_ELBOW: x=0.0937, y=1.0131, z=-1.2203, visibility=0.5117
#
# LEFT_WRIST: x=1.1898, y=0.6357, z=-1.8920, visibility=0.5138
#
# RIGHT_WRIST: x=0.0799, y=0.9849, z=-2.2449, visibility=0.3854
#
# LEFT_PINKY: x=1.1699, y=0.4757, z=-2.0358, visibility=0.4562
#
# RIGHT_PINKY: x=0.0753, y=0.9423, z=-2.4252, visibility=0.3498
#
# LEFT_INDEX: x=1.0887, y=0.3599, z=-1.9098, visibility=0.5219
#
# RIGHT_INDEX: x=0.1532, y=0.8775, z=-2.3266, visibility=0.4304
#
# LEFT_THUMB: x=1.0353, y=0.4003, z=-1.8784, visibility=0.4889
#
# RIGHT_THUMB: x=0.1708, y=0.9060, z=-2.2455, visibility=0.4050
#
# LEFT_HIP: x=0.7532, y=1.8256, z=-0.0473, visibility=0.0032
#
# RIGHT_HIP: x=0.3928, y=1.8179, z=0.0538, visibility=0.0032
#
# LEFT_KNEE: x=0.7100, y=2.6109, z=-0.3961, visibility=0.0185
#
# RIGHT_KNEE: x=0.3707, y=2.5750, z=-0.4306, visibility=0.0074
#
# LEFT_ANKLE: x=0.6965, y=3.3705, z=0.0195, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3674, y=3.3665, z=-0.2718, visibility=0.0002
#
# LEFT_HEEL: x=0.7033, y=3.4803, z=0.0177, visibility=0.0003
#
# RIGHT_HEEL: x=0.3659, y=3.4869, z=-0.2850, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6264, y=3.6015, z=-0.7383, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.3982, y=3.5967, z=-1.0769, visibility=0.0008
#
# NOSE: x=0.5677, y=0.4714, z=-1.2667, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6060, y=0.3923, z=-1.1729, visibility=0.9996
#
# LEFT_EYE: x=0.6287, y=0.3912, z=-1.1732, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6489, y=0.3909, z=-1.1733, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5242, y=0.3990, z=-1.1865, visibility=0.9997
#
# RIGHT_EYE: x=0.4972, y=0.4020, z=-1.1862, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4740, y=0.4061, z=-1.1868, visibility=0.9997
#
# LEFT_EAR: x=0.6797, y=0.4247, z=-0.5836, visibility=0.9997
#
# RIGHT_EAR: x=0.4459, y=0.4423, z=-0.6409, visibility=0.9998
#
# MOUTH_LEFT: x=0.6173, y=0.5540, z=-1.0428, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5230, y=0.5612, z=-1.0619, visibility=0.9998
#
# LEFT_SHOULDER: x=0.8634, y=0.8123, z=-0.2010, visibility=0.9896
#
# RIGHT_SHOULDER: x=0.2861, y=0.8241, z=-0.4077, visibility=0.9883
#
# LEFT_ELBOW: x=1.0564, y=0.9804, z=-0.5910, visibility=0.4854
#
# RIGHT_ELBOW: x=0.0944, y=1.0080, z=-1.2115, visibility=0.5247
#
# LEFT_WRIST: x=1.2510, y=1.0560, z=-1.2683, visibility=0.5035
#
# RIGHT_WRIST: x=0.0875, y=0.9456, z=-2.2915, visibility=0.4055
#
# LEFT_PINKY: x=1.2936, y=1.0627, z=-1.3698, visibility=0.4483
#
# RIGHT_PINKY: x=0.0770, y=0.9200, z=-2.4924, visibility=0.3656
#
# LEFT_INDEX: x=1.2557, y=1.0180, z=-1.3718, visibility=0.5159
#
# RIGHT_INDEX: x=0.1528, y=0.8665, z=-2.4269, visibility=0.4454
#
# LEFT_THUMB: x=1.2161, y=1.0328, z=-1.3011, visibility=0.4838
#
# RIGHT_THUMB: x=0.1732, y=0.8769, z=-2.3041, visibility=0.4205
#
# LEFT_HIP: x=0.7537, y=1.8260, z=-0.0420, visibility=0.0033
#
# RIGHT_HIP: x=0.3926, y=1.8182, z=0.0484, visibility=0.0034
#
# LEFT_KNEE: x=0.7144, y=2.6108, z=-0.3399, visibility=0.0206
#
# RIGHT_KNEE: x=0.3835, y=2.5751, z=-0.4217, visibility=0.0086
#
# LEFT_ANKLE: x=0.7065, y=3.3707, z=0.1199, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3765, y=3.3668, z=-0.2419, visibility=0.0002
#
# LEFT_HEEL: x=0.7122, y=3.4811, z=0.1167, visibility=0.0003
#
# RIGHT_HEEL: x=0.3726, y=3.4872, z=-0.2528, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6475, y=3.6013, z=-0.6704, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4092, y=3.5971, z=-1.0752, visibility=0.0008
#
# NOSE: x=0.5687, y=0.4718, z=-1.3408, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6072, y=0.3929, z=-1.2426, visibility=0.9996
#
# LEFT_EYE: x=0.6298, y=0.3920, z=-1.2427, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6501, y=0.3920, z=-1.2426, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5247, y=0.3990, z=-1.2580, visibility=0.9997
#
# RIGHT_EYE: x=0.4973, y=0.4020, z=-1.2576, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4740, y=0.4060, z=-1.2582, visibility=0.9997
#
# LEFT_EAR: x=0.6799, y=0.4251, z=-0.6309, visibility=0.9997
#
# RIGHT_EAR: x=0.4459, y=0.4420, z=-0.6982, visibility=0.9998
#
# MOUTH_LEFT: x=0.6176, y=0.5546, z=-1.1107, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5234, y=0.5614, z=-1.1326, visibility=0.9998
#
# LEFT_SHOULDER: x=0.8600, y=0.8124, z=-0.2463, visibility=0.9888
#
# RIGHT_SHOULDER: x=0.2858, y=0.8236, z=-0.4293, visibility=0.9874
#
# LEFT_ELBOW: x=1.1864, y=1.0007, z=-0.9202, visibility=0.4946
#
# RIGHT_ELBOW: x=0.0785, y=1.0239, z=-1.1941, visibility=0.5263
#
# LEFT_WRIST: x=1.2484, y=0.7387, z=-1.7309, visibility=0.5188
#
# RIGHT_WRIST: x=0.0716, y=1.0571, z=-2.2496, visibility=0.3955
#
# LEFT_PINKY: x=1.1908, y=0.5080, z=-1.8794, visibility=0.4565
#
# RIGHT_PINKY: x=0.0685, y=1.0457, z=-2.4146, visibility=0.3546
#
# LEFT_INDEX: x=1.1626, y=0.4299, z=-1.7837, visibility=0.5216
#
# RIGHT_INDEX: x=0.1523, y=0.8982, z=-2.3523, visibility=0.4328
#
# LEFT_THUMB: x=1.0870, y=0.5126, z=-1.7296, visibility=0.4899
#
# RIGHT_THUMB: x=0.1692, y=0.9231, z=-2.2574, visibility=0.4086
#
# LEFT_HIP: x=0.7538, y=1.8259, z=-0.0510, visibility=0.0033
#
# RIGHT_HIP: x=0.3928, y=1.8186, z=0.0573, visibility=0.0034
#
# LEFT_KNEE: x=0.7146, y=2.6103, z=-0.2963, visibility=0.0200
#
# RIGHT_KNEE: x=0.3850, y=2.5758, z=-0.2593, visibility=0.0083
#
# ...
#
# LEFT_ELBOW: x=1.0894, y=1.2559, z=-0.4539, visibility=0.2426
#
# RIGHT_ELBOW: x=0.0742, y=1.0492, z=-1.0958, visibility=0.5018
#
# LEFT_WRIST: x=1.1269, y=1.4969, z=-0.9750, visibility=0.1119
#
# RIGHT_WRIST: x=0.0643, y=0.9335, z=-2.3304, visibility=0.5113
#
# LEFT_PINKY: x=1.1559, y=1.5914, z=-1.0777, visibility=0.1241
#
# RIGHT_PINKY: x=0.0649, y=0.8871, z=-2.5749, visibility=0.4461
#
# LEFT_INDEX: x=1.1183, y=1.5505, z=-1.1386, visibility=0.1716
#
# RIGHT_INDEX: x=0.0940, y=0.8407, z=-2.5694, visibility=0.5228
#
# LEFT_THUMB: x=1.0932, y=1.5229, z=-1.0243, visibility=0.1584
#
# RIGHT_THUMB: x=0.1074, y=0.8690, z=-2.3720, visibility=0.4831
#
# LEFT_HIP: x=0.7398, y=1.8150, z=-0.0447, visibility=0.0063
#
# RIGHT_HIP: x=0.3746, y=1.8053, z=0.0501, visibility=0.0064
#
# LEFT_KNEE: x=0.7016, y=2.5973, z=-0.1900, visibility=0.0365
#
# RIGHT_KNEE: x=0.3879, y=2.5667, z=-0.4224, visibility=0.0246
#
# LEFT_ANKLE: x=0.6951, y=3.3405, z=0.3831, visibility=0.0039
#
# RIGHT_ANKLE: x=0.3795, y=3.3372, z=-0.0886, visibility=0.0040
#
# LEFT_HEEL: x=0.6967, y=3.4534, z=0.3892, visibility=0.0029
#
# RIGHT_HEEL: x=0.3799, y=3.4508, z=-0.0896, visibility=0.0029
#
# LEFT_FOOT_INDEX: x=0.6445, y=3.5647, z=-0.4322, visibility=0.0049
#
# RIGHT_FOOT_INDEX: x=0.4112, y=3.5581, z=-0.9816, visibility=0.0059
#
# NOSE: x=0.5923, y=0.4749, z=-1.3603, visibility=0.9985
#
# LEFT_EYE_INNER: x=0.6217, y=0.4000, z=-1.2721, visibility=0.9980
#
# LEFT_EYE: x=0.6417, y=0.3995, z=-1.2726, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6609, y=0.3985, z=-1.2730, visibility=0.9975
#
# RIGHT_EYE_INNER: x=0.5434, y=0.4017, z=-1.2892, visibility=0.9983
#
# RIGHT_EYE: x=0.5146, y=0.4040, z=-1.2892, visibility=0.9984
#
# RIGHT_EYE_OUTER: x=0.4898, y=0.4073, z=-1.2897, visibility=0.9985
#
# LEFT_EAR: x=0.6823, y=0.4279, z=-0.6845, visibility=0.9984
#
# RIGHT_EAR: x=0.4518, y=0.4455, z=-0.7477, visibility=0.9989
#
# MOUTH_LEFT: x=0.6319, y=0.5595, z=-1.1328, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5426, y=0.5634, z=-1.1542, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8620, y=0.8167, z=-0.3036, visibility=0.9807
#
# RIGHT_SHOULDER: x=0.2738, y=0.8265, z=-0.4368, visibility=0.9795
#
# LEFT_ELBOW: x=1.1421, y=1.2062, z=-0.6258, visibility=0.2466
#
# RIGHT_ELBOW: x=0.0690, y=1.0417, z=-1.1266, visibility=0.5110
#
# LEFT_WRIST: x=1.1671, y=1.2010, z=-1.3041, visibility=0.1152
#
# RIGHT_WRIST: x=0.0508, y=0.8658, z=-2.3298, visibility=0.5157
#
# LEFT_PINKY: x=1.1898, y=1.2086, z=-1.4127, visibility=0.1257
#
# RIGHT_PINKY: x=0.0507, y=0.7882, z=-2.5589, visibility=0.4469
#
# LEFT_INDEX: x=1.1576, y=1.1550, z=-1.3930, visibility=0.1730
#
# RIGHT_INDEX: x=0.0760, y=0.7370, z=-2.5067, visibility=0.5230
#
# LEFT_THUMB: x=1.1331, y=1.1653, z=-1.3244, visibility=0.1595
#
# RIGHT_THUMB: x=0.0914, y=0.7752, z=-2.3580, visibility=0.4826
#
# LEFT_HIP: x=0.7398, y=1.8230, z=-0.0446, visibility=0.0058
#
# RIGHT_HIP: x=0.3747, y=1.8145, z=0.0499, visibility=0.0059
#
# LEFT_KNEE: x=0.7040, y=2.5960, z=-0.1503, visibility=0.0373
#
# RIGHT_KNEE: x=0.3899, y=2.5677, z=-0.3371, visibility=0.0240
#
# LEFT_ANKLE: x=0.6955, y=3.3372, z=0.4356, visibility=0.0036
#
# RIGHT_ANKLE: x=0.3808, y=3.3336, z=0.0223, visibility=0.0037
#
# LEFT_HEEL: x=0.6970, y=3.4499, z=0.4482, visibility=0.0027
#
# RIGHT_HEEL: x=0.3806, y=3.4481, z=0.0285, visibility=0.0027
#
# LEFT_FOOT_INDEX: x=0.6449, y=3.5631, z=-0.3034, visibility=0.0045
#
# RIGHT_FOOT_INDEX: x=0.4129, y=3.5561, z=-0.7939, visibility=0.0055
#
# NOSE: x=0.5927, y=0.4748, z=-1.3824, visibility=0.9985
#
# LEFT_EYE_INNER: x=0.6218, y=0.3995, z=-1.2958, visibility=0.9980
#
# LEFT_EYE: x=0.6417, y=0.3989, z=-1.2964, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6609, y=0.3978, z=-1.2967, visibility=0.9974
#
# RIGHT_EYE_INNER: x=0.5434, y=0.4013, z=-1.3082, visibility=0.9982
#
# RIGHT_EYE: x=0.5146, y=0.4036, z=-1.3081, visibility=0.9984
#
# RIGHT_EYE_OUTER: x=0.4898, y=0.4069, z=-1.3086, visibility=0.9984
#
# LEFT_EAR: x=0.6822, y=0.4274, z=-0.7069, visibility=0.9984
#
# RIGHT_EAR: x=0.4517, y=0.4451, z=-0.7523, visibility=0.9988
#
# MOUTH_LEFT: x=0.6321, y=0.5592, z=-1.1554, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5430, y=0.5634, z=-1.1704, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8622, y=0.8163, z=-0.3341, visibility=0.9809
#
# RIGHT_SHOULDER: x=0.2738, y=0.8267, z=-0.4366, visibility=0.9791
#
# LEFT_ELBOW: x=1.1375, y=1.2240, z=-0.6118, visibility=0.2414
#
# RIGHT_ELBOW: x=0.0629, y=1.0415, z=-1.1280, visibility=0.5107
#
# LEFT_WRIST: x=1.1633, y=1.3771, z=-1.1500, visibility=0.1104
#
# RIGHT_WRIST: x=0.0483, y=0.8452, z=-2.3636, visibility=0.5140
#
# LEFT_PINKY: x=1.1867, y=1.4402, z=-1.2550, visibility=0.1209
#
# RIGHT_PINKY: x=0.0489, y=0.7648, z=-2.6018, visibility=0.4440
#
# LEFT_INDEX: x=1.1537, y=1.3961, z=-1.2715, visibility=0.1672
#
# RIGHT_INDEX: x=0.0793, y=0.7078, z=-2.5568, visibility=0.5207
#
# LEFT_THUMB: x=1.1292, y=1.3832, z=-1.1831, visibility=0.1543
#
# RIGHT_THUMB: x=0.0893, y=0.7525, z=-2.3935, visibility=0.4806
#
# LEFT_HIP: x=0.7410, y=1.8228, z=-0.0540, visibility=0.0053
#
# RIGHT_HIP: x=0.3748, y=1.8141, z=0.0592, visibility=0.0054
#
# LEFT_KNEE: x=0.7105, y=2.5993, z=-0.0944, visibility=0.0360
#
# RIGHT_KNEE: x=0.3923, y=2.5759, z=-0.1939, visibility=0.0226
#
# LEFT_ANKLE: x=0.7039, y=3.3371, z=0.6289, visibility=0.0033
#
# RIGHT_ANKLE: x=0.3875, y=3.3316, z=0.2982, visibility=0.0034
#
# LEFT_HEEL: x=0.7058, y=3.4493, z=0.6530, visibility=0.0025
#
# RIGHT_HEEL: x=0.3872, y=3.4462, z=0.3196, visibility=0.0025
#
# LEFT_FOOT_INDEX: x=0.6548, y=3.5632, z=-0.1533, visibility=0.0041
#
# RIGHT_FOOT_INDEX: x=0.4201, y=3.5550, z=-0.5514, visibility=0.0051
#
# NOSE: x=0.5927, y=0.4746, z=-1.3393, visibility=0.9984
#
# LEFT_EYE_INNER: x=0.6217, y=0.3993, z=-1.2509, visibility=0.9979
#
# LEFT_EYE: x=0.6416, y=0.3987, z=-1.2515, visibility=0.9978
#
# LEFT_EYE_OUTER: x=0.6608, y=0.3975, z=-1.2518, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5434, y=0.4012, z=-1.2731, visibility=0.9981
#
# RIGHT_EYE: x=0.5145, y=0.4035, z=-1.2731, visibility=0.9983
#
# RIGHT_EYE_OUTER: x=0.4897, y=0.4068, z=-1.2737, visibility=0.9984
#
# LEFT_EAR: x=0.6819, y=0.4269, z=-0.6639, visibility=0.9984
#
# RIGHT_EAR: x=0.4516, y=0.4451, z=-0.7473, visibility=0.9988
#
# MOUTH_LEFT: x=0.6321, y=0.5590, z=-1.1129, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5430, y=0.5632, z=-1.1405, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8620, y=0.8154, z=-0.2847, visibility=0.9803
#
# RIGHT_SHOULDER: x=0.2742, y=0.8267, z=-0.4457, visibility=0.9776
#
# LEFT_ELBOW: x=1.1742, y=1.1655, z=-0.7089, visibility=0.2573
#
# RIGHT_ELBOW: x=0.0630, y=1.0385, z=-1.1925, visibility=0.5177
#
# LEFT_WRIST: x=1.2140, y=1.1171, z=-1.4348, visibility=0.1284
#
# RIGHT_WRIST: x=0.0460, y=0.8452, z=-2.3299, visibility=0.5142
#
# LEFT_PINKY: x=1.2421, y=1.1031, z=-1.5481, visibility=0.1346
#
# RIGHT_PINKY: x=0.0458, y=0.7665, z=-2.5346, visibility=0.4416
#
# LEFT_INDEX: x=1.2121, y=1.0583, z=-1.5222, visibility=0.1828
#
# RIGHT_INDEX: x=0.0719, y=0.7104, z=-2.4673, visibility=0.5174
#
# LEFT_THUMB: x=1.1831, y=1.0801, z=-1.4551, visibility=0.1693
#
# RIGHT_THUMB: x=0.0852, y=0.7545, z=-2.3448, visibility=0.4775
#
# LEFT_HIP: x=0.7409, y=1.8229, z=-0.0449, visibility=0.0050
#
# RIGHT_HIP: x=0.3751, y=1.8151, z=0.0501, visibility=0.0051
#
# LEFT_KNEE: x=0.7104, y=2.5984, z=-0.0959, visibility=0.0366
#
# RIGHT_KNEE: x=0.3907, y=2.5739, z=-0.2299, visibility=0.0221
#
# LEFT_ANKLE: x=0.7033, y=3.3362, z=0.5073, visibility=0.0031
#
# RIGHT_ANKLE: x=0.3820, y=3.3300, z=0.1357, visibility=0.0031
#
# LEFT_HEEL: x=0.7054, y=3.4483, z=0.5222, visibility=0.0023
#
# RIGHT_HEEL: x=0.3806, y=3.4449, z=0.1386, visibility=0.0023
#
# LEFT_FOOT_INDEX: x=0.6543, y=3.5624, z=-0.1959, visibility=0.0039
#
# RIGHT_FOOT_INDEX: x=0.4143, y=3.5537, z=-0.6011, visibility=0.0048
#
# NOSE: x=0.5925, y=0.4747, z=-1.3477, visibility=0.9984
#
# LEFT_EYE_INNER: x=0.6216, y=0.3993, z=-1.2618, visibility=0.9978
#
# LEFT_EYE: x=0.6416, y=0.3987, z=-1.2623, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6608, y=0.3975, z=-1.2626, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.5433, y=0.4012, z=-1.2792, visibility=0.9981
#
# RIGHT_EYE: x=0.5144, y=0.4035, z=-1.2792, visibility=0.9983
#
# RIGHT_EYE_OUTER: x=0.4895, y=0.4068, z=-1.2798, visibility=0.9984
#
# LEFT_EAR: x=0.6819, y=0.4269, z=-0.6777, visibility=0.9983
#
# RIGHT_EAR: x=0.4512, y=0.4450, z=-0.7480, visibility=0.9988
#
# MOUTH_LEFT: x=0.6319, y=0.5592, z=-1.1218, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5428, y=0.5635, z=-1.1447, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8615, y=0.8151, z=-0.3032, visibility=0.9803
#
# RIGHT_SHOULDER: x=0.2740, y=0.8267, z=-0.4339, visibility=0.9777
#
# LEFT_ELBOW: x=1.1436, y=1.2087, z=-0.5839, visibility=0.2563
#
# RIGHT_ELBOW: x=0.0648, y=1.0346, z=-1.1194, visibility=0.5164
#
# LEFT_WRIST: x=1.1779, y=1.3649, z=-1.1390, visibility=0.1237
#
# RIGHT_WRIST: x=0.0475, y=0.8418, z=-2.2961, visibility=0.5151
#
# LEFT_PINKY: x=1.2031, y=1.4350, z=-1.2334, visibility=0.1305
#
# RIGHT_PINKY: x=0.0481, y=0.7655, z=-2.5186, visibility=0.4430
#
# LEFT_INDEX: x=1.1715, y=1.3872, z=-1.2678, visibility=0.1781
#
# RIGHT_INDEX: x=0.0793, y=0.7000, z=-2.4666, visibility=0.5194
#
# LEFT_THUMB: x=1.1473, y=1.3688, z=-1.1765, visibility=0.1650
#
# RIGHT_THUMB: x=0.0876, y=0.7529, z=-2.3188, visibility=0.4787
#
# LEFT_HIP: x=0.7406, y=1.8227, z=-0.0455, visibility=0.0046
#
# RIGHT_HIP: x=0.3758, y=1.8148, z=0.0506, visibility=0.0047
#
# LEFT_KNEE: x=0.7091, y=2.5933, z=-0.1095, visibility=0.0360
#
# RIGHT_KNEE: x=0.3907, y=2.5654, z=-0.2455, visibility=0.0212
#
# LEFT_ANKLE: x=0.6991, y=3.3344, z=0.5039, visibility=0.0029
#
# RIGHT_ANKLE: x=0.3817, y=3.3293, z=0.1114, visibility=0.0028
#
# LEFT_HEEL: x=0.7004, y=3.4466, z=0.5202, visibility=0.0021
#
# RIGHT_HEEL: x=0.3806, y=3.4444, z=0.1143, visibility=0.0021
#
# LEFT_FOOT_INDEX: x=0.6494, y=3.5621, z=-0.2139, visibility=0.0036
#
# RIGHT_FOOT_INDEX: x=0.4111, y=3.5531, z=-0.6059, visibility=0.0044
#
# NOSE: x=0.5923, y=0.4749, z=-1.3570, visibility=0.9984
#
# LEFT_EYE_INNER: x=0.6216, y=0.3993, z=-1.2720, visibility=0.9978
#
# LEFT_EYE: x=0.6415, y=0.3987, z=-1.2725, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6607, y=0.3976, z=-1.2728, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.5433, y=0.4013, z=-1.2865, visibility=0.9981
#
# RIGHT_EYE: x=0.5143, y=0.4036, z=-1.2866, visibility=0.9983
#
# RIGHT_EYE_OUTER: x=0.4894, y=0.4069, z=-1.2872, visibility=0.9983
#
# LEFT_EAR: x=0.6819, y=0.4269, z=-0.6870, visibility=0.9983
#
# RIGHT_EAR: x=0.4510, y=0.4450, z=-0.7495, visibility=0.9987
#
# MOUTH_LEFT: x=0.6318, y=0.5594, z=-1.1305, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5427, y=0.5636, z=-1.1505, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8611, y=0.8148, z=-0.3150, visibility=0.9803
#
# RIGHT_SHOULDER: x=0.2739, y=0.8267, z=-0.4286, visibility=0.9778
#
# LEFT_ELBOW: x=1.1270, y=1.2272, z=-0.5445, visibility=0.2555
#
# RIGHT_ELBOW: x=0.0661, y=1.0321, z=-1.0968, visibility=0.5146
#
# LEFT_WRIST: x=1.1596, y=1.4349, z=-1.0794, visibility=0.1194
#
# RIGHT_WRIST: x=0.0482, y=0.8408, z=-2.2836, visibility=0.5147
#
# LEFT_PINKY: x=1.1840, y=1.5175, z=-1.1746, visibility=0.1267
#
# RIGHT_PINKY: x=0.0495, y=0.7660, z=-2.5121, visibility=0.4432
#
# LEFT_INDEX: x=1.1514, y=1.4703, z=-1.2164, visibility=0.1739
#
# RIGHT_INDEX: x=0.0846, y=0.6957, z=-2.4655, visibility=0.5200
#
# LEFT_THUMB: x=1.1289, y=1.4465, z=-1.1195, visibility=0.1610
#
# RIGHT_THUMB: x=0.0892, y=0.7532, z=-2.3088, visibility=0.4787
#
# LEFT_HIP: x=0.7403, y=1.8226, z=-0.0459, visibility=0.0042
#
# RIGHT_HIP: x=0.3763, y=1.8145, z=0.0510, visibility=0.0044
#
# LEFT_KNEE: x=0.7081, y=2.5898, z=-0.1161, visibility=0.0354
#
# RIGHT_KNEE: x=0.3907, y=2.5598, z=-0.2610, visibility=0.0204
#
# LEFT_ANKLE: x=0.6967, y=3.3328, z=0.5032, visibility=0.0027
#
# RIGHT_ANKLE: x=0.3816, y=3.3286, z=0.0977, visibility=0.0026
#
# LEFT_HEEL: x=0.6975, y=3.4451, z=0.5201, visibility=0.0019
#
# RIGHT_HEEL: x=0.3806, y=3.4440, z=0.1010, visibility=0.0019
#
# LEFT_FOOT_INDEX: x=0.6467, y=3.5619, z=-0.2257, visibility=0.0033
#
# RIGHT_FOOT_INDEX: x=0.4095, y=3.5524, z=-0.6184, visibility=0.0042
#
# NOSE: x=0.5923, y=0.4755, z=-1.3678, visibility=0.9983
#
# LEFT_EYE_INNER: x=0.6216, y=0.4000, z=-1.2801, visibility=0.9977
#
# LEFT_EYE: x=0.6415, y=0.3995, z=-1.2807, visibility=0.9976
#
# LEFT_EYE_OUTER: x=0.6607, y=0.3985, z=-1.2811, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5433, y=0.4018, z=-1.2944, visibility=0.9980
#
# RIGHT_EYE: x=0.5144, y=0.4040, z=-1.2945, visibility=0.9982
#
# RIGHT_EYE_OUTER: x=0.4895, y=0.4072, z=-1.2951, visibility=0.9983
#
# LEFT_EAR: x=0.6817, y=0.4276, z=-0.6900, visibility=0.9982
#
# RIGHT_EAR: x=0.4510, y=0.4450, z=-0.7516, visibility=0.9987
#
# MOUTH_LEFT: x=0.6318, y=0.5601, z=-1.1399, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5427, y=0.5641, z=-1.1596, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8607, y=0.8152, z=-0.3203, visibility=0.9799
#
# RIGHT_SHOULDER: x=0.2739, y=0.8265, z=-0.4288, visibility=0.9772
#
# LEFT_ELBOW: x=1.1237, y=1.2287, z=-0.5210, visibility=0.2524
#
# RIGHT_ELBOW: x=0.0655, y=1.0320, z=-1.1004, visibility=0.5129
#
# LEFT_WRIST: x=1.1613, y=1.4475, z=-1.0435, visibility=0.1143
#
# RIGHT_WRIST: x=0.0447, y=0.8412, z=-2.2899, visibility=0.5090
#
# LEFT_PINKY: x=1.1891, y=1.5293, z=-1.1385, visibility=0.1219
#
# RIGHT_PINKY: x=0.0446, y=0.7666, z=-2.5194, visibility=0.4377
#
# LEFT_INDEX: x=1.1567, y=1.4860, z=-1.1883, visibility=0.1680
#
# RIGHT_INDEX: x=0.0732, y=0.7002, z=-2.4718, visibility=0.5149
#
# LEFT_THUMB: x=1.1327, y=1.4637, z=-1.0876, visibility=0.1557
#
# RIGHT_THUMB: x=0.0838, y=0.7540, z=-2.3157, visibility=0.4735
#
# LEFT_HIP: x=0.7386, y=1.8226, z=-0.0461, visibility=0.0039
#
# RIGHT_HIP: x=0.3760, y=1.8144, z=0.0511, visibility=0.0041
#
# LEFT_KNEE: x=0.7057, y=2.5893, z=-0.1287, visibility=0.0355
#
# RIGHT_KNEE: x=0.3891, y=2.5583, z=-0.3004, visibility=0.0200
#
# LEFT_ANKLE: x=0.6924, y=3.3318, z=0.4897, visibility=0.0026
#
# RIGHT_ANKLE: x=0.3791, y=3.3276, z=0.0633, visibility=0.0024
#
# LEFT_HEEL: x=0.6927, y=3.4439, z=0.5054, visibility=0.0018
#
# RIGHT_HEEL: x=0.3783, y=3.4431, z=0.0673, visibility=0.0018
#
# LEFT_FOOT_INDEX: x=0.6420, y=3.5610, z=-0.2624, visibility=0.0031
#
# RIGHT_FOOT_INDEX: x=0.4059, y=3.5515, z=-0.7393, visibility=0.0039
#
# NOSE: x=0.5923, y=0.4752, z=-1.3854, visibility=0.9983
#
# LEFT_EYE_INNER: x=0.6216, y=0.3993, z=-1.2948, visibility=0.9977
#
# LEFT_EYE: x=0.6415, y=0.3988, z=-1.2954, visibility=0.9976
#
# LEFT_EYE_OUTER: x=0.6607, y=0.3978, z=-1.2956, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5432, y=0.4012, z=-1.3131, visibility=0.9980
#
# RIGHT_EYE: x=0.5142, y=0.4035, z=-1.3132, visibility=0.9982
#
# RIGHT_EYE_OUTER: x=0.4892, y=0.4068, z=-1.3138, visibility=0.9983
#
# LEFT_EAR: x=0.6817, y=0.4273, z=-0.6920, visibility=0.9982
#
# RIGHT_EAR: x=0.4508, y=0.4450, z=-0.7647, visibility=0.9987
#
# MOUTH_LEFT: x=0.6318, y=0.5599, z=-1.1519, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5427, y=0.5640, z=-1.1758, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8608, y=0.8151, z=-0.3061, visibility=0.9797
#
# RIGHT_SHOULDER: x=0.2739, y=0.8278, z=-0.4573, visibility=0.9768
#
# LEFT_ELBOW: x=1.1426, y=1.2248, z=-0.4919, visibility=0.2540
#
# RIGHT_ELBOW: x=0.0646, y=1.0422, z=-1.2020, visibility=0.5116
#
# LEFT_WRIST: x=1.2043, y=1.3984, z=-0.9972, visibility=0.1150
#
# RIGHT_WRIST: x=0.0460, y=0.8557, z=-2.3599, visibility=0.5032
#
# LEFT_PINKY: x=1.2373, y=1.4561, z=-1.0778, visibility=0.1221
#
# RIGHT_PINKY: x=0.0479, y=0.7878, z=-2.5751, visibility=0.4326
#
# LEFT_INDEX: x=1.2103, y=1.4115, z=-1.1026, visibility=0.1683
#
# RIGHT_INDEX: x=0.0750, y=0.7300, z=-2.5217, visibility=0.5089
#
# LEFT_THUMB: x=1.1820, y=1.4025, z=-1.0311, visibility=0.1562
#
# RIGHT_THUMB: x=0.0857, y=0.7718, z=-2.3798, visibility=0.4683
#
# LEFT_HIP: x=0.7432, y=1.8248, z=-0.0461, visibility=0.0036
#
# RIGHT_HIP: x=0.3771, y=1.8176, z=0.0511, visibility=0.0038
#
# LEFT_KNEE: x=0.7074, y=2.5906, z=-0.0881, visibility=0.0365
#
# RIGHT_KNEE: x=0.3891, y=2.5669, z=-0.2460, visibility=0.0197
#
# LEFT_ANKLE: x=0.6956, y=3.3312, z=0.5819, visibility=0.0025
#
# RIGHT_ANKLE: x=0.3796, y=3.3296, z=0.1881, visibility=0.0023
#
# LEFT_HEEL: x=0.6964, y=3.4433, z=0.6018, visibility=0.0017
#
# RIGHT_HEEL: x=0.3791, y=3.4448, z=0.2022, visibility=0.0017
#
# LEFT_FOOT_INDEX: x=0.6462, y=3.5611, z=-0.1834, visibility=0.0030
#
# RIGHT_FOOT_INDEX: x=0.4079, y=3.5566, z=-0.6446, visibility=0.0038

# %%
len(landmarks)   # total number of landmarks
# Out:
# 33

# %%
# name of all landmarks
for lndmrk in mp_pose.PoseLandmark:
    print(lndmrk)
# Out:
# PoseLandmark.NOSE
# PoseLandmark.LEFT_EYE_INNER
# PoseLandmark.LEFT_EYE
# PoseLandmark.LEFT_EYE_OUTER
# PoseLandmark.RIGHT_EYE_INNER
# PoseLandmark.RIGHT_EYE
# PoseLandmark.RIGHT_EYE_OUTER
# PoseLandmark.LEFT_EAR
# PoseLandmark.RIGHT_EAR
# PoseLandmark.MOUTH_LEFT
# PoseLandmark.MOUTH_RIGHT
# PoseLandmark.LEFT_SHOULDER
# PoseLandmark.RIGHT_SHOULDER
# PoseLandmark.LEFT_ELBOW
# PoseLandmark.RIGHT_ELBOW
# PoseLandmark.LEFT_WRIST
# PoseLandmark.RIGHT_WRIST
# PoseLandmark.LEFT_PINKY
# PoseLandmark.RIGHT_PINKY
# PoseLandmark.LEFT_INDEX
# PoseLandmark.RIGHT_INDEX
# PoseLandmark.LEFT_THUMB
# PoseLandmark.RIGHT_THUMB
# PoseLandmark.LEFT_HIP
# PoseLandmark.RIGHT_HIP
# PoseLandmark.LEFT_KNEE
# PoseLandmark.RIGHT_KNEE
# PoseLandmark.LEFT_ANKLE
# PoseLandmark.RIGHT_ANKLE
# PoseLandmark.LEFT_HEEL
# PoseLandmark.RIGHT_HEEL
# PoseLandmark.LEFT_FOOT_INDEX
# PoseLandmark.RIGHT_FOOT_INDEX

# %%
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]   # all values of left shoulder
# Out:
# x: 0.860797286
# y: 0.815134108
# z: -0.306114405
# visibility: 0.979674

# %%
landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value]   # all values of right shoulder
# Out:
# x: 0.273914725
# y: 0.827847242
# z: -0.457290262
# visibility: 0.976803899

# %%
mp_pose.PoseLandmark.LEFT_SHOULDER.value   # index of left shoulder
# Out:
# 11

# %%
mp_pose.PoseLandmark.RIGHT_SHOULDER.value   # index of right shoulder
# Out:
# 12

# %% [markdown]
# # Calculations

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark

            # function to calculate mid point of shoulder
            def shldr_midpt(ls,rs):   # arguments are left shoulder and right shoulder
                 ls = np.array(ls)
                 rs = np.array(rs)
                 mids = (ls+rs)/2
                 return mids
            
            # function to calculate coordinate of chin
            def chin_coord(n,ll,rl):   # arguments are nose, left side of mouth and right side of mouth
                 n = np.array(n)
                 ll = np.array(ll)
                 rl = np.array(rl)
                 midm = (ll+rl)/2   # mid point of mouth

                 gap = abs(n[1] - midm[1])   # gap between nose and mouth

                 chin_pt = [midm[0], midm[1] + gap * 1.25]   # projecting downwards to estimate chin coordinate; scaling factor is 1.25
                 
                 return chin_pt
            
            # function to calculate angle
            def calculate_angle(a,b,c):
                 a = np.array(a)   # first
                 b = np.array(b)   # mid
                 c = np.array(c)   # end

                 radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])   # Y value - X value
                 angle = np.abs(radians*180.0/np.pi)

                 if angle > 180.0:
                      angle = 360-angle
                 
                 return angle
        
            # getting X and Y value; coordinates of landmark
            shoulderL = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            shoulderR = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            mouthL = [landmarks[mp_pose.PoseLandmark.MOUTH_LEFT.value].x, landmarks[mp_pose.PoseLandmark.MOUTH_LEFT.value].y]
            mouthR = [landmarks[mp_pose.PoseLandmark.MOUTH_RIGHT.value].x, landmarks[mp_pose.PoseLandmark.MOUTH_RIGHT.value].y]

            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x, landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            shoulderM = shldr_midpt(shoulderL,shoulderR)   # mid point of shoulder
            chin = chin_coord(nose,mouthL,mouthR)   # coordinate of chin

            angleL = calculate_angle(shoulderL, shoulderM, nose)   # left dirn
            angleR = calculate_angle(shoulderR, shoulderM, nose)   # right dirn

            # visulaising the chin and mid point of shoulder
            cv2.circle(image,tuple(np.multiply(chin,[640,480]).astype(int)),
                       5,(0,0,255),-1)
            cv2.circle(image,tuple(np.multiply(shoulderM,[640,480]).astype(int)),
                       5,(0,0,255),-1)
            cv2.line(image,tuple(np.multiply(chin,[640,480]).astype(int)),
                     tuple(np.multiply(shoulderM,[640,480]).astype(int)),
                     (0,255,255),2)

            if angleR > 80:
                dirn = 'Left'
            
            if angleL > 80:
                dirn = 'Right'

            # visualising angle
            '''cv2.putText(image, f"Direction: {dirn}",
                        (15,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)'''



            # Define box color depending on direction
            if dirn == "Left":
                box_color = (0, 0, 255)   # Red
            elif dirn == "Right":
                box_color = (255, 0, 0)   # Blue

            # Draw filled rectangle (top-left corner)
            (startX, startY) = (10, 10)
            (endX, endY) = (200, 50)
            cv2.rectangle(image, (startX, startY), (endX, endY), box_color, -1)

            # Put direction text inside the box
            cv2.putText(image, f"Direction: {dirn}",
                        (startX + 10, startY + 30),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7,
                        (255, 255, 255), 2, cv2.LINE_AA)



            for id, lm in enumerate(landmarks):
                landmark_name = mp_pose.PoseLandmark(id).name   # get landmark name
                print(f"{landmark_name}: "
                      f"x={lm.x:.4f}, y={lm.y:.4f}, z={lm.z:.4f}, visibility={lm.visibility:.4f} \n")

        except:
            pass
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Camera Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# NOSE: x=0.5873, y=0.4802, z=-1.2552, visibility=0.9999
#
# LEFT_EYE_INNER: x=0.6158, y=0.3963, z=-1.1649, visibility=0.9999
#
# LEFT_EYE: x=0.6359, y=0.3961, z=-1.1648, visibility=0.9998
#
# LEFT_EYE_OUTER: x=0.6555, y=0.3959, z=-1.1650, visibility=0.9998
#
# RIGHT_EYE_INNER: x=0.5398, y=0.4022, z=-1.1820, visibility=0.9999
#
# RIGHT_EYE: x=0.5114, y=0.4061, z=-1.1811, visibility=0.9999
#
# RIGHT_EYE_OUTER: x=0.4850, y=0.4097, z=-1.1815, visibility=0.9999
#
# LEFT_EAR: x=0.6798, y=0.4347, z=-0.5734, visibility=0.9999
#
# RIGHT_EAR: x=0.4449, y=0.4532, z=-0.6432, visibility=0.9999
#
# MOUTH_LEFT: x=0.6280, y=0.5659, z=-1.0351, visibility=0.9999
#
# MOUTH_RIGHT: x=0.5382, y=0.5699, z=-1.0552, visibility=0.9999
#
# LEFT_SHOULDER: x=0.8462, y=0.8057, z=-0.1596, visibility=0.9980
#
# RIGHT_SHOULDER: x=0.2914, y=0.8041, z=-0.3807, visibility=0.9979
#
# LEFT_ELBOW: x=1.0856, y=0.9545, z=-0.6384, visibility=0.7811
#
# RIGHT_ELBOW: x=0.0917, y=1.0569, z=-0.8891, visibility=0.7179
#
# LEFT_WRIST: x=1.1964, y=0.9077, z=-1.5234, visibility=0.8742
#
# RIGHT_WRIST: x=-0.0034, y=1.2621, z=-1.9841, visibility=0.6520
#
# LEFT_PINKY: x=1.2146, y=0.8389, z=-1.7082, visibility=0.8061
#
# RIGHT_PINKY: x=-0.0352, y=1.4449, z=-2.1849, visibility=0.6156
#
# LEFT_INDEX: x=1.1643, y=0.8060, z=-1.6439, visibility=0.8399
#
# RIGHT_INDEX: x=0.0161, y=1.3901, z=-2.2395, visibility=0.7051
#
# LEFT_THUMB: x=1.1312, y=0.8536, z=-1.5373, visibility=0.8288
#
# RIGHT_THUMB: x=0.0424, y=1.3829, z=-2.0426, visibility=0.6967
#
# LEFT_HIP: x=0.7571, y=1.8321, z=-0.0401, visibility=0.0046
#
# RIGHT_HIP: x=0.3870, y=1.8393, z=0.0469, visibility=0.0035
#
# LEFT_KNEE: x=0.7522, y=2.6989, z=-0.3066, visibility=0.0030
#
# RIGHT_KNEE: x=0.4023, y=2.7028, z=-0.1335, visibility=0.0010
#
# LEFT_ANKLE: x=0.7587, y=3.4907, z=0.1932, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4251, y=3.4906, z=0.0695, visibility=0.0000
#
# LEFT_HEEL: x=0.7692, y=3.6006, z=0.1951, visibility=0.0002
#
# RIGHT_HEEL: x=0.4157, y=3.6010, z=0.0614, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7057, y=3.7155, z=-0.6113, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4785, y=3.7262, z=-0.8067, visibility=0.0001
#
# NOSE: x=0.5888, y=0.4801, z=-1.3685, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6183, y=0.3967, z=-1.2774, visibility=0.9995
#
# LEFT_EYE: x=0.6381, y=0.3967, z=-1.2778, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6578, y=0.3970, z=-1.2785, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5427, y=0.4027, z=-1.2969, visibility=0.9996
#
# RIGHT_EYE: x=0.5145, y=0.4068, z=-1.2962, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.4887, y=0.4112, z=-1.2967, visibility=0.9996
#
# LEFT_EAR: x=0.6803, y=0.4347, z=-0.6779, visibility=0.9996
#
# RIGHT_EAR: x=0.4486, y=0.4529, z=-0.7559, visibility=0.9997
#
# MOUTH_LEFT: x=0.6292, y=0.5653, z=-1.1401, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5407, y=0.5698, z=-1.1630, visibility=0.9998
#
# LEFT_SHOULDER: x=0.8486, y=0.8057, z=-0.2665, visibility=0.9973
#
# RIGHT_SHOULDER: x=0.2904, y=0.8060, z=-0.4155, visibility=0.9967
#
# LEFT_ELBOW: x=1.0958, y=1.1005, z=-0.3671, visibility=0.7322
#
# RIGHT_ELBOW: x=0.0917, y=1.0503, z=-0.7374, visibility=0.6792
#
# LEFT_WRIST: x=1.2017, y=1.3554, z=-0.9609, visibility=0.7992
#
# RIGHT_WRIST: x=0.0406, y=1.3591, z=-1.7150, visibility=0.5994
#
# LEFT_PINKY: x=1.2559, y=1.4415, z=-1.1193, visibility=0.7399
#
# RIGHT_PINKY: x=0.0165, y=1.4607, z=-1.9526, visibility=0.5689
#
# LEFT_INDEX: x=1.2090, y=1.4166, z=-1.2214, visibility=0.7771
#
# RIGHT_INDEX: x=0.0686, y=1.4105, z=-2.0363, visibility=0.6566
#
# LEFT_THUMB: x=1.1722, y=1.3995, z=-1.0380, visibility=0.7662
#
# RIGHT_THUMB: x=0.0857, y=1.3923, z=-1.7898, visibility=0.6481
#
# LEFT_HIP: x=0.7562, y=1.8182, z=-0.0376, visibility=0.0042
#
# RIGHT_HIP: x=0.3827, y=1.8177, z=0.0446, visibility=0.0032
#
# LEFT_KNEE: x=0.7480, y=2.6455, z=-0.3603, visibility=0.0030
#
# RIGHT_KNEE: x=0.4023, y=2.6145, z=-0.5432, visibility=0.0011
#
# LEFT_ANKLE: x=0.7552, y=3.4366, z=0.1158, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4093, y=3.4319, z=-0.3509, visibility=0.0000
#
# LEFT_HEEL: x=0.7625, y=3.5514, z=0.1107, visibility=0.0002
#
# RIGHT_HEEL: x=0.4018, y=3.5566, z=-0.3663, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7000, y=3.6648, z=-0.7546, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4564, y=3.6573, z=-1.3073, visibility=0.0001
#
# NOSE: x=0.5887, y=0.4800, z=-1.3939, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6184, y=0.3969, z=-1.3009, visibility=0.9994
#
# LEFT_EYE: x=0.6383, y=0.3969, z=-1.3014, visibility=0.9994
#
# LEFT_EYE_OUTER: x=0.6579, y=0.3973, z=-1.3020, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5427, y=0.4030, z=-1.3211, visibility=0.9995
#
# RIGHT_EYE: x=0.5146, y=0.4071, z=-1.3205, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4889, y=0.4116, z=-1.3209, visibility=0.9995
#
# LEFT_EAR: x=0.6803, y=0.4342, z=-0.6794, visibility=0.9996
#
# RIGHT_EAR: x=0.4497, y=0.4523, z=-0.7606, visibility=0.9997
#
# MOUTH_LEFT: x=0.6292, y=0.5649, z=-1.1551, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5408, y=0.5697, z=-1.1798, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8524, y=0.8059, z=-0.2606, visibility=0.9969
#
# RIGHT_SHOULDER: x=0.2883, y=0.8067, z=-0.4188, visibility=0.9957
#
# LEFT_ELBOW: x=1.1182, y=1.1254, z=-0.4388, visibility=0.6931
#
# RIGHT_ELBOW: x=0.0927, y=1.0313, z=-0.7695, visibility=0.6525
#
# LEFT_WRIST: x=1.2024, y=1.3236, z=-1.1341, visibility=0.7393
#
# RIGHT_WRIST: x=0.0769, y=1.2607, z=-1.7707, visibility=0.5627
#
# LEFT_PINKY: x=1.2574, y=1.3911, z=-1.2912, visibility=0.6869
#
# RIGHT_PINKY: x=0.0671, y=1.2842, z=-2.0885, visibility=0.5354
#
# LEFT_INDEX: x=1.2094, y=1.3591, z=-1.3567, visibility=0.7287
#
# RIGHT_INDEX: x=0.1491, y=1.1017, z=-2.0881, visibility=0.6227
#
# LEFT_THUMB: x=1.1746, y=1.3488, z=-1.1950, visibility=0.7168
#
# RIGHT_THUMB: x=0.1640, y=1.0673, z=-1.7977, visibility=0.6129
#
# LEFT_HIP: x=0.7562, y=1.8137, z=-0.0376, visibility=0.0039
#
# RIGHT_HIP: x=0.3813, y=1.8118, z=0.0446, visibility=0.0029
#
# LEFT_KNEE: x=0.7466, y=2.6308, z=-0.3519, visibility=0.0034
#
# RIGHT_KNEE: x=0.4024, y=2.5973, z=-0.5123, visibility=0.0014
#
# LEFT_ANKLE: x=0.7517, y=3.4118, z=0.1319, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4053, y=3.4080, z=-0.3030, visibility=0.0000
#
# LEFT_HEEL: x=0.7576, y=3.5281, z=0.1287, visibility=0.0002
#
# RIGHT_HEEL: x=0.3991, y=3.5343, z=-0.3165, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6950, y=3.6379, z=-0.7300, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4485, y=3.6295, z=-1.2506, visibility=0.0001
#
# NOSE: x=0.5887, y=0.4792, z=-1.3620, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6186, y=0.3966, z=-1.2701, visibility=0.9994
#
# LEFT_EYE: x=0.6384, y=0.3965, z=-1.2703, visibility=0.9994
#
# LEFT_EYE_OUTER: x=0.6580, y=0.3971, z=-1.2708, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5430, y=0.4024, z=-1.2896, visibility=0.9995
#
# RIGHT_EYE: x=0.5150, y=0.4063, z=-1.2889, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.4895, y=0.4111, z=-1.2894, visibility=0.9995
#
# LEFT_EAR: x=0.6803, y=0.4324, z=-0.6593, visibility=0.9996
#
# RIGHT_EAR: x=0.4504, y=0.4500, z=-0.7465, visibility=0.9997
#
# MOUTH_LEFT: x=0.6292, y=0.5636, z=-1.1299, visibility=0.9997
#
# MOUTH_RIGHT: x=0.5410, y=0.5688, z=-1.1543, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8526, y=0.8060, z=-0.2452, visibility=0.9967
#
# RIGHT_SHOULDER: x=0.2881, y=0.8088, z=-0.4478, visibility=0.9953
#
# LEFT_ELBOW: x=1.1516, y=1.0967, z=-0.6652, visibility=0.6815
#
# RIGHT_ELBOW: x=0.0928, y=1.0325, z=-0.8119, visibility=0.6405
#
# LEFT_WRIST: x=1.2071, y=1.2083, z=-1.6015, visibility=0.7281
#
# RIGHT_WRIST: x=0.0744, y=1.3322, z=-1.8030, visibility=0.5312
#
# LEFT_PINKY: x=1.2602, y=1.2471, z=-1.7925, visibility=0.6754
#
# RIGHT_PINKY: x=0.0606, y=1.3317, z=-2.0294, visibility=0.5064
#
# LEFT_INDEX: x=1.2132, y=1.2135, z=-1.8023, visibility=0.7198
#
# RIGHT_INDEX: x=0.1215, y=1.2260, z=-2.0598, visibility=0.5933
#
# LEFT_THUMB: x=1.1766, y=1.2137, z=-1.6488, visibility=0.7072
#
# RIGHT_THUMB: x=0.1396, y=1.1425, z=-1.8493, visibility=0.5841
#
# LEFT_HIP: x=0.7579, y=1.8122, z=-0.0363, visibility=0.0040
#
# RIGHT_HIP: x=0.3824, y=1.8131, z=0.0432, visibility=0.0030
#
# LEFT_KNEE: x=0.7479, y=2.6378, z=-0.2699, visibility=0.0038
#
# RIGHT_KNEE: x=0.4070, y=2.6140, z=-0.4206, visibility=0.0017
#
# LEFT_ANKLE: x=0.7543, y=3.4155, z=0.2305, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4091, y=3.4160, z=-0.1945, visibility=0.0000
#
# LEFT_HEEL: x=0.7605, y=3.5284, z=0.2298, visibility=0.0002
#
# RIGHT_HEEL: x=0.4027, y=3.5375, z=-0.2030, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6971, y=3.6439, z=-0.6000, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4584, y=3.6412, z=-1.1076, visibility=0.0002
#
# NOSE: x=0.5892, y=0.4791, z=-1.4331, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6189, y=0.3966, z=-1.3361, visibility=0.9994
#
# LEFT_EYE: x=0.6387, y=0.3965, z=-1.3364, visibility=0.9994
#
# LEFT_EYE_OUTER: x=0.6581, y=0.3971, z=-1.3368, visibility=0.9994
#
# RIGHT_EYE_INNER: x=0.5438, y=0.4024, z=-1.3599, visibility=0.9994
#
# RIGHT_EYE: x=0.5159, y=0.4063, z=-1.3591, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.4902, y=0.4111, z=-1.3596, visibility=0.9995
#
# LEFT_EAR: x=0.6800, y=0.4319, z=-0.7048, visibility=0.9995
#
# RIGHT_EAR: x=0.4507, y=0.4494, z=-0.8048, visibility=0.9996
#
# MOUTH_LEFT: x=0.6293, y=0.5630, z=-1.1923, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5414, y=0.5686, z=-1.2215, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8524, y=0.8061, z=-0.2649, visibility=0.9966
#
# RIGHT_SHOULDER: x=0.2867, y=0.8091, z=-0.4770, visibility=0.9950
#
# LEFT_ELBOW: x=1.0397, y=1.0382, z=-0.4233, visibility=0.6423
#
# RIGHT_ELBOW: x=0.0932, y=1.0330, z=-0.8244, visibility=0.6159
#
# LEFT_WRIST: x=1.1881, y=1.3934, z=-1.1503, visibility=0.6752
#
# RIGHT_WRIST: x=0.0704, y=1.3669, z=-1.8436, visibility=0.4987
#
# LEFT_PINKY: x=1.2513, y=1.4819, z=-1.3260, visibility=0.6305
#
# RIGHT_PINKY: x=0.0535, y=1.4021, z=-2.0326, visibility=0.4793
#
# LEFT_INDEX: x=1.2032, y=1.4536, z=-1.4290, visibility=0.6795
#
# RIGHT_INDEX: x=0.1097, y=1.3370, z=-2.1236, visibility=0.5671
#
# LEFT_THUMB: x=1.1661, y=1.4358, z=-1.2288, visibility=0.6667
#
# RIGHT_THUMB: x=0.1271, y=1.3152, z=-1.8945, visibility=0.5573
#
# LEFT_HIP: x=0.7576, y=1.8084, z=-0.0280, visibility=0.0037
#
# RIGHT_HIP: x=0.3800, y=1.8108, z=0.0355, visibility=0.0028
#
# LEFT_KNEE: x=0.7471, y=2.6284, z=-0.2726, visibility=0.0038
#
# RIGHT_KNEE: x=0.4086, y=2.6054, z=-0.5384, visibility=0.0017
#
# LEFT_ANKLE: x=0.7543, y=3.4085, z=0.2240, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4091, y=3.4156, z=-0.3065, visibility=0.0000
#
# LEFT_HEEL: x=0.7605, y=3.5225, z=0.2240, visibility=0.0002
#
# RIGHT_HEEL: x=0.4023, y=3.5392, z=-0.3172, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6972, y=3.6412, z=-0.6377, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4589, y=3.6416, z=-1.2704, visibility=0.0002
#
# NOSE: x=0.5897, y=0.4790, z=-1.4363, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6193, y=0.3966, z=-1.3426, visibility=0.9992
#
# LEFT_EYE: x=0.6390, y=0.3965, z=-1.3430, visibility=0.9993
#
# LEFT_EYE_OUTER: x=0.6583, y=0.3971, z=-1.3434, visibility=0.9992
#
# RIGHT_EYE_INNER: x=0.5444, y=0.4025, z=-1.3641, visibility=0.9993
#
# RIGHT_EYE: x=0.5165, y=0.4064, z=-1.3634, visibility=0.9993
#
# RIGHT_EYE_OUTER: x=0.4911, y=0.4113, z=-1.3639, visibility=0.9994
#
# LEFT_EAR: x=0.6800, y=0.4304, z=-0.7220, visibility=0.9994
#
# RIGHT_EAR: x=0.4517, y=0.4492, z=-0.8095, visibility=0.9996
#
# MOUTH_LEFT: x=0.6296, y=0.5623, z=-1.1992, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5422, y=0.5686, z=-1.2250, visibility=0.9996
#
# LEFT_SHOULDER: x=0.8541, y=0.8060, z=-0.2931, visibility=0.9963
#
# RIGHT_SHOULDER: x=0.2851, y=0.8098, z=-0.4694, visibility=0.9944
#
# LEFT_ELBOW: x=1.0589, y=1.1383, z=-0.4082, visibility=0.6056
#
# RIGHT_ELBOW: x=0.0918, y=1.0342, z=-0.7926, visibility=0.5933
#
# LEFT_WRIST: x=1.1735, y=1.4201, z=-1.1109, visibility=0.6254
#
# RIGHT_WRIST: x=0.0648, y=1.3876, z=-1.8295, visibility=0.4656
#
# LEFT_PINKY: x=1.2338, y=1.5085, z=-1.2846, visibility=0.5874
#
# RIGHT_PINKY: x=0.0470, y=1.4487, z=-2.0563, visibility=0.4505
#
# LEFT_INDEX: x=1.1852, y=1.4764, z=-1.3766, visibility=0.6394
#
# RIGHT_INDEX: x=0.1020, y=1.3899, z=-2.1357, visibility=0.5379
#
# LEFT_THUMB: x=1.1500, y=1.4583, z=-1.1831, visibility=0.6267
#
# RIGHT_THUMB: x=0.1197, y=1.3746, z=-1.8949, visibility=0.5278
#
# LEFT_HIP: x=0.7575, y=1.8073, z=-0.0283, visibility=0.0034
#
# RIGHT_HIP: x=0.3797, y=1.8112, z=0.0357, visibility=0.0026
#
# LEFT_KNEE: x=0.7471, y=2.6283, z=-0.2781, visibility=0.0038
#
# RIGHT_KNEE: x=0.4087, y=2.6098, z=-0.4780, visibility=0.0017
#
# LEFT_ANKLE: x=0.7543, y=3.4045, z=0.2236, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4092, y=3.4141, z=-0.2415, visibility=0.0000
#
# LEFT_HEEL: x=0.7605, y=3.5188, z=0.2229, visibility=0.0002
#
# RIGHT_HEEL: x=0.4024, y=3.5381, z=-0.2510, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6961, y=3.6363, z=-0.6380, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4589, y=3.6385, z=-1.1865, visibility=0.0002
#
# NOSE: x=0.5911, y=0.4776, z=-1.4072, visibility=0.9994
#
# LEFT_EYE_INNER: x=0.6203, y=0.3961, z=-1.3153, visibility=0.9992
#
# LEFT_EYE: x=0.6398, y=0.3959, z=-1.3156, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6591, y=0.3964, z=-1.3159, visibility=0.9992
#
# RIGHT_EYE_INNER: x=0.5459, y=0.4021, z=-1.3349, visibility=0.9993
#
# RIGHT_EYE: x=0.5184, y=0.4060, z=-1.3341, visibility=0.9993
#
# RIGHT_EYE_OUTER: x=0.4932, y=0.4110, z=-1.3346, visibility=0.9994
#
# LEFT_EAR: x=0.6803, y=0.4294, z=-0.7047, visibility=0.9994
#
# RIGHT_EAR: x=0.4532, y=0.4488, z=-0.7848, visibility=0.9995
#
# MOUTH_LEFT: x=0.6309, y=0.5607, z=-1.1743, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5448, y=0.5673, z=-1.1984, visibility=0.9996
#
# LEFT_SHOULDER: x=0.8571, y=0.8061, z=-0.2767, visibility=0.9961
#
# RIGHT_SHOULDER: x=0.2848, y=0.8120, z=-0.4772, visibility=0.9938
#
# LEFT_ELBOW: x=1.1187, y=1.1184, z=-0.4217, visibility=0.5846
#
# RIGHT_ELBOW: x=0.0919, y=1.0324, z=-0.9083, visibility=0.5835
#
# LEFT_WRIST: x=1.2125, y=1.2945, z=-1.1042, visibility=0.6006
#
# RIGHT_WRIST: x=0.0738, y=1.3248, z=-1.9022, visibility=0.4463
#
# LEFT_PINKY: x=1.2764, y=1.3350, z=-1.2558, visibility=0.5648
#
# RIGHT_PINKY: x=0.0610, y=1.3555, z=-2.1261, visibility=0.4314
#
# LEFT_INDEX: x=1.2300, y=1.3030, z=-1.3175, visibility=0.6207
#
# RIGHT_INDEX: x=0.1132, y=1.1696, z=-2.1697, visibility=0.5187
#
# LEFT_THUMB: x=1.1924, y=1.3050, z=-1.1633, visibility=0.6069
#
# RIGHT_THUMB: x=0.1376, y=1.1298, z=-1.9540, visibility=0.5081
#
# LEFT_HIP: x=0.7591, y=1.8075, z=-0.0287, visibility=0.0033
#
# RIGHT_HIP: x=0.3800, y=1.8118, z=0.0361, visibility=0.0025
#
# LEFT_KNEE: x=0.7480, y=2.6307, z=-0.2814, visibility=0.0042
#
# RIGHT_KNEE: x=0.4091, y=2.6143, z=-0.4280, visibility=0.0019
#
# LEFT_ANKLE: x=0.7558, y=3.4045, z=0.2205, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4104, y=3.4076, z=-0.2030, visibility=0.0000
#
# LEFT_HEEL: x=0.7621, y=3.5192, z=0.2195, visibility=0.0002
#
# RIGHT_HEEL: x=0.4037, y=3.5279, z=-0.2134, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6999, y=3.6291, z=-0.6380, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4617, y=3.6300, z=-1.1325, visibility=0.0002
#
# NOSE: x=0.5924, y=0.4775, z=-1.4035, visibility=0.9993
#
# LEFT_EYE_INNER: x=0.6209, y=0.3961, z=-1.3109, visibility=0.9991
#
# LEFT_EYE: x=0.6403, y=0.3959, z=-1.3113, visibility=0.9991
#
# LEFT_EYE_OUTER: x=0.6596, y=0.3963, z=-1.3117, visibility=0.9990
#
# RIGHT_EYE_INNER: x=0.5472, y=0.4021, z=-1.3306, visibility=0.9992
#
# RIGHT_EYE: x=0.5198, y=0.4060, z=-1.3300, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.4950, y=0.4110, z=-1.3305, visibility=0.9993
#
# LEFT_EAR: x=0.6803, y=0.4288, z=-0.7005, visibility=0.9993
#
# RIGHT_EAR: x=0.4547, y=0.4487, z=-0.7804, visibility=0.9995
#
# MOUTH_LEFT: x=0.6316, y=0.5606, z=-1.1703, visibility=0.9994
#
# MOUTH_RIGHT: x=0.5463, y=0.5672, z=-1.1945, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8582, y=0.8061, z=-0.2854, visibility=0.9953
#
# RIGHT_SHOULDER: x=0.2849, y=0.8121, z=-0.4748, visibility=0.9927
#
# LEFT_ELBOW: x=1.0353, y=1.0035, z=-0.3842, visibility=0.5523
#
# RIGHT_ELBOW: x=0.0895, y=1.0323, z=-0.8765, visibility=0.5684
#
# LEFT_WRIST: x=1.2130, y=1.3440, z=-0.9796, visibility=0.5573
#
# RIGHT_WRIST: x=0.0709, y=1.3183, z=-1.8926, visibility=0.4201
#
# LEFT_PINKY: x=1.2755, y=1.4212, z=-1.1237, visibility=0.5265
#
# RIGHT_PINKY: x=0.0593, y=1.3608, z=-2.1225, visibility=0.4069
#
# LEFT_INDEX: x=1.2298, y=1.3916, z=-1.2099, visibility=0.5839
#
# RIGHT_INDEX: x=0.1161, y=1.1494, z=-2.1669, visibility=0.4929
#
# LEFT_THUMB: x=1.1930, y=1.3772, z=-1.0461, visibility=0.5701
#
# RIGHT_THUMB: x=0.1404, y=1.1020, z=-1.9474, visibility=0.4818
#
# LEFT_HIP: x=0.7598, y=1.8075, z=-0.0341, visibility=0.0031
#
# RIGHT_HIP: x=0.3813, y=1.8122, z=0.0412, visibility=0.0024
#
# LEFT_KNEE: x=0.7508, y=2.6192, z=-0.3331, visibility=0.0045
#
# RIGHT_KNEE: x=0.4156, y=2.6026, z=-0.4710, visibility=0.0022
#
# LEFT_ANKLE: x=0.7633, y=3.3921, z=0.1508, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4183, y=3.3968, z=-0.2595, visibility=0.0001
#
# LEFT_HEEL: x=0.7707, y=3.5086, z=0.1447, visibility=0.0002
#
# RIGHT_HEEL: x=0.4131, y=3.5200, z=-0.2713, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7068, y=3.6171, z=-0.7165, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4667, y=3.6173, z=-1.1851, visibility=0.0002
#
# NOSE: x=0.5934, y=0.4775, z=-1.4012, visibility=0.9993
#
# LEFT_EYE_INNER: x=0.6215, y=0.3961, z=-1.3082, visibility=0.9990
#
# LEFT_EYE: x=0.6407, y=0.3958, z=-1.3087, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6600, y=0.3963, z=-1.3091, visibility=0.9989
#
# RIGHT_EYE_INNER: x=0.5481, y=0.4021, z=-1.3284, visibility=0.9991
#
# RIGHT_EYE: x=0.5208, y=0.4060, z=-1.3278, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.4963, y=0.4110, z=-1.3283, visibility=0.9992
#
# LEFT_EAR: x=0.6803, y=0.4284, z=-0.6978, visibility=0.9992
#
# RIGHT_EAR: x=0.4557, y=0.4486, z=-0.7795, visibility=0.9994
#
# MOUTH_LEFT: x=0.6322, y=0.5605, z=-1.1678, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5475, y=0.5672, z=-1.1925, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8589, y=0.8061, z=-0.2863, visibility=0.9947
#
# RIGHT_SHOULDER: x=0.2850, y=0.8122, z=-0.4741, visibility=0.9918
#
# LEFT_ELBOW: x=1.0150, y=0.9702, z=-0.3832, visibility=0.5237
#
# RIGHT_ELBOW: x=0.0883, y=1.0321, z=-0.8543, visibility=0.5544
#
# LEFT_WRIST: x=1.2135, y=1.3477, z=-0.9886, visibility=0.5185
#
# RIGHT_WRIST: x=0.0688, y=1.3171, z=-1.8756, visibility=0.3959
#
# LEFT_PINKY: x=1.2752, y=1.4269, z=-1.1356, visibility=0.4922
#
# RIGHT_PINKY: x=0.0574, y=1.3668, z=-2.1091, visibility=0.3846
#
# LEFT_INDEX: x=1.2297, y=1.3974, z=-1.2211, visibility=0.5510
#
# RIGHT_INDEX: x=0.1123, y=1.2030, z=-2.1558, visibility=0.4694
#
# LEFT_THUMB: x=1.1932, y=1.3823, z=-1.0554, visibility=0.5371
#
# RIGHT_THUMB: x=0.1415, y=1.0970, z=-1.9330, visibility=0.4577
#
# LEFT_HIP: x=0.7601, y=1.8076, z=-0.0363, visibility=0.0029
#
# RIGHT_HIP: x=0.3821, y=1.8125, z=0.0433, visibility=0.0023
#
# LEFT_KNEE: x=0.7519, y=2.6129, z=-0.3505, visibility=0.0049
#
# RIGHT_KNEE: x=0.4187, y=2.5959, z=-0.4887, visibility=0.0024
#
# LEFT_ANKLE: x=0.7665, y=3.3860, z=0.1265, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4218, y=3.3918, z=-0.2845, visibility=0.0001
#
# LEFT_HEEL: x=0.7743, y=3.5031, z=0.1197, visibility=0.0002
#
# RIGHT_HEEL: x=0.4171, y=3.5164, z=-0.2971, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7094, y=3.6118, z=-0.7377, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4688, y=3.6123, z=-1.2084, visibility=0.0003
#
# NOSE: x=0.5934, y=0.4775, z=-1.4234, visibility=0.9992
#
# LEFT_EYE_INNER: x=0.6216, y=0.3964, z=-1.3254, visibility=0.9989
#
# LEFT_EYE: x=0.6408, y=0.3961, z=-1.3259, visibility=0.9989
#
# LEFT_EYE_OUTER: x=0.6600, y=0.3968, z=-1.3263, visibility=0.9989
#
# RIGHT_EYE_INNER: x=0.5481, y=0.4024, z=-1.3518, visibility=0.9990
#
# RIGHT_EYE: x=0.5208, y=0.4063, z=-1.3512, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.4962, y=0.4113, z=-1.3518, visibility=0.9992
#
# LEFT_EAR: x=0.6803, y=0.4286, z=-0.6961, visibility=0.9992
#
# RIGHT_EAR: x=0.4555, y=0.4486, z=-0.8018, visibility=0.9994
#
# MOUTH_LEFT: x=0.6321, y=0.5605, z=-1.1810, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5473, y=0.5672, z=-1.2137, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8588, y=0.8078, z=-0.2833, visibility=0.9944
#
# RIGHT_SHOULDER: x=0.2845, y=0.8126, z=-0.4813, visibility=0.9912
#
# LEFT_ELBOW: x=1.0123, y=0.9542, z=-0.3958, visibility=0.5035
#
# RIGHT_ELBOW: x=0.0901, y=1.0346, z=-0.8384, visibility=0.5375
#
# LEFT_WRIST: x=1.2086, y=1.3297, z=-1.0826, visibility=0.4874
#
# RIGHT_WRIST: x=0.0845, y=1.3443, z=-1.7957, visibility=0.3717
#
# LEFT_PINKY: x=1.2738, y=1.4028, z=-1.2438, visibility=0.4652
#
# RIGHT_PINKY: x=0.0763, y=1.4110, z=-2.0353, visibility=0.3639
#
# LEFT_INDEX: x=1.2258, y=1.3737, z=-1.2953, visibility=0.5260
#
# RIGHT_INDEX: x=0.1289, y=1.3274, z=-2.0972, visibility=0.4477
#
# LEFT_THUMB: x=1.1889, y=1.3619, z=-1.1446, visibility=0.5120
#
# RIGHT_THUMB: x=0.1451, y=1.3024, z=-1.8579, visibility=0.4358
#
# LEFT_HIP: x=0.7588, y=1.8077, z=-0.0341, visibility=0.0028
#
# RIGHT_HIP: x=0.3785, y=1.8127, z=0.0413, visibility=0.0022
#
# LEFT_KNEE: x=0.7486, y=2.6134, z=-0.3359, visibility=0.0050
#
# RIGHT_KNEE: x=0.4149, y=2.5947, z=-0.5246, visibility=0.0025
#
# LEFT_ANKLE: x=0.7611, y=3.3860, z=0.1611, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4125, y=3.3919, z=-0.2890, visibility=0.0001
#
# LEFT_HEEL: x=0.7673, y=3.5026, z=0.1551, visibility=0.0002
#
# RIGHT_HEEL: x=0.4069, y=3.5167, z=-0.2989, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7041, y=3.6137, z=-0.7334, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4626, y=3.6140, z=-1.2347, visibility=0.0003
#
# NOSE: x=0.5938, y=0.4774, z=-1.4243, visibility=0.9992
#
# LEFT_EYE_INNER: x=0.6225, y=0.3964, z=-1.3274, visibility=0.9989
#
# LEFT_EYE: x=0.6419, y=0.3962, z=-1.3278, visibility=0.9989
#
# LEFT_EYE_OUTER: x=0.6610, y=0.3968, z=-1.3283, visibility=0.9989
#
# RIGHT_EYE_INNER: x=0.5486, y=0.4024, z=-1.3513, visibility=0.9991
#
# RIGHT_EYE: x=0.5211, y=0.4061, z=-1.3507, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.4964, y=0.4110, z=-1.3512, visibility=0.9992
#
# LEFT_EAR: x=0.6808, y=0.4283, z=-0.6954, visibility=0.9992
#
# RIGHT_EAR: x=0.4556, y=0.4472, z=-0.7942, visibility=0.9994
#
# MOUTH_LEFT: x=0.6325, y=0.5604, z=-1.1827, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5474, y=0.5668, z=-1.2121, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8589, y=0.8077, z=-0.2770, visibility=0.9945
#
# RIGHT_SHOULDER: x=0.2837, y=0.8125, z=-0.4747, visibility=0.9911
#
# LEFT_ELBOW: x=1.1057, y=1.0925, z=-0.3975, visibility=0.4913
#
# RIGHT_ELBOW: x=0.0901, y=1.0345, z=-0.8693, visibility=0.5324
#
# LEFT_WRIST: x=1.2084, y=1.3301, z=-1.0805, visibility=0.4663
#
# RIGHT_WRIST: x=0.0831, y=1.3328, z=-1.9596, visibility=0.3603
#
# LEFT_PINKY: x=1.2720, y=1.3976, z=-1.2414, visibility=0.4464
#
# RIGHT_PINKY: x=0.0732, y=1.3847, z=-2.2065, visibility=0.3540
#
# LEFT_INDEX: x=1.2244, y=1.3646, z=-1.3052, visibility=0.5099
#
# RIGHT_INDEX: x=0.1241, y=1.1743, z=-2.2625, visibility=0.4385
#
# LEFT_THUMB: x=1.1872, y=1.3560, z=-1.1416, visibility=0.4953
#
# RIGHT_THUMB: x=0.1432, y=1.1340, z=-2.0219, visibility=0.4263
#
# LEFT_HIP: x=0.7588, y=1.8075, z=-0.0353, visibility=0.0027
#
# RIGHT_HIP: x=0.3785, y=1.8130, z=0.0425, visibility=0.0021
#
# LEFT_KNEE: x=0.7487, y=2.6145, z=-0.3112, visibility=0.0050
#
# RIGHT_KNEE: x=0.4135, y=2.5986, z=-0.4703, visibility=0.0025
#
# LEFT_ANKLE: x=0.7610, y=3.3886, z=0.2202, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4127, y=3.3945, z=-0.1801, visibility=0.0001
#
# LEFT_HEEL: x=0.7672, y=3.5048, z=0.2173, visibility=0.0002
#
# RIGHT_HEEL: x=0.4070, y=3.5185, z=-0.1853, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7042, y=3.6166, z=-0.6687, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4628, y=3.6173, z=-1.1344, visibility=0.0003
#
# NOSE: x=0.5941, y=0.4774, z=-1.4225, visibility=0.9992
#
# LEFT_EYE_INNER: x=0.6230, y=0.3964, z=-1.3260, visibility=0.9990
#
# LEFT_EYE: x=0.6427, y=0.3962, z=-1.3264, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6617, y=0.3968, z=-1.3269, visibility=0.9989
#
# RIGHT_EYE_INNER: x=0.5490, y=0.4023, z=-1.3491, visibility=0.9991
#
# RIGHT_EYE: x=0.5213, y=0.4060, z=-1.3485, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.4965, y=0.4108, z=-1.3490, visibility=0.9992
#
# LEFT_EAR: x=0.6811, y=0.4281, z=-0.6937, visibility=0.9992
#
# RIGHT_EAR: x=0.4556, y=0.4461, z=-0.7896, visibility=0.9994
#
# MOUTH_LEFT: x=0.6327, y=0.5603, z=-1.1814, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5474, y=0.5666, z=-1.2096, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8589, y=0.8075, z=-0.2733, visibility=0.9946
#
# RIGHT_SHOULDER: x=0.2831, y=0.8124, z=-0.4706, visibility=0.9911
#
# LEFT_ELBOW: x=1.1315, y=1.1242, z=-0.4038, visibility=0.4810
#
# RIGHT_ELBOW: x=0.0901, y=1.0345, z=-0.8888, visibility=0.5290
#
# LEFT_WRIST: x=1.2083, y=1.3258, z=-1.0957, visibility=0.4488
#
# RIGHT_WRIST: x=0.0812, y=1.3202, z=-2.0049, visibility=0.3524
#
# LEFT_PINKY: x=1.2718, y=1.3901, z=-1.2579, visibility=0.4310
#
# RIGHT_PINKY: x=0.0699, y=1.3661, z=-2.2512, visibility=0.3472
#
# LEFT_INDEX: x=1.2236, y=1.3556, z=-1.3220, visibility=0.4972
#
# RIGHT_INDEX: x=0.1212, y=1.1427, z=-2.3038, visibility=0.4327
#
# LEFT_THUMB: x=1.1870, y=1.3486, z=-1.1561, visibility=0.4820
#
# RIGHT_THUMB: x=0.1423, y=1.0977, z=-2.0660, visibility=0.4199
#
# LEFT_HIP: x=0.7588, y=1.8074, z=-0.0356, visibility=0.0025
#
# RIGHT_HIP: x=0.3783, y=1.8132, z=0.0429, visibility=0.0020
#
# LEFT_KNEE: x=0.7487, y=2.6153, z=-0.2969, visibility=0.0050
#
# RIGHT_KNEE: x=0.4121, y=2.6017, z=-0.4389, visibility=0.0025
#
# LEFT_ANKLE: x=0.7608, y=3.3906, z=0.2404, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4129, y=3.3963, z=-0.1460, visibility=0.0001
#
# LEFT_HEEL: x=0.7669, y=3.5066, z=0.2384, visibility=0.0002
#
# RIGHT_HEEL: x=0.4071, y=3.5197, z=-0.1510, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7042, y=3.6185, z=-0.6395, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4630, y=3.6196, z=-1.0946, visibility=0.0003
#
# NOSE: x=0.5985, y=0.4774, z=-1.4186, visibility=0.9992
#
# LEFT_EYE_INNER: x=0.6259, y=0.3964, z=-1.3219, visibility=0.9988
#
# LEFT_EYE: x=0.6457, y=0.3962, z=-1.3222, visibility=0.9988
#
# LEFT_EYE_OUTER: x=0.6647, y=0.3969, z=-1.3227, visibility=0.9988
#
# RIGHT_EYE_INNER: x=0.5534, y=0.4023, z=-1.3479, visibility=0.9990
#
# RIGHT_EYE: x=0.5257, y=0.4061, z=-1.3473, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.4999, y=0.4111, z=-1.3478, visibility=0.9991
#
# LEFT_EAR: x=0.6834, y=0.4280, z=-0.6918, visibility=0.9991
#
# RIGHT_EAR: x=0.4566, y=0.4462, z=-0.8085, visibility=0.9994
#
# MOUTH_LEFT: x=0.6366, y=0.5604, z=-1.1783, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5518, y=0.5669, z=-1.2106, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8589, y=0.8073, z=-0.2635, visibility=0.9942
#
# RIGHT_SHOULDER: x=0.2830, y=0.8124, z=-0.4871, visibility=0.9908
#
# LEFT_ELBOW: x=1.0564, y=1.0005, z=-0.3551, visibility=0.4748
#
# RIGHT_ELBOW: x=0.0904, y=1.0345, z=-0.7935, visibility=0.5275
#
# LEFT_WRIST: x=1.2158, y=1.2901, z=-1.0391, visibility=0.4315
#
# RIGHT_WRIST: x=0.0618, y=1.4169, z=-1.6946, visibility=0.3324
#
# LEFT_PINKY: x=1.2752, y=1.3515, z=-1.1999, visibility=0.4139
#
# RIGHT_PINKY: x=0.0443, y=1.5111, z=-1.9199, visibility=0.3284
#
# LEFT_INDEX: x=1.2290, y=1.3189, z=-1.2750, visibility=0.4812
#
# RIGHT_INDEX: x=0.0991, y=1.4397, z=-1.9986, visibility=0.4122
#
# LEFT_THUMB: x=1.1928, y=1.3138, z=-1.1049, visibility=0.4658
#
# RIGHT_THUMB: x=0.1139, y=1.4128, z=-1.7613, visibility=0.3996
#
# LEFT_HIP: x=0.7587, y=1.8082, z=-0.0311, visibility=0.0025
#
# RIGHT_HIP: x=0.3780, y=1.8156, z=0.0382, visibility=0.0019
#
# LEFT_KNEE: x=0.7476, y=2.6152, z=-0.2874, visibility=0.0052
#
# RIGHT_KNEE: x=0.4112, y=2.6027, z=-0.4604, visibility=0.0026
#
# LEFT_ANKLE: x=0.7601, y=3.3888, z=0.2340, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4129, y=3.3955, z=-0.1965, visibility=0.0001
#
# LEFT_HEEL: x=0.7665, y=3.5043, z=0.2318, visibility=0.0002
#
# RIGHT_HEEL: x=0.4071, y=3.5182, z=-0.2033, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7037, y=3.6180, z=-0.6302, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4631, y=3.6204, z=-1.1270, visibility=0.0003
#
# NOSE: x=0.6144, y=0.4795, z=-1.4276, visibility=0.9991
#
# LEFT_EYE_INNER: x=0.6350, y=0.3984, z=-1.3289, visibility=0.9987
#
# LEFT_EYE: x=0.6534, y=0.3980, z=-1.3293, visibility=0.9987
#
# LEFT_EYE_OUTER: x=0.6710, y=0.3983, z=-1.3298, visibility=0.9986
#
# RIGHT_EYE_INNER: x=0.5676, y=0.4039, z=-1.3634, visibility=0.9989
#
# RIGHT_EYE: x=0.5386, y=0.4077, z=-1.3628, visibility=0.9989
#
# RIGHT_EYE_OUTER: x=0.5121, y=0.4129, z=-1.3633, visibility=0.9990
#
# LEFT_EAR: x=0.6842, y=0.4282, z=-0.6905, visibility=0.9989
#
# RIGHT_EAR: x=0.4590, y=0.4465, z=-0.8372, visibility=0.9993
#
# MOUTH_LEFT: x=0.6457, y=0.5627, z=-1.1806, visibility=0.9992
#
# MOUTH_RIGHT: x=0.5676, y=0.5700, z=-1.2226, visibility=0.9994
#
# LEFT_SHOULDER: x=0.8561, y=0.8073, z=-0.2463, visibility=0.9940
#
# RIGHT_SHOULDER: x=0.2833, y=0.8093, z=-0.4872, visibility=0.9905
#
# LEFT_ELBOW: x=1.0172, y=0.9818, z=-0.2735, visibility=0.4579
#
# RIGHT_ELBOW: x=0.0911, y=1.0362, z=-0.7639, visibility=0.5191
#
# LEFT_WRIST: x=1.1894, y=1.3823, z=-0.9639, visibility=0.4075
#
# RIGHT_WRIST: x=0.0802, y=1.4500, z=-1.6981, visibility=0.3161
#
# LEFT_PINKY: x=1.2485, y=1.4745, z=-1.1352, visibility=0.3945
#
# RIGHT_PINKY: x=0.0681, y=1.5507, z=-1.9386, visibility=0.3153
#
# LEFT_INDEX: x=1.2038, y=1.4473, z=-1.2447, visibility=0.4635
#
# RIGHT_INDEX: x=0.1224, y=1.4951, z=-2.0181, visibility=0.3991
#
# LEFT_THUMB: x=1.1672, y=1.4299, z=-1.0448, visibility=0.4478
#
# RIGHT_THUMB: x=0.1333, y=1.4679, z=-1.7661, visibility=0.3855
#
# LEFT_HIP: x=0.7539, y=1.8078, z=-0.0281, visibility=0.0023
#
# RIGHT_HIP: x=0.3765, y=1.8147, z=0.0355, visibility=0.0019
#
# LEFT_KNEE: x=0.7364, y=2.6043, z=-0.3374, visibility=0.0053
#
# RIGHT_KNEE: x=0.4095, y=2.5822, z=-0.5664, visibility=0.0027
#
# LEFT_ANKLE: x=0.7471, y=3.3859, z=0.1608, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4037, y=3.3928, z=-0.3413, visibility=0.0001
#
# LEFT_HEEL: x=0.7501, y=3.4995, z=0.1581, visibility=0.0002
#
# RIGHT_HEEL: x=0.3957, y=3.5167, z=-0.3526, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6909, y=3.6189, z=-0.6998, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4538, y=3.6212, z=-1.2924, visibility=0.0003
#
# NOSE: x=0.6228, y=0.4816, z=-1.4368, visibility=0.9990
#
# LEFT_EYE_INNER: x=0.6406, y=0.4003, z=-1.3361, visibility=0.9986
#
# LEFT_EYE: x=0.6581, y=0.3996, z=-1.3365, visibility=0.9986
#
# LEFT_EYE_OUTER: x=0.6749, y=0.3997, z=-1.3370, visibility=0.9986
#
# RIGHT_EYE_INNER: x=0.5757, y=0.4058, z=-1.3737, visibility=0.9988
#
# RIGHT_EYE: x=0.5461, y=0.4097, z=-1.3731, visibility=0.9989
#
# RIGHT_EYE_OUTER: x=0.5193, y=0.4150, z=-1.3736, visibility=0.9990
#
# LEFT_EAR: x=0.6847, y=0.4285, z=-0.6900, visibility=0.9989
#
# RIGHT_EAR: x=0.4608, y=0.4471, z=-0.8434, visibility=0.9993
#
# MOUTH_LEFT: x=0.6512, y=0.5647, z=-1.1838, visibility=0.9992
#
# MOUTH_RIGHT: x=0.5764, y=0.5728, z=-1.2305, visibility=0.9994
#
# LEFT_SHOULDER: x=0.8550, y=0.8075, z=-0.2388, visibility=0.9939
#
# RIGHT_SHOULDER: x=0.2837, y=0.8088, z=-0.4838, visibility=0.9901
#
# LEFT_ELBOW: x=1.0033, y=0.9756, z=-0.2909, visibility=0.4434
#
# RIGHT_ELBOW: x=0.0914, y=1.0391, z=-0.7777, visibility=0.5106
#
# LEFT_WRIST: x=1.1688, y=1.3980, z=-1.0058, visibility=0.3869
#
# RIGHT_WRIST: x=0.0946, y=1.4252, z=-1.7534, visibility=0.3037
#
# LEFT_PINKY: x=1.2234, y=1.4933, z=-1.1796, visibility=0.3788
#
# RIGHT_PINKY: x=0.0875, y=1.5198, z=-1.9906, visibility=0.3062
#
# LEFT_INDEX: x=1.1769, y=1.4624, z=-1.2738, visibility=0.4496
#
# RIGHT_INDEX: x=0.1384, y=1.4482, z=-2.0593, visibility=0.3904
#
# LEFT_THUMB: x=1.1422, y=1.4432, z=-1.0826, visibility=0.4334
#
# RIGHT_THUMB: x=0.1470, y=1.4203, z=-1.8187, visibility=0.3756
#
# LEFT_HIP: x=0.7516, y=1.8077, z=-0.0273, visibility=0.0022
#
# RIGHT_HIP: x=0.3761, y=1.8145, z=0.0348, visibility=0.0018
#
# LEFT_KNEE: x=0.7307, y=2.5967, z=-0.3677, visibility=0.0055
#
# RIGHT_KNEE: x=0.4085, y=2.5715, z=-0.5885, visibility=0.0028
#
# LEFT_ANKLE: x=0.7410, y=3.3832, z=0.1171, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4005, y=3.3914, z=-0.3789, visibility=0.0001
#
# LEFT_HEEL: x=0.7432, y=3.4958, z=0.1135, visibility=0.0002
#
# RIGHT_HEEL: x=0.3922, y=3.5161, z=-0.3917, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6852, y=3.6193, z=-0.7433, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.4501, y=3.6218, z=-1.3315, visibility=0.0003
#
# NOSE: x=0.6463, y=0.4831, z=-1.4289, visibility=0.9989
#
# LEFT_EYE_INNER: x=0.6602, y=0.4026, z=-1.3202, visibility=0.9985
#
# LEFT_EYE: x=0.6768, y=0.4022, z=-1.3207, visibility=0.9984
#
# LEFT_EYE_OUTER: x=0.6927, y=0.4028, z=-1.3212, visibility=0.9984
#
# RIGHT_EYE_INNER: x=0.5993, y=0.4073, z=-1.3699, visibility=0.9987
#
# RIGHT_EYE: x=0.5707, y=0.4111, z=-1.3691, visibility=0.9988
#
# RIGHT_EYE_OUTER: x=0.5407, y=0.4165, z=-1.3696, visibility=0.9989
#
# LEFT_EAR: x=0.6906, y=0.4300, z=-0.6517, visibility=0.9987
#
# RIGHT_EAR: x=0.4725, y=0.4482, z=-0.8535, visibility=0.9992
#
# MOUTH_LEFT: x=0.6669, y=0.5668, z=-1.1670, visibility=0.9990
#
# MOUTH_RIGHT: x=0.5970, y=0.5754, z=-1.2262, visibility=0.9993
#
# LEFT_SHOULDER: x=0.8564, y=0.8083, z=-0.2110, visibility=0.9933
#
# RIGHT_SHOULDER: x=0.2842, y=0.8088, z=-0.5159, visibility=0.9894
#
# LEFT_ELBOW: x=1.0062, y=0.9515, z=-0.3804, visibility=0.4401
#
# RIGHT_ELBOW: x=0.0932, y=1.0391, z=-0.9406, visibility=0.5141
#
# LEFT_WRIST: x=1.1970, y=1.2549, z=-1.2308, visibility=0.3826
#
# RIGHT_WRIST: x=0.1224, y=1.4242, z=-1.9016, visibility=0.2948
#
# LEFT_PINKY: x=1.2564, y=1.3081, z=-1.4132, visibility=0.3761
#
# RIGHT_PINKY: x=0.1258, y=1.5049, z=-2.1318, visibility=0.2978
#
# LEFT_INDEX: x=1.2124, y=1.2788, z=-1.4838, visibility=0.4482
#
# RIGHT_INDEX: x=0.1738, y=1.4211, z=-2.1763, visibility=0.3815
#
# LEFT_THUMB: x=1.1758, y=1.2771, z=-1.3001, visibility=0.4313
#
# RIGHT_THUMB: x=0.1770, y=1.3859, z=-1.9537, visibility=0.3656
#
# LEFT_HIP: x=0.7544, y=1.8106, z=-0.0169, visibility=0.0023
#
# RIGHT_HIP: x=0.3832, y=1.8204, z=0.0237, visibility=0.0018
#
# LEFT_KNEE: x=0.7310, y=2.5984, z=-0.3645, visibility=0.0069
#
# RIGHT_KNEE: x=0.4168, y=2.5754, z=-0.5824, visibility=0.0036
#
# LEFT_ANKLE: x=0.7416, y=3.3841, z=0.1209, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4034, y=3.3953, z=-0.3902, visibility=0.0001
#
# LEFT_HEEL: x=0.7436, y=3.4969, z=0.1169, visibility=0.0002
#
# RIGHT_HEEL: x=0.3940, y=3.5205, z=-0.4041, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6855, y=3.6200, z=-0.7291, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.4535, y=3.6269, z=-1.3122, visibility=0.0004
#
# NOSE: x=0.6671, y=0.4835, z=-1.3247, visibility=0.9987
#
# LEFT_EYE_INNER: x=0.6758, y=0.4060, z=-1.2120, visibility=0.9983
#
# LEFT_EYE: x=0.6900, y=0.4063, z=-1.2124, visibility=0.9983
#
# LEFT_EYE_OUTER: x=0.7032, y=0.4074, z=-1.2130, visibility=0.9982
#
# RIGHT_EYE_INNER: x=0.6228, y=0.4090, z=-1.2760, visibility=0.9986
#
# RIGHT_EYE: x=0.5947, y=0.4126, z=-1.2756, visibility=0.9987
#
# RIGHT_EYE_OUTER: x=0.5649, y=0.4179, z=-1.2762, visibility=0.9988
#
# LEFT_EAR: x=0.6907, y=0.4342, z=-0.5325, visibility=0.9986
#
# RIGHT_EAR: x=0.4904, y=0.4500, z=-0.8182, visibility=0.9992
#
# MOUTH_LEFT: x=0.6801, y=0.5671, z=-1.0622, visibility=0.9989
#
# MOUTH_RIGHT: x=0.6181, y=0.5762, z=-1.1446, visibility=0.9992
#
# LEFT_SHOULDER: x=0.8564, y=0.8091, z=-0.1255, visibility=0.9929
#
# RIGHT_SHOULDER: x=0.2865, y=0.8086, z=-0.5112, visibility=0.9884
#
# LEFT_ELBOW: x=1.0665, y=1.0289, z=-0.4024, visibility=0.4337
#
# RIGHT_ELBOW: x=0.0928, y=1.0378, z=-1.0603, visibility=0.5276
#
# LEFT_WRIST: x=1.1356, y=1.1858, z=-1.2861, visibility=0.3868
#
# RIGHT_WRIST: x=0.1295, y=1.2545, z=-2.1303, visibility=0.3073
#
# LEFT_PINKY: x=1.1703, y=1.2236, z=-1.4632, visibility=0.3820
#
# RIGHT_PINKY: x=0.1380, y=1.2887, z=-2.3638, visibility=0.3078
#
# LEFT_INDEX: x=1.1261, y=1.1823, z=-1.5057, visibility=0.4550
#
# RIGHT_INDEX: x=0.1803, y=1.2298, z=-2.3682, visibility=0.3918
#
# LEFT_THUMB: x=1.0994, y=1.1872, z=-1.3410, visibility=0.4361
#
# RIGHT_THUMB: x=0.1834, y=1.2321, z=-2.1670, visibility=0.3734
#
# LEFT_HIP: x=0.7535, y=1.8103, z=-0.0102, visibility=0.0023
#
# RIGHT_HIP: x=0.3849, y=1.8199, z=0.0166, visibility=0.0019
#
# LEFT_KNEE: x=0.7297, y=2.5983, z=-0.3640, visibility=0.0078
#
# RIGHT_KNEE: x=0.4167, y=2.5780, z=-0.5714, visibility=0.0042
#
# LEFT_ANKLE: x=0.7372, y=3.3849, z=0.1280, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4035, y=3.3955, z=-0.3487, visibility=0.0001
#
# LEFT_HEEL: x=0.7372, y=3.4973, z=0.1244, visibility=0.0002
#
# RIGHT_HEEL: x=0.3943, y=3.5206, z=-0.3609, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6861, y=3.6198, z=-0.7091, visibility=0.0004
#
# RIGHT_FOOT_INDEX: x=0.4539, y=3.6271, z=-1.2907, visibility=0.0005
#
# NOSE: x=0.6761, y=0.4849, z=-1.3130, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6801, y=0.4090, z=-1.2051, visibility=0.9978
#
# LEFT_EYE: x=0.6926, y=0.4095, z=-1.2056, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.7042, y=0.4105, z=-1.2062, visibility=0.9977
#
# RIGHT_EYE_INNER: x=0.6321, y=0.4115, z=-1.2675, visibility=0.9982
#
# RIGHT_EYE: x=0.6059, y=0.4151, z=-1.2673, visibility=0.9982
#
# RIGHT_EYE_OUTER: x=0.5781, y=0.4202, z=-1.2679, visibility=0.9984
#
# LEFT_EAR: x=0.6881, y=0.4369, z=-0.5375, visibility=0.9983
#
# RIGHT_EAR: x=0.5039, y=0.4531, z=-0.8171, visibility=0.9988
#
# MOUTH_LEFT: x=0.6857, y=0.5672, z=-1.0539, visibility=0.9985
#
# MOUTH_RIGHT: x=0.6298, y=0.5772, z=-1.1357, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8567, y=0.8095, z=-0.1156, visibility=0.9920
#
# RIGHT_SHOULDER: x=0.2877, y=0.8090, z=-0.5180, visibility=0.9858
#
# LEFT_ELBOW: x=1.1081, y=1.0513, z=-0.2895, visibility=0.4324
#
# RIGHT_ELBOW: x=0.0935, y=1.0371, z=-1.1880, visibility=0.5325
#
# LEFT_WRIST: x=1.1754, y=1.2044, z=-0.9823, visibility=0.3843
#
# RIGHT_WRIST: x=0.1457, y=1.2058, z=-2.3257, visibility=0.3075
#
# LEFT_PINKY: x=1.2203, y=1.2501, z=-1.1149, visibility=0.3803
#
# RIGHT_PINKY: x=0.1602, y=1.2395, z=-2.5643, visibility=0.3071
#
# LEFT_INDEX: x=1.1887, y=1.2125, z=-1.1919, visibility=0.4545
#
# RIGHT_INDEX: x=0.1988, y=1.1804, z=-2.5643, visibility=0.3899
#
# LEFT_THUMB: x=1.1591, y=1.2138, z=-1.0445, visibility=0.4350
#
# RIGHT_THUMB: x=0.1999, y=1.1840, z=-2.3638, visibility=0.3699
#
# LEFT_HIP: x=0.7530, y=1.8113, z=0.0014, visibility=0.0024
#
# RIGHT_HIP: x=0.3875, y=1.8198, z=0.0047, visibility=0.0019
#
# LEFT_KNEE: x=0.7253, y=2.5859, z=-0.3286, visibility=0.0093
#
# RIGHT_KNEE: x=0.4165, y=2.5639, z=-0.5605, visibility=0.0054
#
# LEFT_ANKLE: x=0.7229, y=3.3775, z=0.1550, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3957, y=3.3911, z=-0.3334, visibility=0.0002
#
# LEFT_HEEL: x=0.7199, y=3.4872, z=0.1543, visibility=0.0002
#
# RIGHT_HEEL: x=0.3824, y=3.5151, z=-0.3447, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6826, y=3.6117, z=-0.6213, visibility=0.0005
#
# RIGHT_FOOT_INDEX: x=0.4461, y=3.6233, z=-1.2327, visibility=0.0006
#
# NOSE: x=0.6912, y=0.4872, z=-1.2877, visibility=0.9980
#
# LEFT_EYE_INNER: x=0.6917, y=0.4121, z=-1.1771, visibility=0.9976
#
# LEFT_EYE: x=0.7023, y=0.4126, z=-1.1776, visibility=0.9975
#
# LEFT_EYE_OUTER: x=0.7119, y=0.4133, z=-1.1781, visibility=0.9975
#
# RIGHT_EYE_INNER: x=0.6466, y=0.4146, z=-1.2456, visibility=0.9980
#
# RIGHT_EYE: x=0.6220, y=0.4181, z=-1.2454, visibility=0.9981
#
# RIGHT_EYE_OUTER: x=0.5950, y=0.4230, z=-1.2460, visibility=0.9982
#
# LEFT_EAR: x=0.6879, y=0.4390, z=-0.5124, visibility=0.9981
#
# RIGHT_EAR: x=0.5188, y=0.4565, z=-0.8165, visibility=0.9987
#
# MOUTH_LEFT: x=0.6987, y=0.5685, z=-1.0315, visibility=0.9983
#
# MOUTH_RIGHT: x=0.6476, y=0.5797, z=-1.1212, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8567, y=0.8111, z=-0.1021, visibility=0.9917
#
# RIGHT_SHOULDER: x=0.2920, y=0.8104, z=-0.5284, visibility=0.9848
#
# LEFT_ELBOW: x=1.0397, y=0.9817, z=-0.2581, visibility=0.4290
#
# RIGHT_ELBOW: x=0.0921, y=1.0389, z=-1.2310, visibility=0.5467
#
# LEFT_WRIST: x=1.1764, y=1.1969, z=-0.9412, visibility=0.3921
#
# RIGHT_WRIST: x=0.1522, y=1.2000, z=-2.3670, visibility=0.3192
#
# LEFT_PINKY: x=1.2220, y=1.2435, z=-1.0768, visibility=0.3895
#
# RIGHT_PINKY: x=0.1711, y=1.2292, z=-2.6003, visibility=0.3170
#
# LEFT_INDEX: x=1.1882, y=1.2052, z=-1.1431, visibility=0.4651
#
# RIGHT_INDEX: x=0.2119, y=1.1668, z=-2.5914, visibility=0.3997
#
# LEFT_THUMB: x=1.1588, y=1.2081, z=-0.9996, visibility=0.4441
#
# RIGHT_THUMB: x=0.2114, y=1.1718, z=-2.3995, visibility=0.3774
#
# LEFT_HIP: x=0.7531, y=1.8120, z=0.0092, visibility=0.0024
#
# RIGHT_HIP: x=0.3949, y=1.8218, z=-0.0031, visibility=0.0019
#
# LEFT_KNEE: x=0.7259, y=2.5834, z=-0.3584, visibility=0.0098
#
# RIGHT_KNEE: x=0.4224, y=2.5670, z=-0.5440, visibility=0.0059
#
# LEFT_ANKLE: x=0.7244, y=3.3777, z=0.0795, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3992, y=3.3934, z=-0.3694, visibility=0.0002
#
# LEFT_HEEL: x=0.7215, y=3.4869, z=0.0756, visibility=0.0003
#
# RIGHT_HEEL: x=0.3831, y=3.5174, z=-0.3874, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6879, y=3.6092, z=-0.6739, visibility=0.0005
#
# RIGHT_FOOT_INDEX: x=0.4523, y=3.6236, z=-1.2504, visibility=0.0006
#
# NOSE: x=0.6944, y=0.4875, z=-1.2981, visibility=0.9976
#
# LEFT_EYE_INNER: x=0.6949, y=0.4125, z=-1.1864, visibility=0.9973
#
# LEFT_EYE: x=0.7056, y=0.4129, z=-1.1869, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.7149, y=0.4135, z=-1.1875, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.6490, y=0.4155, z=-1.2515, visibility=0.9978
#
# RIGHT_EYE: x=0.6238, y=0.4193, z=-1.2514, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5966, y=0.4246, z=-1.2520, visibility=0.9980
#
# LEFT_EAR: x=0.6880, y=0.4394, z=-0.5107, visibility=0.9979
#
# RIGHT_EAR: x=0.5217, y=0.4596, z=-0.8140, visibility=0.9986
#
# MOUTH_LEFT: x=0.7039, y=0.5688, z=-1.0388, visibility=0.9981
#
# MOUTH_RIGHT: x=0.6513, y=0.5812, z=-1.1248, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8569, y=0.8117, z=-0.0924, visibility=0.9914
#
# RIGHT_SHOULDER: x=0.2967, y=0.8118, z=-0.5235, visibility=0.9833
#
# LEFT_ELBOW: x=1.0217, y=0.9693, z=-0.1814, visibility=0.4325
#
# RIGHT_ELBOW: x=0.0922, y=1.0392, z=-1.2435, visibility=0.5639
#
# LEFT_WRIST: x=1.1991, y=1.2022, z=-0.7850, visibility=0.3969
#
# RIGHT_WRIST: x=0.1777, y=1.1955, z=-2.4081, visibility=0.3225
#
# LEFT_PINKY: x=1.2466, y=1.2503, z=-0.9037, visibility=0.3916
#
# RIGHT_PINKY: x=0.2063, y=1.2286, z=-2.6442, visibility=0.3163
#
# LEFT_INDEX: x=1.2169, y=1.2126, z=-0.9766, visibility=0.4676
#
# RIGHT_INDEX: x=0.2459, y=1.1638, z=-2.6286, visibility=0.3973
#
# LEFT_THUMB: x=1.1869, y=1.2146, z=-0.8424, visibility=0.4452
#
# RIGHT_THUMB: x=0.2411, y=1.1662, z=-2.4382, visibility=0.3731
#
# LEFT_HIP: x=0.7571, y=1.8121, z=0.0073, visibility=0.0025
#
# RIGHT_HIP: x=0.4042, y=1.8222, z=-0.0009, visibility=0.0020
#
# LEFT_KNEE: x=0.7283, y=2.5813, z=-0.3657, visibility=0.0110
#
# RIGHT_KNEE: x=0.4265, y=2.5687, z=-0.5022, visibility=0.0069
#
# LEFT_ANKLE: x=0.7248, y=3.3735, z=0.0890, visibility=0.0005
#
# RIGHT_ANKLE: x=0.4146, y=3.3913, z=-0.3508, visibility=0.0003
#
# LEFT_HEEL: x=0.7226, y=3.4825, z=0.0853, visibility=0.0003
#
# RIGHT_HEEL: x=0.4001, y=3.5126, z=-0.3732, visibility=0.0004
#
# LEFT_FOOT_INDEX: x=0.6958, y=3.5996, z=-0.6834, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4656, y=3.6206, z=-1.2147, visibility=0.0007
#
# NOSE: x=0.6953, y=0.4878, z=-1.3031, visibility=0.9974
#
# LEFT_EYE_INNER: x=0.6961, y=0.4129, z=-1.1907, visibility=0.9971
#
# LEFT_EYE: x=0.7069, y=0.4132, z=-1.1912, visibility=0.9969
#
# LEFT_EYE_OUTER: x=0.7162, y=0.4138, z=-1.1918, visibility=0.9969
#
# RIGHT_EYE_INNER: x=0.6497, y=0.4163, z=-1.2553, visibility=0.9976
#
# RIGHT_EYE: x=0.6243, y=0.4203, z=-1.2552, visibility=0.9977
#
# RIGHT_EYE_OUTER: x=0.5971, y=0.4260, z=-1.2557, visibility=0.9979
#
# LEFT_EAR: x=0.6880, y=0.4397, z=-0.5107, visibility=0.9978
#
# RIGHT_EAR: x=0.5225, y=0.4617, z=-0.8135, visibility=0.9985
#
# MOUTH_LEFT: x=0.7059, y=0.5692, z=-1.0421, visibility=0.9980
#
# MOUTH_RIGHT: x=0.6525, y=0.5824, z=-1.1275, visibility=0.9984
#
# LEFT_SHOULDER: x=0.8570, y=0.8122, z=-0.0880, visibility=0.9912
#
# RIGHT_SHOULDER: x=0.2991, y=0.8130, z=-0.5221, visibility=0.9821
#
# LEFT_ELBOW: x=1.0146, y=0.9640, z=-0.1802, visibility=0.4367
#
# RIGHT_ELBOW: x=0.0922, y=1.0395, z=-1.2524, visibility=0.5801
#
# LEFT_WRIST: x=1.2097, y=1.2006, z=-0.7926, visibility=0.4032
#
# RIGHT_WRIST: x=0.1845, y=1.1970, z=-2.4206, visibility=0.3257
#
# LEFT_PINKY: x=1.2574, y=1.2466, z=-0.9123, visibility=0.3950
#
# RIGHT_PINKY: x=0.2143, y=1.2325, z=-2.6563, visibility=0.3158
#
# LEFT_INDEX: x=1.2283, y=1.2086, z=-0.9816, visibility=0.4712
#
# RIGHT_INDEX: x=0.2539, y=1.1664, z=-2.6396, visibility=0.3953
#
# LEFT_THUMB: x=1.1977, y=1.2117, z=-0.8487, visibility=0.4475
#
# RIGHT_THUMB: x=0.2488, y=1.1674, z=-2.4503, visibility=0.3693
#
# LEFT_HIP: x=0.7596, y=1.8123, z=0.0056, visibility=0.0026
#
# RIGHT_HIP: x=0.4086, y=1.8228, z=0.0008, visibility=0.0021
#
# LEFT_KNEE: x=0.7299, y=2.5808, z=-0.3642, visibility=0.0121
#
# RIGHT_KNEE: x=0.4282, y=2.5702, z=-0.4763, visibility=0.0079
#
# LEFT_ANKLE: x=0.7250, y=3.3713, z=0.0981, visibility=0.0005
#
# RIGHT_ANKLE: x=0.4216, y=3.3907, z=-0.3208, visibility=0.0003
#
# LEFT_HEEL: x=0.7236, y=3.4801, z=0.0946, visibility=0.0003
#
# RIGHT_HEEL: x=0.4078, y=3.5106, z=-0.3424, visibility=0.0004
#
# LEFT_FOOT_INDEX: x=0.7006, y=3.5948, z=-0.6832, visibility=0.0007
#
# RIGHT_FOOT_INDEX: x=0.4726, y=3.6194, z=-1.1861, visibility=0.0009
#
# NOSE: x=0.6920, y=0.4871, z=-1.2239, visibility=0.9976
#
# LEFT_EYE_INNER: x=0.6938, y=0.4126, z=-1.1118, visibility=0.9973
#
# LEFT_EYE: x=0.7050, y=0.4129, z=-1.1120, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.7149, y=0.4133, z=-1.1121, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.6461, y=0.4157, z=-1.1836, visibility=0.9978
#
# RIGHT_EYE: x=0.6203, y=0.4198, z=-1.1835, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5928, y=0.4254, z=-1.1842, visibility=0.9981
#
# LEFT_EAR: x=0.6860, y=0.4394, z=-0.4585, visibility=0.9980
#
# RIGHT_EAR: x=0.5194, y=0.4617, z=-0.7909, visibility=0.9986
#
# MOUTH_LEFT: x=0.7037, y=0.5676, z=-0.9729, visibility=0.9981
#
# MOUTH_RIGHT: x=0.6483, y=0.5820, z=-1.0695, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8568, y=0.8123, z=-0.0502, visibility=0.9910
#
# RIGHT_SHOULDER: x=0.2990, y=0.8161, z=-0.5483, visibility=0.9823
#
# LEFT_ELBOW: x=1.1583, y=1.0194, z=-0.5979, visibility=0.4588
#
# RIGHT_ELBOW: x=0.0816, y=1.0424, z=-1.3584, visibility=0.5931
#
# LEFT_WRIST: x=1.1922, y=0.6990, z=-1.4063, visibility=0.4510
#
# RIGHT_WRIST: x=0.1382, y=1.1106, z=-2.3592, visibility=0.3517
#
# LEFT_PINKY: x=1.2109, y=0.5576, z=-1.5409, visibility=0.4372
#
# RIGHT_PINKY: x=0.1612, y=1.0902, z=-2.5503, visibility=0.3347
#
# LEFT_INDEX: x=1.1365, y=0.4060, z=-1.4366, visibility=0.5082
#
# RIGHT_INDEX: x=0.1800, y=1.0402, z=-2.5364, visibility=0.4140
#
# LEFT_THUMB: x=1.1555, y=0.5951, z=-1.4039, visibility=0.4845
#
# RIGHT_THUMB: x=0.1830, y=1.0666, z=-2.3775, visibility=0.3867
#
# LEFT_HIP: x=0.7596, y=1.8128, z=0.0236, visibility=0.0027
#
# RIGHT_HIP: x=0.4094, y=1.8238, z=-0.0178, visibility=0.0022
#
# LEFT_KNEE: x=0.7301, y=2.6121, z=-0.2637, visibility=0.0122
#
# RIGHT_KNEE: x=0.4239, y=2.6109, z=-0.4048, visibility=0.0076
#
# LEFT_ANKLE: x=0.7254, y=3.3869, z=0.2047, visibility=0.0005
#
# RIGHT_ANKLE: x=0.4185, y=3.4141, z=-0.1868, visibility=0.0003
#
# LEFT_HEEL: x=0.7238, y=3.4912, z=0.2077, visibility=0.0003
#
# RIGHT_HEEL: x=0.4066, y=3.5315, z=-0.1960, visibility=0.0004
#
# LEFT_FOOT_INDEX: x=0.6979, y=3.6110, z=-0.5264, visibility=0.0007
#
# RIGHT_FOOT_INDEX: x=0.4658, y=3.6312, z=-1.0199, visibility=0.0009
#
# NOSE: x=0.6886, y=0.4867, z=-1.2421, visibility=0.9975
#
# LEFT_EYE_INNER: x=0.6919, y=0.4125, z=-1.1141, visibility=0.9972
#
# LEFT_EYE: x=0.7038, y=0.4129, z=-1.1143, visibility=0.9970
#
# LEFT_EYE_OUTER: x=0.7145, y=0.4134, z=-1.1145, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.6430, y=0.4152, z=-1.1953, visibility=0.9978
#
# RIGHT_EYE: x=0.6172, y=0.4186, z=-1.1952, visibility=0.9978
#
# RIGHT_EYE_OUTER: x=0.5904, y=0.4234, z=-1.1957, visibility=0.9980
#
# LEFT_EAR: x=0.6885, y=0.4394, z=-0.4821, visibility=0.9979
#
# RIGHT_EAR: x=0.5186, y=0.4605, z=-0.8136, visibility=0.9986
#
# MOUTH_LEFT: x=0.7017, y=0.5672, z=-1.0073, visibility=0.9980
#
# MOUTH_RIGHT: x=0.6456, y=0.5804, z=-1.1065, visibility=0.9985
#
# LEFT_SHOULDER: x=0.8569, y=0.8140, z=-0.0649, visibility=0.9909
#
# RIGHT_SHOULDER: x=0.2976, y=0.8184, z=-0.5774, visibility=0.9816
#
# LEFT_ELBOW: x=1.1450, y=1.0985, z=-0.2092, visibility=0.4500
#
# RIGHT_ELBOW: x=0.0862, y=1.0457, z=-1.2685, visibility=0.5855
#
# LEFT_WRIST: x=1.2361, y=1.1569, z=-0.7571, visibility=0.4518
#
# RIGHT_WRIST: x=0.1414, y=1.1362, z=-2.3616, visibility=0.3514
#
# LEFT_PINKY: x=1.2879, y=1.1831, z=-0.8675, visibility=0.4403
#
# RIGHT_PINKY: x=0.1603, y=1.1058, z=-2.5927, visibility=0.3368
#
# LEFT_INDEX: x=1.2489, y=1.1408, z=-0.9408, visibility=0.5140
#
# RIGHT_INDEX: x=0.1909, y=1.0598, z=-2.5983, visibility=0.4174
#
# LEFT_THUMB: x=1.2229, y=1.1617, z=-0.8175, visibility=0.4898
#
# RIGHT_THUMB: x=0.1880, y=1.1082, z=-2.3998, visibility=0.3886
#
# LEFT_HIP: x=0.7593, y=1.8101, z=0.0260, visibility=0.0026
#
# RIGHT_HIP: x=0.4092, y=1.8205, z=-0.0199, visibility=0.0021
#
# LEFT_KNEE: x=0.7304, y=2.6039, z=-0.2793, visibility=0.0124
#
# RIGHT_KNEE: x=0.4258, y=2.6009, z=-0.4667, visibility=0.0077
#
# ...
#
# LEFT_ELBOW: x=1.2016, y=1.0781, z=-0.9226, visibility=0.5416
#
# RIGHT_ELBOW: x=0.0981, y=0.9906, z=-0.9628, visibility=0.3867
#
# LEFT_WRIST: x=1.1926, y=0.7941, z=-1.8167, visibility=0.5617
#
# RIGHT_WRIST: x=-0.0028, y=1.2030, z=-1.8973, visibility=0.2746
#
# LEFT_PINKY: x=1.2152, y=0.7025, z=-1.9523, visibility=0.5040
#
# RIGHT_PINKY: x=-0.0290, y=1.2402, z=-2.0631, visibility=0.2702
#
# LEFT_INDEX: x=1.0530, y=0.5684, z=-1.9003, visibility=0.5613
#
# RIGHT_INDEX: x=0.0184, y=1.2055, z=-2.0517, visibility=0.3406
#
# LEFT_THUMB: x=1.1449, y=0.7186, z=-1.7978, visibility=0.5176
#
# RIGHT_THUMB: x=0.1012, y=1.0280, z=-1.9293, visibility=0.3155
#
# LEFT_HIP: x=0.7361, y=1.8444, z=-0.0369, visibility=0.0023
#
# RIGHT_HIP: x=0.3869, y=1.8364, z=0.0429, visibility=0.0024
#
# LEFT_KNEE: x=0.7013, y=2.5897, z=-0.3424, visibility=0.0161
#
# RIGHT_KNEE: x=0.3773, y=2.5718, z=-0.3571, visibility=0.0064
#
# LEFT_ANKLE: x=0.6984, y=3.3562, z=0.1269, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3751, y=3.3648, z=-0.1612, visibility=0.0003
#
# LEFT_HEEL: x=0.7032, y=3.4643, z=0.1299, visibility=0.0003
#
# RIGHT_HEEL: x=0.3766, y=3.4872, z=-0.1717, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6374, y=3.5982, z=-0.6005, visibility=0.0010
#
# RIGHT_FOOT_INDEX: x=0.4044, y=3.5922, z=-0.9894, visibility=0.0013
#
# NOSE: x=0.5863, y=0.4698, z=-1.2930, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6203, y=0.3935, z=-1.1920, visibility=0.9997
#
# LEFT_EYE: x=0.6403, y=0.3933, z=-1.1922, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6603, y=0.3932, z=-1.1923, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5395, y=0.3968, z=-1.2211, visibility=0.9997
#
# RIGHT_EYE: x=0.5099, y=0.3993, z=-1.2209, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4842, y=0.4020, z=-1.2215, visibility=0.9997
#
# LEFT_EAR: x=0.6851, y=0.4287, z=-0.5639, visibility=0.9997
#
# RIGHT_EAR: x=0.4485, y=0.4409, z=-0.7083, visibility=0.9998
#
# MOUTH_LEFT: x=0.6277, y=0.5536, z=-1.0569, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5379, y=0.5581, z=-1.1004, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8626, y=0.8189, z=-0.1796, visibility=0.9741
#
# RIGHT_SHOULDER: x=0.2959, y=0.8222, z=-0.3892, visibility=0.9729
#
# LEFT_ELBOW: x=1.0874, y=0.9881, z=-0.9406, visibility=0.5493
#
# RIGHT_ELBOW: x=0.0980, y=0.9907, z=-1.1133, visibility=0.3931
#
# LEFT_WRIST: x=1.1760, y=0.7215, z=-1.8281, visibility=0.5692
#
# RIGHT_WRIST: x=0.0350, y=1.0622, z=-2.1796, visibility=0.2757
#
# LEFT_PINKY: x=1.1944, y=0.6001, z=-1.9633, visibility=0.5094
#
# RIGHT_PINKY: x=0.0302, y=1.0319, z=-2.3577, visibility=0.2698
#
# LEFT_INDEX: x=1.0491, y=0.4766, z=-1.8981, visibility=0.5662
#
# RIGHT_INDEX: x=0.0979, y=0.9431, z=-2.2880, visibility=0.3396
#
# LEFT_THUMB: x=1.0684, y=0.5167, z=-1.8060, visibility=0.5218
#
# RIGHT_THUMB: x=0.1270, y=0.9551, z=-2.1916, visibility=0.3142
#
# LEFT_HIP: x=0.7370, y=1.8441, z=-0.0353, visibility=0.0023
#
# RIGHT_HIP: x=0.3892, y=1.8364, z=0.0413, visibility=0.0024
#
# LEFT_KNEE: x=0.7022, y=2.5787, z=-0.3459, visibility=0.0160
#
# RIGHT_KNEE: x=0.3778, y=2.5695, z=-0.3512, visibility=0.0063
#
# LEFT_ANKLE: x=0.7001, y=3.3503, z=0.1250, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3750, y=3.3644, z=-0.1545, visibility=0.0003
#
# LEFT_HEEL: x=0.7040, y=3.4589, z=0.1288, visibility=0.0003
#
# RIGHT_HEEL: x=0.3756, y=3.4868, z=-0.1662, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6431, y=3.5941, z=-0.6003, visibility=0.0011
#
# RIGHT_FOOT_INDEX: x=0.4043, y=3.5905, z=-0.9711, visibility=0.0014
#
# NOSE: x=0.5865, y=0.4700, z=-1.3129, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6203, y=0.3935, z=-1.2128, visibility=0.9997
#
# LEFT_EYE: x=0.6406, y=0.3932, z=-1.2130, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6606, y=0.3931, z=-1.2130, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5390, y=0.3969, z=-1.2389, visibility=0.9997
#
# RIGHT_EYE: x=0.5095, y=0.3995, z=-1.2388, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4839, y=0.4024, z=-1.2395, visibility=0.9997
#
# LEFT_EAR: x=0.6853, y=0.4284, z=-0.5816, visibility=0.9997
#
# RIGHT_EAR: x=0.4487, y=0.4415, z=-0.7071, visibility=0.9998
#
# MOUTH_LEFT: x=0.6292, y=0.5539, z=-1.0732, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5382, y=0.5590, z=-1.1113, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8632, y=0.8191, z=-0.1911, visibility=0.9737
#
# RIGHT_SHOULDER: x=0.2960, y=0.8227, z=-0.4099, visibility=0.9722
#
# LEFT_ELBOW: x=1.1728, y=1.0165, z=-0.9957, visibility=0.5608
#
# RIGHT_ELBOW: x=0.0968, y=0.9908, z=-1.2000, visibility=0.3957
#
# LEFT_WRIST: x=1.1756, y=0.5807, z=-1.8280, visibility=0.5843
#
# RIGHT_WRIST: x=0.0295, y=1.0606, z=-2.2828, visibility=0.2728
#
# LEFT_PINKY: x=1.1611, y=0.3792, z=-1.9627, visibility=0.5195
#
# RIGHT_PINKY: x=0.0226, y=1.0326, z=-2.4598, visibility=0.2662
#
# LEFT_INDEX: x=1.0504, y=0.3613, z=-1.8655, visibility=0.5748
#
# RIGHT_INDEX: x=0.0660, y=0.9579, z=-2.3956, visibility=0.3354
#
# LEFT_THUMB: x=1.0544, y=0.4055, z=-1.8089, visibility=0.5302
#
# RIGHT_THUMB: x=0.0798, y=1.0060, z=-2.2983, visibility=0.3100
#
# LEFT_HIP: x=0.7376, y=1.8442, z=-0.0337, visibility=0.0023
#
# RIGHT_HIP: x=0.3894, y=1.8364, z=0.0396, visibility=0.0024
#
# LEFT_KNEE: x=0.7028, y=2.5902, z=-0.3136, visibility=0.0163
#
# RIGHT_KNEE: x=0.3783, y=2.5698, z=-0.3287, visibility=0.0062
#
# LEFT_ANKLE: x=0.7002, y=3.3531, z=0.1834, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3748, y=3.3662, z=-0.0943, visibility=0.0003
#
# LEFT_HEEL: x=0.7043, y=3.4600, z=0.1903, visibility=0.0003
#
# RIGHT_HEEL: x=0.3751, y=3.4886, z=-0.1028, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6416, y=3.5973, z=-0.5494, visibility=0.0011
#
# RIGHT_FOOT_INDEX: x=0.4042, y=3.5936, z=-0.9049, visibility=0.0014
#
# NOSE: x=0.5866, y=0.4702, z=-1.3141, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6202, y=0.3934, z=-1.2148, visibility=0.9997
#
# LEFT_EYE: x=0.6408, y=0.3932, z=-1.2149, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6608, y=0.3931, z=-1.2149, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5386, y=0.3970, z=-1.2392, visibility=0.9997
#
# RIGHT_EYE: x=0.5092, y=0.3997, z=-1.2391, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4837, y=0.4027, z=-1.2397, visibility=0.9997
#
# LEFT_EAR: x=0.6854, y=0.4282, z=-0.5853, visibility=0.9997
#
# RIGHT_EAR: x=0.4489, y=0.4419, z=-0.7016, visibility=0.9998
#
# MOUTH_LEFT: x=0.6301, y=0.5540, z=-1.0743, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5383, y=0.5597, z=-1.1098, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8637, y=0.8192, z=-0.1924, visibility=0.9733
#
# RIGHT_SHOULDER: x=0.2963, y=0.8231, z=-0.4147, visibility=0.9716
#
# LEFT_ELBOW: x=1.1994, y=1.0314, z=-1.0112, visibility=0.5706
#
# RIGHT_ELBOW: x=0.0963, y=0.9909, z=-1.2247, visibility=0.3984
#
# LEFT_WRIST: x=1.1749, y=0.5505, z=-1.8238, visibility=0.5982
#
# RIGHT_WRIST: x=0.0277, y=1.0591, z=-2.3108, visibility=0.2712
#
# LEFT_PINKY: x=1.1450, y=0.3429, z=-1.9560, visibility=0.5292
#
# RIGHT_PINKY: x=0.0199, y=1.0302, z=-2.4882, visibility=0.2637
#
# LEFT_INDEX: x=1.0517, y=0.3365, z=-1.8424, visibility=0.5830
#
# RIGHT_INDEX: x=0.0542, y=0.9601, z=-2.4225, visibility=0.3325
#
# LEFT_THUMB: x=1.0468, y=0.3852, z=-1.8057, visibility=0.5383
#
# RIGHT_THUMB: x=0.0670, y=1.0146, z=-2.3260, visibility=0.3070
#
# LEFT_HIP: x=0.7381, y=1.8442, z=-0.0322, visibility=0.0024
#
# RIGHT_HIP: x=0.3898, y=1.8364, z=0.0381, visibility=0.0025
#
# LEFT_KNEE: x=0.7031, y=2.5953, z=-0.2997, visibility=0.0165
#
# RIGHT_KNEE: x=0.3786, y=2.5696, z=-0.3195, visibility=0.0061
#
# LEFT_ANKLE: x=0.7003, y=3.3545, z=0.2008, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3747, y=3.3669, z=-0.0774, visibility=0.0003
#
# LEFT_HEEL: x=0.7045, y=3.4606, z=0.2081, visibility=0.0003
#
# RIGHT_HEEL: x=0.3748, y=3.4892, z=-0.0853, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6407, y=3.5986, z=-0.5333, visibility=0.0012
#
# RIGHT_FOOT_INDEX: x=0.4041, y=3.5949, z=-0.8847, visibility=0.0015
#
# NOSE: x=0.5860, y=0.4698, z=-1.3093, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6200, y=0.3928, z=-1.2104, visibility=0.9997
#
# LEFT_EYE: x=0.6407, y=0.3925, z=-1.2105, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6607, y=0.3924, z=-1.2105, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5382, y=0.3969, z=-1.2386, visibility=0.9997
#
# RIGHT_EYE: x=0.5089, y=0.3997, z=-1.2385, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4835, y=0.4027, z=-1.2391, visibility=0.9997
#
# LEFT_EAR: x=0.6856, y=0.4280, z=-0.5838, visibility=0.9997
#
# RIGHT_EAR: x=0.4489, y=0.4420, z=-0.6940, visibility=0.9998
#
# MOUTH_LEFT: x=0.6298, y=0.5534, z=-1.0699, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5378, y=0.5597, z=-1.1084, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8645, y=0.8193, z=-0.1932, visibility=0.9736
#
# RIGHT_SHOULDER: x=0.2962, y=0.8215, z=-0.4110, visibility=0.9716
#
# LEFT_ELBOW: x=1.2068, y=1.0372, z=-0.9992, visibility=0.5701
#
# RIGHT_ELBOW: x=0.0974, y=0.9911, z=-1.2029, visibility=0.3974
#
# LEFT_WRIST: x=1.1752, y=0.5581, z=-1.7921, visibility=0.6051
#
# RIGHT_WRIST: x=0.0347, y=1.0817, z=-2.1647, visibility=0.2671
#
# LEFT_PINKY: x=1.1343, y=0.3366, z=-1.9273, visibility=0.5333
#
# RIGHT_PINKY: x=0.0267, y=1.0689, z=-2.3204, visibility=0.2597
#
# LEFT_INDEX: x=1.0603, y=0.3222, z=-1.8077, visibility=0.5862
#
# RIGHT_INDEX: x=0.1038, y=0.9614, z=-2.2577, visibility=0.3281
#
# LEFT_THUMB: x=1.0386, y=0.3842, z=-1.7777, visibility=0.5420
#
# RIGHT_THUMB: x=0.1107, y=1.0098, z=-2.1761, visibility=0.3030
#
# LEFT_HIP: x=0.7383, y=1.8439, z=-0.0332, visibility=0.0024
#
# RIGHT_HIP: x=0.3895, y=1.8353, z=0.0391, visibility=0.0025
#
# LEFT_KNEE: x=0.7062, y=2.6070, z=-0.3078, visibility=0.0163
#
# RIGHT_KNEE: x=0.3818, y=2.5736, z=-0.3258, visibility=0.0059
#
# LEFT_ANKLE: x=0.7015, y=3.3671, z=0.1978, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3787, y=3.3678, z=-0.0874, visibility=0.0003
#
# LEFT_HEEL: x=0.7063, y=3.4731, z=0.2054, visibility=0.0003
#
# RIGHT_HEEL: x=0.3782, y=3.4902, z=-0.0965, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6404, y=3.6106, z=-0.5603, visibility=0.0012
#
# RIGHT_FOOT_INDEX: x=0.4089, y=3.5958, z=-0.8896, visibility=0.0014
#
# NOSE: x=0.5855, y=0.4698, z=-1.3262, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6198, y=0.3926, z=-1.2243, visibility=0.9997
#
# LEFT_EYE: x=0.6407, y=0.3922, z=-1.2244, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6607, y=0.3918, z=-1.2244, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5380, y=0.3969, z=-1.2462, visibility=0.9997
#
# RIGHT_EYE: x=0.5087, y=0.3997, z=-1.2461, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4834, y=0.4027, z=-1.2466, visibility=0.9997
#
# LEFT_EAR: x=0.6858, y=0.4264, z=-0.5897, visibility=0.9997
#
# RIGHT_EAR: x=0.4489, y=0.4418, z=-0.6895, visibility=0.9998
#
# MOUTH_LEFT: x=0.6297, y=0.5534, z=-1.0841, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5375, y=0.5597, z=-1.1151, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8679, y=0.8206, z=-0.2049, visibility=0.9741
#
# RIGHT_SHOULDER: x=0.2955, y=0.8215, z=-0.4065, visibility=0.9711
#
# LEFT_ELBOW: x=1.2030, y=1.0967, z=-1.0635, visibility=0.5694
#
# RIGHT_ELBOW: x=0.0974, y=0.9953, z=-1.2145, visibility=0.3984
#
# LEFT_WRIST: x=1.1629, y=0.6007, z=-1.9246, visibility=0.6121
#
# RIGHT_WRIST: x=0.0660, y=1.0183, z=-2.2902, visibility=0.2711
#
# LEFT_PINKY: x=1.1346, y=0.4191, z=-2.0698, visibility=0.5399
#
# RIGHT_PINKY: x=0.0673, y=0.9728, z=-2.4771, visibility=0.2609
#
# LEFT_INDEX: x=1.0599, y=0.3436, z=-1.9396, visibility=0.5929
#
# RIGHT_INDEX: x=0.1530, y=0.8827, z=-2.3774, visibility=0.3288
#
# LEFT_THUMB: x=1.0366, y=0.4084, z=-1.9072, visibility=0.5468
#
# RIGHT_THUMB: x=0.1604, y=0.9352, z=-2.2915, visibility=0.3024
#
# LEFT_HIP: x=0.7380, y=1.8471, z=-0.0381, visibility=0.0023
#
# RIGHT_HIP: x=0.3866, y=1.8368, z=0.0441, visibility=0.0024
#
# LEFT_KNEE: x=0.7024, y=2.6098, z=-0.3471, visibility=0.0162
#
# RIGHT_KNEE: x=0.3678, y=2.5737, z=-0.3812, visibility=0.0058
#
# LEFT_ANKLE: x=0.6978, y=3.3693, z=0.1603, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3727, y=3.3679, z=-0.1253, visibility=0.0003
#
# LEFT_HEEL: x=0.7033, y=3.4773, z=0.1655, visibility=0.0003
#
# RIGHT_HEEL: x=0.3744, y=3.4903, z=-0.1330, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6352, y=3.6100, z=-0.6252, visibility=0.0011
#
# RIGHT_FOOT_INDEX: x=0.4011, y=3.5958, z=-0.9569, visibility=0.0014
#
# NOSE: x=0.5852, y=0.4698, z=-1.3271, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6197, y=0.3922, z=-1.2258, visibility=0.9997
#
# LEFT_EYE: x=0.6406, y=0.3916, z=-1.2259, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6607, y=0.3909, z=-1.2259, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5379, y=0.3968, z=-1.2454, visibility=0.9997
#
# RIGHT_EYE: x=0.5085, y=0.3996, z=-1.2452, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4832, y=0.4027, z=-1.2457, visibility=0.9997
#
# LEFT_EAR: x=0.6860, y=0.4250, z=-0.5933, visibility=0.9998
#
# RIGHT_EAR: x=0.4489, y=0.4415, z=-0.6867, visibility=0.9999
#
# MOUTH_LEFT: x=0.6295, y=0.5532, z=-1.0862, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5372, y=0.5597, z=-1.1144, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8693, y=0.8212, z=-0.2110, visibility=0.9743
#
# RIGHT_SHOULDER: x=0.2952, y=0.8212, z=-0.4041, visibility=0.9706
#
# LEFT_ELBOW: x=1.2005, y=1.1081, z=-1.0690, visibility=0.5696
#
# RIGHT_ELBOW: x=0.0975, y=0.9972, z=-1.2026, visibility=0.3983
#
# LEFT_WRIST: x=1.1564, y=0.6035, z=-1.9209, visibility=0.6205
#
# RIGHT_WRIST: x=0.0707, y=1.0079, z=-2.2907, visibility=0.2738
#
# LEFT_PINKY: x=1.1349, y=0.4201, z=-2.0645, visibility=0.5477
#
# RIGHT_PINKY: x=0.0716, y=0.9632, z=-2.4779, visibility=0.2615
#
# LEFT_INDEX: x=1.0593, y=0.3521, z=-1.9363, visibility=0.6003
#
# RIGHT_INDEX: x=0.1428, y=0.8644, z=-2.3825, visibility=0.3290
#
# LEFT_THUMB: x=1.0346, y=0.4178, z=-1.9041, visibility=0.5529
#
# RIGHT_THUMB: x=0.1736, y=0.9106, z=-2.2941, visibility=0.3014
#
# LEFT_HIP: x=0.7375, y=1.8478, z=-0.0397, visibility=0.0023
#
# RIGHT_HIP: x=0.3843, y=1.8369, z=0.0459, visibility=0.0023
#
# LEFT_KNEE: x=0.6995, y=2.6115, z=-0.3589, visibility=0.0160
#
# RIGHT_KNEE: x=0.3640, y=2.5736, z=-0.3795, visibility=0.0056
#
# LEFT_ANKLE: x=0.6953, y=3.3701, z=0.1450, visibility=0.0005
#
# RIGHT_ANKLE: x=0.3682, y=3.3678, z=-0.1267, visibility=0.0003
#
# LEFT_HEEL: x=0.7014, y=3.4788, z=0.1490, visibility=0.0003
#
# RIGHT_HEEL: x=0.3702, y=3.4902, z=-0.1347, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6313, y=3.6095, z=-0.6424, visibility=0.0011
#
# RIGHT_FOOT_INDEX: x=0.3959, y=3.5956, z=-0.9632, visibility=0.0014
#
# NOSE: x=0.5847, y=0.4698, z=-1.3244, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6195, y=0.3922, z=-1.2258, visibility=0.9997
#
# LEFT_EYE: x=0.6405, y=0.3916, z=-1.2261, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6606, y=0.3909, z=-1.2262, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5377, y=0.3967, z=-1.2450, visibility=0.9997
#
# RIGHT_EYE: x=0.5083, y=0.3994, z=-1.2449, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4831, y=0.4024, z=-1.2454, visibility=0.9997
#
# LEFT_EAR: x=0.6861, y=0.4249, z=-0.5930, visibility=0.9998
#
# RIGHT_EAR: x=0.4489, y=0.4411, z=-0.6848, visibility=0.9998
#
# MOUTH_LEFT: x=0.6291, y=0.5533, z=-1.0831, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5366, y=0.5598, z=-1.1110, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8694, y=0.8220, z=-0.1853, visibility=0.9752
#
# RIGHT_SHOULDER: x=0.2948, y=0.8207, z=-0.3651, visibility=0.9715
#
# LEFT_ELBOW: x=1.1993, y=1.1660, z=-0.8306, visibility=0.5611
#
# RIGHT_ELBOW: x=0.0983, y=0.9972, z=-1.0648, visibility=0.4029
#
# LEFT_WRIST: x=1.1855, y=0.9789, z=-1.7375, visibility=0.5987
#
# RIGHT_WRIST: x=0.0845, y=1.0125, z=-2.1614, visibility=0.2769
#
# LEFT_PINKY: x=1.2017, y=0.9255, z=-1.8878, visibility=0.5300
#
# RIGHT_PINKY: x=0.0872, y=0.9897, z=-2.3644, visibility=0.2639
#
# LEFT_INDEX: x=1.1662, y=0.8811, z=-1.8412, visibility=0.5852
#
# RIGHT_INDEX: x=0.1650, y=0.8852, z=-2.2978, visibility=0.3312
#
# LEFT_THUMB: x=1.1377, y=0.9143, z=-1.7522, visibility=0.5374
#
# RIGHT_THUMB: x=0.1813, y=0.9160, z=-2.1723, visibility=0.3030
#
# LEFT_HIP: x=0.7349, y=1.8488, z=-0.0412, visibility=0.0024
#
# RIGHT_HIP: x=0.3793, y=1.8372, z=0.0472, visibility=0.0025
#
# LEFT_KNEE: x=0.6999, y=2.5852, z=-0.4184, visibility=0.0174
#
# RIGHT_KNEE: x=0.3571, y=2.5526, z=-0.5397, visibility=0.0066
#
# LEFT_ANKLE: x=0.6930, y=3.3622, z=0.0330, visibility=0.0006
#
# RIGHT_ANKLE: x=0.3629, y=3.3670, z=-0.3236, visibility=0.0003
#
# LEFT_HEEL: x=0.6972, y=3.4725, z=0.0330, visibility=0.0003
#
# RIGHT_HEEL: x=0.3657, y=3.4899, z=-0.3344, visibility=0.0003
#
# LEFT_FOOT_INDEX: x=0.6291, y=3.6065, z=-0.7376, visibility=0.0012
#
# RIGHT_FOOT_INDEX: x=0.3855, y=3.5958, z=-1.1510, visibility=0.0015
