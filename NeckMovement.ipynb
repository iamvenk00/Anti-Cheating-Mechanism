# %% [markdown]
# # Install and Import Dependencies

# %%
pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.10.21)
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: absl-py in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: jaxlib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.10.5)
# Requirement already satisfied: numpy<2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# video feed
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Camera Feed', frame)
    
    if cv2.waitKey(10) & 0xFF == ord('x'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Make Detections

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Video Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Determining Joints

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            for id, lm in enumerate(landmarks):
                landmark_name = mp_pose.PoseLandmark(id).name   # get landmark name
                print(f"{landmark_name}: "
                      f"x={lm.x:.4f}, y={lm.y:.4f}, z={lm.z:.4f}, visibility={lm.visibility:.4f} \n")

        except:
            pass
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Camera Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# NOSE: x=0.6037, y=0.7065, z=-1.1658, visibility=0.9991
#
# LEFT_EYE_INNER: x=0.6275, y=0.6347, z=-1.1030, visibility=0.9986
#
# LEFT_EYE: x=0.6455, y=0.6333, z=-1.1032, visibility=0.9988
#
# LEFT_EYE_OUTER: x=0.6630, y=0.6325, z=-1.1033, visibility=0.9984
#
# RIGHT_EYE_INNER: x=0.5660, y=0.6393, z=-1.0997, visibility=0.9985
#
# RIGHT_EYE: x=0.5440, y=0.6417, z=-1.0989, visibility=0.9987
#
# RIGHT_EYE_OUTER: x=0.5243, y=0.6448, z=-1.0994, visibility=0.9983
#
# LEFT_EAR: x=0.6951, y=0.6567, z=-0.6242, visibility=0.9986
#
# RIGHT_EAR: x=0.4896, y=0.6774, z=-0.5896, visibility=0.9989
#
# MOUTH_LEFT: x=0.6388, y=0.7764, z=-0.9803, visibility=0.9990
#
# MOUTH_RIGHT: x=0.5663, y=0.7829, z=-0.9710, visibility=0.9992
#
# LEFT_SHOULDER: x=0.8381, y=0.9335, z=-0.3643, visibility=0.9918
#
# RIGHT_SHOULDER: x=0.3682, y=0.9659, z=-0.3237, visibility=0.9931
#
# LEFT_ELBOW: x=0.8900, y=1.0615, z=-0.8553, visibility=0.1471
#
# RIGHT_ELBOW: x=0.3319, y=1.4128, z=-0.5865, visibility=0.1575
#
# LEFT_WRIST: x=0.8333, y=1.2233, z=-1.7913, visibility=0.2582
#
# RIGHT_WRIST: x=0.3840, y=1.6156, z=-1.4727, visibility=0.0934
#
# LEFT_PINKY: x=0.8417, y=1.2463, z=-2.0223, visibility=0.3115
#
# RIGHT_PINKY: x=0.3813, y=1.7220, z=-1.6869, visibility=0.1356
#
# LEFT_INDEX: x=0.8018, y=1.2043, z=-2.0411, visibility=0.3873
#
# RIGHT_INDEX: x=0.4131, y=1.6657, z=-1.7516, visibility=0.1964
#
# LEFT_THUMB: x=0.7862, y=1.2020, z=-1.8363, visibility=0.3553
#
# RIGHT_THUMB: x=0.4227, y=1.6256, z=-1.5297, visibility=0.1812
#
# LEFT_HIP: x=0.7969, y=1.7036, z=-0.0652, visibility=0.0012
#
# RIGHT_HIP: x=0.4775, y=1.7245, z=0.0716, visibility=0.0010
#
# LEFT_KNEE: x=0.8029, y=2.3575, z=0.0247, visibility=0.0003
#
# RIGHT_KNEE: x=0.5007, y=2.3607, z=0.0229, visibility=0.0002
#
# LEFT_ANKLE: x=0.8165, y=2.9391, z=0.6845, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5235, y=2.9500, z=0.5088, visibility=0.0000
#
# LEFT_HEEL: x=0.8238, y=3.0288, z=0.7094, visibility=0.0000
#
# RIGHT_HEEL: x=0.5213, y=3.0429, z=0.5294, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7693, y=3.1317, z=0.0044, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5847, y=3.1294, z=-0.2311, visibility=0.0000
#
# NOSE: x=0.6013, y=0.7063, z=-1.1695, visibility=0.9989
#
# LEFT_EYE_INNER: x=0.6270, y=0.6342, z=-1.1191, visibility=0.9982
#
# LEFT_EYE: x=0.6451, y=0.6330, z=-1.1193, visibility=0.9984
#
# LEFT_EYE_OUTER: x=0.6626, y=0.6325, z=-1.1197, visibility=0.9979
#
# RIGHT_EYE_INNER: x=0.5638, y=0.6390, z=-1.1146, visibility=0.9981
#
# RIGHT_EYE: x=0.5409, y=0.6417, z=-1.1138, visibility=0.9984
#
# RIGHT_EYE_OUTER: x=0.5212, y=0.6448, z=-1.1143, visibility=0.9981
#
# LEFT_EAR: x=0.6951, y=0.6566, z=-0.6757, visibility=0.9982
#
# RIGHT_EAR: x=0.4885, y=0.6768, z=-0.6281, visibility=0.9988
#
# MOUTH_LEFT: x=0.6380, y=0.7764, z=-0.9898, visibility=0.9988
#
# MOUTH_RIGHT: x=0.5633, y=0.7831, z=-0.9778, visibility=0.9991
#
# LEFT_SHOULDER: x=0.8367, y=0.9328, z=-0.3834, visibility=0.9908
#
# RIGHT_SHOULDER: x=0.3652, y=0.9664, z=-0.3349, visibility=0.9932
#
# LEFT_ELBOW: x=0.8846, y=1.0494, z=-0.7067, visibility=0.1388
#
# RIGHT_ELBOW: x=0.3319, y=1.4128, z=-0.5572, visibility=0.1727
#
# LEFT_WRIST: x=0.8533, y=1.3328, z=-1.4321, visibility=0.2345
#
# RIGHT_WRIST: x=0.3798, y=1.6212, z=-1.3850, visibility=0.0930
#
# LEFT_PINKY: x=0.8687, y=1.4013, z=-1.6172, visibility=0.2833
#
# RIGHT_PINKY: x=0.3762, y=1.7250, z=-1.5775, visibility=0.1332
#
# LEFT_INDEX: x=0.8276, y=1.3743, z=-1.6539, visibility=0.3527
#
# RIGHT_INDEX: x=0.4067, y=1.6686, z=-1.6486, visibility=0.1929
#
# LEFT_THUMB: x=0.8097, y=1.3549, z=-1.4773, visibility=0.3240
#
# RIGHT_THUMB: x=0.4189, y=1.6292, z=-1.4382, visibility=0.1776
#
# LEFT_HIP: x=0.7723, y=1.6701, z=-0.0755, visibility=0.0012
#
# RIGHT_HIP: x=0.4693, y=1.6835, z=0.0813, visibility=0.0010
#
# LEFT_KNEE: x=0.7851, y=2.2943, z=-0.0982, visibility=0.0004
#
# RIGHT_KNEE: x=0.4979, y=2.2977, z=0.1285, visibility=0.0003
#
# LEFT_ANKLE: x=0.7896, y=2.8604, z=0.4954, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5127, y=2.8639, z=0.6003, visibility=0.0000
#
# LEFT_HEEL: x=0.7957, y=2.9454, z=0.5139, visibility=0.0000
#
# RIGHT_HEEL: x=0.5074, y=2.9512, z=0.6246, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7406, y=3.0540, z=-0.1808, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5660, y=3.0512, z=-0.0921, visibility=0.0000
#
# NOSE: x=0.6013, y=0.7064, z=-1.1800, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6270, y=0.6339, z=-1.1336, visibility=0.9979
#
# LEFT_EYE: x=0.6452, y=0.6327, z=-1.1339, visibility=0.9981
#
# LEFT_EYE_OUTER: x=0.6627, y=0.6323, z=-1.1344, visibility=0.9976
#
# RIGHT_EYE_INNER: x=0.5637, y=0.6390, z=-1.1343, visibility=0.9979
#
# RIGHT_EYE: x=0.5407, y=0.6417, z=-1.1335, visibility=0.9981
#
# RIGHT_EYE_OUTER: x=0.5209, y=0.6448, z=-1.1339, visibility=0.9979
#
# LEFT_EAR: x=0.6951, y=0.6557, z=-0.6855, visibility=0.9980
#
# RIGHT_EAR: x=0.4882, y=0.6764, z=-0.6650, visibility=0.9986
#
# MOUTH_LEFT: x=0.6382, y=0.7764, z=-0.9989, visibility=0.9987
#
# MOUTH_RIGHT: x=0.5633, y=0.7842, z=-0.9929, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8334, y=0.9318, z=-0.3857, visibility=0.9900
#
# RIGHT_SHOULDER: x=0.3640, y=0.9674, z=-0.3509, visibility=0.9927
#
# LEFT_ELBOW: x=0.8741, y=1.0454, z=-0.5759, visibility=0.1307
#
# RIGHT_ELBOW: x=0.3322, y=1.4128, z=-0.5553, visibility=0.1787
#
# LEFT_WRIST: x=0.8673, y=1.4463, z=-1.1752, visibility=0.2125
#
# RIGHT_WRIST: x=0.3791, y=1.6140, z=-1.3848, visibility=0.0909
#
# LEFT_PINKY: x=0.8867, y=1.5409, z=-1.3405, visibility=0.2571
#
# RIGHT_PINKY: x=0.3753, y=1.7062, z=-1.5756, visibility=0.1291
#
# LEFT_INDEX: x=0.8459, y=1.5236, z=-1.3916, visibility=0.3205
#
# RIGHT_INDEX: x=0.4043, y=1.6511, z=-1.6523, visibility=0.1872
#
# LEFT_THUMB: x=0.8265, y=1.4958, z=-1.2230, visibility=0.2948
#
# RIGHT_THUMB: x=0.4170, y=1.6165, z=-1.4404, visibility=0.1722
#
# LEFT_HIP: x=0.7653, y=1.6603, z=-0.0831, visibility=0.0012
#
# RIGHT_HIP: x=0.4691, y=1.6758, z=0.0883, visibility=0.0010
#
# LEFT_KNEE: x=0.7792, y=2.2790, z=-0.1079, visibility=0.0005
#
# RIGHT_KNEE: x=0.4979, y=2.2861, z=0.1578, visibility=0.0003
#
# LEFT_ANKLE: x=0.7819, y=2.8472, z=0.4705, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5113, y=2.8490, z=0.6009, visibility=0.0000
#
# LEFT_HEEL: x=0.7889, y=2.9326, z=0.4878, visibility=0.0000
#
# RIGHT_HEEL: x=0.5058, y=2.9356, z=0.6246, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7329, y=3.0354, z=-0.1933, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5608, y=3.0329, z=-0.0788, visibility=0.0001
#
# NOSE: x=0.6038, y=0.7071, z=-1.1917, visibility=0.9985
#
# LEFT_EYE_INNER: x=0.6284, y=0.6340, z=-1.1415, visibility=0.9976
#
# LEFT_EYE: x=0.6460, y=0.6328, z=-1.1418, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6630, y=0.6324, z=-1.1422, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.5654, y=0.6393, z=-1.1476, visibility=0.9976
#
# RIGHT_EYE: x=0.5422, y=0.6421, z=-1.1468, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5218, y=0.6455, z=-1.1473, visibility=0.9977
#
# LEFT_EAR: x=0.6945, y=0.6557, z=-0.6815, visibility=0.9978
#
# RIGHT_EAR: x=0.4882, y=0.6765, z=-0.6820, visibility=0.9985
#
# MOUTH_LEFT: x=0.6395, y=0.7765, z=-1.0067, visibility=0.9986
#
# MOUTH_RIGHT: x=0.5655, y=0.7857, z=-1.0077, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8285, y=0.9261, z=-0.3757, visibility=0.9896
#
# RIGHT_SHOULDER: x=0.3620, y=0.9685, z=-0.3725, visibility=0.9926
#
# LEFT_ELBOW: x=0.8728, y=1.0284, z=-0.6744, visibility=0.1266
#
# RIGHT_ELBOW: x=0.3320, y=1.4148, z=-0.5561, visibility=0.1857
#
# LEFT_WRIST: x=0.8640, y=1.3097, z=-1.4438, visibility=0.1967
#
# RIGHT_WRIST: x=0.3642, y=1.6165, z=-1.3481, visibility=0.0901
#
# LEFT_PINKY: x=0.8813, y=1.3685, z=-1.6378, visibility=0.2379
#
# RIGHT_PINKY: x=0.3549, y=1.7066, z=-1.5327, visibility=0.1268
#
# LEFT_INDEX: x=0.8417, y=1.3490, z=-1.6591, visibility=0.2973
#
# RIGHT_INDEX: x=0.3808, y=1.6525, z=-1.6074, visibility=0.1842
#
# LEFT_THUMB: x=0.8223, y=1.3353, z=-1.4854, visibility=0.2739
#
# RIGHT_THUMB: x=0.3963, y=1.6177, z=-1.4019, visibility=0.1691
#
# LEFT_HIP: x=0.7676, y=1.6595, z=-0.0752, visibility=0.0012
#
# RIGHT_HIP: x=0.4692, y=1.6778, z=0.0804, visibility=0.0010
#
# LEFT_KNEE: x=0.7808, y=2.2788, z=-0.0990, visibility=0.0006
#
# RIGHT_KNEE: x=0.4993, y=2.2848, z=-0.0106, visibility=0.0004
#
# LEFT_ANKLE: x=0.7839, y=2.8429, z=0.4609, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5149, y=2.8476, z=0.3546, visibility=0.0000
#
# LEFT_HEEL: x=0.7909, y=2.9292, z=0.4753, visibility=0.0000
#
# RIGHT_HEEL: x=0.5092, y=2.9355, z=0.3665, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7344, y=3.0321, z=-0.2031, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5676, y=3.0304, z=-0.3471, visibility=0.0001
#
# NOSE: x=0.6041, y=0.7072, z=-1.1722, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6284, y=0.6336, z=-1.1263, visibility=0.9973
#
# LEFT_EYE: x=0.6460, y=0.6322, z=-1.1266, visibility=0.9975
#
# LEFT_EYE_OUTER: x=0.6629, y=0.6318, z=-1.1271, visibility=0.9968
#
# RIGHT_EYE_INNER: x=0.5655, y=0.6393, z=-1.1378, visibility=0.9973
#
# RIGHT_EYE: x=0.5422, y=0.6421, z=-1.1370, visibility=0.9977
#
# RIGHT_EYE_OUTER: x=0.5219, y=0.6455, z=-1.1373, visibility=0.9974
#
# LEFT_EAR: x=0.6934, y=0.6539, z=-0.6770, visibility=0.9975
#
# RIGHT_EAR: x=0.4879, y=0.6765, z=-0.6693, visibility=0.9983
#
# MOUTH_LEFT: x=0.6397, y=0.7764, z=-0.9912, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5656, y=0.7870, z=-0.9967, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8258, y=0.9237, z=-0.3670, visibility=0.9890
#
# RIGHT_SHOULDER: x=0.3619, y=0.9692, z=-0.3687, visibility=0.9922
#
# LEFT_ELBOW: x=0.8734, y=1.0300, z=-0.6030, visibility=0.1209
#
# RIGHT_ELBOW: x=0.3354, y=1.4164, z=-0.5447, visibility=0.1872
#
# LEFT_WRIST: x=0.8670, y=1.3253, z=-1.2291, visibility=0.1802
#
# RIGHT_WRIST: x=0.3696, y=1.6117, z=-1.3250, visibility=0.0881
#
# LEFT_PINKY: x=0.8818, y=1.3874, z=-1.3970, visibility=0.2182
#
# RIGHT_PINKY: x=0.3620, y=1.6981, z=-1.5050, visibility=0.1235
#
# LEFT_INDEX: x=0.8408, y=1.3648, z=-1.4208, visibility=0.2732
#
# RIGHT_INDEX: x=0.3832, y=1.6426, z=-1.5778, visibility=0.1797
#
# LEFT_THUMB: x=0.8230, y=1.3491, z=-1.2669, visibility=0.2525
#
# RIGHT_THUMB: x=0.3991, y=1.6078, z=-1.3782, visibility=0.1648
#
# LEFT_HIP: x=0.7682, y=1.6596, z=-0.0750, visibility=0.0012
#
# RIGHT_HIP: x=0.4693, y=1.6796, z=0.0803, visibility=0.0010
#
# LEFT_KNEE: x=0.7817, y=2.2791, z=-0.1048, visibility=0.0007
#
# RIGHT_KNEE: x=0.5001, y=2.2880, z=0.0144, visibility=0.0005
#
# LEFT_ANKLE: x=0.7864, y=2.8456, z=0.4519, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5151, y=2.8523, z=0.4174, visibility=0.0000
#
# LEFT_HEEL: x=0.7933, y=2.9311, z=0.4680, visibility=0.0001
#
# RIGHT_HEEL: x=0.5093, y=2.9404, z=0.4338, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7377, y=3.0369, z=-0.1984, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5683, y=3.0343, z=-0.3004, visibility=0.0001
#
# NOSE: x=0.6041, y=0.7073, z=-1.1851, visibility=0.9979
#
# LEFT_EYE_INNER: x=0.6284, y=0.6332, z=-1.1406, visibility=0.9970
#
# LEFT_EYE: x=0.6460, y=0.6318, z=-1.1409, visibility=0.9973
#
# LEFT_EYE_OUTER: x=0.6628, y=0.6313, z=-1.1415, visibility=0.9964
#
# RIGHT_EYE_INNER: x=0.5653, y=0.6391, z=-1.1497, visibility=0.9970
#
# RIGHT_EYE: x=0.5418, y=0.6421, z=-1.1489, visibility=0.9974
#
# RIGHT_EYE_OUTER: x=0.5213, y=0.6455, z=-1.1493, visibility=0.9971
#
# LEFT_EAR: x=0.6931, y=0.6524, z=-0.6933, visibility=0.9973
#
# RIGHT_EAR: x=0.4872, y=0.6763, z=-0.6943, visibility=0.9981
#
# MOUTH_LEFT: x=0.6397, y=0.7764, z=-1.0040, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5653, y=0.7878, z=-1.0081, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8246, y=0.9231, z=-0.3781, visibility=0.9882
#
# RIGHT_SHOULDER: x=0.3620, y=0.9692, z=-0.3755, visibility=0.9914
#
# LEFT_ELBOW: x=0.8737, y=1.0307, z=-0.5428, visibility=0.1148
#
# RIGHT_ELBOW: x=0.3372, y=1.4174, z=-0.5221, visibility=0.1862
#
# LEFT_WRIST: x=0.8773, y=1.4063, z=-1.0967, visibility=0.1643
#
# RIGHT_WRIST: x=0.3739, y=1.6061, z=-1.2942, visibility=0.0853
#
# LEFT_PINKY: x=0.8947, y=1.4914, z=-1.2515, visibility=0.1991
#
# RIGHT_PINKY: x=0.3689, y=1.6892, z=-1.4695, visibility=0.1192
#
# LEFT_INDEX: x=0.8526, y=1.4715, z=-1.2946, visibility=0.2498
#
# RIGHT_INDEX: x=0.3866, y=1.6327, z=-1.5455, visibility=0.1740
#
# LEFT_THUMB: x=0.8344, y=1.4469, z=-1.1393, visibility=0.2316
#
# RIGHT_THUMB: x=0.4018, y=1.5987, z=-1.3477, visibility=0.1593
#
# LEFT_HIP: x=0.7685, y=1.6594, z=-0.0769, visibility=0.0012
#
# RIGHT_HIP: x=0.4694, y=1.6799, z=0.0820, visibility=0.0010
#
# LEFT_KNEE: x=0.7819, y=2.2795, z=-0.1364, visibility=0.0007
#
# RIGHT_KNEE: x=0.5004, y=2.2905, z=0.1119, visibility=0.0005
#
# LEFT_ANKLE: x=0.7868, y=2.8486, z=0.4059, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5152, y=2.8548, z=0.5095, visibility=0.0000
#
# LEFT_HEEL: x=0.7935, y=2.9346, z=0.4210, visibility=0.0001
#
# RIGHT_HEEL: x=0.5096, y=2.9425, z=0.5291, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7394, y=3.0399, z=-0.2510, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5672, y=3.0374, z=-0.1595, visibility=0.0001
#
# NOSE: x=0.6026, y=0.7088, z=-1.2203, visibility=0.9980
#
# LEFT_EYE_INNER: x=0.6276, y=0.6339, z=-1.1687, visibility=0.9970
#
# LEFT_EYE: x=0.6454, y=0.6322, z=-1.1690, visibility=0.9973
#
# LEFT_EYE_OUTER: x=0.6624, y=0.6315, z=-1.1694, visibility=0.9965
#
# RIGHT_EYE_INNER: x=0.5625, y=0.6404, z=-1.1737, visibility=0.9971
#
# RIGHT_EYE: x=0.5388, y=0.6435, z=-1.1729, visibility=0.9975
#
# RIGHT_EYE_OUTER: x=0.5185, y=0.6470, z=-1.1733, visibility=0.9972
#
# LEFT_EAR: x=0.6930, y=0.6523, z=-0.7009, visibility=0.9973
#
# RIGHT_EAR: x=0.4858, y=0.6767, z=-0.6932, visibility=0.9982
#
# MOUTH_LEFT: x=0.6393, y=0.7771, z=-1.0327, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5635, y=0.7900, z=-1.0325, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8263, y=0.9245, z=-0.3836, visibility=0.9877
#
# RIGHT_SHOULDER: x=0.3612, y=0.9726, z=-0.3855, visibility=0.9912
#
# LEFT_ELBOW: x=0.8731, y=1.0292, z=-0.6313, visibility=0.1100
#
# RIGHT_ELBOW: x=0.3370, y=1.4185, z=-0.6149, visibility=0.1896
#
# LEFT_WRIST: x=0.8755, y=1.3746, z=-1.3351, visibility=0.1505
#
# RIGHT_WRIST: x=0.3748, y=1.5841, z=-1.5032, visibility=0.0848
#
# LEFT_PINKY: x=0.8908, y=1.4416, z=-1.4922, visibility=0.1827
#
# RIGHT_PINKY: x=0.3723, y=1.6647, z=-1.7023, visibility=0.1182
#
# LEFT_INDEX: x=0.8485, y=1.4158, z=-1.5158, visibility=0.2298
#
# RIGHT_INDEX: x=0.3888, y=1.5997, z=-1.7577, visibility=0.1726
#
# LEFT_THUMB: x=0.8310, y=1.3982, z=-1.3734, visibility=0.2135
#
# RIGHT_THUMB: x=0.4026, y=1.5680, z=-1.5520, visibility=0.1575
#
# LEFT_HIP: x=0.7693, y=1.6610, z=-0.0767, visibility=0.0012
#
# RIGHT_HIP: x=0.4684, y=1.6810, z=0.0819, visibility=0.0009
#
# LEFT_KNEE: x=0.7824, y=2.2835, z=-0.1208, visibility=0.0007
#
# RIGHT_KNEE: x=0.5002, y=2.2912, z=0.0991, visibility=0.0005
#
# LEFT_ANKLE: x=0.7880, y=2.8509, z=0.4560, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5129, y=2.8526, z=0.5304, visibility=0.0000
#
# LEFT_HEEL: x=0.7948, y=2.9374, z=0.4724, visibility=0.0001
#
# RIGHT_HEEL: x=0.5068, y=2.9397, z=0.5513, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7408, y=3.0417, z=-0.2260, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5668, y=3.0375, z=-0.1658, visibility=0.0001
#
# NOSE: x=0.6025, y=0.7089, z=-1.2293, visibility=0.9979
#
# LEFT_EYE_INNER: x=0.6276, y=0.6341, z=-1.1751, visibility=0.9969
#
# LEFT_EYE: x=0.6455, y=0.6324, z=-1.1755, visibility=0.9972
#
# LEFT_EYE_OUTER: x=0.6625, y=0.6317, z=-1.1759, visibility=0.9964
#
# RIGHT_EYE_INNER: x=0.5624, y=0.6405, z=-1.1792, visibility=0.9970
#
# RIGHT_EYE: x=0.5386, y=0.6435, z=-1.1785, visibility=0.9974
#
# RIGHT_EYE_OUTER: x=0.5183, y=0.6470, z=-1.1789, visibility=0.9971
#
# LEFT_EAR: x=0.6930, y=0.6524, z=-0.7027, visibility=0.9972
#
# RIGHT_EAR: x=0.4854, y=0.6767, z=-0.6941, visibility=0.9980
#
# MOUTH_LEFT: x=0.6393, y=0.7772, z=-1.0410, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5633, y=0.7901, z=-1.0398, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8259, y=0.9246, z=-0.3873, visibility=0.9871
#
# RIGHT_SHOULDER: x=0.3610, y=0.9742, z=-0.3808, visibility=0.9907
#
# LEFT_ELBOW: x=0.8733, y=1.0299, z=-0.6055, visibility=0.1039
#
# RIGHT_ELBOW: x=0.3415, y=1.4190, z=-0.5557, visibility=0.1900
#
# LEFT_WRIST: x=0.8775, y=1.4230, z=-1.2713, visibility=0.1367
#
# RIGHT_WRIST: x=0.3853, y=1.5862, z=-1.3607, visibility=0.0815
#
# LEFT_PINKY: x=0.8948, y=1.5088, z=-1.4427, visibility=0.1662
#
# RIGHT_PINKY: x=0.3856, y=1.6693, z=-1.5465, visibility=0.1134
#
# LEFT_INDEX: x=0.8520, y=1.4880, z=-1.4915, visibility=0.2094
#
# RIGHT_INDEX: x=0.4017, y=1.6071, z=-1.6178, visibility=0.1661
#
# LEFT_THUMB: x=0.8344, y=1.4619, z=-1.3201, visibility=0.1948
#
# RIGHT_THUMB: x=0.4131, y=1.5740, z=-1.4133, visibility=0.1513
#
# LEFT_HIP: x=0.7681, y=1.6588, z=-0.0788, visibility=0.0012
#
# RIGHT_HIP: x=0.4685, y=1.6785, z=0.0841, visibility=0.0009
#
# LEFT_KNEE: x=0.7824, y=2.2789, z=-0.1848, visibility=0.0008
#
# RIGHT_KNEE: x=0.5008, y=2.2876, z=0.1040, visibility=0.0006
#
# LEFT_ANKLE: x=0.7882, y=2.8467, z=0.3541, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5130, y=2.8500, z=0.5248, visibility=0.0000
#
# LEFT_HEEL: x=0.7950, y=2.9332, z=0.3666, visibility=0.0001
#
# RIGHT_HEEL: x=0.5068, y=2.9376, z=0.5417, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7411, y=3.0342, z=-0.3389, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5667, y=3.0320, z=-0.1678, visibility=0.0001
#
# NOSE: x=0.6019, y=0.7093, z=-1.2313, visibility=0.9978
#
# LEFT_EYE_INNER: x=0.6271, y=0.6344, z=-1.1773, visibility=0.9968
#
# LEFT_EYE: x=0.6451, y=0.6326, z=-1.1776, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.6621, y=0.6319, z=-1.1781, visibility=0.9963
#
# RIGHT_EYE_INNER: x=0.5617, y=0.6407, z=-1.1810, visibility=0.9969
#
# RIGHT_EYE: x=0.5380, y=0.6436, z=-1.1802, visibility=0.9973
#
# RIGHT_EYE_OUTER: x=0.5177, y=0.6471, z=-1.1806, visibility=0.9971
#
# LEFT_EAR: x=0.6926, y=0.6523, z=-0.7067, visibility=0.9971
#
# RIGHT_EAR: x=0.4850, y=0.6767, z=-0.6976, visibility=0.9980
#
# MOUTH_LEFT: x=0.6389, y=0.7773, z=-1.0441, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5624, y=0.7903, z=-1.0423, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8258, y=0.9248, z=-0.3906, visibility=0.9867
#
# RIGHT_SHOULDER: x=0.3606, y=0.9747, z=-0.3802, visibility=0.9904
#
# LEFT_ELBOW: x=0.8734, y=1.0303, z=-0.5799, visibility=0.0988
#
# RIGHT_ELBOW: x=0.3424, y=1.4191, z=-0.5318, visibility=0.1926
#
# LEFT_WRIST: x=0.8801, y=1.4378, z=-1.2134, visibility=0.1243
#
# RIGHT_WRIST: x=0.3875, y=1.5876, z=-1.3135, visibility=0.0791
#
# LEFT_PINKY: x=0.8988, y=1.5263, z=-1.3799, visibility=0.1513
#
# RIGHT_PINKY: x=0.3883, y=1.6725, z=-1.4962, visibility=0.1095
#
# LEFT_INDEX: x=0.8563, y=1.5073, z=-1.4321, visibility=0.1910
#
# RIGHT_INDEX: x=0.4049, y=1.6115, z=-1.5716, visibility=0.1609
#
# LEFT_THUMB: x=0.8382, y=1.4801, z=-1.2628, visibility=0.1780
#
# RIGHT_THUMB: x=0.4156, y=1.5777, z=-1.3674, visibility=0.1463
#
# LEFT_HIP: x=0.7662, y=1.6562, z=-0.0797, visibility=0.0012
#
# RIGHT_HIP: x=0.4682, y=1.6750, z=0.0849, visibility=0.0009
#
# LEFT_KNEE: x=0.7813, y=2.2754, z=-0.1916, visibility=0.0008
#
# RIGHT_KNEE: x=0.5008, y=2.2838, z=0.1067, visibility=0.0006
#
# LEFT_ANKLE: x=0.7868, y=2.8433, z=0.3490, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5120, y=2.8462, z=0.5238, visibility=0.0000
#
# LEFT_HEEL: x=0.7935, y=2.9298, z=0.3616, visibility=0.0001
#
# RIGHT_HEEL: x=0.5053, y=2.9338, z=0.5390, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7397, y=3.0295, z=-0.3437, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5649, y=3.0270, z=-0.1706, visibility=0.0001
#
# NOSE: x=0.6017, y=0.7094, z=-1.1158, visibility=0.9977
#
# LEFT_EYE_INNER: x=0.6271, y=0.6344, z=-1.0659, visibility=0.9969
#
# LEFT_EYE: x=0.6451, y=0.6327, z=-1.0662, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.6622, y=0.6319, z=-1.0666, visibility=0.9963
#
# RIGHT_EYE_INNER: x=0.5612, y=0.6406, z=-1.0659, visibility=0.9969
#
# RIGHT_EYE: x=0.5373, y=0.6436, z=-1.0650, visibility=0.9973
#
# RIGHT_EYE_OUTER: x=0.5170, y=0.6471, z=-1.0654, visibility=0.9971
#
# LEFT_EAR: x=0.6928, y=0.6521, z=-0.6241, visibility=0.9972
#
# RIGHT_EAR: x=0.4844, y=0.6764, z=-0.5991, visibility=0.9980
#
# MOUTH_LEFT: x=0.6390, y=0.7775, z=-0.9405, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5621, y=0.7907, z=-0.9345, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8267, y=0.9243, z=-0.3552, visibility=0.9860
#
# RIGHT_SHOULDER: x=0.3600, y=0.9745, z=-0.3044, visibility=0.9903
#
# LEFT_ELBOW: x=0.8728, y=1.0273, z=-0.6781, visibility=0.0987
#
# RIGHT_ELBOW: x=0.3406, y=1.4135, z=-0.5378, visibility=0.1980
#
# LEFT_WRIST: x=0.8671, y=1.2492, z=-1.3887, visibility=0.1187
#
# RIGHT_WRIST: x=0.3875, y=1.5694, z=-1.4128, visibility=0.0805
#
# LEFT_PINKY: x=0.8748, y=1.2855, z=-1.5508, visibility=0.1441
#
# RIGHT_PINKY: x=0.3889, y=1.6547, z=-1.5909, visibility=0.1107
#
# LEFT_INDEX: x=0.8370, y=1.2497, z=-1.4855, visibility=0.1820
#
# RIGHT_INDEX: x=0.4066, y=1.5860, z=-1.6245, visibility=0.1615
#
# LEFT_THUMB: x=0.8211, y=1.2451, z=-1.4030, visibility=0.1704
#
# RIGHT_THUMB: x=0.4170, y=1.5529, z=-1.4522, visibility=0.1466
#
# LEFT_HIP: x=0.7664, y=1.6533, z=-0.0816, visibility=0.0012
#
# RIGHT_HIP: x=0.4680, y=1.6713, z=0.0868, visibility=0.0010
#
# LEFT_KNEE: x=0.7812, y=2.2700, z=-0.1895, visibility=0.0009
#
# RIGHT_KNEE: x=0.5003, y=2.2768, z=0.1651, visibility=0.0007
#
# LEFT_ANKLE: x=0.7868, y=2.8304, z=0.3313, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5114, y=2.8329, z=0.6196, visibility=0.0000
#
# LEFT_HEEL: x=0.7933, y=2.9128, z=0.3427, visibility=0.0001
#
# RIGHT_HEEL: x=0.5044, y=2.9167, z=0.6426, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7401, y=3.0226, z=-0.3493, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5651, y=3.0207, z=-0.0511, visibility=0.0001
#
# NOSE: x=0.6015, y=0.7098, z=-1.1028, visibility=0.9977
#
# LEFT_EYE_INNER: x=0.6269, y=0.6346, z=-1.0547, visibility=0.9969
#
# LEFT_EYE: x=0.6449, y=0.6328, z=-1.0549, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.6619, y=0.6321, z=-1.0551, visibility=0.9963
#
# RIGHT_EYE_INNER: x=0.5605, y=0.6409, z=-1.0566, visibility=0.9969
#
# RIGHT_EYE: x=0.5364, y=0.6440, z=-1.0557, visibility=0.9973
#
# RIGHT_EYE_OUTER: x=0.5160, y=0.6477, z=-1.0560, visibility=0.9971
#
# LEFT_EAR: x=0.6928, y=0.6520, z=-0.6244, visibility=0.9971
#
# RIGHT_EAR: x=0.4836, y=0.6768, z=-0.6054, visibility=0.9980
#
# MOUTH_LEFT: x=0.6389, y=0.7776, z=-0.9316, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5620, y=0.7917, z=-0.9276, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8275, y=0.9244, z=-0.3563, visibility=0.9850
#
# RIGHT_SHOULDER: x=0.3596, y=0.9745, z=-0.3157, visibility=0.9898
#
# LEFT_ELBOW: x=0.8726, y=1.0270, z=-0.6940, visibility=0.0962
#
# RIGHT_ELBOW: x=0.3405, y=1.4124, z=-0.5403, visibility=0.1969
#
# LEFT_WRIST: x=0.8442, y=1.1970, z=-1.3790, visibility=0.1135
#
# RIGHT_WRIST: x=0.3877, y=1.5629, z=-1.3383, visibility=0.0802
#
# LEFT_PINKY: x=0.8449, y=1.2201, z=-1.5429, visibility=0.1380
#
# RIGHT_PINKY: x=0.3891, y=1.6459, z=-1.5047, visibility=0.1104
#
# LEFT_INDEX: x=0.8115, y=1.1816, z=-1.5168, visibility=0.1747
#
# RIGHT_INDEX: x=0.4069, y=1.5777, z=-1.5473, visibility=0.1611
#
# LEFT_THUMB: x=0.7980, y=1.1822, z=-1.3980, visibility=0.1647
#
# RIGHT_THUMB: x=0.4173, y=1.5454, z=-1.3792, visibility=0.1467
#
# LEFT_HIP: x=0.7660, y=1.6521, z=-0.0814, visibility=0.0012
#
# RIGHT_HIP: x=0.4667, y=1.6708, z=0.0867, visibility=0.0010
#
# LEFT_KNEE: x=0.7809, y=2.2687, z=-0.1570, visibility=0.0009
#
# RIGHT_KNEE: x=0.5005, y=2.2764, z=0.1571, visibility=0.0007
#
# LEFT_ANKLE: x=0.7871, y=2.8286, z=0.3985, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5135, y=2.8300, z=0.5908, visibility=0.0000
#
# LEFT_HEEL: x=0.7935, y=2.9108, z=0.4157, visibility=0.0001
#
# RIGHT_HEEL: x=0.5072, y=2.9126, z=0.6175, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7402, y=3.0204, z=-0.2362, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5670, y=3.0172, z=-0.0928, visibility=0.0001
#
# NOSE: x=0.6015, y=0.7105, z=-1.1213, visibility=0.9977
#
# LEFT_EYE_INNER: x=0.6268, y=0.6348, z=-1.0719, visibility=0.9969
#
# LEFT_EYE: x=0.6448, y=0.6330, z=-1.0721, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.6618, y=0.6322, z=-1.0724, visibility=0.9964
#
# RIGHT_EYE_INNER: x=0.5602, y=0.6414, z=-1.0744, visibility=0.9970
#
# RIGHT_EYE: x=0.5359, y=0.6447, z=-1.0735, visibility=0.9973
#
# RIGHT_EYE_OUTER: x=0.5154, y=0.6486, z=-1.0738, visibility=0.9971
#
# LEFT_EAR: x=0.6928, y=0.6519, z=-0.6312, visibility=0.9972
#
# RIGHT_EAR: x=0.4829, y=0.6777, z=-0.6061, visibility=0.9980
#
# MOUTH_LEFT: x=0.6389, y=0.7778, z=-0.9464, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5619, y=0.7931, z=-0.9431, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8282, y=0.9250, z=-0.3565, visibility=0.9844
#
# RIGHT_SHOULDER: x=0.3583, y=0.9747, z=-0.3322, visibility=0.9894
#
# LEFT_ELBOW: x=0.8725, y=1.0269, z=-0.6937, visibility=0.0935
#
# RIGHT_ELBOW: x=0.3404, y=1.4122, z=-0.5661, visibility=0.1962
#
# LEFT_WRIST: x=0.8407, y=1.2111, z=-1.3424, visibility=0.1074
#
# RIGHT_WRIST: x=0.3913, y=1.5429, z=-1.3396, visibility=0.0806
#
# LEFT_PINKY: x=0.8413, y=1.2406, z=-1.5051, visibility=0.1309
#
# RIGHT_PINKY: x=0.3950, y=1.6173, z=-1.5220, visibility=0.1107
#
# LEFT_INDEX: x=0.8079, y=1.2015, z=-1.4921, visibility=0.1662
#
# RIGHT_INDEX: x=0.4116, y=1.5469, z=-1.5748, visibility=0.1613
#
# LEFT_THUMB: x=0.7949, y=1.1991, z=-1.3650, visibility=0.1576
#
# RIGHT_THUMB: x=0.4210, y=1.5177, z=-1.3897, visibility=0.1471
#
# LEFT_HIP: x=0.7655, y=1.6499, z=-0.0813, visibility=0.0012
#
# RIGHT_HIP: x=0.4652, y=1.6697, z=0.0866, visibility=0.0009
#
# LEFT_KNEE: x=0.7804, y=2.2667, z=-0.1499, visibility=0.0009
#
# RIGHT_KNEE: x=0.5005, y=2.2755, z=0.1465, visibility=0.0007
#
# LEFT_ANKLE: x=0.7873, y=2.8273, z=0.4093, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5141, y=2.8276, z=0.5826, visibility=0.0000
#
# LEFT_HEEL: x=0.7937, y=2.9095, z=0.4272, visibility=0.0001
#
# RIGHT_HEEL: x=0.5080, y=2.9090, z=0.6068, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7406, y=3.0180, z=-0.2245, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5676, y=3.0144, z=-0.0962, visibility=0.0001
#
# NOSE: x=0.6015, y=0.7110, z=-1.0605, visibility=0.9979
#
# LEFT_EYE_INNER: x=0.6268, y=0.6351, z=-1.0036, visibility=0.9971
#
# LEFT_EYE: x=0.6447, y=0.6332, z=-1.0038, visibility=0.9973
#
# LEFT_EYE_OUTER: x=0.6618, y=0.6324, z=-1.0038, visibility=0.9966
#
# RIGHT_EYE_INNER: x=0.5602, y=0.6419, z=-1.0091, visibility=0.9972
#
# RIGHT_EYE: x=0.5359, y=0.6455, z=-1.0080, visibility=0.9975
#
# RIGHT_EYE_OUTER: x=0.5153, y=0.6496, z=-1.0084, visibility=0.9973
#
# LEFT_EAR: x=0.6927, y=0.6519, z=-0.5664, visibility=0.9974
#
# RIGHT_EAR: x=0.4826, y=0.6786, z=-0.5614, visibility=0.9982
#
# MOUTH_LEFT: x=0.6390, y=0.7780, z=-0.8896, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5619, y=0.7940, z=-0.8908, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8290, y=0.9265, z=-0.3250, visibility=0.9851
#
# RIGHT_SHOULDER: x=0.3571, y=0.9797, z=-0.3331, visibility=0.9900
#
# LEFT_ELBOW: x=0.8770, y=1.0387, z=-0.7991, visibility=0.0942
#
# RIGHT_ELBOW: x=0.3404, y=1.4231, z=-0.5616, visibility=0.1975
#
# LEFT_WRIST: x=0.8322, y=1.1826, z=-1.6287, visibility=0.1070
#
# RIGHT_WRIST: x=0.3846, y=1.6296, z=-1.2676, visibility=0.0809
#
# LEFT_PINKY: x=0.8301, y=1.1960, z=-1.8153, visibility=0.1308
#
# RIGHT_PINKY: x=0.3805, y=1.7340, z=-1.4338, visibility=0.1125
#
# LEFT_INDEX: x=0.7966, y=1.1527, z=-1.7860, visibility=0.1667
#
# RIGHT_INDEX: x=0.4042, y=1.6766, z=-1.4840, visibility=0.1642
#
# LEFT_THUMB: x=0.7837, y=1.1572, z=-1.6520, visibility=0.1581
#
# RIGHT_THUMB: x=0.4166, y=1.6368, z=-1.3126, visibility=0.1498
#
# LEFT_HIP: x=0.7665, y=1.6545, z=-0.0782, visibility=0.0012
#
# RIGHT_HIP: x=0.4626, y=1.6734, z=0.0840, visibility=0.0009
#
# LEFT_KNEE: x=0.7809, y=2.2754, z=-0.1474, visibility=0.0008
#
# RIGHT_KNEE: x=0.5005, y=2.2815, z=0.0341, visibility=0.0006
#
# LEFT_ANKLE: x=0.7943, y=2.8299, z=0.4390, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5177, y=2.8287, z=0.4346, visibility=0.0000
#
# LEFT_HEEL: x=0.8027, y=2.9147, z=0.4569, visibility=0.0001
#
# RIGHT_HEEL: x=0.5129, y=2.9113, z=0.4498, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7469, y=3.0204, z=-0.2173, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5762, y=3.0178, z=-0.2696, visibility=0.0001
#
# NOSE: x=0.6041, y=0.7119, z=-1.1002, visibility=0.9980
#
# LEFT_EYE_INNER: x=0.6288, y=0.6353, z=-1.0365, visibility=0.9973
#
# LEFT_EYE: x=0.6463, y=0.6334, z=-1.0365, visibility=0.9975
#
# LEFT_EYE_OUTER: x=0.6635, y=0.6325, z=-1.0360, visibility=0.9968
#
# RIGHT_EYE_INNER: x=0.5625, y=0.6420, z=-1.0487, visibility=0.9974
#
# RIGHT_EYE: x=0.5373, y=0.6455, z=-1.0476, visibility=0.9976
#
# RIGHT_EYE_OUTER: x=0.5159, y=0.6496, z=-1.0478, visibility=0.9975
#
# LEFT_EAR: x=0.6934, y=0.6520, z=-0.5896, visibility=0.9975
#
# RIGHT_EAR: x=0.4826, y=0.6787, z=-0.6116, visibility=0.9983
#
# MOUTH_LEFT: x=0.6404, y=0.7790, z=-0.9264, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5635, y=0.7952, z=-0.9361, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8292, y=0.9272, z=-0.3657, visibility=0.9841
#
# RIGHT_SHOULDER: x=0.3536, y=0.9819, z=-0.3592, visibility=0.9893
#
# LEFT_ELBOW: x=0.8778, y=1.0459, z=-0.8807, visibility=0.0960
#
# RIGHT_ELBOW: x=0.3366, y=1.4252, z=-0.6535, visibility=0.1922
#
# LEFT_WRIST: x=0.8135, y=1.0454, z=-1.6589, visibility=0.1244
#
# RIGHT_WRIST: x=0.3846, y=1.5469, z=-1.4527, visibility=0.0833
#
# LEFT_PINKY: x=0.8128, y=1.1006, z=-1.8331, visibility=0.1484
#
# RIGHT_PINKY: x=0.3837, y=1.6153, z=-1.6171, visibility=0.1166
#
# LEFT_INDEX: x=0.7887, y=1.0515, z=-1.7895, visibility=0.1852
#
# RIGHT_INDEX: x=0.4043, y=1.5377, z=-1.6267, visibility=0.1690
#
# LEFT_THUMB: x=0.7737, y=1.0683, z=-1.6728, visibility=0.1763
#
# RIGHT_THUMB: x=0.4166, y=1.5118, z=-1.4839, visibility=0.1538
#
# LEFT_HIP: x=0.7665, y=1.6547, z=-0.0804, visibility=0.0012
#
# RIGHT_HIP: x=0.4569, y=1.6737, z=0.0862, visibility=0.0009
#
# LEFT_KNEE: x=0.7804, y=2.2757, z=-0.1064, visibility=0.0008
#
# RIGHT_KNEE: x=0.4989, y=2.2820, z=0.1516, visibility=0.0006
#
# LEFT_ANKLE: x=0.7942, y=2.8315, z=0.5526, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5178, y=2.8307, z=0.7130, visibility=0.0000
#
# LEFT_HEEL: x=0.8023, y=2.9156, z=0.5767, visibility=0.0001
#
# RIGHT_HEEL: x=0.5132, y=2.9131, z=0.7466, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7480, y=3.0224, z=-0.1144, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5762, y=3.0196, z=0.0319, visibility=0.0001
#
# NOSE: x=0.6058, y=0.7128, z=-1.1424, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6300, y=0.6354, z=-1.0798, visibility=0.9975
#
# LEFT_EYE: x=0.6473, y=0.6335, z=-1.0799, visibility=0.9976
#
# LEFT_EYE_OUTER: x=0.6645, y=0.6326, z=-1.0796, visibility=0.9970
#
# RIGHT_EYE_INNER: x=0.5639, y=0.6421, z=-1.0921, visibility=0.9975
#
# RIGHT_EYE: x=0.5383, y=0.6456, z=-1.0911, visibility=0.9978
#
# RIGHT_EYE_OUTER: x=0.5164, y=0.6497, z=-1.0913, visibility=0.9976
#
# LEFT_EAR: x=0.6939, y=0.6521, z=-0.6221, visibility=0.9977
#
# RIGHT_EAR: x=0.4825, y=0.6787, z=-0.6469, visibility=0.9984
#
# MOUTH_LEFT: x=0.6414, y=0.7798, z=-0.9635, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5646, y=0.7962, z=-0.9733, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8296, y=0.9277, z=-0.3830, visibility=0.9832
#
# RIGHT_SHOULDER: x=0.3511, y=0.9835, z=-0.3764, visibility=0.9887
#
# LEFT_ELBOW: x=0.8782, y=1.0503, z=-0.8788, visibility=0.0972
#
# RIGHT_ELBOW: x=0.3341, y=1.4274, z=-0.6854, visibility=0.1892
#
# LEFT_WRIST: x=0.8068, y=1.0325, z=-1.6533, visibility=0.1371
#
# RIGHT_WRIST: x=0.3851, y=1.5128, z=-1.5128, visibility=0.0866
#
# LEFT_PINKY: x=0.8113, y=1.1067, z=-1.8261, visibility=0.1612
#
# RIGHT_PINKY: x=0.3874, y=1.5717, z=-1.6826, visibility=0.1211
#
# LEFT_INDEX: x=0.7883, y=1.0579, z=-1.7847, visibility=0.1987
#
# RIGHT_INDEX: x=0.4047, y=1.4916, z=-1.6923, visibility=0.1742
#
# LEFT_THUMB: x=0.7727, y=1.0732, z=-1.6676, visibility=0.1897
#
# RIGHT_THUMB: x=0.4167, y=1.4688, z=-1.5436, visibility=0.1582
#
# LEFT_HIP: x=0.7666, y=1.6549, z=-0.0817, visibility=0.0012
#
# RIGHT_HIP: x=0.4544, y=1.6739, z=0.0874, visibility=0.0009
#
# LEFT_KNEE: x=0.7801, y=2.2761, z=-0.0936, visibility=0.0008
#
# RIGHT_KNEE: x=0.4976, y=2.2825, z=0.1870, visibility=0.0006
#
# LEFT_ANKLE: x=0.7941, y=2.8323, z=0.5691, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5178, y=2.8313, z=0.7609, visibility=0.0000
#
# LEFT_HEEL: x=0.8018, y=2.9159, z=0.5929, visibility=0.0001
#
# RIGHT_HEEL: x=0.5133, y=2.9129, z=0.7957, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7487, y=3.0235, z=-0.1044, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5763, y=3.0205, z=0.0789, visibility=0.0001
#
# NOSE: x=0.6070, y=0.7121, z=-0.9693, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6308, y=0.6347, z=-0.9103, visibility=0.9975
#
# LEFT_EYE: x=0.6480, y=0.6328, z=-0.9104, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6652, y=0.6318, z=-0.9103, visibility=0.9970
#
# RIGHT_EYE_INNER: x=0.5651, y=0.6412, z=-0.9193, visibility=0.9976
#
# RIGHT_EYE: x=0.5393, y=0.6447, z=-0.9182, visibility=0.9978
#
# RIGHT_EYE_OUTER: x=0.5171, y=0.6490, z=-0.9186, visibility=0.9976
#
# LEFT_EAR: x=0.6941, y=0.6514, z=-0.4971, visibility=0.9977
#
# RIGHT_EAR: x=0.4825, y=0.6783, z=-0.5106, visibility=0.9984
#
# MOUTH_LEFT: x=0.6422, y=0.7796, z=-0.8101, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5662, y=0.7960, z=-0.8162, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8295, y=0.9277, z=-0.3008, visibility=0.9824
#
# RIGHT_SHOULDER: x=0.3512, y=0.9842, z=-0.2997, visibility=0.9889
#
# LEFT_ELBOW: x=0.8788, y=1.0527, z=-0.8016, visibility=0.0946
#
# RIGHT_ELBOW: x=0.3317, y=1.4387, z=-0.4998, visibility=0.1859
#
# LEFT_WRIST: x=0.8026, y=1.0388, z=-1.4684, visibility=0.1375
#
# RIGHT_WRIST: x=0.3813, y=1.6350, z=-1.1357, visibility=0.0855
#
# LEFT_PINKY: x=0.8126, y=1.1184, z=-1.6118, visibility=0.1609
#
# RIGHT_PINKY: x=0.3812, y=1.7335, z=-1.2680, visibility=0.1208
#
# LEFT_INDEX: x=0.7893, y=1.0781, z=-1.5513, visibility=0.1982
#
# RIGHT_INDEX: x=0.3999, y=1.6735, z=-1.3063, visibility=0.1739
#
# LEFT_THUMB: x=0.7732, y=1.0931, z=-1.4721, visibility=0.1907
#
# RIGHT_THUMB: x=0.4128, y=1.6355, z=-1.1716, visibility=0.1581
#
# LEFT_HIP: x=0.7669, y=1.6557, z=-0.0813, visibility=0.0011
#
# RIGHT_HIP: x=0.4547, y=1.6753, z=0.0869, visibility=0.0009
#
# LEFT_KNEE: x=0.7806, y=2.2796, z=-0.1115, visibility=0.0008
#
# RIGHT_KNEE: x=0.4980, y=2.2874, z=0.1456, visibility=0.0006
#
# LEFT_ANKLE: x=0.7963, y=2.8343, z=0.4978, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5194, y=2.8378, z=0.6113, visibility=0.0000
#
# LEFT_HEEL: x=0.8044, y=2.9178, z=0.5189, visibility=0.0001
#
# RIGHT_HEEL: x=0.5155, y=2.9205, z=0.6348, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7520, y=3.0271, z=-0.1282, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5779, y=3.0279, z=-0.0198, visibility=0.0001
#
# NOSE: x=0.6087, y=0.7120, z=-1.2065, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6321, y=0.6344, z=-1.1467, visibility=0.9976
#
# LEFT_EYE: x=0.6492, y=0.6326, z=-1.1470, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6665, y=0.6317, z=-1.1474, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5670, y=0.6400, z=-1.1592, visibility=0.9976
#
# RIGHT_EYE: x=0.5410, y=0.6432, z=-1.1585, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5183, y=0.6474, z=-1.1588, visibility=0.9977
#
# LEFT_EAR: x=0.6946, y=0.6512, z=-0.6518, visibility=0.9977
#
# RIGHT_EAR: x=0.4825, y=0.6762, z=-0.6839, visibility=0.9985
#
# MOUTH_LEFT: x=0.6431, y=0.7796, z=-1.0104, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5672, y=0.7958, z=-1.0206, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8295, y=0.9275, z=-0.3391, visibility=0.9825
#
# RIGHT_SHOULDER: x=0.3503, y=0.9840, z=-0.3797, visibility=0.9887
#
# LEFT_ELBOW: x=0.8790, y=1.0569, z=-0.6677, visibility=0.0918
#
# RIGHT_ELBOW: x=0.3312, y=1.4356, z=-0.6097, visibility=0.1925
#
# LEFT_WRIST: x=0.8629, y=1.3372, z=-1.3789, visibility=0.1278
#
# RIGHT_WRIST: x=0.3870, y=1.5619, z=-1.4756, visibility=0.0884
#
# LEFT_PINKY: x=0.8822, y=1.4113, z=-1.5530, visibility=0.1501
#
# RIGHT_PINKY: x=0.3933, y=1.6348, z=-1.6696, visibility=0.1229
#
# LEFT_INDEX: x=0.8431, y=1.3757, z=-1.5707, visibility=0.1855
#
# RIGHT_INDEX: x=0.4104, y=1.5601, z=-1.7209, visibility=0.1766
#
# LEFT_THUMB: x=0.8239, y=1.3564, z=-1.4182, visibility=0.1790
#
# RIGHT_THUMB: x=0.4193, y=1.5321, z=-1.5204, visibility=0.1599
#
# LEFT_HIP: x=0.7670, y=1.6558, z=-0.0810, visibility=0.0012
#
# RIGHT_HIP: x=0.4551, y=1.6754, z=0.0866, visibility=0.0009
#
# LEFT_KNEE: x=0.7807, y=2.2792, z=-0.1134, visibility=0.0009
#
# RIGHT_KNEE: x=0.4982, y=2.2875, z=0.2000, visibility=0.0007
#
# LEFT_ANKLE: x=0.7951, y=2.8350, z=0.4879, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5188, y=2.8380, z=0.7299, visibility=0.0000
#
# LEFT_HEEL: x=0.8018, y=2.9186, z=0.5064, visibility=0.0001
#
# RIGHT_HEEL: x=0.5141, y=2.9209, z=0.7609, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7516, y=3.0275, z=-0.1884, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5777, y=3.0274, z=0.0474, visibility=0.0001
#
# NOSE: x=0.6100, y=0.7118, z=-1.2507, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6332, y=0.6342, z=-1.1938, visibility=0.9976
#
# LEFT_EYE: x=0.6502, y=0.6325, z=-1.1941, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6676, y=0.6317, z=-1.1945, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5685, y=0.6396, z=-1.2048, visibility=0.9976
#
# RIGHT_EYE: x=0.5424, y=0.6427, z=-1.2041, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5193, y=0.6467, z=-1.2044, visibility=0.9977
#
# LEFT_EAR: x=0.6951, y=0.6511, z=-0.7020, visibility=0.9977
#
# RIGHT_EAR: x=0.4825, y=0.6751, z=-0.7279, visibility=0.9985
#
# MOUTH_LEFT: x=0.6439, y=0.7796, z=-1.0547, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5683, y=0.7957, z=-1.0630, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8293, y=0.9271, z=-0.3669, visibility=0.9823
#
# RIGHT_SHOULDER: x=0.3501, y=0.9836, z=-0.4080, visibility=0.9884
#
# LEFT_ELBOW: x=0.8770, y=1.0445, z=-0.6632, visibility=0.0901
#
# RIGHT_ELBOW: x=0.3314, y=1.4322, z=-0.6290, visibility=0.1979
#
# LEFT_WRIST: x=0.8739, y=1.3298, z=-1.3832, visibility=0.1194
#
# RIGHT_WRIST: x=0.3899, y=1.5494, z=-1.4823, visibility=0.0892
#
# LEFT_PINKY: x=0.8911, y=1.3930, z=-1.5604, visibility=0.1406
#
# RIGHT_PINKY: x=0.3980, y=1.6224, z=-1.6718, visibility=0.1227
#
# LEFT_INDEX: x=0.8507, y=1.3584, z=-1.5834, visibility=0.1744
#
# RIGHT_INDEX: x=0.4151, y=1.5474, z=-1.7248, visibility=0.1763
#
# LEFT_THUMB: x=0.8318, y=1.3422, z=-1.4233, visibility=0.1687
#
# RIGHT_THUMB: x=0.4227, y=1.5187, z=-1.5274, visibility=0.1593
#
# LEFT_HIP: x=0.7668, y=1.6557, z=-0.0808, visibility=0.0013
#
# RIGHT_HIP: x=0.4556, y=1.6753, z=0.0862, visibility=0.0009
#
# LEFT_KNEE: x=0.7807, y=2.2776, z=-0.1136, visibility=0.0010
#
# RIGHT_KNEE: x=0.4986, y=2.2862, z=0.1893, visibility=0.0008
#
# LEFT_ANKLE: x=0.7943, y=2.8348, z=0.4860, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5187, y=2.8365, z=0.7037, visibility=0.0000
#
# LEFT_HEEL: x=0.8001, y=2.9184, z=0.5041, visibility=0.0001
#
# RIGHT_HEEL: x=0.5137, y=2.9192, z=0.7331, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7515, y=3.0269, z=-0.1949, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5776, y=3.0254, z=0.0184, visibility=0.0001
#
# NOSE: x=0.6105, y=0.7115, z=-1.1558, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6337, y=0.6339, z=-1.1024, visibility=0.9976
#
# LEFT_EYE: x=0.6509, y=0.6322, z=-1.1028, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6685, y=0.6315, z=-1.1034, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5691, y=0.6392, z=-1.1117, visibility=0.9976
#
# RIGHT_EYE: x=0.5432, y=0.6423, z=-1.1108, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5201, y=0.6464, z=-1.1111, visibility=0.9977
#
# LEFT_EAR: x=0.6958, y=0.6507, z=-0.6214, visibility=0.9978
#
# RIGHT_EAR: x=0.4826, y=0.6745, z=-0.6354, visibility=0.9985
#
# MOUTH_LEFT: x=0.6446, y=0.7796, z=-0.9631, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5692, y=0.7955, z=-0.9677, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8296, y=0.9253, z=-0.3179, visibility=0.9833
#
# RIGHT_SHOULDER: x=0.3512, y=0.9816, z=-0.3249, visibility=0.9885
#
# LEFT_ELBOW: x=0.8794, y=1.0500, z=-0.5907, visibility=0.0912
#
# RIGHT_ELBOW: x=0.3324, y=1.4320, z=-0.6234, visibility=0.2050
#
# LEFT_WRIST: x=0.8745, y=1.3376, z=-1.2493, visibility=0.1134
#
# RIGHT_WRIST: x=0.3958, y=1.4746, z=-1.5493, visibility=0.0965
#
# LEFT_PINKY: x=0.8881, y=1.3962, z=-1.4141, visibility=0.1332
#
# RIGHT_PINKY: x=0.4052, y=1.5157, z=-1.7441, visibility=0.1283
#
# LEFT_INDEX: x=0.8478, y=1.3603, z=-1.4314, visibility=0.1659
#
# RIGHT_INDEX: x=0.4185, y=1.4432, z=-1.7809, visibility=0.1823
#
# LEFT_THUMB: x=0.8307, y=1.3458, z=-1.2828, visibility=0.1611
#
# RIGHT_THUMB: x=0.4265, y=1.4269, z=-1.5906, visibility=0.1645
#
# LEFT_HIP: x=0.7677, y=1.6557, z=-0.0801, visibility=0.0013
#
# RIGHT_HIP: x=0.4590, y=1.6754, z=0.0854, visibility=0.0010
#
# LEFT_KNEE: x=0.7808, y=2.2770, z=-0.0559, visibility=0.0011
#
# RIGHT_KNEE: x=0.4986, y=2.2849, z=0.2027, visibility=0.0008
#
# LEFT_ANKLE: x=0.7932, y=2.8351, z=0.5320, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5180, y=2.8362, z=0.7149, visibility=0.0000
#
# LEFT_HEEL: x=0.7985, y=2.9187, z=0.5502, visibility=0.0001
#
# RIGHT_HEEL: x=0.5127, y=2.9183, z=0.7455, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7515, y=3.0269, z=-0.1393, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5772, y=3.0245, z=0.0333, visibility=0.0001
#
# NOSE: x=0.6129, y=0.7114, z=-1.1895, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6352, y=0.6338, z=-1.1332, visibility=0.9976
#
# LEFT_EYE: x=0.6521, y=0.6321, z=-1.1336, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6696, y=0.6314, z=-1.1340, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5722, y=0.6392, z=-1.1421, visibility=0.9977
#
# RIGHT_EYE: x=0.5464, y=0.6422, z=-1.1413, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5234, y=0.6463, z=-1.1417, visibility=0.9977
#
# LEFT_EAR: x=0.6959, y=0.6506, z=-0.6402, visibility=0.9977
#
# RIGHT_EAR: x=0.4838, y=0.6736, z=-0.6567, visibility=0.9985
#
# MOUTH_LEFT: x=0.6460, y=0.7797, z=-0.9935, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5721, y=0.7952, z=-0.9986, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8295, y=0.9228, z=-0.3258, visibility=0.9833
#
# RIGHT_SHOULDER: x=0.3529, y=0.9797, z=-0.3504, visibility=0.9884
#
# LEFT_ELBOW: x=0.8787, y=1.0359, z=-0.6308, visibility=0.0929
#
# RIGHT_ELBOW: x=0.3368, y=1.4214, z=-0.6495, visibility=0.2178
#
# LEFT_WRIST: x=0.8709, y=1.3173, z=-1.2837, visibility=0.1077
#
# RIGHT_WRIST: x=0.3990, y=1.4826, z=-1.5610, visibility=0.0975
#
# LEFT_PINKY: x=0.8837, y=1.3914, z=-1.4383, visibility=0.1271
#
# RIGHT_PINKY: x=0.4078, y=1.5458, z=-1.7563, visibility=0.1287
#
# LEFT_INDEX: x=0.8447, y=1.3465, z=-1.5026, visibility=0.1587
#
# RIGHT_INDEX: x=0.4241, y=1.4703, z=-1.8100, visibility=0.1824
#
# LEFT_THUMB: x=0.8275, y=1.3235, z=-1.2963, visibility=0.1540
#
# RIGHT_THUMB: x=0.4321, y=1.4443, z=-1.6076, visibility=0.1643
#
# LEFT_HIP: x=0.7690, y=1.6499, z=-0.0799, visibility=0.0014
#
# RIGHT_HIP: x=0.4669, y=1.6719, z=0.0852, visibility=0.0010
#
# LEFT_KNEE: x=0.7828, y=2.2653, z=-0.1097, visibility=0.0013
#
# RIGHT_KNEE: x=0.5030, y=2.2760, z=0.1916, visibility=0.0010
#
# LEFT_ANKLE: x=0.7947, y=2.8238, z=0.4215, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5231, y=2.8279, z=0.6917, visibility=0.0000
#
# LEFT_HEEL: x=0.7996, y=2.9056, z=0.4333, visibility=0.0001
#
# RIGHT_HEEL: x=0.5174, y=2.9092, z=0.7204, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7550, y=3.0161, z=-0.2583, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5828, y=3.0155, z=0.0088, visibility=0.0002
#
# NOSE: x=0.6139, y=0.7114, z=-1.2054, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6358, y=0.6339, z=-1.1493, visibility=0.9976
#
# LEFT_EYE: x=0.6527, y=0.6322, z=-1.1496, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6701, y=0.6314, z=-1.1500, visibility=0.9971
#
# RIGHT_EYE_INNER: x=0.5734, y=0.6392, z=-1.1573, visibility=0.9977
#
# RIGHT_EYE: x=0.5479, y=0.6422, z=-1.1565, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5251, y=0.6463, z=-1.1570, visibility=0.9978
#
# LEFT_EAR: x=0.6960, y=0.6505, z=-0.6566, visibility=0.9978
#
# RIGHT_EAR: x=0.4847, y=0.6731, z=-0.6705, visibility=0.9985
#
# MOUTH_LEFT: x=0.6465, y=0.7797, z=-1.0100, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5733, y=0.7952, z=-1.0143, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8293, y=0.9219, z=-0.3289, visibility=0.9834
#
# RIGHT_SHOULDER: x=0.3551, y=0.9781, z=-0.3683, visibility=0.9885
#
# LEFT_ELBOW: x=0.8782, y=1.0298, z=-0.6350, visibility=0.0941
#
# RIGHT_ELBOW: x=0.3387, y=1.4106, z=-0.6583, visibility=0.2289
#
# LEFT_WRIST: x=0.8688, y=1.2994, z=-1.3388, visibility=0.1024
#
# RIGHT_WRIST: x=0.4008, y=1.4958, z=-1.5600, visibility=0.1003
#
# LEFT_PINKY: x=0.8806, y=1.3645, z=-1.5062, visibility=0.1214
#
# RIGHT_PINKY: x=0.4089, y=1.5583, z=-1.7547, visibility=0.1314
#
# LEFT_INDEX: x=0.8425, y=1.3227, z=-1.5355, visibility=0.1522
#
# RIGHT_INDEX: x=0.4265, y=1.4855, z=-1.8107, visibility=0.1857
#
# LEFT_THUMB: x=0.8254, y=1.3070, z=-1.3635, visibility=0.1477
#
# RIGHT_THUMB: x=0.4347, y=1.4599, z=-1.6073, visibility=0.1670
#
# LEFT_HIP: x=0.7690, y=1.6450, z=-0.0795, visibility=0.0014
#
# RIGHT_HIP: x=0.4688, y=1.6670, z=0.0847, visibility=0.0011
#
# LEFT_KNEE: x=0.7829, y=2.2580, z=-0.1352, visibility=0.0014
#
# RIGHT_KNEE: x=0.5039, y=2.2684, z=0.1869, visibility=0.0011
#
# LEFT_ANKLE: x=0.7946, y=2.8171, z=0.3852, visibility=0.0002
#
# RIGHT_ANKLE: x=0.5237, y=2.8212, z=0.6810, visibility=0.0000
#
# LEFT_HEEL: x=0.7994, y=2.8985, z=0.3961, visibility=0.0001
#
# RIGHT_HEEL: x=0.5179, y=2.9023, z=0.7091, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7551, y=3.0087, z=-0.2978, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.5832, y=3.0077, z=-0.0027, visibility=0.0002
#
# NOSE: x=0.6152, y=0.7112, z=-1.0126, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6377, y=0.6338, z=-0.9538, visibility=0.9976
#
# LEFT_EYE: x=0.6552, y=0.6322, z=-0.9542, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6736, y=0.6316, z=-0.9545, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.5747, y=0.6389, z=-0.9589, visibility=0.9977
#
# RIGHT_EYE: x=0.5492, y=0.6418, z=-0.9580, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5263, y=0.6457, z=-0.9586, visibility=0.9978
#
# LEFT_EAR: x=0.7000, y=0.6511, z=-0.5069, visibility=0.9977
#
# RIGHT_EAR: x=0.4850, y=0.6727, z=-0.5002, visibility=0.9985
#
# MOUTH_LEFT: x=0.6485, y=0.7797, z=-0.8384, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5745, y=0.7946, z=-0.8379, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8304, y=0.9213, z=-0.2530, visibility=0.9832
#
# RIGHT_SHOULDER: x=0.3551, y=0.9781, z=-0.2523, visibility=0.9888
#
# LEFT_ELBOW: x=0.8768, y=1.0257, z=-0.5984, visibility=0.0914
#
# RIGHT_ELBOW: x=0.3382, y=1.4147, z=-0.4504, visibility=0.2397
#
# LEFT_WRIST: x=0.8680, y=1.2580, z=-1.3114, visibility=0.0957
#
# RIGHT_WRIST: x=0.3905, y=1.6048, z=-1.1718, visibility=0.0977
#
# LEFT_PINKY: x=0.8795, y=1.2946, z=-1.4781, visibility=0.1137
#
# RIGHT_PINKY: x=0.3925, y=1.7047, z=-1.3359, visibility=0.1276
#
# LEFT_INDEX: x=0.8412, y=1.2615, z=-1.4829, visibility=0.1428
#
# RIGHT_INDEX: x=0.4170, y=1.6451, z=-1.3908, visibility=0.1803
#
# LEFT_THUMB: x=0.8243, y=1.2551, z=-1.3410, visibility=0.1388
#
# RIGHT_THUMB: x=0.4270, y=1.6068, z=-1.2163, visibility=0.1626
#
# LEFT_HIP: x=0.7696, y=1.6454, z=-0.0802, visibility=0.0014
#
# RIGHT_HIP: x=0.4695, y=1.6672, z=0.0856, visibility=0.0011
#
# LEFT_KNEE: x=0.7855, y=2.2588, z=-0.1769, visibility=0.0013
#
# RIGHT_KNEE: x=0.5065, y=2.2689, z=0.1840, visibility=0.0011
#
# LEFT_ANKLE: x=0.7990, y=2.8175, z=0.3428, visibility=0.0002
#
# RIGHT_ANKLE: x=0.5271, y=2.8221, z=0.6574, visibility=0.0000
#
# LEFT_HEEL: x=0.8054, y=2.8992, z=0.3549, visibility=0.0001
#
# RIGHT_HEEL: x=0.5210, y=2.9033, z=0.6823, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7581, y=3.0093, z=-0.3317, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.5895, y=3.0084, z=-0.0126, visibility=0.0002
#
# NOSE: x=0.6152, y=0.7115, z=-1.0344, visibility=0.9983
#
# LEFT_EYE_INNER: x=0.6377, y=0.6339, z=-0.9820, visibility=0.9978
#
# LEFT_EYE: x=0.6554, y=0.6322, z=-0.9822, visibility=0.9978
#
# LEFT_EYE_OUTER: x=0.6739, y=0.6317, z=-0.9825, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5747, y=0.6389, z=-0.9870, visibility=0.9978
#
# RIGHT_EYE: x=0.5492, y=0.6418, z=-0.9861, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5264, y=0.6457, z=-0.9864, visibility=0.9979
#
# LEFT_EAR: x=0.7021, y=0.6513, z=-0.5362, visibility=0.9979
#
# RIGHT_EAR: x=0.4852, y=0.6726, z=-0.5324, visibility=0.9986
#
# MOUTH_LEFT: x=0.6488, y=0.7802, z=-0.8576, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5745, y=0.7947, z=-0.8578, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8310, y=0.9212, z=-0.2692, visibility=0.9836
#
# RIGHT_SHOULDER: x=0.3564, y=0.9756, z=-0.2661, visibility=0.9887
#
# LEFT_ELBOW: x=0.8788, y=1.0451, z=-0.6571, visibility=0.0952
#
# RIGHT_ELBOW: x=0.3384, y=1.4156, z=-0.6037, visibility=0.2389
#
# LEFT_WRIST: x=0.8515, y=1.1899, z=-1.3234, visibility=0.1061
#
# RIGHT_WRIST: x=0.3968, y=1.4531, z=-1.5213, visibility=0.1059
#
# LEFT_PINKY: x=0.8483, y=1.1849, z=-1.5084, visibility=0.1234
#
# RIGHT_PINKY: x=0.4034, y=1.4848, z=-1.6946, visibility=0.1360
#
# LEFT_INDEX: x=0.8183, y=1.1385, z=-1.4943, visibility=0.1540
#
# RIGHT_INDEX: x=0.4199, y=1.4110, z=-1.6842, visibility=0.1898
#
# LEFT_THUMB: x=0.8037, y=1.1500, z=-1.3687, visibility=0.1496
#
# RIGHT_THUMB: x=0.4305, y=1.4002, z=-1.5449, visibility=0.1705
#
# LEFT_HIP: x=0.7697, y=1.6463, z=-0.0800, visibility=0.0015
#
# RIGHT_HIP: x=0.4694, y=1.6674, z=0.0854, visibility=0.0011
#
# LEFT_KNEE: x=0.7850, y=2.2607, z=-0.1702, visibility=0.0014
#
# RIGHT_KNEE: x=0.5055, y=2.2692, z=0.1816, visibility=0.0011
#
# LEFT_ANKLE: x=0.7979, y=2.8214, z=0.3781, visibility=0.0002
#
# ...
#
# LEFT_ELBOW: x=0.8801, y=1.0540, z=-0.6753, visibility=0.0984
#
# RIGHT_ELBOW: x=0.3385, y=1.4165, z=-0.6444, visibility=0.2386
#
# LEFT_WRIST: x=0.8448, y=1.1731, z=-1.3380, visibility=0.1147
#
# RIGHT_WRIST: x=0.4010, y=1.4241, z=-1.5750, visibility=0.1135
#
# LEFT_PINKY: x=0.8383, y=1.1668, z=-1.5205, visibility=0.1314
#
# RIGHT_PINKY: x=0.4099, y=1.4517, z=-1.7517, visibility=0.1437
#
# LEFT_INDEX: x=0.8101, y=1.1189, z=-1.4944, visibility=0.1633
#
# RIGHT_INDEX: x=0.4225, y=1.3765, z=-1.7459, visibility=0.1984
#
# LEFT_THUMB: x=0.7960, y=1.1312, z=-1.3801, visibility=0.1585
#
# RIGHT_THUMB: x=0.4333, y=1.3671, z=-1.6000, visibility=0.1778
#
# LEFT_HIP: x=0.7698, y=1.6471, z=-0.0798, visibility=0.0015
#
# RIGHT_HIP: x=0.4693, y=1.6676, z=0.0852, visibility=0.0011
#
# LEFT_KNEE: x=0.7846, y=2.2623, z=-0.1661, visibility=0.0015
#
# RIGHT_KNEE: x=0.5046, y=2.2696, z=0.1799, visibility=0.0012
#
# LEFT_ANKLE: x=0.7971, y=2.8241, z=0.3939, visibility=0.0002
#
# RIGHT_ANKLE: x=0.5269, y=2.8228, z=0.6506, visibility=0.0000
#
# LEFT_HEEL: x=0.8032, y=2.9056, z=0.4082, visibility=0.0001
#
# RIGHT_HEEL: x=0.5208, y=2.9045, z=0.6744, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7576, y=3.0128, z=-0.2830, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.5839, y=3.0110, z=-0.0159, visibility=0.0002
#
# NOSE: x=0.6151, y=0.7116, z=-1.1298, visibility=0.9983
#
# LEFT_EYE_INNER: x=0.6382, y=0.6339, z=-1.0784, visibility=0.9979
#
# LEFT_EYE: x=0.6565, y=0.6323, z=-1.0786, visibility=0.9980
#
# LEFT_EYE_OUTER: x=0.6755, y=0.6319, z=-1.0789, visibility=0.9975
#
# RIGHT_EYE_INNER: x=0.5746, y=0.6388, z=-1.0810, visibility=0.9979
#
# RIGHT_EYE: x=0.5492, y=0.6416, z=-1.0801, visibility=0.9981
#
# RIGHT_EYE_OUTER: x=0.5264, y=0.6455, z=-1.0805, visibility=0.9980
#
# LEFT_EAR: x=0.7056, y=0.6516, z=-0.6328, visibility=0.9980
#
# RIGHT_EAR: x=0.4853, y=0.6724, z=-0.6146, visibility=0.9986
#
# MOUTH_LEFT: x=0.6494, y=0.7811, z=-0.9527, visibility=0.9986
#
# MOUTH_RIGHT: x=0.5745, y=0.7949, z=-0.9487, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8352, y=0.9229, z=-0.3513, visibility=0.9839
#
# RIGHT_SHOULDER: x=0.3575, y=0.9744, z=-0.3263, visibility=0.9889
#
# LEFT_ELBOW: x=0.8802, y=1.0571, z=-0.6710, visibility=0.0943
#
# RIGHT_ELBOW: x=0.3400, y=1.4172, z=-0.5273, visibility=0.2402
#
# LEFT_WRIST: x=0.8535, y=1.3033, z=-1.3476, visibility=0.1062
#
# RIGHT_WRIST: x=0.4010, y=1.5710, z=-1.2465, visibility=0.1082
#
# LEFT_PINKY: x=0.8586, y=1.3521, z=-1.5240, visibility=0.1221
#
# RIGHT_PINKY: x=0.4095, y=1.6629, z=-1.4158, visibility=0.1376
#
# LEFT_INDEX: x=0.8248, y=1.3193, z=-1.5059, visibility=0.1524
#
# RIGHT_INDEX: x=0.4234, y=1.6033, z=-1.4748, visibility=0.1911
#
# LEFT_THUMB: x=0.8094, y=1.3068, z=-1.3862, visibility=0.1483
#
# RIGHT_THUMB: x=0.4338, y=1.5672, z=-1.2934, visibility=0.1714
#
# LEFT_HIP: x=0.7718, y=1.6472, z=-0.0803, visibility=0.0014
#
# RIGHT_HIP: x=0.4712, y=1.6677, z=0.0858, visibility=0.0010
#
# LEFT_KNEE: x=0.7878, y=2.2628, z=-0.1905, visibility=0.0014
#
# RIGHT_KNEE: x=0.5077, y=2.2702, z=0.1788, visibility=0.0011
#
# LEFT_ANKLE: x=0.8000, y=2.8242, z=0.3479, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5305, y=2.8230, z=0.6292, visibility=0.0000
#
# LEFT_HEEL: x=0.8071, y=2.9071, z=0.3608, visibility=0.0001
#
# RIGHT_HEEL: x=0.5247, y=2.9053, z=0.6502, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7580, y=3.0134, z=-0.3441, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.5891, y=3.0116, z=-0.0532, visibility=0.0002
#
# NOSE: x=0.6151, y=0.7117, z=-1.1293, visibility=0.9984
#
# LEFT_EYE_INNER: x=0.6383, y=0.6339, z=-1.0775, visibility=0.9980
#
# LEFT_EYE: x=0.6567, y=0.6323, z=-1.0778, visibility=0.9980
#
# LEFT_EYE_OUTER: x=0.6759, y=0.6319, z=-1.0782, visibility=0.9976
#
# RIGHT_EYE_INNER: x=0.5746, y=0.6387, z=-1.0792, visibility=0.9980
#
# RIGHT_EYE: x=0.5491, y=0.6416, z=-1.0782, visibility=0.9982
#
# RIGHT_EYE_OUTER: x=0.5264, y=0.6455, z=-1.0786, visibility=0.9981
#
# LEFT_EAR: x=0.7065, y=0.6516, z=-0.6283, visibility=0.9981
#
# RIGHT_EAR: x=0.4853, y=0.6725, z=-0.6101, visibility=0.9987
#
# MOUTH_LEFT: x=0.6499, y=0.7812, z=-0.9508, visibility=0.9987
#
# MOUTH_RIGHT: x=0.5748, y=0.7949, z=-0.9484, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8374, y=0.9237, z=-0.3535, visibility=0.9840
#
# RIGHT_SHOULDER: x=0.3590, y=0.9727, z=-0.3213, visibility=0.9890
#
# LEFT_ELBOW: x=0.8802, y=1.0582, z=-0.7993, visibility=0.1029
#
# RIGHT_ELBOW: x=0.3400, y=1.4087, z=-0.5709, visibility=0.2444
#
# LEFT_WRIST: x=0.8158, y=1.0780, z=-1.5440, visibility=0.1263
#
# RIGHT_WRIST: x=0.4009, y=1.5198, z=-1.3381, visibility=0.1182
#
# LEFT_PINKY: x=0.8250, y=1.1883, z=-1.7117, visibility=0.1403
#
# RIGHT_PINKY: x=0.4092, y=1.5972, z=-1.4679, visibility=0.1486
#
# LEFT_INDEX: x=0.7992, y=1.1418, z=-1.6711, visibility=0.1716
#
# RIGHT_INDEX: x=0.4230, y=1.5224, z=-1.5180, visibility=0.2032
#
# LEFT_THUMB: x=0.7851, y=1.1522, z=-1.5580, visibility=0.1678
#
# RIGHT_THUMB: x=0.4332, y=1.4950, z=-1.3591, visibility=0.1833
#
# LEFT_HIP: x=0.7719, y=1.6436, z=-0.0804, visibility=0.0015
#
# RIGHT_HIP: x=0.4692, y=1.6604, z=0.0859, visibility=0.0011
#
# LEFT_KNEE: x=0.7856, y=2.2600, z=-0.1583, visibility=0.0013
#
# RIGHT_KNEE: x=0.5011, y=2.2627, z=0.1782, visibility=0.0011
#
# LEFT_ANKLE: x=0.7955, y=2.8164, z=0.4175, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5227, y=2.8115, z=0.6429, visibility=0.0000
#
# LEFT_HEEL: x=0.8019, y=2.8976, z=0.4340, visibility=0.0001
#
# RIGHT_HEEL: x=0.5175, y=2.8917, z=0.6673, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7547, y=3.0061, z=-0.2601, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.5828, y=3.0007, z=-0.0384, visibility=0.0002
#
# NOSE: x=0.6151, y=0.7114, z=-1.1303, visibility=0.9984
#
# LEFT_EYE_INNER: x=0.6384, y=0.6335, z=-1.0771, visibility=0.9980
#
# LEFT_EYE: x=0.6569, y=0.6320, z=-1.0774, visibility=0.9981
#
# LEFT_EYE_OUTER: x=0.6762, y=0.6316, z=-1.0777, visibility=0.9976
#
# RIGHT_EYE_INNER: x=0.5744, y=0.6384, z=-1.0783, visibility=0.9981
#
# RIGHT_EYE: x=0.5491, y=0.6414, z=-1.0774, visibility=0.9982
#
# RIGHT_EYE_OUTER: x=0.5263, y=0.6454, z=-1.0778, visibility=0.9981
#
# LEFT_EAR: x=0.7078, y=0.6516, z=-0.6281, visibility=0.9982
#
# RIGHT_EAR: x=0.4855, y=0.6724, z=-0.6002, visibility=0.9987
#
# MOUTH_LEFT: x=0.6503, y=0.7810, z=-0.9533, visibility=0.9987
#
# MOUTH_RIGHT: x=0.5749, y=0.7946, z=-0.9479, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8400, y=0.9250, z=-0.3604, visibility=0.9835
#
# RIGHT_SHOULDER: x=0.3606, y=0.9725, z=-0.3073, visibility=0.9889
#
# LEFT_ELBOW: x=0.8780, y=1.0456, z=-0.8031, visibility=0.1071
#
# RIGHT_ELBOW: x=0.3398, y=1.4054, z=-0.5527, visibility=0.2480
#
# LEFT_WRIST: x=0.8195, y=1.1232, z=-1.5514, visibility=0.1321
#
# RIGHT_WRIST: x=0.4001, y=1.5199, z=-1.3487, visibility=0.1231
#
# LEFT_PINKY: x=0.8287, y=1.1923, z=-1.7205, visibility=0.1455
#
# RIGHT_PINKY: x=0.4084, y=1.5977, z=-1.5061, visibility=0.1545
#
# LEFT_INDEX: x=0.8014, y=1.1467, z=-1.6911, visibility=0.1773
#
# RIGHT_INDEX: x=0.4225, y=1.5224, z=-1.5413, visibility=0.2102
#
# LEFT_THUMB: x=0.7871, y=1.1543, z=-1.5687, visibility=0.1743
#
# RIGHT_THUMB: x=0.4321, y=1.4950, z=-1.3816, visibility=0.1904
#
# LEFT_HIP: x=0.7726, y=1.6439, z=-0.0837, visibility=0.0015
#
# RIGHT_HIP: x=0.4690, y=1.6606, z=0.0892, visibility=0.0011
#
# LEFT_KNEE: x=0.7855, y=2.2603, z=-0.1573, visibility=0.0013
#
# RIGHT_KNEE: x=0.5002, y=2.2636, z=0.1891, visibility=0.0011
#
# LEFT_ANKLE: x=0.7947, y=2.8169, z=0.4168, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5211, y=2.8117, z=0.6748, visibility=0.0000
#
# LEFT_HEEL: x=0.8010, y=2.8981, z=0.4331, visibility=0.0001
#
# RIGHT_HEEL: x=0.5159, y=2.8915, z=0.7016, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7538, y=3.0063, z=-0.2672, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5821, y=3.0010, z=-0.0104, visibility=0.0002
#
# NOSE: x=0.6150, y=0.7109, z=-1.1543, visibility=0.9985
#
# LEFT_EYE_INNER: x=0.6384, y=0.6328, z=-1.0982, visibility=0.9981
#
# LEFT_EYE: x=0.6570, y=0.6314, z=-1.0985, visibility=0.9982
#
# LEFT_EYE_OUTER: x=0.6765, y=0.6312, z=-1.0988, visibility=0.9977
#
# RIGHT_EYE_INNER: x=0.5740, y=0.6376, z=-1.0968, visibility=0.9981
#
# RIGHT_EYE: x=0.5487, y=0.6406, z=-1.0959, visibility=0.9983
#
# RIGHT_EYE_OUTER: x=0.5262, y=0.6446, z=-1.0963, visibility=0.9982
#
# LEFT_EAR: x=0.7086, y=0.6515, z=-0.6403, visibility=0.9982
#
# RIGHT_EAR: x=0.4858, y=0.6719, z=-0.6023, visibility=0.9988
#
# MOUTH_LEFT: x=0.6506, y=0.7808, z=-0.9748, visibility=0.9987
#
# MOUTH_RIGHT: x=0.5750, y=0.7940, z=-0.9651, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8420, y=0.9262, z=-0.3616, visibility=0.9834
#
# RIGHT_SHOULDER: x=0.3623, y=0.9725, z=-0.3073, visibility=0.9891
#
# LEFT_ELBOW: x=0.8820, y=1.0519, z=-0.7582, visibility=0.1058
#
# RIGHT_ELBOW: x=0.3393, y=1.4055, z=-0.5005, visibility=0.2537
#
# LEFT_WRIST: x=0.8437, y=1.2527, z=-1.4593, visibility=0.1260
#
# RIGHT_WRIST: x=0.3970, y=1.5437, z=-1.2791, visibility=0.1261
#
# LEFT_PINKY: x=0.8504, y=1.3052, z=-1.6282, visibility=0.1392
#
# RIGHT_PINKY: x=0.4025, y=1.6322, z=-1.4454, visibility=0.1580
#
# LEFT_INDEX: x=0.8176, y=1.2673, z=-1.6307, visibility=0.1704
#
# RIGHT_INDEX: x=0.4205, y=1.5606, z=-1.4919, visibility=0.2149
#
# LEFT_THUMB: x=0.8048, y=1.2608, z=-1.4890, visibility=0.1684
#
# RIGHT_THUMB: x=0.4297, y=1.5290, z=-1.3206, visibility=0.1954
#
# LEFT_HIP: x=0.7745, y=1.6461, z=-0.0877, visibility=0.0015
#
# RIGHT_HIP: x=0.4694, y=1.6627, z=0.0933, visibility=0.0011
#
# LEFT_KNEE: x=0.7864, y=2.2630, z=-0.1670, visibility=0.0012
#
# RIGHT_KNEE: x=0.5005, y=2.2679, z=0.2366, visibility=0.0010
#
# LEFT_ANKLE: x=0.7947, y=2.8182, z=0.4046, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5206, y=2.8136, z=0.7555, visibility=0.0000
#
# LEFT_HEEL: x=0.8010, y=2.8995, z=0.4202, visibility=0.0001
#
# RIGHT_HEEL: x=0.5153, y=2.8938, z=0.7870, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7533, y=3.0069, z=-0.2931, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5820, y=3.0024, z=0.0682, visibility=0.0002
#
# NOSE: x=0.6150, y=0.7105, z=-0.9480, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6385, y=0.6328, z=-0.8916, visibility=0.9982
#
# LEFT_EYE: x=0.6572, y=0.6314, z=-0.8918, visibility=0.9983
#
# LEFT_EYE_OUTER: x=0.6768, y=0.6312, z=-0.8918, visibility=0.9979
#
# RIGHT_EYE_INNER: x=0.5738, y=0.6370, z=-0.8952, visibility=0.9983
#
# RIGHT_EYE: x=0.5485, y=0.6398, z=-0.8941, visibility=0.9984
#
# RIGHT_EYE_OUTER: x=0.5260, y=0.6436, z=-0.8944, visibility=0.9983
#
# LEFT_EAR: x=0.7091, y=0.6515, z=-0.4665, visibility=0.9984
#
# RIGHT_EAR: x=0.4858, y=0.6703, z=-0.4557, visibility=0.9989
#
# MOUTH_LEFT: x=0.6507, y=0.7808, z=-0.7823, visibility=0.9988
#
# MOUTH_RIGHT: x=0.5746, y=0.7937, z=-0.7816, visibility=0.9991
#
# LEFT_SHOULDER: x=0.8419, y=0.9257, z=-0.2478, visibility=0.9837
#
# RIGHT_SHOULDER: x=0.3604, y=0.9726, z=-0.2403, visibility=0.9897
#
# LEFT_ELBOW: x=0.8821, y=1.0526, z=-0.7242, visibility=0.1059
#
# RIGHT_ELBOW: x=0.3299, y=1.4066, z=-0.5165, visibility=0.2551
#
# LEFT_WRIST: x=0.8353, y=1.1946, z=-1.4376, visibility=0.1305
#
# RIGHT_WRIST: x=0.3927, y=1.5491, z=-1.3195, visibility=0.1294
#
# LEFT_PINKY: x=0.8336, y=1.1888, z=-1.5997, visibility=0.1450
#
# RIGHT_PINKY: x=0.3983, y=1.6363, z=-1.4882, visibility=0.1642
#
# LEFT_INDEX: x=0.8078, y=1.1422, z=-1.5539, visibility=0.1773
#
# RIGHT_INDEX: x=0.4186, y=1.5610, z=-1.5198, visibility=0.2230
#
# LEFT_THUMB: x=0.7932, y=1.1553, z=-1.4506, visibility=0.1758
#
# RIGHT_THUMB: x=0.4278, y=1.5302, z=-1.3573, visibility=0.2031
#
# LEFT_HIP: x=0.7744, y=1.6462, z=-0.0849, visibility=0.0014
#
# RIGHT_HIP: x=0.4663, y=1.6638, z=0.0907, visibility=0.0010
#
# LEFT_KNEE: x=0.7865, y=2.2647, z=-0.1498, visibility=0.0011
#
# RIGHT_KNEE: x=0.5008, y=2.2710, z=0.1776, visibility=0.0010
#
# LEFT_ANKLE: x=0.7975, y=2.8193, z=0.4082, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5246, y=2.8182, z=0.6367, visibility=0.0000
#
# LEFT_HEEL: x=0.8040, y=2.9007, z=0.4238, visibility=0.0001
#
# RIGHT_HEEL: x=0.5205, y=2.8985, z=0.6619, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7574, y=3.0097, z=-0.2632, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5858, y=3.0082, z=-0.0319, visibility=0.0002
#
# NOSE: x=0.6150, y=0.7101, z=-0.9845, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6384, y=0.6321, z=-0.9268, visibility=0.9982
#
# LEFT_EYE: x=0.6571, y=0.6308, z=-0.9271, visibility=0.9983
#
# LEFT_EYE_OUTER: x=0.6766, y=0.6306, z=-0.9273, visibility=0.9979
#
# RIGHT_EYE_INNER: x=0.5735, y=0.6362, z=-0.9325, visibility=0.9983
#
# RIGHT_EYE: x=0.5483, y=0.6391, z=-0.9315, visibility=0.9984
#
# RIGHT_EYE_OUTER: x=0.5258, y=0.6430, z=-0.9319, visibility=0.9983
#
# LEFT_EAR: x=0.7087, y=0.6504, z=-0.4892, visibility=0.9984
#
# RIGHT_EAR: x=0.4857, y=0.6697, z=-0.4877, visibility=0.9989
#
# MOUTH_LEFT: x=0.6507, y=0.7805, z=-0.8130, visibility=0.9988
#
# MOUTH_RIGHT: x=0.5746, y=0.7936, z=-0.8147, visibility=0.9991
#
# LEFT_SHOULDER: x=0.8418, y=0.9257, z=-0.2445, visibility=0.9834
#
# RIGHT_SHOULDER: x=0.3585, y=0.9724, z=-0.2528, visibility=0.9895
#
# LEFT_ELBOW: x=0.8816, y=1.0550, z=-0.6115, visibility=0.1017
#
# RIGHT_ELBOW: x=0.3298, y=1.4080, z=-0.5249, visibility=0.2528
#
# LEFT_WRIST: x=0.8476, y=1.2063, z=-1.2982, visibility=0.1235
#
# RIGHT_WRIST: x=0.3942, y=1.5483, z=-1.3311, visibility=0.1249
#
# LEFT_PINKY: x=0.8543, y=1.1980, z=-1.4554, visibility=0.1381
#
# RIGHT_PINKY: x=0.4013, y=1.6337, z=-1.5030, visibility=0.1593
#
# LEFT_INDEX: x=0.8245, y=1.1518, z=-1.4471, visibility=0.1694
#
# RIGHT_INDEX: x=0.4223, y=1.5607, z=-1.5335, visibility=0.2171
#
# LEFT_THUMB: x=0.8072, y=1.1599, z=-1.3240, visibility=0.1681
#
# RIGHT_THUMB: x=0.4299, y=1.5288, z=-1.3681, visibility=0.1976
#
# LEFT_HIP: x=0.7737, y=1.6445, z=-0.0795, visibility=0.0014
#
# RIGHT_HIP: x=0.4660, y=1.6631, z=0.0853, visibility=0.0010
#
# LEFT_KNEE: x=0.7865, y=2.2616, z=-0.1514, visibility=0.0011
#
# RIGHT_KNEE: x=0.5010, y=2.2692, z=0.1298, visibility=0.0010
#
# LEFT_ANKLE: x=0.7977, y=2.8168, z=0.3805, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5249, y=2.8174, z=0.5312, visibility=0.0000
#
# LEFT_HEEL: x=0.8042, y=2.8994, z=0.3933, visibility=0.0001
#
# RIGHT_HEEL: x=0.5206, y=2.8981, z=0.5485, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7575, y=3.0058, z=-0.2887, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5867, y=3.0067, z=-0.1452, visibility=0.0002
#
# NOSE: x=0.6149, y=0.7098, z=-1.0037, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6382, y=0.6316, z=-0.9449, visibility=0.9983
#
# LEFT_EYE: x=0.6568, y=0.6303, z=-0.9452, visibility=0.9983
#
# LEFT_EYE_OUTER: x=0.6763, y=0.6301, z=-0.9456, visibility=0.9979
#
# RIGHT_EYE_INNER: x=0.5730, y=0.6355, z=-0.9515, visibility=0.9983
#
# RIGHT_EYE: x=0.5479, y=0.6385, z=-0.9506, visibility=0.9984
#
# RIGHT_EYE_OUTER: x=0.5256, y=0.6425, z=-0.9510, visibility=0.9984
#
# LEFT_EAR: x=0.7082, y=0.6497, z=-0.4989, visibility=0.9984
#
# RIGHT_EAR: x=0.4857, y=0.6693, z=-0.5016, visibility=0.9989
#
# MOUTH_LEFT: x=0.6506, y=0.7802, z=-0.8289, visibility=0.9988
#
# MOUTH_RIGHT: x=0.5744, y=0.7935, z=-0.8315, visibility=0.9991
#
# LEFT_SHOULDER: x=0.8418, y=0.9256, z=-0.2367, visibility=0.9834
#
# RIGHT_SHOULDER: x=0.3575, y=0.9722, z=-0.2590, visibility=0.9896
#
# LEFT_ELBOW: x=0.8811, y=1.0565, z=-0.5245, visibility=0.0972
#
# RIGHT_ELBOW: x=0.3299, y=1.4084, z=-0.5158, visibility=0.2529
#
# LEFT_WRIST: x=0.8615, y=1.2705, z=-1.1715, visibility=0.1152
#
# RIGHT_WRIST: x=0.3953, y=1.5473, z=-1.3178, visibility=0.1211
#
# LEFT_PINKY: x=0.8744, y=1.3005, z=-1.3251, visibility=0.1295
#
# RIGHT_PINKY: x=0.4031, y=1.6311, z=-1.4933, visibility=0.1550
#
# LEFT_INDEX: x=0.8410, y=1.2602, z=-1.3371, visibility=0.1593
#
# RIGHT_INDEX: x=0.4245, y=1.5585, z=-1.5280, visibility=0.2118
#
# LEFT_THUMB: x=0.8226, y=1.2532, z=-1.2047, visibility=0.1584
#
# RIGHT_THUMB: x=0.4314, y=1.5275, z=-1.3563, visibility=0.1927
#
# LEFT_HIP: x=0.7736, y=1.6439, z=-0.0758, visibility=0.0014
#
# RIGHT_HIP: x=0.4660, y=1.6629, z=0.0816, visibility=0.0010
#
# LEFT_KNEE: x=0.7866, y=2.2594, z=-0.1573, visibility=0.0011
#
# RIGHT_KNEE: x=0.5015, y=2.2683, z=0.1303, visibility=0.0010
#
# LEFT_ANKLE: x=0.7981, y=2.8158, z=0.3627, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5251, y=2.8174, z=0.5431, visibility=0.0000
#
# LEFT_HEEL: x=0.8046, y=2.8990, z=0.3741, visibility=0.0001
#
# RIGHT_HEEL: x=0.5207, y=2.8984, z=0.5615, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7578, y=3.0039, z=-0.3150, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5873, y=3.0059, z=-0.1394, visibility=0.0002

# %%
len(landmarks)   # total number of landmarks
# Out:
# 33

# %%
# name of all landmarks
for lndmrk in mp_pose.PoseLandmark:
    print(lndmrk)
# Out:
# PoseLandmark.NOSE
# PoseLandmark.LEFT_EYE_INNER
# PoseLandmark.LEFT_EYE
# PoseLandmark.LEFT_EYE_OUTER
# PoseLandmark.RIGHT_EYE_INNER
# PoseLandmark.RIGHT_EYE
# PoseLandmark.RIGHT_EYE_OUTER
# PoseLandmark.LEFT_EAR
# PoseLandmark.RIGHT_EAR
# PoseLandmark.MOUTH_LEFT
# PoseLandmark.MOUTH_RIGHT
# PoseLandmark.LEFT_SHOULDER
# PoseLandmark.RIGHT_SHOULDER
# PoseLandmark.LEFT_ELBOW
# PoseLandmark.RIGHT_ELBOW
# PoseLandmark.LEFT_WRIST
# PoseLandmark.RIGHT_WRIST
# PoseLandmark.LEFT_PINKY
# PoseLandmark.RIGHT_PINKY
# PoseLandmark.LEFT_INDEX
# PoseLandmark.RIGHT_INDEX
# PoseLandmark.LEFT_THUMB
# PoseLandmark.RIGHT_THUMB
# PoseLandmark.LEFT_HIP
# PoseLandmark.RIGHT_HIP
# PoseLandmark.LEFT_KNEE
# PoseLandmark.RIGHT_KNEE
# PoseLandmark.LEFT_ANKLE
# PoseLandmark.RIGHT_ANKLE
# PoseLandmark.LEFT_HEEL
# PoseLandmark.RIGHT_HEEL
# PoseLandmark.LEFT_FOOT_INDEX
# PoseLandmark.RIGHT_FOOT_INDEX

# %%
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]   # all values of left shoulder
# Out:
# x: 0.841772556
# y: 0.925619423
# z: -0.236703947
# visibility: 0.983397365

# %%
landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value]   # all values of right shoulder
# Out:
# x: 0.357485712
# y: 0.972153604
# z: -0.259043396
# visibility: 0.989570081

# %%
mp_pose.PoseLandmark.LEFT_SHOULDER.value   # index of left shoulder
# Out:
# 11

# %%
mp_pose.PoseLandmark.RIGHT_SHOULDER.value   # index of right shoulder
# Out:
# 12

# %% [markdown]
# # Calculations

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark

            # function to calculate mid point of shoulder
            def shldr_midpt(ls,rs):   # arguments are left shoulder and right shoulder
                 ls = np.array(ls)
                 rs = np.array(rs)
                 mids = (ls+rs)/2
                 return mids
            
            # function to calculate coordinate of chin
            def chin_coord(n,ll,rl):   # arguments are nose, left side of mouth and right side of mouth
                 n = np.array(n)
                 ll = np.array(ll)
                 rl = np.array(rl)
                 midm = (ll+rl)/2   # mid point of mouth

                 gap = abs(n[1] - midm[1])   # gap between nose and mouth

                 chin_pt = [midm[0], midm[1] + gap * 1.25]   # projecting downwards to estimate chin coordinate; scaling factor is 1.25
                 
                 return chin_pt
            
            # function to calculate angle
            def calculate_angle(a,b,c):
                 a = np.array(a)   # first
                 b = np.array(b)   # mid
                 c = np.array(c)   # end

                 radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])   # Y value - X value
                 angle = np.abs(radians*180.0/np.pi)

                 if angle > 180.0:
                      angle = 360-angle
                 
                 return angle
        
            # getting X and Y value; coordinates of landmark
            shoulderL = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            shoulderR = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            mouthL = [landmarks[mp_pose.PoseLandmark.MOUTH_LEFT.value].x, landmarks[mp_pose.PoseLandmark.MOUTH_LEFT.value].y]
            mouthR = [landmarks[mp_pose.PoseLandmark.MOUTH_RIGHT.value].x, landmarks[mp_pose.PoseLandmark.MOUTH_RIGHT.value].y]

            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x, landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            shoulderM = shldr_midpt(shoulderL,shoulderR)   # mid point of shoulder
            chin = chin_coord(nose,mouthL,mouthR)   # coordinate of chin

            angleL = calculate_angle(shoulderL, shoulderM, nose)   # left dirn
            angleR = calculate_angle(shoulderR, shoulderM, nose)   # right dirn

            # visulaising the chin and mid point of shoulder
            cv2.circle(image,tuple(np.multiply(chin,[640,480]).astype(int)),
                       5,(0,0,255),-1)
            cv2.circle(image,tuple(np.multiply(shoulderM,[640,480]).astype(int)),
                       5,(0,0,255),-1)
            cv2.line(image,tuple(np.multiply(chin,[640,480]).astype(int)),
                     tuple(np.multiply(shoulderM,[640,480]).astype(int)),
                     (0,255,255),2)
            
            if angleR > 80:
                dirn = 'Left'
            
            if angleL > 80:
                dirn = 'Right'

            # visualising angle
            cv2.putText(image, f"Direction: {dirn}",
                        (15,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)

            for id, lm in enumerate(landmarks):
                landmark_name = mp_pose.PoseLandmark(id).name   # get landmark name
                print(f"{landmark_name}: "
                      f"x={lm.x:.4f}, y={lm.y:.4f}, z={lm.z:.4f}, visibility={lm.visibility:.4f} \n")

        except:
            pass
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Camera Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# NOSE: x=0.6101, y=0.7041, z=-1.1306, visibility=0.9992
#
# LEFT_EYE_INNER: x=0.6350, y=0.6327, z=-1.0674, visibility=0.9987
#
# LEFT_EYE: x=0.6533, y=0.6312, z=-1.0676, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6715, y=0.6302, z=-1.0680, visibility=0.9987
#
# RIGHT_EYE_INNER: x=0.5728, y=0.6366, z=-1.0778, visibility=0.9985
#
# RIGHT_EYE: x=0.5491, y=0.6379, z=-1.0771, visibility=0.9988
#
# RIGHT_EYE_OUTER: x=0.5281, y=0.6397, z=-1.0776, visibility=0.9985
#
# LEFT_EAR: x=0.6991, y=0.6522, z=-0.5816, visibility=0.9990
#
# RIGHT_EAR: x=0.4868, y=0.6696, z=-0.6193, visibility=0.9990
#
# MOUTH_LEFT: x=0.6408, y=0.7762, z=-0.9387, visibility=0.9990
#
# MOUTH_RIGHT: x=0.5697, y=0.7814, z=-0.9509, visibility=0.9992
#
# LEFT_SHOULDER: x=0.8319, y=0.9223, z=-0.3006, visibility=0.9913
#
# RIGHT_SHOULDER: x=0.3448, y=0.9641, z=-0.3853, visibility=0.9917
#
# LEFT_ELBOW: x=0.8859, y=1.1025, z=-0.6072, visibility=0.0374
#
# RIGHT_ELBOW: x=0.3159, y=1.3809, z=-0.7562, visibility=0.0605
#
# LEFT_WRIST: x=0.8950, y=1.4939, z=-1.3725, visibility=0.0378
#
# RIGHT_WRIST: x=0.3791, y=1.4486, z=-1.7736, visibility=0.1122
#
# LEFT_PINKY: x=0.9302, y=1.5806, z=-1.5641, visibility=0.0752
#
# RIGHT_PINKY: x=0.3754, y=1.5076, z=-2.0090, visibility=0.1916
#
# LEFT_INDEX: x=0.8749, y=1.5565, z=-1.6245, visibility=0.1187
#
# RIGHT_INDEX: x=0.4017, y=1.4484, z=-2.0476, visibility=0.2789
#
# LEFT_THUMB: x=0.8504, y=1.5251, z=-1.4298, visibility=0.1124
#
# RIGHT_THUMB: x=0.4125, y=1.4276, z=-1.8234, visibility=0.2430
#
# LEFT_HIP: x=0.7783, y=1.6639, z=-0.0087, visibility=0.0005
#
# RIGHT_HIP: x=0.4551, y=1.6824, z=0.0151, visibility=0.0004
#
# LEFT_KNEE: x=0.7809, y=2.3092, z=0.0535, visibility=0.0004
#
# RIGHT_KNEE: x=0.4804, y=2.2974, z=-0.1246, visibility=0.0002
#
# LEFT_ANKLE: x=0.7917, y=2.8804, z=0.6611, visibility=0.0000
#
# RIGHT_ANKLE: x=0.4927, y=2.8853, z=0.3328, visibility=0.0000
#
# LEFT_HEEL: x=0.7978, y=2.9727, z=0.6820, visibility=0.0000
#
# RIGHT_HEEL: x=0.4890, y=2.9827, z=0.3489, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7449, y=3.0712, z=-0.0139, visibility=0.0000
#
# RIGHT_FOOT_INDEX: x=0.5493, y=3.0582, z=-0.4123, visibility=0.0000
#
# NOSE: x=0.6100, y=0.7052, z=-1.2932, visibility=0.9988
#
# LEFT_EYE_INNER: x=0.6349, y=0.6326, z=-1.2494, visibility=0.9980
#
# LEFT_EYE: x=0.6533, y=0.6311, z=-1.2496, visibility=0.9984
#
# LEFT_EYE_OUTER: x=0.6714, y=0.6302, z=-1.2500, visibility=0.9980
#
# RIGHT_EYE_INNER: x=0.5719, y=0.6366, z=-1.2537, visibility=0.9979
#
# RIGHT_EYE: x=0.5477, y=0.6380, z=-1.2529, visibility=0.9983
#
# RIGHT_EYE_OUTER: x=0.5264, y=0.6403, z=-1.2533, visibility=0.9980
#
# LEFT_EAR: x=0.6993, y=0.6515, z=-0.8119, visibility=0.9982
#
# RIGHT_EAR: x=0.4865, y=0.6696, z=-0.8045, visibility=0.9986
#
# MOUTH_LEFT: x=0.6412, y=0.7763, z=-1.1143, visibility=0.9986
#
# MOUTH_RIGHT: x=0.5696, y=0.7840, z=-1.1133, visibility=0.9990
#
# LEFT_SHOULDER: x=0.8347, y=0.9225, z=-0.4647, visibility=0.9894
#
# RIGHT_SHOULDER: x=0.3512, y=0.9650, z=-0.4776, visibility=0.9909
#
# LEFT_ELBOW: x=0.8794, y=1.0490, z=-0.4861, visibility=0.0377
#
# RIGHT_ELBOW: x=0.3195, y=1.3944, z=-0.5320, visibility=0.0722
#
# LEFT_WRIST: x=0.8838, y=1.4746, z=-0.8563, visibility=0.0349
#
# RIGHT_WRIST: x=0.3792, y=1.5992, z=-1.1245, visibility=0.1046
#
# LEFT_PINKY: x=0.9033, y=1.5645, z=-0.9717, visibility=0.0688
#
# RIGHT_PINKY: x=0.3764, y=1.6955, z=-1.2724, visibility=0.1770
#
# LEFT_INDEX: x=0.8635, y=1.5477, z=-1.0188, visibility=0.1086
#
# RIGHT_INDEX: x=0.4030, y=1.6481, z=-1.3484, visibility=0.2579
#
# LEFT_THUMB: x=0.8446, y=1.5176, z=-0.8957, visibility=0.1031
#
# RIGHT_THUMB: x=0.4134, y=1.6097, z=-1.1737, visibility=0.2250
#
# LEFT_HIP: x=0.7764, y=1.6448, z=-0.0611, visibility=0.0005
#
# RIGHT_HIP: x=0.4608, y=1.6626, z=0.0663, visibility=0.0004
#
# LEFT_KNEE: x=0.7809, y=2.2711, z=-0.0614, visibility=0.0004
#
# RIGHT_KNEE: x=0.4932, y=2.2764, z=0.1496, visibility=0.0002
#
# LEFT_ANKLE: x=0.7916, y=2.8351, z=0.5657, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5091, y=2.8337, z=0.6426, visibility=0.0000
#
# LEFT_HEEL: x=0.7978, y=2.9221, z=0.5877, visibility=0.0000
#
# RIGHT_HEEL: x=0.5045, y=2.9197, z=0.6726, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7449, y=3.0243, z=-0.0971, visibility=0.0000
#
# RIGHT_FOOT_INDEX: x=0.5674, y=3.0183, z=-0.0369, visibility=0.0000
#
# NOSE: x=0.6100, y=0.7052, z=-1.3927, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6348, y=0.6314, z=-1.3480, visibility=0.9976
#
# LEFT_EYE: x=0.6531, y=0.6300, z=-1.3481, visibility=0.9980
#
# LEFT_EYE_OUTER: x=0.6712, y=0.6292, z=-1.3485, visibility=0.9974
#
# RIGHT_EYE_INNER: x=0.5716, y=0.6361, z=-1.3537, visibility=0.9976
#
# RIGHT_EYE: x=0.5472, y=0.6379, z=-1.3529, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5258, y=0.6403, z=-1.3534, visibility=0.9977
#
# LEFT_EAR: x=0.6992, y=0.6495, z=-0.9033, visibility=0.9977
#
# RIGHT_EAR: x=0.4865, y=0.6696, z=-0.8995, visibility=0.9984
#
# MOUTH_LEFT: x=0.6415, y=0.7757, z=-1.2115, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5698, y=0.7847, z=-1.2116, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8378, y=0.9239, z=-0.5286, visibility=0.9884
#
# RIGHT_SHOULDER: x=0.3537, y=0.9693, z=-0.5525, visibility=0.9908
#
# LEFT_ELBOW: x=0.8793, y=1.0547, z=-0.4635, visibility=0.0389
#
# RIGHT_ELBOW: x=0.3203, y=1.4129, z=-0.4797, visibility=0.0884
#
# LEFT_WRIST: x=0.8811, y=1.4755, z=-0.8130, visibility=0.0323
#
# RIGHT_WRIST: x=0.3787, y=1.6672, z=-0.9686, visibility=0.0980
#
# LEFT_PINKY: x=0.8955, y=1.5652, z=-0.9254, visibility=0.0631
#
# RIGHT_PINKY: x=0.3763, y=1.7738, z=-1.1063, visibility=0.1638
#
# LEFT_INDEX: x=0.8607, y=1.5493, z=-0.9796, visibility=0.0995
#
# RIGHT_INDEX: x=0.4030, y=1.7314, z=-1.1942, visibility=0.2390
#
# LEFT_THUMB: x=0.8436, y=1.5191, z=-0.8548, visibility=0.0946
#
# RIGHT_THUMB: x=0.4134, y=1.6877, z=-1.0199, visibility=0.2088
#
# LEFT_HIP: x=0.7764, y=1.6422, z=-0.0732, visibility=0.0005
#
# RIGHT_HIP: x=0.4649, y=1.6616, z=0.0783, visibility=0.0004
#
# LEFT_KNEE: x=0.7841, y=2.2641, z=-0.1069, visibility=0.0004
#
# RIGHT_KNEE: x=0.5034, y=2.2751, z=0.1712, visibility=0.0002
#
# LEFT_ANKLE: x=0.7951, y=2.8249, z=0.5409, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5246, y=2.8262, z=0.6954, visibility=0.0000
#
# LEFT_HEEL: x=0.8023, y=2.9112, z=0.5632, visibility=0.0000
#
# RIGHT_HEEL: x=0.5206, y=2.9119, z=0.7270, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7502, y=3.0142, z=-0.1404, visibility=0.0000
#
# RIGHT_FOOT_INDEX: x=0.5866, y=3.0110, z=0.0042, visibility=0.0000
#
# NOSE: x=0.6097, y=0.7058, z=-1.3570, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6340, y=0.6310, z=-1.3078, visibility=0.9976
#
# LEFT_EYE: x=0.6521, y=0.6294, z=-1.3080, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6702, y=0.6287, z=-1.3083, visibility=0.9974
#
# RIGHT_EYE_INNER: x=0.5702, y=0.6360, z=-1.3121, visibility=0.9976
#
# RIGHT_EYE: x=0.5456, y=0.6381, z=-1.3113, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5239, y=0.6411, z=-1.3118, visibility=0.9977
#
# LEFT_EAR: x=0.6988, y=0.6480, z=-0.8504, visibility=0.9976
#
# RIGHT_EAR: x=0.4853, y=0.6701, z=-0.8416, visibility=0.9984
#
# MOUTH_LEFT: x=0.6415, y=0.7757, z=-1.1735, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5696, y=0.7867, z=-1.1718, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8381, y=0.9241, z=-0.4986, visibility=0.9880
#
# RIGHT_SHOULDER: x=0.3566, y=0.9727, z=-0.5127, visibility=0.9908
#
# LEFT_ELBOW: x=0.8783, y=1.0554, z=-0.4657, visibility=0.0417
#
# RIGHT_ELBOW: x=0.3269, y=1.4170, z=-0.4980, visibility=0.1040
#
# LEFT_WRIST: x=0.8769, y=1.4637, z=-1.0292, visibility=0.0306
#
# RIGHT_WRIST: x=0.3797, y=1.6587, z=-1.0815, visibility=0.0940
#
# LEFT_PINKY: x=0.8881, y=1.5551, z=-1.1690, visibility=0.0589
#
# RIGHT_PINKY: x=0.3777, y=1.7646, z=-1.2281, visibility=0.1549
#
# LEFT_INDEX: x=0.8543, y=1.5352, z=-1.2189, visibility=0.0925
#
# RIGHT_INDEX: x=0.4041, y=1.7178, z=-1.3058, visibility=0.2258
#
# LEFT_THUMB: x=0.8396, y=1.5061, z=-1.0737, visibility=0.0883
#
# RIGHT_THUMB: x=0.4148, y=1.6757, z=-1.1302, visibility=0.1977
#
# LEFT_HIP: x=0.7771, y=1.6408, z=-0.0799, visibility=0.0005
#
# RIGHT_HIP: x=0.4681, y=1.6610, z=0.0852, visibility=0.0004
#
# LEFT_KNEE: x=0.7871, y=2.2593, z=-0.2047, visibility=0.0004
#
# RIGHT_KNEE: x=0.5074, y=2.2741, z=0.2031, visibility=0.0002
#
# LEFT_ANKLE: x=0.7961, y=2.8199, z=0.3680, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5258, y=2.8253, z=0.7181, visibility=0.0000
#
# LEFT_HEEL: x=0.8034, y=2.9051, z=0.3815, visibility=0.0000
#
# RIGHT_HEEL: x=0.5212, y=2.9111, z=0.7477, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7515, y=3.0107, z=-0.3381, visibility=0.0000
#
# RIGHT_FOOT_INDEX: x=0.5879, y=3.0107, z=0.0273, visibility=0.0000
#
# NOSE: x=0.6072, y=0.7058, z=-1.3032, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6314, y=0.6308, z=-1.2499, visibility=0.9976
#
# LEFT_EYE: x=0.6496, y=0.6292, z=-1.2501, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6676, y=0.6285, z=-1.2504, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5662, y=0.6361, z=-1.2570, visibility=0.9976
#
# RIGHT_EYE: x=0.5421, y=0.6386, z=-1.2562, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5210, y=0.6422, z=-1.2566, visibility=0.9978
#
# LEFT_EAR: x=0.6979, y=0.6476, z=-0.7883, visibility=0.9976
#
# RIGHT_EAR: x=0.4847, y=0.6714, z=-0.8012, visibility=0.9984
#
# MOUTH_LEFT: x=0.6413, y=0.7751, z=-1.1179, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5683, y=0.7873, z=-1.1207, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8381, y=0.9249, z=-0.4565, visibility=0.9879
#
# RIGHT_SHOULDER: x=0.3577, y=0.9761, z=-0.5110, visibility=0.9912
#
# LEFT_ELBOW: x=0.8784, y=1.0546, z=-0.5918, visibility=0.0437
#
# RIGHT_ELBOW: x=0.3268, y=1.4195, z=-0.5332, visibility=0.1298
#
# LEFT_WRIST: x=0.8770, y=1.4358, z=-1.2736, visibility=0.0289
#
# RIGHT_WRIST: x=0.3652, y=1.6499, z=-1.2080, visibility=0.0924
#
# LEFT_PINKY: x=0.8884, y=1.5223, z=-1.4415, visibility=0.0549
#
# RIGHT_PINKY: x=0.3600, y=1.7516, z=-1.3775, visibility=0.1491
#
# LEFT_INDEX: x=0.8518, y=1.4964, z=-1.4835, visibility=0.0861
#
# RIGHT_INDEX: x=0.3883, y=1.7018, z=-1.4519, visibility=0.2175
#
# LEFT_THUMB: x=0.8377, y=1.4696, z=-1.3198, visibility=0.0822
#
# RIGHT_THUMB: x=0.4011, y=1.6622, z=-1.2592, visibility=0.1907
#
# LEFT_HIP: x=0.7770, y=1.6413, z=-0.0773, visibility=0.0005
#
# RIGHT_HIP: x=0.4706, y=1.6613, z=0.0830, visibility=0.0004
#
# LEFT_KNEE: x=0.7893, y=2.2608, z=-0.2547, visibility=0.0005
#
# RIGHT_KNEE: x=0.5117, y=2.2749, z=0.1258, visibility=0.0003
#
# LEFT_ANKLE: x=0.8019, y=2.8230, z=0.2761, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5365, y=2.8287, z=0.6053, visibility=0.0000
#
# LEFT_HEEL: x=0.8100, y=2.9099, z=0.2861, visibility=0.0000
#
# RIGHT_HEEL: x=0.5317, y=2.9154, z=0.6345, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7585, y=3.0098, z=-0.4267, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5993, y=3.0128, z=-0.1110, visibility=0.0001
#
# NOSE: x=0.6050, y=0.7058, z=-1.2820, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6292, y=0.6307, z=-1.2278, visibility=0.9976
#
# LEFT_EYE: x=0.6475, y=0.6291, z=-1.2280, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6655, y=0.6284, z=-1.2284, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5633, y=0.6362, z=-1.2347, visibility=0.9976
#
# RIGHT_EYE: x=0.5395, y=0.6390, z=-1.2339, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5188, y=0.6430, z=-1.2344, visibility=0.9978
#
# LEFT_EAR: x=0.6972, y=0.6473, z=-0.7695, visibility=0.9977
#
# RIGHT_EAR: x=0.4841, y=0.6723, z=-0.7841, visibility=0.9985
#
# MOUTH_LEFT: x=0.6409, y=0.7748, z=-1.0974, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5669, y=0.7878, z=-1.1000, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8381, y=0.9254, z=-0.4428, visibility=0.9878
#
# RIGHT_SHOULDER: x=0.3582, y=0.9776, z=-0.5048, visibility=0.9915
#
# LEFT_ELBOW: x=0.8785, y=1.0540, z=-0.6405, visibility=0.0456
#
# RIGHT_ELBOW: x=0.3266, y=1.4204, z=-0.5520, visibility=0.1513
#
# LEFT_WRIST: x=0.8769, y=1.4207, z=-1.3430, visibility=0.0274
#
# RIGHT_WRIST: x=0.3596, y=1.6417, z=-1.2618, visibility=0.0908
#
# LEFT_PINKY: x=0.8880, y=1.5042, z=-1.5171, visibility=0.0514
#
# RIGHT_PINKY: x=0.3535, y=1.7414, z=-1.4369, visibility=0.1438
#
# LEFT_INDEX: x=0.8496, y=1.4754, z=-1.5588, visibility=0.0804
#
# RIGHT_INDEX: x=0.3820, y=1.6893, z=-1.5096, visibility=0.2100
#
# LEFT_THUMB: x=0.8359, y=1.4496, z=-1.3897, visibility=0.0769
#
# RIGHT_THUMB: x=0.3954, y=1.6507, z=-1.3134, visibility=0.1842
#
# LEFT_HIP: x=0.7768, y=1.6419, z=-0.0767, visibility=0.0005
#
# RIGHT_HIP: x=0.4715, y=1.6619, z=0.0824, visibility=0.0004
#
# LEFT_KNEE: x=0.7904, y=2.2608, z=-0.2459, visibility=0.0005
#
# RIGHT_KNEE: x=0.5129, y=2.2752, z=0.1172, visibility=0.0003
#
# LEFT_ANKLE: x=0.8046, y=2.8233, z=0.2933, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5392, y=2.8293, z=0.5682, visibility=0.0000
#
# LEFT_HEEL: x=0.8129, y=2.9109, z=0.3044, visibility=0.0000
#
# RIGHT_HEEL: x=0.5345, y=2.9159, z=0.5912, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7617, y=3.0082, z=-0.4066, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6017, y=3.0131, z=-0.1382, visibility=0.0001
#
# NOSE: x=0.6037, y=0.7076, z=-1.2764, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6287, y=0.6313, z=-1.2257, visibility=0.9976
#
# LEFT_EYE: x=0.6473, y=0.6296, z=-1.2259, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6655, y=0.6289, z=-1.2262, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5609, y=0.6368, z=-1.2275, visibility=0.9977
#
# RIGHT_EYE: x=0.5370, y=0.6397, z=-1.2268, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5164, y=0.6438, z=-1.2272, visibility=0.9979
#
# LEFT_EAR: x=0.6981, y=0.6475, z=-0.7760, visibility=0.9977
#
# RIGHT_EAR: x=0.4830, y=0.6728, z=-0.7687, visibility=0.9985
#
# MOUTH_LEFT: x=0.6409, y=0.7756, z=-1.0948, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5646, y=0.7902, z=-1.0914, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8390, y=0.9256, z=-0.4520, visibility=0.9876
#
# RIGHT_SHOULDER: x=0.3590, y=0.9775, z=-0.4430, visibility=0.9916
#
# LEFT_ELBOW: x=0.8811, y=1.0549, z=-0.6329, visibility=0.0471
#
# RIGHT_ELBOW: x=0.3228, y=1.4191, z=-0.4873, visibility=0.1606
#
# LEFT_WRIST: x=0.8780, y=1.4211, z=-1.3025, visibility=0.0260
#
# RIGHT_WRIST: x=0.3459, y=1.6479, z=-1.2119, visibility=0.0863
#
# LEFT_PINKY: x=0.8900, y=1.5131, z=-1.4853, visibility=0.0481
#
# RIGHT_PINKY: x=0.3377, y=1.7526, z=-1.3828, visibility=0.1357
#
# LEFT_INDEX: x=0.8503, y=1.4861, z=-1.5475, visibility=0.0751
#
# RIGHT_INDEX: x=0.3691, y=1.7029, z=-1.4572, visibility=0.1988
#
# LEFT_THUMB: x=0.8361, y=1.4591, z=-1.3564, visibility=0.0720
#
# RIGHT_THUMB: x=0.3834, y=1.6623, z=-1.2650, visibility=0.1745
#
# LEFT_HIP: x=0.7781, y=1.6465, z=-0.0882, visibility=0.0006
#
# RIGHT_HIP: x=0.4749, y=1.6646, z=0.0939, visibility=0.0005
#
# LEFT_KNEE: x=0.7914, y=2.2616, z=-0.2408, visibility=0.0005
#
# RIGHT_KNEE: x=0.5129, y=2.2784, z=0.1233, visibility=0.0003
#
# LEFT_ANKLE: x=0.8044, y=2.8252, z=0.3191, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5367, y=2.8313, z=0.5677, visibility=0.0000
#
# LEFT_HEEL: x=0.8128, y=2.9130, z=0.3326, visibility=0.0000
#
# RIGHT_HEEL: x=0.5324, y=2.9189, z=0.5887, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7606, y=3.0112, z=-0.3820, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5980, y=3.0149, z=-0.1356, visibility=0.0001
#
# NOSE: x=0.6035, y=0.7088, z=-1.0544, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6284, y=0.6319, z=-1.0082, visibility=0.9976
#
# LEFT_EYE: x=0.6470, y=0.6301, z=-1.0083, visibility=0.9978
#
# LEFT_EYE_OUTER: x=0.6652, y=0.6294, z=-1.0085, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5607, y=0.6376, z=-1.0077, visibility=0.9977
#
# RIGHT_EYE: x=0.5367, y=0.6408, z=-1.0067, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5161, y=0.6449, z=-1.0071, visibility=0.9979
#
# LEFT_EAR: x=0.6981, y=0.6479, z=-0.6038, visibility=0.9977
#
# RIGHT_EAR: x=0.4829, y=0.6740, z=-0.5708, visibility=0.9985
#
# MOUTH_LEFT: x=0.6409, y=0.7764, z=-0.8939, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5645, y=0.7922, z=-0.8852, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8388, y=0.9256, z=-0.3560, visibility=0.9871
#
# RIGHT_SHOULDER: x=0.3597, y=0.9777, z=-0.3199, visibility=0.9916
#
# LEFT_ELBOW: x=0.8746, y=1.0316, z=-0.6027, visibility=0.0475
#
# RIGHT_ELBOW: x=0.3280, y=1.4200, z=-0.4522, visibility=0.1644
#
# LEFT_WRIST: x=0.8732, y=1.3440, z=-1.1766, visibility=0.0253
#
# RIGHT_WRIST: x=0.3554, y=1.6410, z=-1.1630, visibility=0.0829
#
# LEFT_PINKY: x=0.8842, y=1.4048, z=-1.3304, visibility=0.0461
#
# RIGHT_PINKY: x=0.3476, y=1.7419, z=-1.3242, visibility=0.1299
#
# LEFT_INDEX: x=0.8457, y=1.3748, z=-1.3420, visibility=0.0715
#
# RIGHT_INDEX: x=0.3771, y=1.6884, z=-1.3872, visibility=0.1905
#
# LEFT_THUMB: x=0.8316, y=1.3602, z=-1.2084, visibility=0.0690
#
# RIGHT_THUMB: x=0.3920, y=1.6493, z=-1.2119, visibility=0.1679
#
# LEFT_HIP: x=0.7778, y=1.6487, z=-0.0852, visibility=0.0005
#
# RIGHT_HIP: x=0.4746, y=1.6682, z=0.0909, visibility=0.0005
#
# LEFT_KNEE: x=0.7915, y=2.2628, z=-0.1947, visibility=0.0005
#
# RIGHT_KNEE: x=0.5135, y=2.2802, z=0.1330, visibility=0.0003
#
# LEFT_ANKLE: x=0.8045, y=2.8271, z=0.3640, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5361, y=2.8330, z=0.5650, visibility=0.0000
#
# LEFT_HEEL: x=0.8127, y=2.9151, z=0.3777, visibility=0.0000
#
# RIGHT_HEEL: x=0.5319, y=2.9207, z=0.5867, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7613, y=3.0129, z=-0.3169, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5960, y=3.0154, z=-0.1106, visibility=0.0001
#
# NOSE: x=0.6036, y=0.7097, z=-1.0159, visibility=0.9986
#
# LEFT_EYE_INNER: x=0.6284, y=0.6323, z=-0.9680, visibility=0.9976
#
# LEFT_EYE: x=0.6469, y=0.6304, z=-0.9681, visibility=0.9978
#
# LEFT_EYE_OUTER: x=0.6651, y=0.6297, z=-0.9683, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5608, y=0.6385, z=-0.9692, visibility=0.9977
#
# RIGHT_EYE: x=0.5368, y=0.6419, z=-0.9682, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5161, y=0.6463, z=-0.9686, visibility=0.9979
#
# LEFT_EAR: x=0.6980, y=0.6482, z=-0.5612, visibility=0.9977
#
# RIGHT_EAR: x=0.4828, y=0.6754, z=-0.5351, visibility=0.9985
#
# MOUTH_LEFT: x=0.6410, y=0.7769, z=-0.8550, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5645, y=0.7935, z=-0.8485, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8387, y=0.9256, z=-0.3177, visibility=0.9870
#
# RIGHT_SHOULDER: x=0.3600, y=0.9782, z=-0.2959, visibility=0.9917
#
# LEFT_ELBOW: x=0.8714, y=1.0236, z=-0.5862, visibility=0.0478
#
# RIGHT_ELBOW: x=0.3310, y=1.4221, z=-0.4458, visibility=0.1685
#
# LEFT_WRIST: x=0.8708, y=1.3263, z=-1.1659, visibility=0.0248
#
# RIGHT_WRIST: x=0.3600, y=1.6426, z=-1.1601, visibility=0.0799
#
# LEFT_PINKY: x=0.8814, y=1.3822, z=-1.3198, visibility=0.0444
#
# RIGHT_PINKY: x=0.3514, y=1.7433, z=-1.3227, visibility=0.1246
#
# LEFT_INDEX: x=0.8431, y=1.3517, z=-1.3293, visibility=0.0685
#
# RIGHT_INDEX: x=0.3810, y=1.6887, z=-1.3846, visibility=0.1830
#
# LEFT_THUMB: x=0.8288, y=1.3386, z=-1.1972, visibility=0.0664
#
# RIGHT_THUMB: x=0.3965, y=1.6492, z=-1.2087, visibility=0.1618
#
# LEFT_HIP: x=0.7777, y=1.6508, z=-0.0829, visibility=0.0006
#
# RIGHT_HIP: x=0.4745, y=1.6716, z=0.0887, visibility=0.0005
#
# LEFT_KNEE: x=0.7918, y=2.2638, z=-0.1767, visibility=0.0005
#
# RIGHT_KNEE: x=0.5138, y=2.2817, z=0.1326, visibility=0.0004
#
# LEFT_ANKLE: x=0.8050, y=2.8285, z=0.3755, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5363, y=2.8343, z=0.5599, visibility=0.0000
#
# LEFT_HEEL: x=0.8131, y=2.9164, z=0.3890, visibility=0.0000
#
# RIGHT_HEEL: x=0.5324, y=2.9218, z=0.5813, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7622, y=3.0145, z=-0.2951, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5951, y=3.0159, z=-0.1110, visibility=0.0001
#
# NOSE: x=0.6041, y=0.7099, z=-1.2550, visibility=0.9985
#
# LEFT_EYE_INNER: x=0.6286, y=0.6324, z=-1.2047, visibility=0.9976
#
# LEFT_EYE: x=0.6470, y=0.6305, z=-1.2050, visibility=0.9978
#
# LEFT_EYE_OUTER: x=0.6652, y=0.6298, z=-1.2053, visibility=0.9972
#
# RIGHT_EYE_INNER: x=0.5612, y=0.6385, z=-1.2089, visibility=0.9977
#
# RIGHT_EYE: x=0.5370, y=0.6420, z=-1.2081, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5162, y=0.6464, z=-1.2085, visibility=0.9979
#
# LEFT_EAR: x=0.6980, y=0.6483, z=-0.7483, visibility=0.9977
#
# RIGHT_EAR: x=0.4825, y=0.6756, z=-0.7383, visibility=0.9985
#
# MOUTH_LEFT: x=0.6416, y=0.7772, z=-1.0701, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5649, y=0.7943, z=-1.0686, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8393, y=0.9271, z=-0.4261, visibility=0.9867
#
# RIGHT_SHOULDER: x=0.3577, y=0.9815, z=-0.4054, visibility=0.9915
#
# LEFT_ELBOW: x=0.8725, y=1.0318, z=-0.6191, visibility=0.0478
#
# RIGHT_ELBOW: x=0.3285, y=1.4289, z=-0.4656, visibility=0.1730
#
# LEFT_WRIST: x=0.8687, y=1.3850, z=-1.2339, visibility=0.0237
#
# RIGHT_WRIST: x=0.3592, y=1.6414, z=-1.1912, visibility=0.0761
#
# LEFT_PINKY: x=0.8791, y=1.4607, z=-1.3980, visibility=0.0419
#
# RIGHT_PINKY: x=0.3522, y=1.7392, z=-1.3551, visibility=0.1183
#
# LEFT_INDEX: x=0.8396, y=1.4239, z=-1.4359, visibility=0.0647
#
# RIGHT_INDEX: x=0.3811, y=1.6840, z=-1.3968, visibility=0.1745
#
# LEFT_THUMB: x=0.8253, y=1.3999, z=-1.2762, visibility=0.0627
#
# RIGHT_THUMB: x=0.3956, y=1.6450, z=-1.2306, visibility=0.1542
#
# LEFT_HIP: x=0.7777, y=1.6561, z=-0.0821, visibility=0.0006
#
# RIGHT_HIP: x=0.4745, y=1.6770, z=0.0879, visibility=0.0005
#
# LEFT_KNEE: x=0.7924, y=2.2676, z=-0.2095, visibility=0.0006
#
# RIGHT_KNEE: x=0.5148, y=2.2853, z=0.0571, visibility=0.0004
#
# LEFT_ANKLE: x=0.8052, y=2.8310, z=0.3458, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5363, y=2.8382, z=0.4461, visibility=0.0000
#
# LEFT_HEEL: x=0.8132, y=2.9190, z=0.3591, visibility=0.0000
#
# RIGHT_HEEL: x=0.5323, y=2.9272, z=0.4619, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7619, y=3.0172, z=-0.3419, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5944, y=3.0195, z=-0.2533, visibility=0.0001
#
# NOSE: x=0.6046, y=0.7099, z=-1.0660, visibility=0.9983
#
# LEFT_EYE_INNER: x=0.6289, y=0.6321, z=-1.0164, visibility=0.9973
#
# LEFT_EYE: x=0.6472, y=0.6302, z=-1.0167, visibility=0.9975
#
# LEFT_EYE_OUTER: x=0.6655, y=0.6296, z=-1.0169, visibility=0.9969
#
# RIGHT_EYE_INNER: x=0.5615, y=0.6384, z=-1.0191, visibility=0.9974
#
# RIGHT_EYE: x=0.5371, y=0.6420, z=-1.0182, visibility=0.9978
#
# RIGHT_EYE_OUTER: x=0.5162, y=0.6464, z=-1.0186, visibility=0.9976
#
# LEFT_EAR: x=0.6982, y=0.6483, z=-0.6013, visibility=0.9974
#
# RIGHT_EAR: x=0.4823, y=0.6757, z=-0.5823, visibility=0.9983
#
# MOUTH_LEFT: x=0.6424, y=0.7772, z=-0.9011, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5658, y=0.7944, z=-0.8967, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8394, y=0.9269, z=-0.3400, visibility=0.9858
#
# RIGHT_SHOULDER: x=0.3576, y=0.9814, z=-0.3101, visibility=0.9911
#
# LEFT_ELBOW: x=0.8728, y=1.0290, z=-0.6092, visibility=0.0475
#
# RIGHT_ELBOW: x=0.3217, y=1.4279, z=-0.4348, visibility=0.1792
#
# LEFT_WRIST: x=0.8690, y=1.3199, z=-1.2085, visibility=0.0241
#
# RIGHT_WRIST: x=0.3542, y=1.6459, z=-1.1091, visibility=0.0739
#
# LEFT_PINKY: x=0.8798, y=1.3707, z=-1.3580, visibility=0.0412
#
# RIGHT_PINKY: x=0.3475, y=1.7476, z=-1.2600, visibility=0.1131
#
# LEFT_INDEX: x=0.8398, y=1.3449, z=-1.3652, visibility=0.0630
#
# RIGHT_INDEX: x=0.3775, y=1.6959, z=-1.3172, visibility=0.1670
#
# LEFT_THUMB: x=0.8255, y=1.3334, z=-1.2378, visibility=0.0615
#
# RIGHT_THUMB: x=0.3912, y=1.6557, z=-1.1535, visibility=0.1482
#
# LEFT_HIP: x=0.7783, y=1.6571, z=-0.0807, visibility=0.0006
#
# RIGHT_HIP: x=0.4752, y=1.6790, z=0.0865, visibility=0.0005
#
# LEFT_KNEE: x=0.7927, y=2.2682, z=-0.1424, visibility=0.0006
#
# RIGHT_KNEE: x=0.5145, y=2.2857, z=0.0958, visibility=0.0004
#
# LEFT_ANKLE: x=0.8054, y=2.8311, z=0.4236, visibility=0.0000
#
# RIGHT_ANKLE: x=0.5357, y=2.8383, z=0.4877, visibility=0.0000
#
# LEFT_HEEL: x=0.8135, y=2.9183, z=0.4415, visibility=0.0000
#
# RIGHT_HEEL: x=0.5317, y=2.9259, z=0.5075, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7621, y=3.0182, z=-0.2157, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5939, y=3.0203, z=-0.1629, visibility=0.0001
#
# NOSE: x=0.6055, y=0.7099, z=-1.0313, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6295, y=0.6319, z=-0.9817, visibility=0.9970
#
# LEFT_EYE: x=0.6478, y=0.6300, z=-0.9820, visibility=0.9972
#
# LEFT_EYE_OUTER: x=0.6661, y=0.6294, z=-0.9823, visibility=0.9965
#
# RIGHT_EYE_INNER: x=0.5623, y=0.6384, z=-0.9852, visibility=0.9971
#
# RIGHT_EYE: x=0.5376, y=0.6420, z=-0.9843, visibility=0.9975
#
# RIGHT_EYE_OUTER: x=0.5165, y=0.6465, z=-0.9848, visibility=0.9973
#
# LEFT_EAR: x=0.6984, y=0.6483, z=-0.5689, visibility=0.9971
#
# RIGHT_EAR: x=0.4823, y=0.6758, z=-0.5542, visibility=0.9982
#
# MOUTH_LEFT: x=0.6435, y=0.7772, z=-0.8674, visibility=0.9981
#
# MOUTH_RIGHT: x=0.5671, y=0.7945, z=-0.8643, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8394, y=0.9265, z=-0.3129, visibility=0.9848
#
# RIGHT_SHOULDER: x=0.3576, y=0.9812, z=-0.2913, visibility=0.9905
#
# LEFT_ELBOW: x=0.8730, y=1.0273, z=-0.6083, visibility=0.0475
#
# RIGHT_ELBOW: x=0.3204, y=1.4274, z=-0.4411, visibility=0.1842
#
# LEFT_WRIST: x=0.8694, y=1.2848, z=-1.2097, visibility=0.0250
#
# RIGHT_WRIST: x=0.3540, y=1.6453, z=-1.1197, visibility=0.0720
#
# LEFT_PINKY: x=0.8809, y=1.3282, z=-1.3590, visibility=0.0412
#
# RIGHT_PINKY: x=0.3478, y=1.7477, z=-1.2715, visibility=0.1088
#
# LEFT_INDEX: x=0.8405, y=1.3015, z=-1.3685, visibility=0.0623
#
# RIGHT_INDEX: x=0.3776, y=1.6961, z=-1.3293, visibility=0.1607
#
# LEFT_THUMB: x=0.8259, y=1.2939, z=-1.2394, visibility=0.0613
#
# RIGHT_THUMB: x=0.3911, y=1.6560, z=-1.1646, visibility=0.1432
#
# LEFT_HIP: x=0.7786, y=1.6576, z=-0.0797, visibility=0.0006
#
# RIGHT_HIP: x=0.4760, y=1.6801, z=0.0855, visibility=0.0005
#
# LEFT_KNEE: x=0.7929, y=2.2689, z=-0.1173, visibility=0.0006
#
# RIGHT_KNEE: x=0.5143, y=2.2857, z=0.1079, visibility=0.0004
#
# LEFT_ANKLE: x=0.8056, y=2.8303, z=0.4476, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5355, y=2.8377, z=0.5065, visibility=0.0000
#
# LEFT_HEEL: x=0.8137, y=2.9162, z=0.4658, visibility=0.0000
#
# RIGHT_HEEL: x=0.5315, y=2.9241, z=0.5276, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7625, y=3.0184, z=-0.1861, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5941, y=3.0207, z=-0.1359, visibility=0.0001
#
# NOSE: x=0.6063, y=0.7098, z=-1.2383, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6312, y=0.6317, z=-1.1805, visibility=0.9970
#
# LEFT_EYE: x=0.6499, y=0.6299, z=-1.1808, visibility=0.9973
#
# LEFT_EYE_OUTER: x=0.6689, y=0.6294, z=-1.1812, visibility=0.9965
#
# RIGHT_EYE_INNER: x=0.5634, y=0.6380, z=-1.1886, visibility=0.9972
#
# RIGHT_EYE: x=0.5384, y=0.6416, z=-1.1878, visibility=0.9976
#
# RIGHT_EYE_OUTER: x=0.5170, y=0.6461, z=-1.1882, visibility=0.9974
#
# LEFT_EAR: x=0.6999, y=0.6484, z=-0.7134, visibility=0.9972
#
# RIGHT_EAR: x=0.4823, y=0.6753, z=-0.7211, visibility=0.9982
#
# MOUTH_LEFT: x=0.6444, y=0.7773, z=-1.0526, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5675, y=0.7943, z=-1.0562, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8394, y=0.9273, z=-0.3928, visibility=0.9849
#
# RIGHT_SHOULDER: x=0.3566, y=0.9812, z=-0.4169, visibility=0.9906
#
# LEFT_ELBOW: x=0.8734, y=1.0403, z=-0.6127, visibility=0.0474
#
# RIGHT_ELBOW: x=0.3198, y=1.4296, z=-0.5869, visibility=0.1857
#
# LEFT_WRIST: x=0.8748, y=1.4226, z=-1.2270, visibility=0.0240
#
# RIGHT_WRIST: x=0.3566, y=1.6434, z=-1.3883, visibility=0.0705
#
# LEFT_PINKY: x=0.8902, y=1.5075, z=-1.3850, visibility=0.0392
#
# RIGHT_PINKY: x=0.3524, y=1.7413, z=-1.5765, visibility=0.1056
#
# LEFT_INDEX: x=0.8460, y=1.4866, z=-1.4209, visibility=0.0592
#
# RIGHT_INDEX: x=0.3820, y=1.6864, z=-1.6368, visibility=0.1563
#
# LEFT_THUMB: x=0.8301, y=1.4581, z=-1.2672, visibility=0.0584
#
# RIGHT_THUMB: x=0.3943, y=1.6473, z=-1.4372, visibility=0.1390
#
# LEFT_HIP: x=0.7786, y=1.6577, z=-0.0754, visibility=0.0006
#
# RIGHT_HIP: x=0.4748, y=1.6800, z=0.0812, visibility=0.0005
#
# LEFT_KNEE: x=0.7922, y=2.2694, z=-0.1158, visibility=0.0007
#
# RIGHT_KNEE: x=0.5111, y=2.2847, z=0.0905, visibility=0.0005
#
# LEFT_ANKLE: x=0.8050, y=2.8302, z=0.4698, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5323, y=2.8362, z=0.5149, visibility=0.0000
#
# LEFT_HEEL: x=0.8131, y=2.9168, z=0.4872, visibility=0.0000
#
# RIGHT_HEEL: x=0.5283, y=2.9237, z=0.5362, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7607, y=3.0173, z=-0.1991, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5935, y=3.0189, z=-0.1461, visibility=0.0001
#
# NOSE: x=0.6084, y=0.7099, z=-1.3550, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6327, y=0.6319, z=-1.3044, visibility=0.9971
#
# LEFT_EYE: x=0.6511, y=0.6302, z=-1.3046, visibility=0.9974
#
# LEFT_EYE_OUTER: x=0.6699, y=0.6297, z=-1.3051, visibility=0.9966
#
# RIGHT_EYE_INNER: x=0.5656, y=0.6382, z=-1.3141, visibility=0.9972
#
# RIGHT_EYE: x=0.5401, y=0.6419, z=-1.3133, visibility=0.9976
#
# RIGHT_EYE_OUTER: x=0.5182, y=0.6464, z=-1.3136, visibility=0.9974
#
# LEFT_EAR: x=0.6999, y=0.6486, z=-0.8344, visibility=0.9972
#
# RIGHT_EAR: x=0.4823, y=0.6757, z=-0.8529, visibility=0.9983
#
# MOUTH_LEFT: x=0.6457, y=0.7775, z=-1.1647, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5693, y=0.7944, z=-1.1711, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8393, y=0.9266, z=-0.4920, visibility=0.9851
#
# RIGHT_SHOULDER: x=0.3551, y=0.9813, z=-0.5114, visibility=0.9902
#
# LEFT_ELBOW: x=0.8787, y=1.0444, z=-0.6312, visibility=0.0479
#
# RIGHT_ELBOW: x=0.3268, y=1.4325, z=-0.6480, visibility=0.1825
#
# LEFT_WRIST: x=0.8893, y=1.4441, z=-1.2262, visibility=0.0235
#
# RIGHT_WRIST: x=0.3769, y=1.6050, z=-1.4450, visibility=0.0696
#
# LEFT_PINKY: x=0.9068, y=1.5311, z=-1.3842, visibility=0.0379
#
# RIGHT_PINKY: x=0.3777, y=1.6822, z=-1.6294, visibility=0.1034
#
# LEFT_INDEX: x=0.8633, y=1.5086, z=-1.4228, visibility=0.0572
#
# RIGHT_INDEX: x=0.4001, y=1.6180, z=-1.6910, visibility=0.1533
#
# LEFT_THUMB: x=0.8461, y=1.4804, z=-1.2667, visibility=0.0566
#
# RIGHT_THUMB: x=0.4100, y=1.5859, z=-1.4939, visibility=0.1361
#
# LEFT_HIP: x=0.7864, y=1.6541, z=-0.0753, visibility=0.0006
#
# RIGHT_HIP: x=0.4800, y=1.6793, z=0.0810, visibility=0.0005
#
# LEFT_KNEE: x=0.7986, y=2.2691, z=-0.1143, visibility=0.0007
#
# RIGHT_KNEE: x=0.5165, y=2.2848, z=0.1052, visibility=0.0005
#
# LEFT_ANKLE: x=0.8110, y=2.8302, z=0.4912, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5360, y=2.8364, z=0.5744, visibility=0.0000
#
# LEFT_HEEL: x=0.8185, y=2.9170, z=0.5104, visibility=0.0000
#
# RIGHT_HEEL: x=0.5319, y=2.9236, z=0.5997, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7684, y=3.0168, z=-0.1882, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5980, y=3.0191, z=-0.1159, visibility=0.0001
#
# NOSE: x=0.6092, y=0.7101, z=-1.3440, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6332, y=0.6321, z=-1.2944, visibility=0.9972
#
# LEFT_EYE: x=0.6515, y=0.6305, z=-1.2947, visibility=0.9974
#
# LEFT_EYE_OUTER: x=0.6703, y=0.6300, z=-1.2951, visibility=0.9967
#
# RIGHT_EYE_INNER: x=0.5664, y=0.6384, z=-1.3033, visibility=0.9973
#
# RIGHT_EYE: x=0.5406, y=0.6421, z=-1.3025, visibility=0.9976
#
# RIGHT_EYE_OUTER: x=0.5186, y=0.6466, z=-1.3028, visibility=0.9975
#
# LEFT_EAR: x=0.6999, y=0.6487, z=-0.8301, visibility=0.9973
#
# RIGHT_EAR: x=0.4823, y=0.6759, z=-0.8448, visibility=0.9983
#
# MOUTH_LEFT: x=0.6462, y=0.7776, z=-1.1561, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5700, y=0.7944, z=-1.1614, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8392, y=0.9262, z=-0.4947, visibility=0.9855
#
# RIGHT_SHOULDER: x=0.3541, y=0.9813, z=-0.5049, visibility=0.9900
#
# LEFT_ELBOW: x=0.8823, y=1.0475, z=-0.6269, visibility=0.0488
#
# RIGHT_ELBOW: x=0.3294, y=1.4357, z=-0.6315, visibility=0.1794
#
# LEFT_WRIST: x=0.8987, y=1.4603, z=-1.2017, visibility=0.0229
#
# RIGHT_WRIST: x=0.3818, y=1.5984, z=-1.4257, visibility=0.0682
#
# LEFT_PINKY: x=0.9177, y=1.5503, z=-1.3596, visibility=0.0366
#
# RIGHT_PINKY: x=0.3825, y=1.6742, z=-1.6095, visibility=0.1009
#
# LEFT_INDEX: x=0.8739, y=1.5296, z=-1.4082, visibility=0.0552
#
# RIGHT_INDEX: x=0.4046, y=1.6109, z=-1.6740, visibility=0.1499
#
# LEFT_THUMB: x=0.8560, y=1.5006, z=-1.2463, visibility=0.0548
#
# RIGHT_THUMB: x=0.4143, y=1.5787, z=-1.4760, visibility=0.1330
#
# LEFT_HIP: x=0.7897, y=1.6519, z=-0.0755, visibility=0.0006
#
# RIGHT_HIP: x=0.4828, y=1.6789, z=0.0811, visibility=0.0005
#
# LEFT_KNEE: x=0.8020, y=2.2690, z=-0.1115, visibility=0.0007
#
# RIGHT_KNEE: x=0.5196, y=2.2850, z=0.1351, visibility=0.0005
#
# LEFT_ANKLE: x=0.8150, y=2.8303, z=0.5034, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5399, y=2.8366, z=0.6225, visibility=0.0000
#
# LEFT_HEEL: x=0.8225, y=2.9172, z=0.5235, visibility=0.0000
#
# RIGHT_HEEL: x=0.5361, y=2.9237, z=0.6490, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7733, y=3.0166, z=-0.1783, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6020, y=3.0193, z=-0.0733, visibility=0.0001
#
# NOSE: x=0.6100, y=0.7106, z=-1.3114, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6334, y=0.6320, z=-1.2602, visibility=0.9972
#
# LEFT_EYE: x=0.6517, y=0.6304, z=-1.2604, visibility=0.9975
#
# LEFT_EYE_OUTER: x=0.6704, y=0.6300, z=-1.2607, visibility=0.9968
#
# RIGHT_EYE_INNER: x=0.5672, y=0.6382, z=-1.2674, visibility=0.9973
#
# RIGHT_EYE: x=0.5414, y=0.6420, z=-1.2666, visibility=0.9977
#
# RIGHT_EYE_OUTER: x=0.5191, y=0.6465, z=-1.2669, visibility=0.9975
#
# LEFT_EAR: x=0.6999, y=0.6488, z=-0.8011, visibility=0.9974
#
# RIGHT_EAR: x=0.4823, y=0.6756, z=-0.8080, visibility=0.9983
#
# MOUTH_LEFT: x=0.6464, y=0.7780, z=-1.1270, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5702, y=0.7946, z=-1.1303, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8392, y=0.9262, z=-0.4794, visibility=0.9851
#
# RIGHT_SHOULDER: x=0.3542, y=0.9793, z=-0.5012, visibility=0.9894
#
# LEFT_ELBOW: x=0.8788, y=1.0346, z=-0.7596, visibility=0.0506
#
# RIGHT_ELBOW: x=0.3402, y=1.4298, z=-0.6852, visibility=0.1793
#
# LEFT_WRIST: x=0.8795, y=1.3064, z=-1.4657, visibility=0.0249
#
# RIGHT_WRIST: x=0.3928, y=1.5788, z=-1.4556, visibility=0.0667
#
# LEFT_PINKY: x=0.8871, y=1.3507, z=-1.6440, visibility=0.0387
#
# RIGHT_PINKY: x=0.3949, y=1.6582, z=-1.6350, visibility=0.0983
#
# LEFT_INDEX: x=0.8502, y=1.3094, z=-1.6565, visibility=0.0576
#
# RIGHT_INDEX: x=0.4155, y=1.5924, z=-1.6906, visibility=0.1462
#
# LEFT_THUMB: x=0.8350, y=1.2985, z=-1.5005, visibility=0.0569
#
# RIGHT_THUMB: x=0.4247, y=1.5593, z=-1.5022, visibility=0.1298
#
# LEFT_HIP: x=0.7879, y=1.6416, z=-0.0754, visibility=0.0006
#
# RIGHT_HIP: x=0.4827, y=1.6663, z=0.0810, visibility=0.0005
#
# LEFT_KNEE: x=0.8008, y=2.2580, z=-0.1331, visibility=0.0008
#
# RIGHT_KNEE: x=0.5193, y=2.2709, z=0.1272, visibility=0.0005
#
# LEFT_ANKLE: x=0.8148, y=2.8181, z=0.4428, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5414, y=2.8187, z=0.6070, visibility=0.0000
#
# LEFT_HEEL: x=0.8219, y=2.9038, z=0.4572, visibility=0.0000
#
# RIGHT_HEEL: x=0.5374, y=2.9015, z=0.6323, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7727, y=3.0035, z=-0.2474, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6040, y=3.0044, z=-0.0899, visibility=0.0001
#
# NOSE: x=0.6144, y=0.7099, z=-0.9979, visibility=0.9983
#
# LEFT_EYE_INNER: x=0.6368, y=0.6311, z=-0.9334, visibility=0.9974
#
# LEFT_EYE: x=0.6552, y=0.6297, z=-0.9338, visibility=0.9977
#
# LEFT_EYE_OUTER: x=0.6735, y=0.6294, z=-0.9340, visibility=0.9970
#
# RIGHT_EYE_INNER: x=0.5712, y=0.6355, z=-0.9442, visibility=0.9975
#
# RIGHT_EYE: x=0.5444, y=0.6387, z=-0.9433, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5212, y=0.6431, z=-0.9437, visibility=0.9977
#
# LEFT_EAR: x=0.7007, y=0.6486, z=-0.4976, visibility=0.9976
#
# RIGHT_EAR: x=0.4825, y=0.6729, z=-0.5163, visibility=0.9985
#
# MOUTH_LEFT: x=0.6495, y=0.7779, z=-0.8294, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5725, y=0.7938, z=-0.8372, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8394, y=0.9269, z=-0.2612, visibility=0.9858
#
# RIGHT_SHOULDER: x=0.3542, y=0.9817, z=-0.3038, visibility=0.9900
#
# LEFT_ELBOW: x=0.8841, y=1.0407, z=-0.6297, visibility=0.0497
#
# RIGHT_ELBOW: x=0.3286, y=1.4420, z=-0.4780, visibility=0.1867
#
# LEFT_WRIST: x=0.8850, y=1.3178, z=-1.3623, visibility=0.0251
#
# RIGHT_WRIST: x=0.3710, y=1.6775, z=-1.1752, visibility=0.0670
#
# LEFT_PINKY: x=0.8981, y=1.3782, z=-1.5269, visibility=0.0389
#
# RIGHT_PINKY: x=0.3646, y=1.7885, z=-1.3456, visibility=0.0987
#
# LEFT_INDEX: x=0.8563, y=1.3471, z=-1.5632, visibility=0.0575
#
# RIGHT_INDEX: x=0.3982, y=1.7340, z=-1.4002, visibility=0.1469
#
# LEFT_THUMB: x=0.8391, y=1.3267, z=-1.4027, visibility=0.0569
#
# RIGHT_THUMB: x=0.4115, y=1.6901, z=-1.2206, visibility=0.1306
#
# LEFT_HIP: x=0.7898, y=1.6599, z=-0.0730, visibility=0.0006
#
# RIGHT_HIP: x=0.4821, y=1.6849, z=0.0789, visibility=0.0005
#
# LEFT_KNEE: x=0.8014, y=2.2762, z=-0.1416, visibility=0.0008
#
# RIGHT_KNEE: x=0.5192, y=2.2905, z=0.0136, visibility=0.0005
#
# LEFT_ANKLE: x=0.8161, y=2.8304, z=0.4401, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5411, y=2.8395, z=0.4313, visibility=0.0000
#
# LEFT_HEEL: x=0.8235, y=2.9194, z=0.4555, visibility=0.0000
#
# RIGHT_HEEL: x=0.5371, y=2.9281, z=0.4491, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7735, y=3.0162, z=-0.2452, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6046, y=3.0245, z=-0.2591, visibility=0.0001
#
# NOSE: x=0.6165, y=0.7092, z=-0.9347, visibility=0.9985
#
# LEFT_EYE_INNER: x=0.6387, y=0.6306, z=-0.8683, visibility=0.9976
#
# LEFT_EYE: x=0.6573, y=0.6294, z=-0.8686, visibility=0.9979
#
# LEFT_EYE_OUTER: x=0.6756, y=0.6293, z=-0.8689, visibility=0.9973
#
# RIGHT_EYE_INNER: x=0.5729, y=0.6335, z=-0.8785, visibility=0.9977
#
# RIGHT_EYE: x=0.5457, y=0.6362, z=-0.8775, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5221, y=0.6404, z=-0.8779, visibility=0.9979
#
# LEFT_EAR: x=0.7016, y=0.6486, z=-0.4269, visibility=0.9978
#
# RIGHT_EAR: x=0.4825, y=0.6705, z=-0.4429, visibility=0.9986
#
# MOUTH_LEFT: x=0.6511, y=0.7779, z=-0.7641, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5733, y=0.7932, z=-0.7711, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8398, y=0.9281, z=-0.1943, visibility=0.9865
#
# RIGHT_SHOULDER: x=0.3542, y=0.9817, z=-0.2415, visibility=0.9906
#
# LEFT_ELBOW: x=0.8867, y=1.0450, z=-0.5498, visibility=0.0488
#
# RIGHT_ELBOW: x=0.3275, y=1.4432, z=-0.4586, visibility=0.1902
#
# LEFT_WRIST: x=0.8897, y=1.3544, z=-1.3169, visibility=0.0250
#
# RIGHT_WRIST: x=0.3710, y=1.6774, z=-1.2118, visibility=0.0667
#
# LEFT_PINKY: x=0.9070, y=1.4170, z=-1.5059, visibility=0.0387
#
# RIGHT_PINKY: x=0.3647, y=1.7870, z=-1.3918, visibility=0.0990
#
# LEFT_INDEX: x=0.8631, y=1.3764, z=-1.5102, visibility=0.0571
#
# RIGHT_INDEX: x=0.3989, y=1.7291, z=-1.4423, visibility=0.1475
#
# LEFT_THUMB: x=0.8444, y=1.3602, z=-1.3557, visibility=0.0565
#
# RIGHT_THUMB: x=0.4123, y=1.6865, z=-1.2573, visibility=0.1311
#
# LEFT_HIP: x=0.7896, y=1.6620, z=-0.0698, visibility=0.0007
#
# RIGHT_HIP: x=0.4773, y=1.6857, z=0.0761, visibility=0.0005
#
# LEFT_KNEE: x=0.8001, y=2.2789, z=-0.1413, visibility=0.0008
#
# RIGHT_KNEE: x=0.5148, y=2.2921, z=0.0199, visibility=0.0005
#
# LEFT_ANKLE: x=0.8141, y=2.8318, z=0.4395, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5337, y=2.8411, z=0.4372, visibility=0.0000
#
# LEFT_HEEL: x=0.8214, y=2.9215, z=0.4551, visibility=0.0000
#
# RIGHT_HEEL: x=0.5298, y=2.9303, z=0.4548, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7694, y=3.0169, z=-0.2427, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5988, y=3.0259, z=-0.2548, visibility=0.0001
#
# NOSE: x=0.6419, y=0.7155, z=-1.4143, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6559, y=0.6355, z=-1.3652, visibility=0.9972
#
# LEFT_EYE: x=0.6736, y=0.6345, z=-1.3654, visibility=0.9974
#
# LEFT_EYE_OUTER: x=0.6911, y=0.6344, z=-1.3658, visibility=0.9967
#
# RIGHT_EYE_INNER: x=0.5971, y=0.6381, z=-1.3867, visibility=0.9973
#
# RIGHT_EYE: x=0.5696, y=0.6407, z=-1.3859, visibility=0.9977
#
# RIGHT_EYE_OUTER: x=0.5431, y=0.6448, z=-1.3862, visibility=0.9975
#
# LEFT_EAR: x=0.7061, y=0.6523, z=-0.8826, visibility=0.9973
#
# RIGHT_EAR: x=0.4866, y=0.6739, z=-0.9487, visibility=0.9984
#
# MOUTH_LEFT: x=0.6727, y=0.7828, z=-1.2159, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5988, y=0.7966, z=-1.2358, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8403, y=0.9280, z=-0.5082, visibility=0.9857
#
# RIGHT_SHOULDER: x=0.3542, y=0.9820, z=-0.5804, visibility=0.9900
#
# LEFT_ELBOW: x=0.8859, y=1.0479, z=-0.5394, visibility=0.0493
#
# RIGHT_ELBOW: x=0.3303, y=1.4425, z=-0.5512, visibility=0.1936
#
# LEFT_WRIST: x=0.8806, y=1.4210, z=-0.9681, visibility=0.0249
#
# RIGHT_WRIST: x=0.3884, y=1.6548, z=-1.1350, visibility=0.0669
#
# LEFT_PINKY: x=0.8931, y=1.5028, z=-1.0975, visibility=0.0376
#
# RIGHT_PINKY: x=0.3908, y=1.7433, z=-1.2706, visibility=0.0972
#
# LEFT_INDEX: x=0.8565, y=1.4756, z=-1.1303, visibility=0.0551
#
# RIGHT_INDEX: x=0.4124, y=1.6833, z=-1.3469, visibility=0.1441
#
# LEFT_THUMB: x=0.8401, y=1.4523, z=-1.0035, visibility=0.0551
#
# RIGHT_THUMB: x=0.4224, y=1.6468, z=-1.1805, visibility=0.1287
#
# LEFT_HIP: x=0.7909, y=1.6608, z=-0.0716, visibility=0.0007
#
# RIGHT_HIP: x=0.4799, y=1.6857, z=0.0773, visibility=0.0005
#
# LEFT_KNEE: x=0.8028, y=2.2788, z=-0.0374, visibility=0.0008
#
# RIGHT_KNEE: x=0.5206, y=2.2950, z=0.2013, visibility=0.0005
#
# LEFT_ANKLE: x=0.8159, y=2.8324, z=0.6511, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5437, y=2.8415, z=0.7985, visibility=0.0000
#
# LEFT_HEEL: x=0.8224, y=2.9211, z=0.6781, visibility=0.0000
#
# RIGHT_HEEL: x=0.5396, y=2.9296, z=0.8416, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.7784, y=3.0213, z=0.0040, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6096, y=3.0270, z=0.1286, visibility=0.0001
#
# NOSE: x=0.6901, y=0.7151, z=-1.5365, visibility=0.9967
#
# LEFT_EYE_INNER: x=0.6929, y=0.6335, z=-1.4728, visibility=0.9950
#
# LEFT_EYE: x=0.7073, y=0.6327, z=-1.4732, visibility=0.9956
#
# LEFT_EYE_OUTER: x=0.7215, y=0.6329, z=-1.4736, visibility=0.9939
#
# RIGHT_EYE_INNER: x=0.6433, y=0.6360, z=-1.5138, visibility=0.9956
#
# RIGHT_EYE: x=0.6176, y=0.6385, z=-1.5134, visibility=0.9965
#
# RIGHT_EYE_OUTER: x=0.5882, y=0.6432, z=-1.5140, visibility=0.9960
#
# LEFT_EAR: x=0.7174, y=0.6522, z=-0.9503, visibility=0.9951
#
# RIGHT_EAR: x=0.5131, y=0.6740, z=-1.1127, visibility=0.9976
#
# MOUTH_LEFT: x=0.7085, y=0.7822, z=-1.3231, visibility=0.9972
#
# MOUTH_RIGHT: x=0.6456, y=0.7966, z=-1.3714, visibility=0.9981
#
# LEFT_SHOULDER: x=0.8446, y=0.9280, z=-0.5537, visibility=0.9849
#
# RIGHT_SHOULDER: x=0.3572, y=0.9838, z=-0.7427, visibility=0.9893
#
# LEFT_ELBOW: x=0.8856, y=1.0544, z=-0.5522, visibility=0.0497
#
# RIGHT_ELBOW: x=0.3315, y=1.4497, z=-0.6483, visibility=0.1993
#
# LEFT_WRIST: x=0.8802, y=1.4538, z=-1.0650, visibility=0.0243
#
# RIGHT_WRIST: x=0.3927, y=1.7117, z=-1.0611, visibility=0.0624
#
# LEFT_PINKY: x=0.8928, y=1.5393, z=-1.2010, visibility=0.0360
#
# RIGHT_PINKY: x=0.3969, y=1.8170, z=-1.1853, visibility=0.0899
#
# LEFT_INDEX: x=0.8566, y=1.5199, z=-1.2451, visibility=0.0525
#
# RIGHT_INDEX: x=0.4175, y=1.7789, z=-1.2807, visibility=0.1335
#
# LEFT_THUMB: x=0.8401, y=1.4932, z=-1.1068, visibility=0.0524
#
# RIGHT_THUMB: x=0.4257, y=1.7333, z=-1.1103, visibility=0.1193
#
# LEFT_HIP: x=0.7994, y=1.6766, z=-0.0634, visibility=0.0007
#
# RIGHT_HIP: x=0.4889, y=1.7056, z=0.0685, visibility=0.0005
#
# LEFT_KNEE: x=0.8083, y=2.2959, z=-0.1501, visibility=0.0010
#
# RIGHT_KNEE: x=0.5306, y=2.3167, z=-0.1041, visibility=0.0006
#
# LEFT_ANKLE: x=0.8248, y=2.8637, z=0.4996, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5565, y=2.8724, z=0.3305, visibility=0.0000
#
# LEFT_HEEL: x=0.8298, y=2.9561, z=0.5214, visibility=0.0001
#
# RIGHT_HEEL: x=0.5512, y=2.9639, z=0.3499, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7963, y=3.0505, z=-0.1675, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6231, y=3.0521, z=-0.3952, visibility=0.0001
#
# NOSE: x=0.7002, y=0.7127, z=-1.5326, visibility=0.9954
#
# LEFT_EYE_INNER: x=0.7023, y=0.6287, z=-1.4670, visibility=0.9932
#
# LEFT_EYE: x=0.7163, y=0.6280, z=-1.4673, visibility=0.9939
#
# LEFT_EYE_OUTER: x=0.7301, y=0.6283, z=-1.4677, visibility=0.9915
#
# RIGHT_EYE_INNER: x=0.6531, y=0.6325, z=-1.5100, visibility=0.9941
#
# RIGHT_EYE: x=0.6274, y=0.6359, z=-1.5095, visibility=0.9953
#
# RIGHT_EYE_OUTER: x=0.5977, y=0.6417, z=-1.5101, visibility=0.9948
#
# LEFT_EAR: x=0.7231, y=0.6515, z=-0.9398, visibility=0.9932
#
# RIGHT_EAR: x=0.5208, y=0.6741, z=-1.1112, visibility=0.9970
#
# MOUTH_LEFT: x=0.7180, y=0.7800, z=-1.3180, visibility=0.9961
#
# MOUTH_RIGHT: x=0.6559, y=0.7961, z=-1.3690, visibility=0.9974
#
# LEFT_SHOULDER: x=0.8468, y=0.9276, z=-0.5362, visibility=0.9836
#
# RIGHT_SHOULDER: x=0.3581, y=0.9838, z=-0.7464, visibility=0.9881
#
# LEFT_ELBOW: x=0.8852, y=1.0584, z=-0.4614, visibility=0.0494
#
# RIGHT_ELBOW: x=0.3350, y=1.4490, z=-0.6577, visibility=0.2048
#
# LEFT_WRIST: x=0.8724, y=1.4614, z=-0.8475, visibility=0.0239
#
# RIGHT_WRIST: x=0.3995, y=1.6976, z=-1.0034, visibility=0.0586
#
# LEFT_PINKY: x=0.8839, y=1.5467, z=-0.9537, visibility=0.0345
#
# RIGHT_PINKY: x=0.4062, y=1.8000, z=-1.1151, visibility=0.0837
#
# LEFT_INDEX: x=0.8522, y=1.5285, z=-1.0016, visibility=0.0500
#
# RIGHT_INDEX: x=0.4245, y=1.7572, z=-1.2028, visibility=0.1243
#
# LEFT_THUMB: x=0.8359, y=1.5027, z=-0.8871, visibility=0.0499
#
# RIGHT_THUMB: x=0.4309, y=1.7140, z=-1.0477, visibility=0.1111
#
# LEFT_HIP: x=0.8018, y=1.6786, z=-0.0590, visibility=0.0007
#
# RIGHT_HIP: x=0.4911, y=1.7078, z=0.0639, visibility=0.0006
#
# LEFT_KNEE: x=0.8088, y=2.2982, z=-0.1593, visibility=0.0011
#
# RIGHT_KNEE: x=0.5313, y=2.3196, z=-0.0968, visibility=0.0007
#
# LEFT_ANKLE: x=0.8248, y=2.8682, z=0.4861, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5553, y=2.8756, z=0.3380, visibility=0.0000
#
# LEFT_HEEL: x=0.8298, y=2.9588, z=0.5078, visibility=0.0001
#
# RIGHT_HEEL: x=0.5499, y=2.9656, z=0.3589, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7959, y=3.0565, z=-0.1815, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6217, y=3.0554, z=-0.3822, visibility=0.0002
#
# NOSE: x=0.7085, y=0.7076, z=-1.4609, visibility=0.9927
#
# LEFT_EYE_INNER: x=0.7104, y=0.6251, z=-1.3950, visibility=0.9892
#
# LEFT_EYE: x=0.7239, y=0.6247, z=-1.3953, visibility=0.9900
#
# LEFT_EYE_OUTER: x=0.7370, y=0.6252, z=-1.3958, visibility=0.9867
#
# RIGHT_EYE_INNER: x=0.6618, y=0.6280, z=-1.4383, visibility=0.9908
#
# RIGHT_EYE: x=0.6380, y=0.6310, z=-1.4377, visibility=0.9927
#
# RIGHT_EYE_OUTER: x=0.6112, y=0.6368, z=-1.4383, visibility=0.9922
#
# LEFT_EAR: x=0.7269, y=0.6501, z=-0.8861, visibility=0.9888
#
# RIGHT_EAR: x=0.5344, y=0.6727, z=-1.0630, visibility=0.9951
#
# MOUTH_LEFT: x=0.7240, y=0.7760, z=-1.2553, visibility=0.9939
#
# MOUTH_RIGHT: x=0.6651, y=0.7924, z=-1.3070, visibility=0.9960
#
# LEFT_SHOULDER: x=0.8468, y=0.9265, z=-0.4994, visibility=0.9822
#
# RIGHT_SHOULDER: x=0.3618, y=0.9827, z=-0.7218, visibility=0.9859
#
# LEFT_ELBOW: x=0.8835, y=1.0392, z=-0.1802, visibility=0.0502
#
# RIGHT_ELBOW: x=0.3348, y=1.4390, z=-0.6367, visibility=0.2118
#
# LEFT_WRIST: x=0.8728, y=1.4655, z=-0.2864, visibility=0.0233
#
# RIGHT_WRIST: x=0.4008, y=1.6886, z=-0.9368, visibility=0.0552
#
# LEFT_PINKY: x=0.8851, y=1.5544, z=-0.3461, visibility=0.0328
#
# RIGHT_PINKY: x=0.4075, y=1.7886, z=-1.0415, visibility=0.0778
#
# LEFT_INDEX: x=0.8574, y=1.5444, z=-0.4040, visibility=0.0472
#
# RIGHT_INDEX: x=0.4277, y=1.7436, z=-1.1358, visibility=0.1155
#
# LEFT_THUMB: x=0.8413, y=1.5171, z=-0.3225, visibility=0.0472
#
# RIGHT_THUMB: x=0.4332, y=1.7016, z=-0.9831, visibility=0.1033
#
# LEFT_HIP: x=0.8012, y=1.6776, z=-0.0484, visibility=0.0007
#
# RIGHT_HIP: x=0.4923, y=1.7067, z=0.0528, visibility=0.0005
#
# LEFT_KNEE: x=0.8089, y=2.2977, z=-0.1191, visibility=0.0011
#
# RIGHT_KNEE: x=0.5322, y=2.3179, z=-0.0563, visibility=0.0007
#
# LEFT_ANKLE: x=0.8244, y=2.8662, z=0.5204, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5554, y=2.8734, z=0.3847, visibility=0.0000
#
# LEFT_HEEL: x=0.8294, y=2.9561, z=0.5411, visibility=0.0001
#
# RIGHT_HEEL: x=0.5497, y=2.9627, z=0.4073, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7966, y=3.0543, z=-0.1284, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.6219, y=3.0539, z=-0.3184, visibility=0.0002
#
# NOSE: x=0.7220, y=0.7002, z=-1.4096, visibility=0.9908
#
# LEFT_EYE_INNER: x=0.7217, y=0.6193, z=-1.3574, visibility=0.9864
#
# LEFT_EYE: x=0.7344, y=0.6192, z=-1.3576, visibility=0.9879
#
# LEFT_EYE_OUTER: x=0.7468, y=0.6198, z=-1.3579, visibility=0.9835
#
# RIGHT_EYE_INNER: x=0.6722, y=0.6213, z=-1.3749, visibility=0.9884
#
# RIGHT_EYE: x=0.6487, y=0.6239, z=-1.3742, visibility=0.9911
#
# RIGHT_EYE_OUTER: x=0.6231, y=0.6293, z=-1.3747, visibility=0.9901
#
# LEFT_EAR: x=0.7295, y=0.6466, z=-0.8406, visibility=0.9864
#
# RIGHT_EAR: x=0.5445, y=0.6681, z=-0.9886, visibility=0.9941
#
# MOUTH_LEFT: x=0.7329, y=0.7692, z=-1.2208, visibility=0.9927
#
# MOUTH_RIGHT: x=0.6762, y=0.7864, z=-1.2425, visibility=0.9953
#
# LEFT_SHOULDER: x=0.8467, y=0.9208, z=-0.4492, visibility=0.9818
#
# RIGHT_SHOULDER: x=0.3644, y=0.9804, z=-0.6627, visibility=0.9845
#
# LEFT_ELBOW: x=0.8923, y=1.0448, z=-0.3410, visibility=0.0525
#
# RIGHT_ELBOW: x=0.3349, y=1.4365, z=-0.6567, visibility=0.2141
#
# LEFT_WRIST: x=0.8969, y=1.4646, z=-0.7497, visibility=0.0240
#
# RIGHT_WRIST: x=0.4022, y=1.6687, z=-0.9994, visibility=0.0525
#
# LEFT_PINKY: x=0.9159, y=1.5529, z=-0.8667, visibility=0.0327
#
# RIGHT_PINKY: x=0.4100, y=1.7624, z=-1.0470, visibility=0.0732
#
# LEFT_INDEX: x=0.8809, y=1.5414, z=-0.9140, visibility=0.0467
#
# RIGHT_INDEX: x=0.4305, y=1.7238, z=-1.2195, visibility=0.1085
#
# LEFT_THUMB: x=0.8622, y=1.5141, z=-0.7901, visibility=0.0467
#
# RIGHT_THUMB: x=0.4349, y=1.6832, z=-1.0522, visibility=0.0972
#
# LEFT_HIP: x=0.8044, y=1.6825, z=-0.0428, visibility=0.0008
#
# RIGHT_HIP: x=0.4986, y=1.7137, z=0.0471, visibility=0.0006
#
# LEFT_KNEE: x=0.8125, y=2.3012, z=-0.0674, visibility=0.0012
#
# RIGHT_KNEE: x=0.5332, y=2.3241, z=-0.0496, visibility=0.0008
#
# LEFT_ANKLE: x=0.8266, y=2.8729, z=0.5716, visibility=0.0001
#
# ...
#
# LEFT_ELBOW: x=0.8721, y=1.0389, z=-0.5290, visibility=0.0640
#
# RIGHT_ELBOW: x=0.3233, y=1.4146, z=-0.7172, visibility=0.2215
#
# LEFT_WRIST: x=0.8679, y=1.3669, z=-1.1396, visibility=0.0413
#
# RIGHT_WRIST: x=0.3921, y=1.4230, z=-1.6835, visibility=0.1066
#
# LEFT_PINKY: x=0.8899, y=1.4312, z=-1.2978, visibility=0.0534
#
# RIGHT_PINKY: x=0.4023, y=1.4684, z=-1.8891, visibility=0.1381
#
# LEFT_INDEX: x=0.8533, y=1.3926, z=-1.3302, visibility=0.0724
#
# RIGHT_INDEX: x=0.4202, y=1.3666, z=-1.9220, visibility=0.1918
#
# LEFT_THUMB: x=0.8352, y=1.3718, z=-1.1797, visibility=0.0729
#
# RIGHT_THUMB: x=0.4276, y=1.3556, z=-1.7260, visibility=0.1734
#
# LEFT_HIP: x=0.7694, y=1.6603, z=-0.0750, visibility=0.0011
#
# RIGHT_HIP: x=0.4628, y=1.6862, z=0.0805, visibility=0.0009
#
# LEFT_KNEE: x=0.7911, y=2.2715, z=-0.0833, visibility=0.0013
#
# RIGHT_KNEE: x=0.5068, y=2.2848, z=0.2348, visibility=0.0012
#
# LEFT_ANKLE: x=0.8082, y=2.8229, z=0.4946, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5293, y=2.8310, z=0.7901, visibility=0.0000
#
# LEFT_HEEL: x=0.8139, y=2.9066, z=0.5083, visibility=0.0001
#
# RIGHT_HEEL: x=0.5240, y=2.9159, z=0.8256, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7711, y=3.0098, z=-0.1934, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5924, y=3.0116, z=0.1230, visibility=0.0002
#
# NOSE: x=0.5913, y=0.6869, z=-1.0802, visibility=0.9977
#
# LEFT_EYE_INNER: x=0.6156, y=0.6152, z=-1.0120, visibility=0.9965
#
# LEFT_EYE: x=0.6332, y=0.6145, z=-1.0125, visibility=0.9968
#
# LEFT_EYE_OUTER: x=0.6504, y=0.6149, z=-1.0128, visibility=0.9959
#
# RIGHT_EYE_INNER: x=0.5539, y=0.6209, z=-1.0170, visibility=0.9969
#
# RIGHT_EYE: x=0.5310, y=0.6244, z=-1.0162, visibility=0.9975
#
# RIGHT_EYE_OUTER: x=0.5107, y=0.6287, z=-1.0166, visibility=0.9974
#
# LEFT_EAR: x=0.6810, y=0.6368, z=-0.5188, visibility=0.9966
#
# RIGHT_EAR: x=0.4751, y=0.6634, z=-0.5214, visibility=0.9980
#
# MOUTH_LEFT: x=0.6284, y=0.7594, z=-0.8917, visibility=0.9978
#
# MOUTH_RIGHT: x=0.5511, y=0.7694, z=-0.8934, visibility=0.9983
#
# LEFT_SHOULDER: x=0.8250, y=0.9251, z=-0.2636, visibility=0.9803
#
# RIGHT_SHOULDER: x=0.3542, y=0.9793, z=-0.2743, visibility=0.9885
#
# LEFT_ELBOW: x=0.8723, y=1.0494, z=-0.4680, visibility=0.0625
#
# RIGHT_ELBOW: x=0.3230, y=1.4020, z=-0.6910, visibility=0.2216
#
# LEFT_WRIST: x=0.8701, y=1.4435, z=-1.0114, visibility=0.0391
#
# RIGHT_WRIST: x=0.3915, y=1.4218, z=-1.6668, visibility=0.1112
#
# LEFT_PINKY: x=0.8909, y=1.5361, z=-1.1533, visibility=0.0508
#
# RIGHT_PINKY: x=0.4016, y=1.4690, z=-1.8699, visibility=0.1425
#
# LEFT_INDEX: x=0.8542, y=1.5084, z=-1.1947, visibility=0.0693
#
# RIGHT_INDEX: x=0.4190, y=1.3938, z=-1.9060, visibility=0.1969
#
# LEFT_THUMB: x=0.8367, y=1.4799, z=-1.0525, visibility=0.0700
#
# RIGHT_THUMB: x=0.4263, y=1.3798, z=-1.7105, visibility=0.1784
#
# LEFT_HIP: x=0.7695, y=1.6603, z=-0.0762, visibility=0.0011
#
# RIGHT_HIP: x=0.4637, y=1.6863, z=0.0816, visibility=0.0009
#
# LEFT_KNEE: x=0.7911, y=2.2716, z=-0.0908, visibility=0.0014
#
# RIGHT_KNEE: x=0.5072, y=2.2849, z=0.2000, visibility=0.0012
#
# LEFT_ANKLE: x=0.8069, y=2.8236, z=0.4932, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5287, y=2.8310, z=0.7023, visibility=0.0000
#
# LEFT_HEEL: x=0.8128, y=2.9068, z=0.5059, visibility=0.0001
#
# RIGHT_HEEL: x=0.5230, y=2.9160, z=0.7318, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7692, y=3.0100, z=-0.2096, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5912, y=3.0112, z=0.0212, visibility=0.0002
#
# NOSE: x=0.5912, y=0.6869, z=-1.1003, visibility=0.9978
#
# LEFT_EYE_INNER: x=0.6156, y=0.6152, z=-1.0324, visibility=0.9967
#
# LEFT_EYE: x=0.6331, y=0.6145, z=-1.0329, visibility=0.9970
#
# LEFT_EYE_OUTER: x=0.6504, y=0.6149, z=-1.0333, visibility=0.9962
#
# RIGHT_EYE_INNER: x=0.5537, y=0.6207, z=-1.0377, visibility=0.9971
#
# RIGHT_EYE: x=0.5308, y=0.6243, z=-1.0369, visibility=0.9976
#
# RIGHT_EYE_OUTER: x=0.5105, y=0.6285, z=-1.0374, visibility=0.9975
#
# LEFT_EAR: x=0.6811, y=0.6368, z=-0.5346, visibility=0.9968
#
# RIGHT_EAR: x=0.4750, y=0.6632, z=-0.5415, visibility=0.9981
#
# MOUTH_LEFT: x=0.6283, y=0.7596, z=-0.9109, visibility=0.9979
#
# MOUTH_RIGHT: x=0.5509, y=0.7695, z=-0.9131, visibility=0.9983
#
# LEFT_SHOULDER: x=0.8250, y=0.9253, z=-0.2676, visibility=0.9806
#
# RIGHT_SHOULDER: x=0.3543, y=0.9794, z=-0.2824, visibility=0.9877
#
# LEFT_ELBOW: x=0.8725, y=1.0550, z=-0.4540, visibility=0.0615
#
# RIGHT_ELBOW: x=0.3227, y=1.3939, z=-0.6805, visibility=0.2210
#
# LEFT_WRIST: x=0.8724, y=1.4649, z=-0.9872, visibility=0.0371
#
# RIGHT_WRIST: x=0.3907, y=1.4253, z=-1.6542, visibility=0.1142
#
# LEFT_PINKY: x=0.8925, y=1.5623, z=-1.1278, visibility=0.0484
#
# RIGHT_PINKY: x=0.4005, y=1.4751, z=-1.8560, visibility=0.1453
#
# LEFT_INDEX: x=0.8554, y=1.5368, z=-1.1704, visibility=0.0663
#
# RIGHT_INDEX: x=0.4179, y=1.4059, z=-1.8945, visibility=0.2001
#
# LEFT_THUMB: x=0.8383, y=1.5074, z=-1.0285, visibility=0.0672
#
# RIGHT_THUMB: x=0.4254, y=1.3906, z=-1.6988, visibility=0.1817
#
# LEFT_HIP: x=0.7695, y=1.6604, z=-0.0767, visibility=0.0011
#
# RIGHT_HIP: x=0.4642, y=1.6864, z=0.0820, visibility=0.0009
#
# LEFT_KNEE: x=0.7910, y=2.2716, z=-0.0928, visibility=0.0014
#
# RIGHT_KNEE: x=0.5073, y=2.2849, z=0.1904, visibility=0.0012
#
# LEFT_ANKLE: x=0.8053, y=2.8240, z=0.4894, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5279, y=2.8311, z=0.6850, visibility=0.0000
#
# LEFT_HEEL: x=0.8115, y=2.9070, z=0.5024, visibility=0.0001
#
# RIGHT_HEEL: x=0.5219, y=2.9160, z=0.7140, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7672, y=3.0102, z=-0.2133, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5899, y=3.0108, z=0.0020, visibility=0.0002
#
# NOSE: x=0.5911, y=0.6869, z=-1.1057, visibility=0.9979
#
# LEFT_EYE_INNER: x=0.6155, y=0.6151, z=-1.0384, visibility=0.9969
#
# LEFT_EYE: x=0.6330, y=0.6145, z=-1.0389, visibility=0.9971
#
# LEFT_EYE_OUTER: x=0.6503, y=0.6149, z=-1.0393, visibility=0.9964
#
# RIGHT_EYE_INNER: x=0.5535, y=0.6206, z=-1.0434, visibility=0.9972
#
# RIGHT_EYE: x=0.5306, y=0.6242, z=-1.0426, visibility=0.9977
#
# RIGHT_EYE_OUTER: x=0.5104, y=0.6284, z=-1.0431, visibility=0.9976
#
# LEFT_EAR: x=0.6811, y=0.6369, z=-0.5427, visibility=0.9970
#
# RIGHT_EAR: x=0.4750, y=0.6630, z=-0.5488, visibility=0.9982
#
# MOUTH_LEFT: x=0.6281, y=0.7597, z=-0.9171, visibility=0.9981
#
# MOUTH_RIGHT: x=0.5507, y=0.7695, z=-0.9189, visibility=0.9984
#
# LEFT_SHOULDER: x=0.8250, y=0.9253, z=-0.2699, visibility=0.9808
#
# RIGHT_SHOULDER: x=0.3543, y=0.9793, z=-0.2876, visibility=0.9871
#
# LEFT_ELBOW: x=0.8726, y=1.0581, z=-0.4420, visibility=0.0609
#
# RIGHT_ELBOW: x=0.3222, y=1.3878, z=-0.6781, visibility=0.2212
#
# LEFT_WRIST: x=0.8741, y=1.4690, z=-0.9625, visibility=0.0352
#
# RIGHT_WRIST: x=0.3903, y=1.4238, z=-1.6525, visibility=0.1173
#
# LEFT_PINKY: x=0.8935, y=1.5665, z=-1.1009, visibility=0.0462
#
# RIGHT_PINKY: x=0.3999, y=1.4736, z=-1.8538, visibility=0.1482
#
# LEFT_INDEX: x=0.8563, y=1.5412, z=-1.1437, visibility=0.0635
#
# RIGHT_INDEX: x=0.4173, y=1.4062, z=-1.8927, visibility=0.2033
#
# LEFT_THUMB: x=0.8394, y=1.5119, z=-1.0036, visibility=0.0646
#
# RIGHT_THUMB: x=0.4247, y=1.3911, z=-1.6972, visibility=0.1849
#
# LEFT_HIP: x=0.7695, y=1.6603, z=-0.0768, visibility=0.0010
#
# RIGHT_HIP: x=0.4643, y=1.6864, z=0.0820, visibility=0.0009
#
# LEFT_KNEE: x=0.7908, y=2.2715, z=-0.0937, visibility=0.0014
#
# RIGHT_KNEE: x=0.5074, y=2.2849, z=0.1864, visibility=0.0012
#
# LEFT_ANKLE: x=0.8038, y=2.8241, z=0.4868, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5271, y=2.8311, z=0.6795, visibility=0.0000
#
# LEFT_HEEL: x=0.8101, y=2.9072, z=0.5002, visibility=0.0001
#
# RIGHT_HEEL: x=0.5208, y=2.9159, z=0.7084, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7653, y=3.0103, z=-0.2158, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5887, y=3.0103, z=-0.0041, visibility=0.0002
#
# NOSE: x=0.5913, y=0.6872, z=-1.2047, visibility=0.9980
#
# LEFT_EYE_INNER: x=0.6156, y=0.6154, z=-1.1348, visibility=0.9970
#
# LEFT_EYE: x=0.6330, y=0.6147, z=-1.1353, visibility=0.9973
#
# LEFT_EYE_OUTER: x=0.6502, y=0.6151, z=-1.1356, visibility=0.9966
#
# RIGHT_EYE_INNER: x=0.5538, y=0.6207, z=-1.1444, visibility=0.9973
#
# RIGHT_EYE: x=0.5309, y=0.6242, z=-1.1437, visibility=0.9978
#
# RIGHT_EYE_OUTER: x=0.5105, y=0.6284, z=-1.1442, visibility=0.9977
#
# LEFT_EAR: x=0.6809, y=0.6370, z=-0.6362, visibility=0.9972
#
# RIGHT_EAR: x=0.4753, y=0.6630, z=-0.6575, visibility=0.9983
#
# MOUTH_LEFT: x=0.6281, y=0.7599, z=-1.0120, visibility=0.9981
#
# MOUTH_RIGHT: x=0.5506, y=0.7695, z=-1.0197, visibility=0.9985
#
# LEFT_SHOULDER: x=0.8256, y=0.9259, z=-0.3431, visibility=0.9814
#
# RIGHT_SHOULDER: x=0.3537, y=0.9805, z=-0.3747, visibility=0.9874
#
# LEFT_ELBOW: x=0.8738, y=1.0581, z=-0.6190, visibility=0.0612
#
# RIGHT_ELBOW: x=0.3160, y=1.3973, z=-0.6832, visibility=0.2258
#
# LEFT_WRIST: x=0.8904, y=1.4710, z=-1.3605, visibility=0.0340
#
# RIGHT_WRIST: x=0.3693, y=1.5598, z=-1.6447, visibility=0.1130
#
# LEFT_PINKY: x=0.9138, y=1.5653, z=-1.5451, visibility=0.0446
#
# RIGHT_PINKY: x=0.3709, y=1.6542, z=-1.8537, visibility=0.1429
#
# LEFT_INDEX: x=0.8693, y=1.5430, z=-1.5915, visibility=0.0615
#
# RIGHT_INDEX: x=0.3994, y=1.5949, z=-1.9082, visibility=0.1972
#
# LEFT_THUMB: x=0.8495, y=1.5135, z=-1.4102, visibility=0.0625
#
# RIGHT_THUMB: x=0.4089, y=1.5592, z=-1.6940, visibility=0.1789
#
# LEFT_HIP: x=0.7724, y=1.6629, z=-0.0755, visibility=0.0011
#
# RIGHT_HIP: x=0.4650, y=1.6901, z=0.0808, visibility=0.0009
#
# LEFT_KNEE: x=0.7926, y=2.2728, z=-0.1137, visibility=0.0014
#
# RIGHT_KNEE: x=0.5082, y=2.2855, z=0.0038, visibility=0.0012
#
# LEFT_ANKLE: x=0.8094, y=2.8246, z=0.4811, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5299, y=2.8328, z=0.4381, visibility=0.0000
#
# LEFT_HEEL: x=0.8170, y=2.9095, z=0.4958, visibility=0.0001
#
# RIGHT_HEEL: x=0.5247, y=2.9211, z=0.4561, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7680, y=3.0111, z=-0.2262, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5949, y=3.0107, z=-0.2816, visibility=0.0002
#
# NOSE: x=0.5914, y=0.6873, z=-1.2176, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6156, y=0.6155, z=-1.1494, visibility=0.9971
#
# LEFT_EYE: x=0.6330, y=0.6148, z=-1.1498, visibility=0.9974
#
# LEFT_EYE_OUTER: x=0.6502, y=0.6152, z=-1.1501, visibility=0.9966
#
# RIGHT_EYE_INNER: x=0.5540, y=0.6207, z=-1.1579, visibility=0.9974
#
# RIGHT_EYE: x=0.5311, y=0.6241, z=-1.1573, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5107, y=0.6284, z=-1.1578, visibility=0.9978
#
# LEFT_EAR: x=0.6809, y=0.6370, z=-0.6602, visibility=0.9973
#
# RIGHT_EAR: x=0.4755, y=0.6629, z=-0.6765, visibility=0.9984
#
# MOUTH_LEFT: x=0.6280, y=0.7600, z=-1.0280, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5505, y=0.7695, z=-1.0344, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8261, y=0.9264, z=-0.3675, visibility=0.9818
#
# RIGHT_SHOULDER: x=0.3534, y=0.9808, z=-0.3972, visibility=0.9878
#
# LEFT_ELBOW: x=0.8743, y=1.0580, z=-0.6768, visibility=0.0608
#
# RIGHT_ELBOW: x=0.3117, y=1.4007, z=-0.6872, visibility=0.2288
#
# LEFT_WRIST: x=0.8947, y=1.4595, z=-1.4455, visibility=0.0329
#
# RIGHT_WRIST: x=0.3582, y=1.5922, z=-1.6431, visibility=0.1089
#
# LEFT_PINKY: x=0.9202, y=1.5496, z=-1.6329, visibility=0.0434
#
# RIGHT_PINKY: x=0.3564, y=1.6914, z=-1.8466, visibility=0.1383
#
# LEFT_INDEX: x=0.8739, y=1.5268, z=-1.6782, visibility=0.0601
#
# RIGHT_INDEX: x=0.3890, y=1.6344, z=-1.8974, visibility=0.1919
#
# LEFT_THUMB: x=0.8527, y=1.4990, z=-1.4956, visibility=0.0609
#
# RIGHT_THUMB: x=0.3995, y=1.5966, z=-1.6877, visibility=0.1737
#
# LEFT_HIP: x=0.7732, y=1.6643, z=-0.0727, visibility=0.0011
#
# RIGHT_HIP: x=0.4652, y=1.6912, z=0.0783, visibility=0.0009
#
# LEFT_KNEE: x=0.7930, y=2.2737, z=-0.1234, visibility=0.0014
#
# RIGHT_KNEE: x=0.5089, y=2.2855, z=-0.0736, visibility=0.0012
#
# LEFT_ANKLE: x=0.8120, y=2.8253, z=0.4638, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5316, y=2.8335, z=0.3258, visibility=0.0000
#
# LEFT_HEEL: x=0.8202, y=2.9119, z=0.4778, visibility=0.0001
#
# RIGHT_HEEL: x=0.5266, y=2.9239, z=0.3396, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7692, y=3.0117, z=-0.2388, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5980, y=3.0107, z=-0.3962, visibility=0.0002
#
# NOSE: x=0.5913, y=0.6879, z=-1.1590, visibility=0.9981
#
# LEFT_EYE_INNER: x=0.6156, y=0.6162, z=-1.0949, visibility=0.9972
#
# LEFT_EYE: x=0.6330, y=0.6158, z=-1.0954, visibility=0.9975
#
# LEFT_EYE_OUTER: x=0.6501, y=0.6163, z=-1.0960, visibility=0.9968
#
# RIGHT_EYE_INNER: x=0.5540, y=0.6208, z=-1.1072, visibility=0.9975
#
# RIGHT_EYE: x=0.5311, y=0.6242, z=-1.1065, visibility=0.9979
#
# RIGHT_EYE_OUTER: x=0.5106, y=0.6284, z=-1.1070, visibility=0.9978
#
# LEFT_EAR: x=0.6809, y=0.6375, z=-0.6091, visibility=0.9974
#
# RIGHT_EAR: x=0.4757, y=0.6626, z=-0.6442, visibility=0.9984
#
# MOUTH_LEFT: x=0.6277, y=0.7603, z=-0.9686, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5500, y=0.7697, z=-0.9793, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8262, y=0.9263, z=-0.3199, visibility=0.9821
#
# RIGHT_SHOULDER: x=0.3518, y=0.9806, z=-0.3613, visibility=0.9878
#
# LEFT_ELBOW: x=0.8754, y=1.0600, z=-0.5389, visibility=0.0594
#
# RIGHT_ELBOW: x=0.3116, y=1.4006, z=-0.6701, visibility=0.2271
#
# LEFT_WRIST: x=0.8946, y=1.4723, z=-1.1587, visibility=0.0313
#
# RIGHT_WRIST: x=0.3598, y=1.5875, z=-1.6375, visibility=0.1074
#
# LEFT_PINKY: x=0.9197, y=1.5683, z=-1.3210, visibility=0.0414
#
# RIGHT_PINKY: x=0.3595, y=1.6892, z=-1.8424, visibility=0.1364
#
# LEFT_INDEX: x=0.8729, y=1.5456, z=-1.3684, visibility=0.0575
#
# RIGHT_INDEX: x=0.3915, y=1.6227, z=-1.8925, visibility=0.1898
#
# LEFT_THUMB: x=0.8520, y=1.5156, z=-1.2049, visibility=0.0585
#
# RIGHT_THUMB: x=0.4011, y=1.5853, z=-1.6835, visibility=0.1714
#
# LEFT_HIP: x=0.7723, y=1.6668, z=-0.0728, visibility=0.0011
#
# RIGHT_HIP: x=0.4650, y=1.6935, z=0.0784, visibility=0.0009
#
# LEFT_KNEE: x=0.7929, y=2.2762, z=-0.1271, visibility=0.0014
#
# RIGHT_KNEE: x=0.5076, y=2.2899, z=0.1044, visibility=0.0012
#
# LEFT_ANKLE: x=0.8116, y=2.8288, z=0.4456, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5303, y=2.8372, z=0.5738, visibility=0.0000
#
# LEFT_HEEL: x=0.8197, y=2.9150, z=0.4592, visibility=0.0001
#
# RIGHT_HEEL: x=0.5252, y=2.9265, z=0.5975, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7685, y=3.0163, z=-0.2495, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5961, y=3.0152, z=-0.1135, visibility=0.0002
#
# NOSE: x=0.5914, y=0.6879, z=-1.1898, visibility=0.9982
#
# LEFT_EYE_INNER: x=0.6158, y=0.6162, z=-1.1258, visibility=0.9974
#
# LEFT_EYE: x=0.6332, y=0.6158, z=-1.1262, visibility=0.9976
#
# LEFT_EYE_OUTER: x=0.6504, y=0.6164, z=-1.1267, visibility=0.9969
#
# RIGHT_EYE_INNER: x=0.5542, y=0.6208, z=-1.1337, visibility=0.9975
#
# RIGHT_EYE: x=0.5312, y=0.6242, z=-1.1330, visibility=0.9980
#
# RIGHT_EYE_OUTER: x=0.5106, y=0.6283, z=-1.1334, visibility=0.9979
#
# LEFT_EAR: x=0.6815, y=0.6375, z=-0.6309, visibility=0.9976
#
# RIGHT_EAR: x=0.4758, y=0.6625, z=-0.6460, visibility=0.9984
#
# MOUTH_LEFT: x=0.6277, y=0.7603, z=-0.9961, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5501, y=0.7697, z=-1.0015, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8263, y=0.9261, z=-0.3264, visibility=0.9825
#
# RIGHT_SHOULDER: x=0.3517, y=0.9798, z=-0.3608, visibility=0.9877
#
# LEFT_ELBOW: x=0.8755, y=1.0617, z=-0.5180, visibility=0.0591
#
# RIGHT_ELBOW: x=0.3136, y=1.4000, z=-0.6983, visibility=0.2311
#
# LEFT_WRIST: x=0.8940, y=1.4756, z=-1.1135, visibility=0.0304
#
# RIGHT_WRIST: x=0.3726, y=1.4997, z=-1.6949, visibility=0.1115
#
# LEFT_PINKY: x=0.9194, y=1.5722, z=-1.2675, visibility=0.0402
#
# RIGHT_PINKY: x=0.3792, y=1.5616, z=-1.9044, visibility=0.1396
#
# LEFT_INDEX: x=0.8728, y=1.5493, z=-1.3199, visibility=0.0561
#
# RIGHT_INDEX: x=0.4011, y=1.4900, z=-1.9510, visibility=0.1941
#
# LEFT_THUMB: x=0.8517, y=1.5189, z=-1.1602, visibility=0.0572
#
# RIGHT_THUMB: x=0.4086, y=1.4698, z=-1.7416, visibility=0.1750
#
# LEFT_HIP: x=0.7723, y=1.6665, z=-0.0729, visibility=0.0011
#
# RIGHT_HIP: x=0.4652, y=1.6924, z=0.0785, visibility=0.0009
#
# LEFT_KNEE: x=0.7916, y=2.2761, z=-0.1326, visibility=0.0014
#
# RIGHT_KNEE: x=0.5048, y=2.2890, z=0.1134, visibility=0.0012
#
# LEFT_ANKLE: x=0.8052, y=2.8296, z=0.4345, visibility=0.0001
#
# RIGHT_ANKLE: x=0.5232, y=2.8370, z=0.5795, visibility=0.0000
#
# LEFT_HEEL: x=0.8122, y=2.9159, z=0.4471, visibility=0.0001
#
# RIGHT_HEEL: x=0.5174, y=2.9258, z=0.6025, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7626, y=3.0163, z=-0.2689, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.5857, y=3.0149, z=-0.1170, visibility=0.0002
