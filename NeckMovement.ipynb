# %% [markdown]
# # Install and Import Dependencies

# %%
pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (0.10.21)
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (4.11.0.86)
# Requirement already satisfied: absl-py in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (2.3.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: jaxlib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.6.2)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (3.10.5)
# Requirement already satisfied: numpy<2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (0.5.3)
# Requirement already satisfied: opt_einsum in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# video feed
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('Camera Feed', frame)
    
    if cv2.waitKey(10) & 0xFF == ord('x'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Make Detections

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Video Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # Determining Joints

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark
            for id, lm in enumerate(landmarks):
                landmark_name = mp_pose.PoseLandmark(id).name   # get landmark name
                print(f"{landmark_name}: "
                      f"x={lm.x:.4f}, y={lm.y:.4f}, z={lm.z:.4f}, visibility={lm.visibility:.4f} \n")

        except:
            pass
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Camera Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# NOSE: x=0.5854, y=0.7097, z=-1.1098, visibility=0.9998
#
# LEFT_EYE_INNER: x=0.6175, y=0.6339, z=-1.0100, visibility=0.9997
#
# LEFT_EYE: x=0.6369, y=0.6324, z=-1.0101, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6551, y=0.6321, z=-1.0102, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5468, y=0.6385, z=-1.0395, visibility=0.9997
#
# RIGHT_EYE: x=0.5170, y=0.6398, z=-1.0386, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4905, y=0.6417, z=-1.0392, visibility=0.9997
#
# LEFT_EAR: x=0.6696, y=0.6665, z=-0.4432, visibility=0.9997
#
# RIGHT_EAR: x=0.4431, y=0.6755, z=-0.5632, visibility=0.9999
#
# MOUTH_LEFT: x=0.6184, y=0.7910, z=-0.8995, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5377, y=0.7957, z=-0.9354, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8035, y=1.0015, z=-0.0361, visibility=0.9847
#
# RIGHT_SHOULDER: x=0.2933, y=1.0027, z=-0.3720, visibility=0.9876
#
# LEFT_ELBOW: x=1.0441, y=1.2508, z=-0.2698, visibility=0.2520
#
# RIGHT_ELBOW: x=0.2413, y=1.5017, z=-0.5009, visibility=0.2776
#
# LEFT_WRIST: x=1.0097, y=1.0062, z=-0.7446, visibility=0.5457
#
# RIGHT_WRIST: x=0.2393, y=1.6502, z=-0.9944, visibility=0.2463
#
# LEFT_PINKY: x=1.0407, y=0.9327, z=-0.8648, visibility=0.4894
#
# RIGHT_PINKY: x=0.2182, y=1.7298, z=-1.1243, visibility=0.3162
#
# LEFT_INDEX: x=0.9196, y=0.8471, z=-0.8306, visibility=0.5494
#
# RIGHT_INDEX: x=0.2409, y=1.6845, z=-1.2070, visibility=0.4283
#
# LEFT_THUMB: x=0.9643, y=0.9486, z=-0.7659, visibility=0.5638
#
# RIGHT_THUMB: x=0.2585, y=1.6604, z=-1.0488, visibility=0.4076
#
# LEFT_HIP: x=0.7270, y=1.9631, z=-0.0017, visibility=0.0021
#
# RIGHT_HIP: x=0.3786, y=1.9580, z=0.0089, visibility=0.0013
#
# LEFT_KNEE: x=0.7201, y=2.7414, z=-0.3624, visibility=0.0008
#
# RIGHT_KNEE: x=0.3854, y=2.7242, z=-0.2729, visibility=0.0004
#
# LEFT_ANKLE: x=0.7102, y=3.4637, z=0.0835, visibility=0.0000
#
# RIGHT_ANKLE: x=0.3767, y=3.4562, z=-0.1165, visibility=0.0000
#
# LEFT_HEEL: x=0.7115, y=3.5689, z=0.0832, visibility=0.0001
#
# RIGHT_HEEL: x=0.3669, y=3.5716, z=-0.1307, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.6653, y=3.6779, z=-0.6822, visibility=0.0001
#
# RIGHT_FOOT_INDEX: x=0.4253, y=3.6559, z=-0.9451, visibility=0.0001
#
# NOSE: x=0.5857, y=0.7125, z=-1.1047, visibility=0.9998
#
# LEFT_EYE_INNER: x=0.6181, y=0.6371, z=-1.0071, visibility=0.9997
#
# LEFT_EYE: x=0.6373, y=0.6360, z=-1.0073, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6555, y=0.6360, z=-1.0074, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5484, y=0.6421, z=-1.0258, visibility=0.9997
#
# RIGHT_EYE: x=0.5189, y=0.6445, z=-1.0253, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4923, y=0.6479, z=-1.0257, visibility=0.9997
#
# LEFT_EAR: x=0.6700, y=0.6690, z=-0.4380, visibility=0.9997
#
# RIGHT_EAR: x=0.4450, y=0.6820, z=-0.4996, visibility=0.9998
#
# MOUTH_LEFT: x=0.6184, y=0.7946, z=-0.8901, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5381, y=0.7996, z=-0.9109, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8032, y=0.9934, z=-0.1352, visibility=0.9846
#
# RIGHT_SHOULDER: x=0.2980, y=1.0008, z=-0.2836, visibility=0.9847
#
# LEFT_ELBOW: x=1.0282, y=1.2426, z=-0.9021, visibility=0.2747
#
# RIGHT_ELBOW: x=0.2120, y=1.4244, z=-0.9938, visibility=0.2805
#
# LEFT_WRIST: x=0.9558, y=0.9695, z=-1.7304, visibility=0.5642
#
# RIGHT_WRIST: x=0.2772, y=1.2655, z=-2.0681, visibility=0.2686
#
# LEFT_PINKY: x=0.9597, y=0.8865, z=-1.9087, visibility=0.5143
#
# RIGHT_PINKY: x=0.2894, y=1.2258, z=-2.2901, visibility=0.3330
#
# LEFT_INDEX: x=0.8650, y=0.8001, z=-1.8404, visibility=0.5733
#
# RIGHT_INDEX: x=0.3046, y=1.1854, z=-2.2289, visibility=0.4429
#
# LEFT_THUMB: x=0.8585, y=0.8607, z=-1.7369, visibility=0.5814
#
# RIGHT_THUMB: x=0.3147, y=1.2111, z=-2.0842, visibility=0.4180
#
# LEFT_HIP: x=0.7231, y=1.9637, z=-0.0240, visibility=0.0021
#
# RIGHT_HIP: x=0.3824, y=1.9626, z=0.0303, visibility=0.0013
#
# LEFT_KNEE: x=0.7164, y=2.7195, z=-0.3579, visibility=0.0018
#
# RIGHT_KNEE: x=0.3913, y=2.6944, z=-0.2849, visibility=0.0007
#
# LEFT_ANKLE: x=0.7183, y=3.4061, z=0.0836, visibility=0.0001
#
# RIGHT_ANKLE: x=0.4101, y=3.3973, z=-0.1181, visibility=0.0000
#
# LEFT_HEEL: x=0.7217, y=3.5117, z=0.0838, visibility=0.0001
#
# RIGHT_HEEL: x=0.4108, y=3.5076, z=-0.1314, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.6814, y=3.6006, z=-0.6380, visibility=0.0002
#
# RIGHT_FOOT_INDEX: x=0.4477, y=3.5879, z=-0.8987, visibility=0.0001
#
# NOSE: x=0.5880, y=0.7202, z=-1.1236, visibility=0.9998
#
# LEFT_EYE_INNER: x=0.6206, y=0.6448, z=-1.0276, visibility=0.9997
#
# LEFT_EYE: x=0.6393, y=0.6445, z=-1.0280, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6571, y=0.6454, z=-1.0281, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5531, y=0.6491, z=-1.0381, visibility=0.9997
#
# RIGHT_EYE: x=0.5246, y=0.6521, z=-1.0379, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.4982, y=0.6561, z=-1.0382, visibility=0.9997
#
# LEFT_EAR: x=0.6700, y=0.6774, z=-0.4656, visibility=0.9998
#
# RIGHT_EAR: x=0.4506, y=0.6896, z=-0.5107, visibility=0.9998
#
# MOUTH_LEFT: x=0.6184, y=0.8034, z=-0.9115, visibility=0.9995
#
# MOUTH_RIGHT: x=0.5399, y=0.8055, z=-0.9244, visibility=0.9997
#
# LEFT_SHOULDER: x=0.7986, y=0.9935, z=-0.2071, visibility=0.9845
#
# RIGHT_SHOULDER: x=0.3035, y=1.0008, z=-0.2725, visibility=0.9815
#
# LEFT_ELBOW: x=1.0357, y=1.2297, z=-0.9752, visibility=0.3051
#
# RIGHT_ELBOW: x=0.1840, y=1.3849, z=-0.9002, visibility=0.2754
#
# LEFT_WRIST: x=0.9636, y=0.7774, z=-1.7276, visibility=0.5873
#
# RIGHT_WRIST: x=0.2560, y=1.1827, z=-1.8508, visibility=0.2779
#
# LEFT_PINKY: x=0.9748, y=0.6389, z=-1.8886, visibility=0.5411
#
# RIGHT_PINKY: x=0.2782, y=1.1262, z=-2.0350, visibility=0.3384
#
# LEFT_INDEX: x=0.9230, y=0.6423, z=-1.8142, visibility=0.5982
#
# RIGHT_INDEX: x=0.2892, y=1.0954, z=-1.9780, visibility=0.4460
#
# LEFT_THUMB: x=0.8850, y=0.7167, z=-1.7303, visibility=0.6006
#
# RIGHT_THUMB: x=0.3003, y=1.1268, z=-1.8653, visibility=0.4185
#
# LEFT_HIP: x=0.7211, y=1.9684, z=-0.0317, visibility=0.0022
#
# RIGHT_HIP: x=0.3886, y=1.9734, z=0.0378, visibility=0.0014
#
# LEFT_KNEE: x=0.7163, y=2.7047, z=-0.3571, visibility=0.0027
#
# RIGHT_KNEE: x=0.3928, y=2.6774, z=-0.3284, visibility=0.0009
#
# LEFT_ANKLE: x=0.7211, y=3.3756, z=0.0788, visibility=0.0001
#
# RIGHT_ANKLE: x=0.4176, y=3.3706, z=-0.1488, visibility=0.0000
#
# LEFT_HEEL: x=0.7244, y=3.4787, z=0.0801, visibility=0.0001
#
# RIGHT_HEEL: x=0.4197, y=3.4794, z=-0.1604, visibility=0.0000
#
# LEFT_FOOT_INDEX: x=0.6864, y=3.5697, z=-0.6266, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.4545, y=3.5569, z=-0.9013, visibility=0.0002
#
# NOSE: x=0.5910, y=0.7276, z=-1.1409, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6221, y=0.6514, z=-1.0421, visibility=0.9996
#
# LEFT_EYE: x=0.6406, y=0.6507, z=-1.0425, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6584, y=0.6510, z=-1.0426, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5556, y=0.6564, z=-1.0524, visibility=0.9996
#
# RIGHT_EYE: x=0.5272, y=0.6599, z=-1.0524, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.5008, y=0.6644, z=-1.0527, visibility=0.9997
#
# LEFT_EAR: x=0.6701, y=0.6808, z=-0.4695, visibility=0.9997
#
# RIGHT_EAR: x=0.4519, y=0.6968, z=-0.5172, visibility=0.9998
#
# MOUTH_LEFT: x=0.6191, y=0.8108, z=-0.9246, visibility=0.9994
#
# MOUTH_RIGHT: x=0.5427, y=0.8127, z=-0.9383, visibility=0.9995
#
# LEFT_SHOULDER: x=0.7984, y=0.9929, z=-0.2219, visibility=0.9802
#
# RIGHT_SHOULDER: x=0.3060, y=1.0009, z=-0.2841, visibility=0.9731
#
# LEFT_ELBOW: x=1.0359, y=1.2116, z=-0.9988, visibility=0.3182
#
# RIGHT_ELBOW: x=0.1790, y=1.3582, z=-0.9630, visibility=0.2706
#
# LEFT_WRIST: x=0.9464, y=0.8119, z=-1.7349, visibility=0.5820
#
# RIGHT_WRIST: x=0.2572, y=1.1436, z=-1.9001, visibility=0.2724
#
# LEFT_PINKY: x=0.9319, y=0.6776, z=-1.8962, visibility=0.5405
#
# RIGHT_PINKY: x=0.2744, y=1.0897, z=-2.0865, visibility=0.3308
#
# LEFT_INDEX: x=0.9166, y=0.6822, z=-1.8146, visibility=0.5977
#
# RIGHT_INDEX: x=0.2875, y=1.0539, z=-2.0240, visibility=0.4346
#
# LEFT_THUMB: x=0.8901, y=0.7516, z=-1.7345, visibility=0.5941
#
# RIGHT_THUMB: x=0.2976, y=1.0845, z=-1.9124, visibility=0.4059
#
# LEFT_HIP: x=0.7185, y=1.9734, z=-0.0330, visibility=0.0022
#
# RIGHT_HIP: x=0.3910, y=1.9833, z=0.0390, visibility=0.0014
#
# LEFT_KNEE: x=0.7178, y=2.6087, z=-0.3781, visibility=0.0035
#
# RIGHT_KNEE: x=0.3926, y=2.5910, z=-0.3703, visibility=0.0011
#
# LEFT_ANKLE: x=0.7294, y=3.2693, z=0.0473, visibility=0.0001
#
# RIGHT_ANKLE: x=0.4399, y=3.2604, z=-0.1739, visibility=0.0000
#
# LEFT_HEEL: x=0.7306, y=3.3759, z=0.0509, visibility=0.0001
#
# RIGHT_HEEL: x=0.4474, y=3.3628, z=-0.1828, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7056, y=3.4597, z=-0.6288, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.4776, y=3.4521, z=-0.8977, visibility=0.0003
#
# NOSE: x=0.5936, y=0.7334, z=-1.1387, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6247, y=0.6561, z=-1.0408, visibility=0.9996
#
# LEFT_EYE: x=0.6431, y=0.6556, z=-1.0413, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6608, y=0.6561, z=-1.0414, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5577, y=0.6609, z=-1.0519, visibility=0.9996
#
# RIGHT_EYE: x=0.5286, y=0.6647, z=-1.0519, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.5017, y=0.6699, z=-1.0522, visibility=0.9996
#
# LEFT_EAR: x=0.6708, y=0.6858, z=-0.4770, visibility=0.9997
#
# RIGHT_EAR: x=0.4519, y=0.7032, z=-0.5215, visibility=0.9998
#
# MOUTH_LEFT: x=0.6198, y=0.8186, z=-0.9249, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5437, y=0.8200, z=-0.9388, visibility=0.9995
#
# LEFT_SHOULDER: x=0.7981, y=0.9937, z=-0.2226, visibility=0.9791
#
# RIGHT_SHOULDER: x=0.3073, y=1.0018, z=-0.2882, visibility=0.9664
#
# LEFT_ELBOW: x=1.0371, y=1.2124, z=-1.0083, visibility=0.3244
#
# RIGHT_ELBOW: x=0.1858, y=1.3820, z=-0.9363, visibility=0.2564
#
# LEFT_WRIST: x=0.9705, y=0.7442, z=-1.7407, visibility=0.5983
#
# RIGHT_WRIST: x=0.2614, y=1.1647, z=-1.8249, visibility=0.2735
#
# LEFT_PINKY: x=0.9371, y=0.6110, z=-1.8928, visibility=0.5611
#
# RIGHT_PINKY: x=0.2736, y=1.1023, z=-1.9929, visibility=0.3305
#
# LEFT_INDEX: x=0.9473, y=0.5952, z=-1.8100, visibility=0.6169
#
# RIGHT_INDEX: x=0.2854, y=1.0680, z=-1.9258, visibility=0.4323
#
# LEFT_THUMB: x=0.9098, y=0.6618, z=-1.7414, visibility=0.6093
#
# RIGHT_THUMB: x=0.2973, y=1.1007, z=-1.8339, visibility=0.4015
#
# LEFT_HIP: x=0.7188, y=1.9923, z=-0.0369, visibility=0.0022
#
# RIGHT_HIP: x=0.3956, y=2.0031, z=0.0432, visibility=0.0014
#
# LEFT_KNEE: x=0.7185, y=2.6596, z=-0.3075, visibility=0.0038
#
# RIGHT_KNEE: x=0.3943, y=2.6347, z=-0.2609, visibility=0.0012
#
# LEFT_ANKLE: x=0.7287, y=3.2903, z=0.1467, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4324, y=3.2943, z=-0.0291, visibility=0.0000
#
# LEFT_HEEL: x=0.7301, y=3.4023, z=0.1542, visibility=0.0001
#
# RIGHT_HEEL: x=0.4360, y=3.4048, z=-0.0346, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7047, y=3.5001, z=-0.5174, visibility=0.0003
#
# RIGHT_FOOT_INDEX: x=0.4728, y=3.4965, z=-0.7320, visibility=0.0003
#
# NOSE: x=0.5971, y=0.7334, z=-1.1557, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6287, y=0.6566, z=-1.0582, visibility=0.9996
#
# LEFT_EYE: x=0.6478, y=0.6561, z=-1.0586, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6664, y=0.6563, z=-1.0587, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5612, y=0.6609, z=-1.0675, visibility=0.9996
#
# RIGHT_EYE: x=0.5317, y=0.6642, z=-1.0674, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.5043, y=0.6691, z=-1.0677, visibility=0.9996
#
# LEFT_EAR: x=0.6782, y=0.6858, z=-0.4804, visibility=0.9997
#
# RIGHT_EAR: x=0.4529, y=0.7024, z=-0.5229, visibility=0.9998
#
# MOUTH_LEFT: x=0.6224, y=0.8185, z=-0.9345, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5466, y=0.8199, z=-0.9462, visibility=0.9995
#
# LEFT_SHOULDER: x=0.8156, y=0.9937, z=-0.2100, visibility=0.9779
#
# RIGHT_SHOULDER: x=0.3071, y=1.0042, z=-0.2778, visibility=0.9646
#
# LEFT_ELBOW: x=1.0325, y=1.2145, z=-0.9801, visibility=0.3259
#
# RIGHT_ELBOW: x=0.1898, y=1.3941, z=-0.9627, visibility=0.2558
#
# LEFT_WRIST: x=0.9366, y=0.9069, z=-1.8217, visibility=0.5942
#
# RIGHT_WRIST: x=0.2862, y=1.2628, z=-2.0208, visibility=0.2750
#
# LEFT_PINKY: x=0.9219, y=0.8377, z=-2.0061, visibility=0.5648
#
# RIGHT_PINKY: x=0.3031, y=1.2425, z=-2.2381, visibility=0.3323
#
# LEFT_INDEX: x=0.9098, y=0.8200, z=-1.9415, visibility=0.6216
#
# RIGHT_INDEX: x=0.3225, y=1.1996, z=-2.1825, visibility=0.4329
#
# LEFT_THUMB: x=0.8815, y=0.8436, z=-1.8302, visibility=0.6085
#
# RIGHT_THUMB: x=0.3314, y=1.2157, z=-2.0380, visibility=0.3987
#
# LEFT_HIP: x=0.7250, y=1.9925, z=-0.0419, visibility=0.0023
#
# RIGHT_HIP: x=0.3981, y=2.0013, z=0.0483, visibility=0.0014
#
# LEFT_KNEE: x=0.7289, y=2.6578, z=-0.4022, visibility=0.0048
#
# RIGHT_KNEE: x=0.4090, y=2.6388, z=-0.3532, visibility=0.0014
#
# LEFT_ANKLE: x=0.7450, y=3.3226, z=0.0234, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4472, y=3.3217, z=-0.1697, visibility=0.0000
#
# LEFT_HEEL: x=0.7482, y=3.4323, z=0.0230, visibility=0.0001
#
# RIGHT_HEEL: x=0.4513, y=3.4330, z=-0.1811, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7133, y=3.5283, z=-0.6841, visibility=0.0004
#
# RIGHT_FOOT_INDEX: x=0.4851, y=3.5209, z=-0.9168, visibility=0.0004
#
# NOSE: x=0.5998, y=0.7358, z=-1.2175, visibility=0.9996
#
# LEFT_EYE_INNER: x=0.6317, y=0.6600, z=-1.1141, visibility=0.9996
#
# LEFT_EYE: x=0.6508, y=0.6595, z=-1.1144, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6694, y=0.6595, z=-1.1145, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5630, y=0.6635, z=-1.1212, visibility=0.9996
#
# RIGHT_EYE: x=0.5329, y=0.6663, z=-1.1209, visibility=0.9996
#
# RIGHT_EYE_OUTER: x=0.5052, y=0.6705, z=-1.1212, visibility=0.9996
#
# LEFT_EAR: x=0.6789, y=0.6884, z=-0.5343, visibility=0.9997
#
# RIGHT_EAR: x=0.4533, y=0.7035, z=-0.5621, visibility=0.9997
#
# MOUTH_LEFT: x=0.6239, y=0.8206, z=-1.0030, visibility=0.9993
#
# MOUTH_RIGHT: x=0.5484, y=0.8206, z=-1.0126, visibility=0.9994
#
# LEFT_SHOULDER: x=0.8143, y=0.9986, z=-0.3059, visibility=0.9783
#
# RIGHT_SHOULDER: x=0.3073, y=1.0115, z=-0.2833, visibility=0.9553
#
# LEFT_ELBOW: x=1.0889, y=1.2041, z=-1.1703, visibility=0.3607
#
# RIGHT_ELBOW: x=0.1821, y=1.4008, z=-0.9236, visibility=0.2433
#
# LEFT_WRIST: x=0.9887, y=0.7040, z=-1.8876, visibility=0.6193
#
# RIGHT_WRIST: x=0.2585, y=1.2007, z=-1.8827, visibility=0.2687
#
# LEFT_PINKY: x=0.9533, y=0.6067, z=-2.0531, visibility=0.5873
#
# RIGHT_PINKY: x=0.2727, y=1.1443, z=-2.0541, visibility=0.3223
#
# LEFT_INDEX: x=0.9454, y=0.5962, z=-1.9436, visibility=0.6416
#
# RIGHT_INDEX: x=0.2831, y=1.1138, z=-2.0080, visibility=0.4196
#
# LEFT_THUMB: x=0.9198, y=0.6405, z=-1.8754, visibility=0.6254
#
# RIGHT_THUMB: x=0.2959, y=1.1454, z=-1.9017, visibility=0.3850
#
# LEFT_HIP: x=0.7191, y=2.0376, z=-0.0580, visibility=0.0025
#
# RIGHT_HIP: x=0.3961, y=2.0436, z=0.0645, visibility=0.0015
#
# LEFT_KNEE: x=0.7246, y=2.7107, z=-0.3768, visibility=0.0053
#
# RIGHT_KNEE: x=0.3912, y=2.6954, z=-0.2335, visibility=0.0015
#
# LEFT_ANKLE: x=0.7121, y=3.3522, z=0.1160, visibility=0.0002
#
# RIGHT_ANKLE: x=0.4017, y=3.3461, z=0.0377, visibility=0.0001
#
# LEFT_HEEL: x=0.7130, y=3.4544, z=0.1225, visibility=0.0002
#
# RIGHT_HEEL: x=0.4018, y=3.4533, z=0.0347, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6695, y=3.5538, z=-0.5836, visibility=0.0004
#
# RIGHT_FOOT_INDEX: x=0.4339, y=3.5365, z=-0.6883, visibility=0.0004
#
# NOSE: x=0.6015, y=0.7389, z=-1.1979, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6332, y=0.6626, z=-1.0964, visibility=0.9996
#
# LEFT_EYE: x=0.6524, y=0.6621, z=-1.0968, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6713, y=0.6619, z=-1.0969, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5648, y=0.6657, z=-1.1076, visibility=0.9996
#
# RIGHT_EYE: x=0.5348, y=0.6682, z=-1.1072, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.5067, y=0.6721, z=-1.1076, visibility=0.9996
#
# LEFT_EAR: x=0.6814, y=0.6912, z=-0.5203, visibility=0.9997
#
# RIGHT_EAR: x=0.4543, y=0.7058, z=-0.5610, visibility=0.9997
#
# MOUTH_LEFT: x=0.6252, y=0.8241, z=-0.9842, visibility=0.9992
#
# MOUTH_RIGHT: x=0.5495, y=0.8258, z=-0.9987, visibility=0.9994
#
# LEFT_SHOULDER: x=0.8139, y=1.0041, z=-0.2541, visibility=0.9753
#
# RIGHT_SHOULDER: x=0.3111, y=1.0153, z=-0.2826, visibility=0.9523
#
# LEFT_ELBOW: x=1.0300, y=1.2424, z=-0.9950, visibility=0.3472
#
# RIGHT_ELBOW: x=0.1864, y=1.4020, z=-0.8767, visibility=0.2329
#
# LEFT_WRIST: x=0.9620, y=0.8726, z=-1.7633, visibility=0.6034
#
# RIGHT_WRIST: x=0.2705, y=1.2541, z=-1.7566, visibility=0.2579
#
# LEFT_PINKY: x=0.9202, y=0.6526, z=-1.9243, visibility=0.5788
#
# RIGHT_PINKY: x=0.2823, y=1.2249, z=-1.9268, visibility=0.3101
#
# LEFT_INDEX: x=0.9173, y=0.7190, z=-1.8593, visibility=0.6343
#
# RIGHT_INDEX: x=0.2945, y=1.1882, z=-1.8927, visibility=0.4041
#
# LEFT_THUMB: x=0.8827, y=0.6883, z=-1.7708, visibility=0.6138
#
# RIGHT_THUMB: x=0.3065, y=1.2082, z=-1.7759, visibility=0.3694
#
# LEFT_HIP: x=0.7314, y=2.0334, z=-0.0544, visibility=0.0027
#
# RIGHT_HIP: x=0.4053, y=2.0404, z=0.0610, visibility=0.0016
#
# LEFT_KNEE: x=0.7440, y=2.7164, z=-0.3443, visibility=0.0065
#
# RIGHT_KNEE: x=0.4217, y=2.6980, z=-0.2975, visibility=0.0018
#
# LEFT_ANKLE: x=0.7602, y=3.3580, z=0.1144, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4544, y=3.3505, z=-0.0543, visibility=0.0001
#
# LEFT_HEEL: x=0.7664, y=3.4615, z=0.1184, visibility=0.0002
#
# RIGHT_HEEL: x=0.4556, y=3.4597, z=-0.0585, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7188, y=3.5582, z=-0.5898, visibility=0.0005
#
# RIGHT_FOOT_INDEX: x=0.4956, y=3.5416, z=-0.7478, visibility=0.0005
#
# NOSE: x=0.6019, y=0.7418, z=-1.1674, visibility=0.9995
#
# LEFT_EYE_INNER: x=0.6339, y=0.6649, z=-1.0741, visibility=0.9996
#
# LEFT_EYE: x=0.6533, y=0.6644, z=-1.0744, visibility=0.9996
#
# LEFT_EYE_OUTER: x=0.6724, y=0.6640, z=-1.0746, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5654, y=0.6676, z=-1.0878, visibility=0.9995
#
# RIGHT_EYE: x=0.5354, y=0.6697, z=-1.0875, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.5074, y=0.6733, z=-1.0880, visibility=0.9995
#
# LEFT_EAR: x=0.6830, y=0.6941, z=-0.5081, visibility=0.9997
#
# RIGHT_EAR: x=0.4544, y=0.7068, z=-0.5567, visibility=0.9997
#
# MOUTH_LEFT: x=0.6256, y=0.8277, z=-0.9516, visibility=0.9992
#
# MOUTH_RIGHT: x=0.5496, y=0.8297, z=-0.9701, visibility=0.9993
#
# LEFT_SHOULDER: x=0.8138, y=1.0096, z=-0.2240, visibility=0.9725
#
# RIGHT_SHOULDER: x=0.3110, y=1.0171, z=-0.2881, visibility=0.9514
#
# LEFT_ELBOW: x=1.0216, y=1.2633, z=-0.9242, visibility=0.3332
#
# RIGHT_ELBOW: x=0.1882, y=1.4177, z=-0.9270, visibility=0.2264
#
# LEFT_WRIST: x=0.9416, y=0.9618, z=-1.6938, visibility=0.5917
#
# RIGHT_WRIST: x=0.2897, y=1.3071, z=-1.8606, visibility=0.2580
#
# LEFT_PINKY: x=0.9284, y=0.8415, z=-1.8573, visibility=0.5727
#
# RIGHT_PINKY: x=0.3020, y=1.2888, z=-2.0520, visibility=0.3092
#
# LEFT_INDEX: x=0.8802, y=0.7953, z=-1.7873, visibility=0.6293
#
# RIGHT_INDEX: x=0.3206, y=1.2397, z=-2.0035, visibility=0.4025
#
# LEFT_THUMB: x=0.8834, y=0.8640, z=-1.7005, visibility=0.6064
#
# RIGHT_THUMB: x=0.3307, y=1.2554, z=-1.8754, visibility=0.3659
#
# LEFT_HIP: x=0.7319, y=2.0285, z=-0.0511, visibility=0.0027
#
# RIGHT_HIP: x=0.4046, y=2.0347, z=0.0573, visibility=0.0017
#
# LEFT_KNEE: x=0.7432, y=2.7395, z=-0.2900, visibility=0.0073
#
# RIGHT_KNEE: x=0.4210, y=2.7197, z=-0.2944, visibility=0.0020
#
# LEFT_ANKLE: x=0.7581, y=3.3969, z=0.1409, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4499, y=3.3826, z=-0.0573, visibility=0.0001
#
# LEFT_HEEL: x=0.7637, y=3.5001, z=0.1428, visibility=0.0002
#
# RIGHT_HEEL: x=0.4500, y=3.4907, z=-0.0636, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7160, y=3.5996, z=-0.5595, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4927, y=3.5723, z=-0.7857, visibility=0.0005
#
# NOSE: x=0.6028, y=0.7417, z=-1.1912, visibility=0.9994
#
# LEFT_EYE_INNER: x=0.6343, y=0.6645, z=-1.0934, visibility=0.9995
#
# LEFT_EYE: x=0.6540, y=0.6641, z=-1.0938, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6734, y=0.6638, z=-1.0939, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5653, y=0.6662, z=-1.1052, visibility=0.9995
#
# RIGHT_EYE: x=0.5354, y=0.6671, z=-1.1050, visibility=0.9995
#
# RIGHT_EYE_OUTER: x=0.5073, y=0.6696, z=-1.1055, visibility=0.9995
#
# LEFT_EAR: x=0.6854, y=0.6940, z=-0.5187, visibility=0.9996
#
# RIGHT_EAR: x=0.4543, y=0.7059, z=-0.5653, visibility=0.9996
#
# MOUTH_LEFT: x=0.6275, y=0.8275, z=-0.9741, visibility=0.9991
#
# MOUTH_RIGHT: x=0.5506, y=0.8289, z=-0.9901, visibility=0.9992
#
# LEFT_SHOULDER: x=0.8142, y=1.0103, z=-0.2535, visibility=0.9690
#
# RIGHT_SHOULDER: x=0.3109, y=1.0170, z=-0.3231, visibility=0.9461
#
# LEFT_ELBOW: x=1.0559, y=1.2380, z=-1.0959, visibility=0.3418
#
# RIGHT_ELBOW: x=0.1893, y=1.4171, z=-1.0927, visibility=0.2204
#
# LEFT_WRIST: x=0.9915, y=0.7575, z=-1.8620, visibility=0.5926
#
# RIGHT_WRIST: x=0.2874, y=1.2356, z=-2.1098, visibility=0.2551
#
# LEFT_PINKY: x=0.9774, y=0.6285, z=-2.0213, visibility=0.5741
#
# RIGHT_PINKY: x=0.2998, y=1.1870, z=-2.3023, visibility=0.3035
#
# LEFT_INDEX: x=0.9337, y=0.6387, z=-1.9264, visibility=0.6304
#
# RIGHT_INDEX: x=0.3156, y=1.1485, z=-2.2282, visibility=0.3940
#
# LEFT_THUMB: x=0.9140, y=0.7181, z=-1.8578, visibility=0.6047
#
# RIGHT_THUMB: x=0.3261, y=1.1777, z=-2.1191, visibility=0.3568
#
# LEFT_HIP: x=0.7308, y=2.0299, z=-0.0494, visibility=0.0027
#
# RIGHT_HIP: x=0.4032, y=2.0356, z=0.0557, visibility=0.0017
#
# LEFT_KNEE: x=0.7382, y=2.7382, z=-0.2978, visibility=0.0072
#
# RIGHT_KNEE: x=0.4082, y=2.7126, z=-0.3041, visibility=0.0020
#
# LEFT_ANKLE: x=0.7535, y=3.3957, z=0.1600, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4342, y=3.3808, z=-0.0592, visibility=0.0001
#
# LEFT_HEEL: x=0.7599, y=3.4993, z=0.1651, visibility=0.0002
#
# RIGHT_HEEL: x=0.4356, y=3.4889, z=-0.0645, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7097, y=3.5989, z=-0.5249, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4740, y=3.5726, z=-0.7935, visibility=0.0005
#
# NOSE: x=0.6033, y=0.7407, z=-1.2107, visibility=0.9994
#
# LEFT_EYE_INNER: x=0.6344, y=0.6644, z=-1.1081, visibility=0.9995
#
# LEFT_EYE: x=0.6540, y=0.6638, z=-1.1084, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6734, y=0.6636, z=-1.1086, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5652, y=0.6642, z=-1.1212, visibility=0.9994
#
# RIGHT_EYE: x=0.5353, y=0.6638, z=-1.1209, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.5072, y=0.6654, z=-1.1213, visibility=0.9994
#
# LEFT_EAR: x=0.6853, y=0.6943, z=-0.5284, visibility=0.9996
#
# RIGHT_EAR: x=0.4542, y=0.7051, z=-0.5816, visibility=0.9996
#
# MOUTH_LEFT: x=0.6280, y=0.8273, z=-0.9943, visibility=0.9990
#
# MOUTH_RIGHT: x=0.5506, y=0.8265, z=-1.0119, visibility=0.9992
#
# LEFT_SHOULDER: x=0.8085, y=1.0121, z=-0.2884, visibility=0.9685
#
# RIGHT_SHOULDER: x=0.3073, y=1.0175, z=-0.3452, visibility=0.9401
#
# LEFT_ELBOW: x=1.1122, y=1.1805, z=-1.1815, visibility=0.3720
#
# RIGHT_ELBOW: x=0.1819, y=1.3989, z=-1.1189, visibility=0.2185
#
# LEFT_WRIST: x=1.0117, y=0.6598, z=-1.8845, visibility=0.6065
#
# RIGHT_WRIST: x=0.2546, y=1.1400, z=-2.1134, visibility=0.2546
#
# LEFT_PINKY: x=0.9979, y=0.5587, z=-2.0398, visibility=0.5823
#
# RIGHT_PINKY: x=0.2600, y=1.0669, z=-2.3012, visibility=0.2979
#
# LEFT_INDEX: x=0.9541, y=0.5554, z=-1.9249, visibility=0.6372
#
# RIGHT_INDEX: x=0.2717, y=1.0378, z=-2.2304, visibility=0.3857
#
# LEFT_THUMB: x=0.9359, y=0.6079, z=-1.8710, visibility=0.6094
#
# RIGHT_THUMB: x=0.2869, y=1.0775, z=-2.1253, visibility=0.3486
#
# LEFT_HIP: x=0.7282, y=2.0412, z=-0.0488, visibility=0.0028
#
# RIGHT_HIP: x=0.4001, y=2.0443, z=0.0551, visibility=0.0017
#
# LEFT_KNEE: x=0.7206, y=2.7392, z=-0.3412, visibility=0.0078
#
# RIGHT_KNEE: x=0.3921, y=2.7116, z=-0.3304, visibility=0.0021
#
# LEFT_ANKLE: x=0.7218, y=3.3999, z=0.1051, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3936, y=3.3815, z=-0.1088, visibility=0.0001
#
# LEFT_HEEL: x=0.7274, y=3.5030, z=0.1085, visibility=0.0003
#
# RIGHT_HEEL: x=0.3921, y=3.4907, z=-0.1162, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6705, y=3.6033, z=-0.5834, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4282, y=3.5727, z=-0.8307, visibility=0.0006
#
# NOSE: x=0.6039, y=0.7404, z=-1.2020, visibility=0.9994
#
# LEFT_EYE_INNER: x=0.6344, y=0.6641, z=-1.1008, visibility=0.9995
#
# LEFT_EYE: x=0.6540, y=0.6636, z=-1.1011, visibility=0.9995
#
# LEFT_EYE_OUTER: x=0.6733, y=0.6636, z=-1.1013, visibility=0.9995
#
# RIGHT_EYE_INNER: x=0.5651, y=0.6633, z=-1.1152, visibility=0.9994
#
# RIGHT_EYE: x=0.5352, y=0.6620, z=-1.1148, visibility=0.9994
#
# RIGHT_EYE_OUTER: x=0.5072, y=0.6630, z=-1.1153, visibility=0.9994
#
# LEFT_EAR: x=0.6852, y=0.6951, z=-0.5227, visibility=0.9996
#
# RIGHT_EAR: x=0.4539, y=0.7049, z=-0.5800, visibility=0.9996
#
# MOUTH_LEFT: x=0.6284, y=0.8272, z=-0.9868, visibility=0.9990
#
# MOUTH_RIGHT: x=0.5507, y=0.8262, z=-1.0048, visibility=0.9992
#
# LEFT_SHOULDER: x=0.8023, y=1.0153, z=-0.2968, visibility=0.9679
#
# RIGHT_SHOULDER: x=0.3065, y=1.0193, z=-0.3455, visibility=0.9329
#
# LEFT_ELBOW: x=1.1370, y=1.1555, z=-1.1464, visibility=0.4049
#
# RIGHT_ELBOW: x=0.1781, y=1.3715, z=-1.0866, visibility=0.2197
#
# LEFT_WRIST: x=1.0331, y=0.6302, z=-1.7700, visibility=0.6159
#
# RIGHT_WRIST: x=0.2441, y=1.0511, z=-1.9867, visibility=0.2525
#
# LEFT_PINKY: x=1.0107, y=0.5270, z=-1.9214, visibility=0.5856
#
# RIGHT_PINKY: x=0.2487, y=0.9606, z=-2.1649, visibility=0.2919
#
# LEFT_INDEX: x=0.9640, y=0.5329, z=-1.8372, visibility=0.6394
#
# RIGHT_INDEX: x=0.2599, y=0.9375, z=-2.0957, visibility=0.3764
#
# LEFT_THUMB: x=0.9474, y=0.5818, z=-1.7619, visibility=0.6095
#
# RIGHT_THUMB: x=0.2752, y=0.9825, z=-1.9970, visibility=0.3403
#
# LEFT_HIP: x=0.7281, y=2.0635, z=-0.0494, visibility=0.0031
#
# RIGHT_HIP: x=0.3999, y=2.0697, z=0.0557, visibility=0.0019
#
# LEFT_KNEE: x=0.7227, y=2.7212, z=-0.4472, visibility=0.0086
#
# RIGHT_KNEE: x=0.3795, y=2.6862, z=-0.4618, visibility=0.0024
#
# LEFT_ANKLE: x=0.7221, y=3.3941, z=-0.0251, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3919, y=3.3755, z=-0.2403, visibility=0.0001
#
# LEFT_HEEL: x=0.7266, y=3.4988, z=-0.0211, visibility=0.0003
#
# RIGHT_HEEL: x=0.3916, y=3.4849, z=-0.2463, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6714, y=3.6002, z=-0.7013, visibility=0.0007
#
# RIGHT_FOOT_INDEX: x=0.4281, y=3.5728, z=-0.9271, visibility=0.0007
#
# NOSE: x=0.6038, y=0.7403, z=-1.1994, visibility=0.9992
#
# LEFT_EYE_INNER: x=0.6339, y=0.6638, z=-1.0945, visibility=0.9993
#
# LEFT_EYE: x=0.6534, y=0.6632, z=-1.0949, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6726, y=0.6631, z=-1.0949, visibility=0.9992
#
# RIGHT_EYE_INNER: x=0.5639, y=0.6632, z=-1.1077, visibility=0.9993
#
# RIGHT_EYE: x=0.5339, y=0.6619, z=-1.1076, visibility=0.9993
#
# RIGHT_EYE_OUTER: x=0.5063, y=0.6628, z=-1.1082, visibility=0.9993
#
# LEFT_EAR: x=0.6844, y=0.6950, z=-0.5127, visibility=0.9995
#
# RIGHT_EAR: x=0.4533, y=0.7050, z=-0.5706, visibility=0.9995
#
# MOUTH_LEFT: x=0.6286, y=0.8265, z=-0.9833, visibility=0.9986
#
# MOUTH_RIGHT: x=0.5506, y=0.8260, z=-1.0015, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8023, y=1.0155, z=-0.2785, visibility=0.9576
#
# RIGHT_SHOULDER: x=0.3061, y=1.0216, z=-0.3660, visibility=0.9205
#
# LEFT_ELBOW: x=1.1340, y=1.1058, z=-1.0683, visibility=0.4178
#
# RIGHT_ELBOW: x=0.1813, y=1.3770, z=-1.1723, visibility=0.2112
#
# LEFT_WRIST: x=1.0414, y=0.6177, z=-1.5821, visibility=0.6096
#
# RIGHT_WRIST: x=0.2745, y=1.1250, z=-2.1676, visibility=0.2420
#
# LEFT_PINKY: x=1.0176, y=0.5192, z=-1.7213, visibility=0.5760
#
# RIGHT_PINKY: x=0.2955, y=1.0669, z=-2.3647, visibility=0.2808
#
# LEFT_INDEX: x=0.9671, y=0.5286, z=-1.6201, visibility=0.6292
#
# RIGHT_INDEX: x=0.2992, y=1.0381, z=-2.2976, visibility=0.3624
#
# LEFT_THUMB: x=0.9517, y=0.5780, z=-1.5704, visibility=0.5988
#
# RIGHT_THUMB: x=0.3046, y=1.0687, z=-2.1817, visibility=0.3271
#
# LEFT_HIP: x=0.7281, y=2.0607, z=-0.0401, visibility=0.0029
#
# RIGHT_HIP: x=0.4007, y=2.0659, z=0.0462, visibility=0.0018
#
# LEFT_KNEE: x=0.7226, y=2.7171, z=-0.3356, visibility=0.0082
#
# RIGHT_KNEE: x=0.3798, y=2.6738, z=-0.4146, visibility=0.0023
#
# LEFT_ANKLE: x=0.7242, y=3.3838, z=0.1905, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3938, y=3.3608, z=-0.0561, visibility=0.0001
#
# LEFT_HEEL: x=0.7278, y=3.4896, z=0.2015, visibility=0.0003
#
# RIGHT_HEEL: x=0.3928, y=3.4703, z=-0.0533, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.6842, y=3.5821, z=-0.4724, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4299, y=3.5536, z=-0.7589, visibility=0.0007
#
# NOSE: x=0.6028, y=0.7253, z=-1.2085, visibility=0.9991
#
# LEFT_EYE_INNER: x=0.6320, y=0.6491, z=-1.1001, visibility=0.9993
#
# LEFT_EYE: x=0.6513, y=0.6490, z=-1.1003, visibility=0.9992
#
# LEFT_EYE_OUTER: x=0.6702, y=0.6496, z=-1.1003, visibility=0.9992
#
# RIGHT_EYE_INNER: x=0.5613, y=0.6484, z=-1.1118, visibility=0.9993
#
# RIGHT_EYE: x=0.5317, y=0.6478, z=-1.1117, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.5048, y=0.6497, z=-1.1123, visibility=0.9993
#
# LEFT_EAR: x=0.6844, y=0.6888, z=-0.5178, visibility=0.9994
#
# RIGHT_EAR: x=0.4523, y=0.7010, z=-0.5710, visibility=0.9995
#
# MOUTH_LEFT: x=0.6286, y=0.8115, z=-0.9948, visibility=0.9985
#
# MOUTH_RIGHT: x=0.5505, y=0.8107, z=-1.0112, visibility=0.9989
#
# LEFT_SHOULDER: x=0.8052, y=1.0154, z=-0.2866, visibility=0.9507
#
# RIGHT_SHOULDER: x=0.3041, y=1.0220, z=-0.3821, visibility=0.9158
#
# LEFT_ELBOW: x=1.1533, y=1.1023, z=-1.1264, visibility=0.4294
#
# RIGHT_ELBOW: x=0.1780, y=1.3842, z=-1.2018, visibility=0.2055
#
# LEFT_WRIST: x=1.0415, y=0.6324, z=-1.7458, visibility=0.6058
#
# RIGHT_WRIST: x=0.2550, y=1.1570, z=-2.2515, visibility=0.2358
#
# LEFT_PINKY: x=1.0149, y=0.5202, z=-1.8950, visibility=0.5695
#
# RIGHT_PINKY: x=0.2726, y=1.1027, z=-2.4525, visibility=0.2748
#
# LEFT_INDEX: x=0.9699, y=0.5284, z=-1.7733, visibility=0.6224
#
# RIGHT_INDEX: x=0.2767, y=1.0702, z=-2.3920, visibility=0.3552
#
# LEFT_THUMB: x=0.9499, y=0.5887, z=-1.7296, visibility=0.5916
#
# RIGHT_THUMB: x=0.2831, y=1.1085, z=-2.2700, visibility=0.3201
#
# LEFT_HIP: x=0.7319, y=2.0586, z=-0.0387, visibility=0.0028
#
# RIGHT_HIP: x=0.4038, y=2.0653, z=0.0448, visibility=0.0017
#
# LEFT_KNEE: x=0.7241, y=2.7335, z=-0.2770, visibility=0.0079
#
# RIGHT_KNEE: x=0.3915, y=2.6924, z=-0.3034, visibility=0.0022
#
# LEFT_ANKLE: x=0.7395, y=3.3992, z=0.2773, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4153, y=3.3746, z=0.0598, visibility=0.0001
#
# LEFT_HEEL: x=0.7447, y=3.5077, z=0.2898, visibility=0.0002
#
# RIGHT_HEEL: x=0.4145, y=3.4842, z=0.0638, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7041, y=3.5928, z=-0.4013, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4549, y=3.5649, z=-0.6648, visibility=0.0006
#
# NOSE: x=0.6021, y=0.7176, z=-1.2183, visibility=0.9990
#
# LEFT_EYE_INNER: x=0.6308, y=0.6425, z=-1.1051, visibility=0.9992
#
# LEFT_EYE: x=0.6501, y=0.6428, z=-1.1054, visibility=0.9991
#
# LEFT_EYE_OUTER: x=0.6692, y=0.6437, z=-1.1053, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5598, y=0.6408, z=-1.1176, visibility=0.9992
#
# RIGHT_EYE: x=0.5307, y=0.6405, z=-1.1176, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.5041, y=0.6425, z=-1.1182, visibility=0.9992
#
# LEFT_EAR: x=0.6845, y=0.6858, z=-0.5161, visibility=0.9994
#
# RIGHT_EAR: x=0.4519, y=0.6980, z=-0.5704, visibility=0.9995
#
# MOUTH_LEFT: x=0.6287, y=0.8050, z=-1.0020, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5505, y=0.8032, z=-1.0195, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8075, y=1.0170, z=-0.2944, visibility=0.9421
#
# RIGHT_SHOULDER: x=0.3022, y=1.0250, z=-0.3846, visibility=0.9111
#
# LEFT_ELBOW: x=1.1406, y=1.1191, z=-1.2107, visibility=0.4377
#
# RIGHT_ELBOW: x=0.1685, y=1.3834, z=-1.2179, visibility=0.2068
#
# LEFT_WRIST: x=1.0418, y=0.6379, z=-1.9377, visibility=0.5886
#
# RIGHT_WRIST: x=0.2150, y=1.1232, z=-2.2789, visibility=0.2298
#
# LEFT_PINKY: x=1.0131, y=0.5237, z=-2.1024, visibility=0.5514
#
# RIGHT_PINKY: x=0.2206, y=1.0557, z=-2.4842, visibility=0.2665
#
# LEFT_INDEX: x=0.9709, y=0.5314, z=-1.9856, visibility=0.6040
#
# RIGHT_INDEX: x=0.2257, y=1.0216, z=-2.4249, visibility=0.3445
#
# LEFT_THUMB: x=0.9486, y=0.5966, z=-1.9273, visibility=0.5722
#
# RIGHT_THUMB: x=0.2368, y=1.0604, z=-2.2995, visibility=0.3106
#
# LEFT_HIP: x=0.7326, y=2.0656, z=-0.0397, visibility=0.0027
#
# RIGHT_HIP: x=0.4035, y=2.0702, z=0.0457, visibility=0.0017
#
# LEFT_KNEE: x=0.7180, y=2.7330, z=-0.2919, visibility=0.0079
#
# RIGHT_KNEE: x=0.3875, y=2.6838, z=-0.3387, visibility=0.0022
#
# LEFT_ANKLE: x=0.7377, y=3.3987, z=0.2358, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4076, y=3.3674, z=0.0061, visibility=0.0001
#
# LEFT_HEEL: x=0.7437, y=3.5075, z=0.2454, visibility=0.0002
#
# RIGHT_HEEL: x=0.4068, y=3.4772, z=0.0044, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7020, y=3.5905, z=-0.4568, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4437, y=3.5591, z=-0.7230, visibility=0.0007
#
# NOSE: x=0.6020, y=0.7161, z=-1.2157, visibility=0.9990
#
# LEFT_EYE_INNER: x=0.6303, y=0.6398, z=-1.1000, visibility=0.9992
#
# LEFT_EYE: x=0.6496, y=0.6402, z=-1.1004, visibility=0.9991
#
# LEFT_EYE_OUTER: x=0.6686, y=0.6411, z=-1.1003, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5597, y=0.6383, z=-1.1159, visibility=0.9992
#
# RIGHT_EYE: x=0.5307, y=0.6382, z=-1.1160, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.5041, y=0.6403, z=-1.1166, visibility=0.9992
#
# LEFT_EAR: x=0.6845, y=0.6843, z=-0.4899, visibility=0.9993
#
# RIGHT_EAR: x=0.4518, y=0.6969, z=-0.5631, visibility=0.9995
#
# MOUTH_LEFT: x=0.6288, y=0.8030, z=-0.9974, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5509, y=0.8010, z=-1.0180, visibility=0.9988
#
# LEFT_SHOULDER: x=0.8088, y=1.0204, z=-0.2735, visibility=0.9376
#
# RIGHT_SHOULDER: x=0.2975, y=1.0271, z=-0.3787, visibility=0.9104
#
# LEFT_ELBOW: x=1.1157, y=1.1557, z=-1.1695, visibility=0.4296
#
# RIGHT_ELBOW: x=0.1618, y=1.3855, z=-1.1994, visibility=0.2087
#
# LEFT_WRIST: x=1.0272, y=0.6902, z=-1.9901, visibility=0.5747
#
# RIGHT_WRIST: x=0.2103, y=1.1449, z=-2.2635, visibility=0.2296
#
# LEFT_PINKY: x=1.0042, y=0.5279, z=-2.1632, visibility=0.5405
#
# RIGHT_PINKY: x=0.2146, y=1.0863, z=-2.4702, visibility=0.2644
#
# LEFT_INDEX: x=0.9684, y=0.5472, z=-2.0680, visibility=0.5935
#
# RIGHT_INDEX: x=0.2239, y=1.0499, z=-2.4056, visibility=0.3412
#
# LEFT_THUMB: x=0.9347, y=0.6613, z=-1.9905, visibility=0.5603
#
# RIGHT_THUMB: x=0.2360, y=1.0839, z=-2.2802, visibility=0.3073
#
# LEFT_HIP: x=0.7325, y=2.0669, z=-0.0396, visibility=0.0027
#
# RIGHT_HIP: x=0.4003, y=2.0722, z=0.0457, visibility=0.0018
#
# LEFT_KNEE: x=0.7156, y=2.7493, z=-0.2699, visibility=0.0079
#
# RIGHT_KNEE: x=0.3872, y=2.6969, z=-0.3412, visibility=0.0023
#
# LEFT_ANKLE: x=0.7378, y=3.4169, z=0.2520, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4082, y=3.3877, z=-0.0171, visibility=0.0001
#
# LEFT_HEEL: x=0.7445, y=3.5257, z=0.2579, visibility=0.0002
#
# RIGHT_HEEL: x=0.4077, y=3.4974, z=-0.0197, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7014, y=3.6135, z=-0.4587, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4456, y=3.5881, z=-0.7261, visibility=0.0007
#
# NOSE: x=0.6028, y=0.7134, z=-1.2113, visibility=0.9990
#
# LEFT_EYE_INNER: x=0.6305, y=0.6373, z=-1.0978, visibility=0.9991
#
# LEFT_EYE: x=0.6497, y=0.6381, z=-1.0982, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6687, y=0.6395, z=-1.0981, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5600, y=0.6351, z=-1.1134, visibility=0.9992
#
# RIGHT_EYE: x=0.5309, y=0.6351, z=-1.1134, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.5043, y=0.6374, z=-1.1140, visibility=0.9992
#
# LEFT_EAR: x=0.6857, y=0.6840, z=-0.4902, visibility=0.9993
#
# RIGHT_EAR: x=0.4517, y=0.6964, z=-0.5630, visibility=0.9994
#
# MOUTH_LEFT: x=0.6309, y=0.8016, z=-0.9937, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5533, y=0.7991, z=-1.0142, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8118, y=1.0204, z=-0.2756, visibility=0.9330
#
# RIGHT_SHOULDER: x=0.2968, y=1.0278, z=-0.3749, visibility=0.9081
#
# LEFT_ELBOW: x=1.1143, y=1.1461, z=-1.1783, visibility=0.4331
#
# RIGHT_ELBOW: x=0.1613, y=1.3872, z=-1.1675, visibility=0.2082
#
# LEFT_WRIST: x=1.0261, y=0.6649, z=-1.9285, visibility=0.5679
#
# RIGHT_WRIST: x=0.2112, y=1.1515, z=-2.2013, visibility=0.2282
#
# LEFT_PINKY: x=1.0038, y=0.5308, z=-2.0937, visibility=0.5346
#
# RIGHT_PINKY: x=0.2146, y=1.0908, z=-2.4032, visibility=0.2620
#
# LEFT_INDEX: x=0.9681, y=0.5432, z=-1.9882, visibility=0.5876
#
# RIGHT_INDEX: x=0.2259, y=1.0544, z=-2.3390, visibility=0.3377
#
# LEFT_THUMB: x=0.9348, y=0.6238, z=-1.9228, visibility=0.5529
#
# RIGHT_THUMB: x=0.2385, y=1.0887, z=-2.2179, visibility=0.3042
#
# LEFT_HIP: x=0.7330, y=2.0659, z=-0.0403, visibility=0.0027
#
# RIGHT_HIP: x=0.4002, y=2.0710, z=0.0464, visibility=0.0018
#
# LEFT_KNEE: x=0.7148, y=2.7475, z=-0.3130, visibility=0.0080
#
# RIGHT_KNEE: x=0.3860, y=2.6862, z=-0.4058, visibility=0.0024
#
# LEFT_ANKLE: x=0.7376, y=3.4161, z=0.1919, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4090, y=3.3835, z=-0.1092, visibility=0.0001
#
# LEFT_HEEL: x=0.7442, y=3.5248, z=0.1957, visibility=0.0002
#
# RIGHT_HEEL: x=0.4094, y=3.4934, z=-0.1102, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7012, y=3.6112, z=-0.5271, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4457, y=3.5841, z=-0.8426, visibility=0.0007
#
# NOSE: x=0.6034, y=0.7112, z=-1.2089, visibility=0.9989
#
# LEFT_EYE_INNER: x=0.6306, y=0.6353, z=-1.0961, visibility=0.9991
#
# LEFT_EYE: x=0.6498, y=0.6364, z=-1.0965, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6688, y=0.6381, z=-1.0965, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5602, y=0.6332, z=-1.1117, visibility=0.9992
#
# RIGHT_EYE: x=0.5312, y=0.6334, z=-1.1116, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.5046, y=0.6359, z=-1.1122, visibility=0.9992
#
# LEFT_EAR: x=0.6866, y=0.6838, z=-0.4903, visibility=0.9993
#
# RIGHT_EAR: x=0.4517, y=0.6959, z=-0.5631, visibility=0.9995
#
# MOUTH_LEFT: x=0.6325, y=0.8000, z=-0.9914, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5551, y=0.7974, z=-1.0121, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8140, y=1.0205, z=-0.2740, visibility=0.9305
#
# RIGHT_SHOULDER: x=0.2964, y=1.0281, z=-0.3728, visibility=0.9077
#
# LEFT_ELBOW: x=1.1134, y=1.1412, z=-1.1766, visibility=0.4363
#
# RIGHT_ELBOW: x=0.1609, y=1.3885, z=-1.1608, visibility=0.2076
#
# LEFT_WRIST: x=1.0254, y=0.6594, z=-1.9306, visibility=0.5624
#
# RIGHT_WRIST: x=0.2093, y=1.1604, z=-2.2147, visibility=0.2264
#
# LEFT_PINKY: x=1.0037, y=0.5444, z=-2.0966, visibility=0.5300
#
# RIGHT_PINKY: x=0.2120, y=1.1036, z=-2.4185, visibility=0.2597
#
# LEFT_INDEX: x=0.9675, y=0.5429, z=-1.9899, visibility=0.5831
#
# RIGHT_INDEX: x=0.2241, y=1.0672, z=-2.3554, visibility=0.3345
#
# LEFT_THUMB: x=0.9350, y=0.6133, z=-1.9244, visibility=0.5470
#
# RIGHT_THUMB: x=0.2376, y=1.0999, z=-2.2323, visibility=0.3011
#
# LEFT_HIP: x=0.7335, y=2.0646, z=-0.0408, visibility=0.0027
#
# RIGHT_HIP: x=0.4002, y=2.0696, z=0.0469, visibility=0.0018
#
# LEFT_KNEE: x=0.7134, y=2.7463, z=-0.3223, visibility=0.0080
#
# RIGHT_KNEE: x=0.3861, y=2.6840, z=-0.3964, visibility=0.0024
#
# LEFT_ANKLE: x=0.7374, y=3.4156, z=0.1819, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4090, y=3.3829, z=-0.1149, visibility=0.0001
#
# LEFT_HEEL: x=0.7440, y=3.5243, z=0.1846, visibility=0.0002
#
# RIGHT_HEEL: x=0.4095, y=3.4931, z=-0.1173, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7009, y=3.6109, z=-0.5409, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4456, y=3.5829, z=-0.8617, visibility=0.0007
#
# NOSE: x=0.6050, y=0.7057, z=-1.2113, visibility=0.9989
#
# LEFT_EYE_INNER: x=0.6311, y=0.6310, z=-1.0988, visibility=0.9991
#
# LEFT_EYE: x=0.6501, y=0.6325, z=-1.0992, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6690, y=0.6346, z=-1.0992, visibility=0.9990
#
# RIGHT_EYE_INNER: x=0.5618, y=0.6287, z=-1.1159, visibility=0.9992
#
# RIGHT_EYE: x=0.5328, y=0.6291, z=-1.1158, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.5061, y=0.6318, z=-1.1164, visibility=0.9992
#
# LEFT_EAR: x=0.6863, y=0.6816, z=-0.4956, visibility=0.9993
#
# RIGHT_EAR: x=0.4515, y=0.6935, z=-0.5756, visibility=0.9994
#
# MOUTH_LEFT: x=0.6336, y=0.7974, z=-0.9933, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5579, y=0.7945, z=-1.0163, visibility=0.9987
#
# LEFT_SHOULDER: x=0.8140, y=1.0209, z=-0.2790, visibility=0.9314
#
# RIGHT_SHOULDER: x=0.2935, y=1.0283, z=-0.3711, visibility=0.9069
#
# LEFT_ELBOW: x=1.1359, y=1.1343, z=-1.1685, visibility=0.4570
#
# RIGHT_ELBOW: x=0.1583, y=1.3889, z=-1.1514, visibility=0.2115
#
# LEFT_WRIST: x=1.0283, y=0.6453, z=-1.8890, visibility=0.5653
#
# RIGHT_WRIST: x=0.2037, y=1.1450, z=-2.1520, visibility=0.2271
#
# LEFT_PINKY: x=1.0045, y=0.5335, z=-2.0509, visibility=0.5285
#
# RIGHT_PINKY: x=0.2060, y=1.0768, z=-2.3387, visibility=0.2586
#
# LEFT_INDEX: x=0.9695, y=0.5389, z=-1.9462, visibility=0.5809
#
# RIGHT_INDEX: x=0.2176, y=1.0434, z=-2.2724, visibility=0.3322
#
# LEFT_THUMB: x=0.9362, y=0.6031, z=-1.8814, visibility=0.5433
#
# RIGHT_THUMB: x=0.2312, y=1.0803, z=-2.1656, visibility=0.2990
#
# LEFT_HIP: x=0.7343, y=2.0706, z=-0.0414, visibility=0.0027
#
# RIGHT_HIP: x=0.4005, y=2.0786, z=0.0475, visibility=0.0018
#
# LEFT_KNEE: x=0.7159, y=2.7453, z=-0.3409, visibility=0.0082
#
# RIGHT_KNEE: x=0.3866, y=2.6889, z=-0.3885, visibility=0.0025
#
# LEFT_ANKLE: x=0.7374, y=3.4173, z=0.1661, visibility=0.0003
#
# RIGHT_ANKLE: x=0.4073, y=3.3868, z=-0.1105, visibility=0.0001
#
# LEFT_HEEL: x=0.7430, y=3.5264, z=0.1715, visibility=0.0002
#
# RIGHT_HEEL: x=0.4067, y=3.4983, z=-0.1125, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7013, y=3.6124, z=-0.5445, visibility=0.0006
#
# RIGHT_FOOT_INDEX: x=0.4443, y=3.5833, z=-0.8464, visibility=0.0007
#
# NOSE: x=0.6058, y=0.7017, z=-1.2098, visibility=0.9988
#
# LEFT_EYE_INNER: x=0.6315, y=0.6266, z=-1.0982, visibility=0.9991
#
# LEFT_EYE: x=0.6509, y=0.6280, z=-1.0986, visibility=0.9989
#
# LEFT_EYE_OUTER: x=0.6701, y=0.6298, z=-1.0986, visibility=0.9990
#
# RIGHT_EYE_INNER: x=0.5616, y=0.6241, z=-1.1154, visibility=0.9991
#
# RIGHT_EYE: x=0.5321, y=0.6247, z=-1.1154, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.5051, y=0.6276, z=-1.1160, visibility=0.9991
#
# LEFT_EAR: x=0.6869, y=0.6743, z=-0.4950, visibility=0.9992
#
# RIGHT_EAR: x=0.4498, y=0.6872, z=-0.5926, visibility=0.9994
#
# MOUTH_LEFT: x=0.6347, y=0.7953, z=-0.9920, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5598, y=0.7918, z=-1.0173, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8134, y=1.0207, z=-0.2611, visibility=0.9320
#
# RIGHT_SHOULDER: x=0.2898, y=1.0286, z=-0.3903, visibility=0.9054
#
# LEFT_ELBOW: x=1.1728, y=1.1342, z=-1.1110, visibility=0.4843
#
# RIGHT_ELBOW: x=0.1441, y=1.3931, z=-1.1504, visibility=0.2230
#
# LEFT_WRIST: x=1.0317, y=0.6293, z=-1.7651, visibility=0.5783
#
# RIGHT_WRIST: x=0.1721, y=1.1125, z=-2.1410, visibility=0.2392
#
# LEFT_PINKY: x=1.0096, y=0.5243, z=-1.9207, visibility=0.5355
#
# RIGHT_PINKY: x=0.1669, y=1.0271, z=-2.3253, visibility=0.2679
#
# LEFT_INDEX: x=0.9687, y=0.5331, z=-1.7956, visibility=0.5870
#
# RIGHT_INDEX: x=0.1795, y=0.9926, z=-2.2674, visibility=0.3418
#
# LEFT_THUMB: x=0.9435, y=0.5893, z=-1.7490, visibility=0.5490
#
# RIGHT_THUMB: x=0.1971, y=1.0365, z=-2.1570, visibility=0.3087
#
# LEFT_HIP: x=0.7343, y=2.0768, z=-0.0320, visibility=0.0028
#
# RIGHT_HIP: x=0.3999, y=2.0848, z=0.0381, visibility=0.0019
#
# LEFT_KNEE: x=0.7330, y=2.7343, z=-0.4155, visibility=0.0097
#
# RIGHT_KNEE: x=0.3875, y=2.6882, z=-0.5031, visibility=0.0029
#
# LEFT_ANKLE: x=0.7441, y=3.4228, z=0.0595, visibility=0.0004
#
# RIGHT_ANKLE: x=0.4114, y=3.3948, z=-0.2187, visibility=0.0001
#
# LEFT_HEEL: x=0.7457, y=3.5314, z=0.0651, visibility=0.0002
#
# RIGHT_HEEL: x=0.4102, y=3.5057, z=-0.2190, visibility=0.0001
#
# LEFT_FOOT_INDEX: x=0.7085, y=3.6288, z=-0.6396, visibility=0.0007
#
# RIGHT_FOOT_INDEX: x=0.4527, y=3.6034, z=-0.9345, visibility=0.0008
#
# NOSE: x=0.6061, y=0.6981, z=-1.2144, visibility=0.9988
#
# LEFT_EYE_INNER: x=0.6319, y=0.6238, z=-1.0995, visibility=0.9990
#
# LEFT_EYE: x=0.6515, y=0.6252, z=-1.0999, visibility=0.9989
#
# LEFT_EYE_OUTER: x=0.6711, y=0.6270, z=-1.0999, visibility=0.9990
#
# RIGHT_EYE_INNER: x=0.5610, y=0.6209, z=-1.1221, visibility=0.9991
#
# RIGHT_EYE: x=0.5308, y=0.6215, z=-1.1222, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.5031, y=0.6246, z=-1.1227, visibility=0.9991
#
# LEFT_EAR: x=0.6874, y=0.6704, z=-0.4936, visibility=0.9993
#
# RIGHT_EAR: x=0.4475, y=0.6821, z=-0.6034, visibility=0.9994
#
# MOUTH_LEFT: x=0.6356, y=0.7936, z=-0.9932, visibility=0.9982
#
# MOUTH_RIGHT: x=0.5608, y=0.7894, z=-1.0250, visibility=0.9986
#
# LEFT_SHOULDER: x=0.8120, y=1.0207, z=-0.2395, visibility=0.9347
#
# RIGHT_SHOULDER: x=0.2837, y=1.0286, z=-0.3945, visibility=0.9053
#
# LEFT_ELBOW: x=1.1962, y=1.1237, z=-1.0856, visibility=0.5175
#
# RIGHT_ELBOW: x=0.1283, y=1.3926, z=-1.1690, visibility=0.2363
#
# LEFT_WRIST: x=1.0321, y=0.6227, z=-1.7411, visibility=0.5974
#
# RIGHT_WRIST: x=0.1601, y=1.0970, z=-2.1530, visibility=0.2507
#
# LEFT_PINKY: x=1.0101, y=0.5203, z=-1.9013, visibility=0.5482
#
# RIGHT_PINKY: x=0.1560, y=1.0133, z=-2.3451, visibility=0.2773
#
# LEFT_INDEX: x=0.9685, y=0.5317, z=-1.7704, visibility=0.5984
#
# RIGHT_INDEX: x=0.1707, y=0.9808, z=-2.2924, visibility=0.3513
#
# LEFT_THUMB: x=0.9447, y=0.5838, z=-1.7222, visibility=0.5598
#
# RIGHT_THUMB: x=0.1875, y=1.0247, z=-2.1714, visibility=0.3182
#
# LEFT_HIP: x=0.7324, y=2.0825, z=-0.0215, visibility=0.0030
#
# RIGHT_HIP: x=0.3957, y=2.0896, z=0.0276, visibility=0.0021
#
# LEFT_KNEE: x=0.7368, y=2.7054, z=-0.4627, visibility=0.0115
#
# RIGHT_KNEE: x=0.3830, y=2.6795, z=-0.5744, visibility=0.0034
#
# LEFT_ANKLE: x=0.7438, y=3.4223, z=-0.0009, visibility=0.0004
#
# RIGHT_ANKLE: x=0.4089, y=3.3966, z=-0.2892, visibility=0.0001
#
# LEFT_HEEL: x=0.7440, y=3.5308, z=0.0034, visibility=0.0003
#
# RIGHT_HEEL: x=0.4068, y=3.5081, z=-0.2903, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.7082, y=3.6305, z=-0.7093, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4525, y=3.6096, z=-1.0167, visibility=0.0009
#
# NOSE: x=0.6074, y=0.6983, z=-1.2080, visibility=0.9989
#
# LEFT_EYE_INNER: x=0.6323, y=0.6241, z=-1.0903, visibility=0.9991
#
# LEFT_EYE: x=0.6519, y=0.6255, z=-1.0907, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6714, y=0.6272, z=-1.0907, visibility=0.9990
#
# RIGHT_EYE_INNER: x=0.5613, y=0.6212, z=-1.1115, visibility=0.9992
#
# RIGHT_EYE: x=0.5310, y=0.6216, z=-1.1116, visibility=0.9991
#
# RIGHT_EYE_OUTER: x=0.5032, y=0.6245, z=-1.1121, visibility=0.9992
#
# LEFT_EAR: x=0.6873, y=0.6709, z=-0.4788, visibility=0.9993
#
# RIGHT_EAR: x=0.4475, y=0.6818, z=-0.5763, visibility=0.9994
#
# MOUTH_LEFT: x=0.6367, y=0.7937, z=-0.9853, visibility=0.9983
#
# MOUTH_RIGHT: x=0.5623, y=0.7894, z=-1.0156, visibility=0.9987
#
# LEFT_SHOULDER: x=0.7992, y=1.0206, z=-0.2286, visibility=0.9372
#
# RIGHT_SHOULDER: x=0.2913, y=1.0260, z=-0.3460, visibility=0.9080
#
# LEFT_ELBOW: x=1.1845, y=1.1133, z=-1.0038, visibility=0.5449
#
# RIGHT_ELBOW: x=0.1324, y=1.3834, z=-1.1032, visibility=0.2561
#
# LEFT_WRIST: x=1.0323, y=0.6245, z=-1.6028, visibility=0.6101
#
# RIGHT_WRIST: x=0.1464, y=1.0734, z=-2.1438, visibility=0.2732
#
# LEFT_PINKY: x=1.0076, y=0.5185, z=-1.7560, visibility=0.5546
#
# RIGHT_PINKY: x=0.1354, y=0.9883, z=-2.3409, visibility=0.2960
#
# LEFT_INDEX: x=0.9677, y=0.5286, z=-1.6398, visibility=0.6041
#
# RIGHT_INDEX: x=0.1472, y=0.9575, z=-2.2995, visibility=0.3707
#
# LEFT_THUMB: x=0.9443, y=0.5831, z=-1.5882, visibility=0.5654
#
# RIGHT_THUMB: x=0.1664, y=1.0014, z=-2.1661, visibility=0.3367
#
# LEFT_HIP: x=0.7309, y=2.0868, z=-0.0351, visibility=0.0031
#
# RIGHT_HIP: x=0.3957, y=2.0895, z=0.0410, visibility=0.0022
#
# LEFT_KNEE: x=0.7117, y=2.7374, z=-0.4364, visibility=0.0121
#
# RIGHT_KNEE: x=0.3828, y=2.6891, z=-0.4213, visibility=0.0037
#
# LEFT_ANKLE: x=0.7147, y=3.4444, z=0.0367, visibility=0.0004
#
# RIGHT_ANKLE: x=0.3873, y=3.4186, z=-0.1848, visibility=0.0001
#
# LEFT_HEEL: x=0.7165, y=3.5535, z=0.0414, visibility=0.0003
#
# RIGHT_HEEL: x=0.3838, y=3.5354, z=-0.1921, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6761, y=3.6433, z=-0.6670, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4094, y=3.6231, z=-0.9345, visibility=0.0009
#
# NOSE: x=0.6079, y=0.6982, z=-1.1530, visibility=0.9990
#
# LEFT_EYE_INNER: x=0.6329, y=0.6243, z=-1.0484, visibility=0.9991
#
# LEFT_EYE: x=0.6526, y=0.6258, z=-1.0487, visibility=0.9990
#
# LEFT_EYE_OUTER: x=0.6721, y=0.6274, z=-1.0488, visibility=0.9991
#
# RIGHT_EYE_INNER: x=0.5617, y=0.6213, z=-1.0633, visibility=0.9992
#
# RIGHT_EYE: x=0.5314, y=0.6218, z=-1.0631, visibility=0.9992
#
# RIGHT_EYE_OUTER: x=0.5035, y=0.6244, z=-1.0636, visibility=0.9992
#
# LEFT_EAR: x=0.6881, y=0.6710, z=-0.4613, visibility=0.9993
#
# RIGHT_EAR: x=0.4480, y=0.6799, z=-0.5328, visibility=0.9995
#
# MOUTH_LEFT: x=0.6377, y=0.7935, z=-0.9367, visibility=0.9984
#
# MOUTH_RIGHT: x=0.5626, y=0.7889, z=-0.9586, visibility=0.9988
#
# LEFT_SHOULDER: x=0.7995, y=1.0150, z=-0.2192, visibility=0.9406
#
# RIGHT_SHOULDER: x=0.2943, y=1.0206, z=-0.2902, visibility=0.9104
#
# LEFT_ELBOW: x=1.1396, y=1.1139, z=-1.0286, visibility=0.5462
#
# RIGHT_ELBOW: x=0.1508, y=1.3751, z=-0.9296, visibility=0.2516
#
# LEFT_WRIST: x=1.0113, y=0.6360, z=-1.7697, visibility=0.6209
#
# RIGHT_WRIST: x=0.1563, y=1.0866, z=-1.7752, visibility=0.2849
#
# LEFT_PINKY: x=0.9952, y=0.5230, z=-1.9334, visibility=0.5669
#
# RIGHT_PINKY: x=0.1367, y=1.0094, z=-1.9375, visibility=0.3084
#
# LEFT_INDEX: x=0.9481, y=0.5400, z=-1.8208, visibility=0.6161
#
# RIGHT_INDEX: x=0.1523, y=0.9785, z=-1.8809, visibility=0.3842
#
# LEFT_THUMB: x=0.9345, y=0.5965, z=-1.7612, visibility=0.5769
#
# RIGHT_THUMB: x=0.1684, y=1.0196, z=-1.7886, visibility=0.3493
#
# LEFT_HIP: x=0.7309, y=2.0824, z=-0.0443, visibility=0.0030
#
# RIGHT_HIP: x=0.3960, y=2.0844, z=0.0506, visibility=0.0021
#
# LEFT_KNEE: x=0.7093, y=2.7792, z=-0.3248, visibility=0.0115
#
# RIGHT_KNEE: x=0.3798, y=2.7431, z=-0.1881, visibility=0.0035
#
# ...
#
# LEFT_ELBOW: x=1.1469, y=1.2460, z=-1.0496, visibility=0.4150
#
# RIGHT_ELBOW: x=0.1395, y=1.4047, z=-1.1729, visibility=0.4081
#
# LEFT_WRIST: x=1.0517, y=0.8423, z=-1.9971, visibility=0.6202
#
# RIGHT_WRIST: x=0.1522, y=1.1053, z=-2.3748, visibility=0.4801
#
# LEFT_PINKY: x=0.9743, y=0.6343, z=-2.1900, visibility=0.6069
#
# RIGHT_PINKY: x=0.1511, y=1.1224, z=-2.6056, visibility=0.4781
#
# LEFT_INDEX: x=0.9266, y=0.6361, z=-2.1032, visibility=0.6572
#
# RIGHT_INDEX: x=0.2047, y=1.0204, z=-2.5563, visibility=0.5666
#
# LEFT_THUMB: x=0.9175, y=0.6761, z=-2.0022, visibility=0.6270
#
# RIGHT_THUMB: x=0.2099, y=1.0244, z=-2.4000, visibility=0.5292
#
# LEFT_HIP: x=0.7386, y=2.0525, z=-0.0204, visibility=0.0023
#
# RIGHT_HIP: x=0.3884, y=2.0453, z=0.0267, visibility=0.0019
#
# LEFT_KNEE: x=0.7083, y=2.8885, z=-0.2325, visibility=0.0112
#
# RIGHT_KNEE: x=0.3775, y=2.8562, z=-0.3134, visibility=0.0035
#
# LEFT_ANKLE: x=0.7055, y=3.6307, z=0.2640, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3858, y=3.6173, z=-0.0744, visibility=0.0001
#
# LEFT_HEEL: x=0.7062, y=3.7413, z=0.2668, visibility=0.0004
#
# RIGHT_HEEL: x=0.3869, y=3.7337, z=-0.0816, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6580, y=3.8435, z=-0.4872, visibility=0.0007
#
# RIGHT_FOOT_INDEX: x=0.4162, y=3.8288, z=-0.9203, visibility=0.0007
#
# NOSE: x=0.6210, y=0.6559, z=-1.2966, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6536, y=0.5825, z=-1.1856, visibility=0.9997
#
# LEFT_EYE: x=0.6717, y=0.5835, z=-1.1862, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6898, y=0.5856, z=-1.1864, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5851, y=0.5856, z=-1.2088, visibility=0.9997
#
# RIGHT_EYE: x=0.5539, y=0.5894, z=-1.2087, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5246, y=0.5939, z=-1.2091, visibility=0.9997
#
# LEFT_EAR: x=0.7066, y=0.6215, z=-0.5423, visibility=0.9997
#
# RIGHT_EAR: x=0.4717, y=0.6322, z=-0.6481, visibility=0.9998
#
# MOUTH_LEFT: x=0.6501, y=0.7526, z=-1.0495, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5721, y=0.7529, z=-1.0859, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8372, y=0.9949, z=-0.2443, visibility=0.9849
#
# RIGHT_SHOULDER: x=0.2856, y=1.0095, z=-0.3794, visibility=0.9806
#
# LEFT_ELBOW: x=1.1093, y=1.2473, z=-1.1092, visibility=0.4274
#
# RIGHT_ELBOW: x=0.1392, y=1.3967, z=-1.1728, visibility=0.4016
#
# LEFT_WRIST: x=1.0314, y=0.8862, z=-2.0813, visibility=0.6337
#
# RIGHT_WRIST: x=0.1447, y=1.1178, z=-2.4247, visibility=0.4754
#
# LEFT_PINKY: x=0.9782, y=0.7199, z=-2.2826, visibility=0.6221
#
# RIGHT_PINKY: x=0.1511, y=1.1289, z=-2.6721, visibility=0.4750
#
# LEFT_INDEX: x=0.9249, y=0.7005, z=-2.2076, visibility=0.6717
#
# RIGHT_INDEX: x=0.2006, y=1.0188, z=-2.6281, visibility=0.5637
#
# LEFT_THUMB: x=0.9270, y=0.7570, z=-2.0892, visibility=0.6391
#
# RIGHT_THUMB: x=0.2088, y=1.0279, z=-2.4560, visibility=0.5247
#
# LEFT_HIP: x=0.7384, y=2.0536, z=-0.0211, visibility=0.0023
#
# RIGHT_HIP: x=0.3884, y=2.0502, z=0.0275, visibility=0.0019
#
# LEFT_KNEE: x=0.7059, y=2.8632, z=-0.3291, visibility=0.0118
#
# RIGHT_KNEE: x=0.3775, y=2.8267, z=-0.3837, visibility=0.0036
#
# LEFT_ANKLE: x=0.7114, y=3.6049, z=0.1540, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3955, y=3.5937, z=-0.1630, visibility=0.0001
#
# LEFT_HEEL: x=0.7136, y=3.7200, z=0.1565, visibility=0.0004
#
# RIGHT_HEEL: x=0.3977, y=3.7111, z=-0.1739, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6740, y=3.8099, z=-0.5871, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4299, y=3.8038, z=-0.9851, visibility=0.0007
#
# NOSE: x=0.6210, y=0.6559, z=-1.3082, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6534, y=0.5830, z=-1.1942, visibility=0.9997
#
# LEFT_EYE: x=0.6715, y=0.5839, z=-1.1947, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6895, y=0.5857, z=-1.1949, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5850, y=0.5859, z=-1.2195, visibility=0.9997
#
# RIGHT_EYE: x=0.5538, y=0.5894, z=-1.2193, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5244, y=0.5936, z=-1.2197, visibility=0.9997
#
# LEFT_EAR: x=0.7057, y=0.6216, z=-0.5428, visibility=0.9997
#
# RIGHT_EAR: x=0.4716, y=0.6320, z=-0.6588, visibility=0.9998
#
# MOUTH_LEFT: x=0.6501, y=0.7532, z=-1.0608, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5719, y=0.7528, z=-1.0985, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8342, y=0.9919, z=-0.2424, visibility=0.9850
#
# RIGHT_SHOULDER: x=0.2826, y=1.0125, z=-0.3790, visibility=0.9786
#
# LEFT_ELBOW: x=1.1074, y=1.2470, z=-1.1055, visibility=0.4349
#
# RIGHT_ELBOW: x=0.1344, y=1.3957, z=-1.1692, visibility=0.3816
#
# LEFT_WRIST: x=1.0358, y=0.8378, z=-2.0475, visibility=0.6496
#
# RIGHT_WRIST: x=0.1438, y=1.1300, z=-2.3719, visibility=0.4561
#
# LEFT_PINKY: x=1.0216, y=0.6940, z=-2.2462, visibility=0.6381
#
# RIGHT_PINKY: x=0.1514, y=1.1552, z=-2.6030, visibility=0.4596
#
# LEFT_INDEX: x=0.9339, y=0.6132, z=-2.1651, visibility=0.6866
#
# RIGHT_INDEX: x=0.2002, y=1.0436, z=-2.5598, visibility=0.5480
#
# LEFT_THUMB: x=0.9275, y=0.6906, z=-2.0547, visibility=0.6524
#
# RIGHT_THUMB: x=0.2089, y=1.0390, z=-2.4014, visibility=0.5081
#
# LEFT_HIP: x=0.7310, y=2.0540, z=-0.0225, visibility=0.0023
#
# RIGHT_HIP: x=0.3813, y=2.0497, z=0.0288, visibility=0.0019
#
# LEFT_KNEE: x=0.6942, y=2.8555, z=-0.3599, visibility=0.0114
#
# RIGHT_KNEE: x=0.3684, y=2.8084, z=-0.4172, visibility=0.0034
#
# LEFT_ANKLE: x=0.7006, y=3.5938, z=0.1271, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3841, y=3.5770, z=-0.1792, visibility=0.0001
#
# LEFT_HEEL: x=0.7027, y=3.7094, z=0.1286, visibility=0.0004
#
# RIGHT_HEEL: x=0.3852, y=3.6975, z=-0.1891, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6596, y=3.7988, z=-0.6337, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4163, y=3.7834, z=-1.0077, visibility=0.0007
#
# NOSE: x=0.6205, y=0.6551, z=-1.3189, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6528, y=0.5820, z=-1.2042, visibility=0.9997
#
# LEFT_EYE: x=0.6713, y=0.5829, z=-1.2046, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6893, y=0.5848, z=-1.2046, visibility=0.9996
#
# RIGHT_EYE_INNER: x=0.5825, y=0.5848, z=-1.2331, visibility=0.9997
#
# RIGHT_EYE: x=0.5514, y=0.5883, z=-1.2328, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5225, y=0.5926, z=-1.2333, visibility=0.9997
#
# LEFT_EAR: x=0.7056, y=0.6209, z=-0.5530, visibility=0.9997
#
# RIGHT_EAR: x=0.4708, y=0.6309, z=-0.6865, visibility=0.9998
#
# MOUTH_LEFT: x=0.6498, y=0.7522, z=-1.0736, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5710, y=0.7519, z=-1.1143, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8346, y=0.9904, z=-0.2371, visibility=0.9851
#
# RIGHT_SHOULDER: x=0.2771, y=1.0125, z=-0.3990, visibility=0.9778
#
# LEFT_ELBOW: x=1.1079, y=1.2530, z=-1.0610, visibility=0.4426
#
# RIGHT_ELBOW: x=0.1295, y=1.4148, z=-1.0844, visibility=0.3680
#
# LEFT_WRIST: x=1.0359, y=0.8326, z=-2.0028, visibility=0.6672
#
# RIGHT_WRIST: x=0.1569, y=1.3560, z=-2.0827, visibility=0.4392
#
# LEFT_PINKY: x=1.0302, y=0.6888, z=-2.2076, visibility=0.6539
#
# RIGHT_PINKY: x=0.1624, y=1.3647, z=-2.2910, visibility=0.4443
#
# LEFT_INDEX: x=0.9371, y=0.5991, z=-2.1234, visibility=0.7007
#
# RIGHT_INDEX: x=0.1990, y=1.1194, z=-2.2804, visibility=0.5333
#
# LEFT_THUMB: x=0.9203, y=0.6826, z=-2.0109, visibility=0.6664
#
# RIGHT_THUMB: x=0.2038, y=1.0918, z=-2.1176, visibility=0.4927
#
# LEFT_HIP: x=0.7304, y=2.0540, z=-0.0227, visibility=0.0024
#
# RIGHT_HIP: x=0.3768, y=2.0492, z=0.0291, visibility=0.0019
#
# LEFT_KNEE: x=0.6953, y=2.8734, z=-0.3466, visibility=0.0112
#
# RIGHT_KNEE: x=0.3666, y=2.8255, z=-0.4261, visibility=0.0033
#
# LEFT_ANKLE: x=0.7013, y=3.6159, z=0.1415, visibility=0.0006
#
# RIGHT_ANKLE: x=0.3819, y=3.5956, z=-0.1861, visibility=0.0001
#
# LEFT_HEEL: x=0.7035, y=3.7314, z=0.1424, visibility=0.0004
#
# RIGHT_HEEL: x=0.3830, y=3.7196, z=-0.1943, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6586, y=3.8282, z=-0.6450, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4166, y=3.8004, z=-1.0354, visibility=0.0008
#
# NOSE: x=0.6204, y=0.6546, z=-1.3127, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6527, y=0.5814, z=-1.2005, visibility=0.9997
#
# LEFT_EYE: x=0.6712, y=0.5822, z=-1.2009, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6892, y=0.5841, z=-1.2011, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5818, y=0.5841, z=-1.2310, visibility=0.9997
#
# RIGHT_EYE: x=0.5506, y=0.5875, z=-1.2308, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5219, y=0.5918, z=-1.2313, visibility=0.9997
#
# LEFT_EAR: x=0.7057, y=0.6202, z=-0.5523, visibility=0.9997
#
# RIGHT_EAR: x=0.4706, y=0.6301, z=-0.6808, visibility=0.9998
#
# MOUTH_LEFT: x=0.6499, y=0.7515, z=-1.0661, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5710, y=0.7513, z=-1.1084, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8368, y=0.9898, z=-0.2247, visibility=0.9854
#
# RIGHT_SHOULDER: x=0.2739, y=1.0126, z=-0.3704, visibility=0.9772
#
# LEFT_ELBOW: x=1.1034, y=1.2531, z=-1.0417, visibility=0.4441
#
# RIGHT_ELBOW: x=0.1294, y=1.4143, z=-0.8339, visibility=0.3528
#
# LEFT_WRIST: x=1.0325, y=0.8568, z=-1.9931, visibility=0.6779
#
# RIGHT_WRIST: x=0.1695, y=1.3507, z=-1.7054, visibility=0.4211
#
# LEFT_PINKY: x=1.0309, y=0.6990, z=-2.2015, visibility=0.6648
#
# RIGHT_PINKY: x=0.1720, y=1.3546, z=-1.8940, visibility=0.4289
#
# LEFT_INDEX: x=0.9389, y=0.6449, z=-2.1307, visibility=0.7110
#
# RIGHT_INDEX: x=0.1967, y=1.1225, z=-1.8737, visibility=0.5178
#
# LEFT_THUMB: x=0.9436, y=0.7018, z=-2.0068, visibility=0.6751
#
# RIGHT_THUMB: x=0.2003, y=1.0975, z=-1.7317, visibility=0.4767
#
# LEFT_HIP: x=0.7309, y=2.0532, z=-0.0234, visibility=0.0025
#
# RIGHT_HIP: x=0.3759, y=2.0479, z=0.0300, visibility=0.0019
#
# LEFT_KNEE: x=0.7025, y=2.8740, z=-0.3397, visibility=0.0115
#
# RIGHT_KNEE: x=0.3707, y=2.8279, z=-0.4354, visibility=0.0034
#
# LEFT_ANKLE: x=0.7107, y=3.6191, z=0.1364, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3873, y=3.5985, z=-0.2062, visibility=0.0001
#
# LEFT_HEEL: x=0.7131, y=3.7346, z=0.1353, visibility=0.0004
#
# RIGHT_HEEL: x=0.3877, y=3.7220, z=-0.2155, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6672, y=3.8331, z=-0.6622, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4276, y=3.8044, z=-1.0645, visibility=0.0008
#
# NOSE: x=0.6205, y=0.6544, z=-1.3101, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6527, y=0.5811, z=-1.1990, visibility=0.9997
#
# LEFT_EYE: x=0.6712, y=0.5818, z=-1.1994, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6892, y=0.5836, z=-1.1995, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5818, y=0.5839, z=-1.2284, visibility=0.9997
#
# RIGHT_EYE: x=0.5505, y=0.5871, z=-1.2281, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5217, y=0.5912, z=-1.2286, visibility=0.9997
#
# LEFT_EAR: x=0.7058, y=0.6197, z=-0.5512, visibility=0.9997
#
# RIGHT_EAR: x=0.4703, y=0.6296, z=-0.6784, visibility=0.9998
#
# MOUTH_LEFT: x=0.6499, y=0.7511, z=-1.0653, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5710, y=0.7510, z=-1.1070, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8383, y=0.9895, z=-0.2221, visibility=0.9858
#
# RIGHT_SHOULDER: x=0.2722, y=1.0129, z=-0.3556, visibility=0.9767
#
# LEFT_ELBOW: x=1.1039, y=1.2528, z=-1.0295, visibility=0.4521
#
# RIGHT_ELBOW: x=0.1293, y=1.4138, z=-0.8740, visibility=0.3410
#
# LEFT_WRIST: x=1.0308, y=0.8707, z=-1.9910, visibility=0.6894
#
# RIGHT_WRIST: x=0.1689, y=1.2314, z=-1.8438, visibility=0.4080
#
# LEFT_PINKY: x=1.0307, y=0.7109, z=-2.1994, visibility=0.6757
#
# RIGHT_PINKY: x=0.1757, y=1.3443, z=-2.0487, visibility=0.4176
#
# LEFT_INDEX: x=0.9397, y=0.6626, z=-2.1277, visibility=0.7212
#
# RIGHT_INDEX: x=0.1965, y=1.1002, z=-2.0236, visibility=0.5064
#
# LEFT_THUMB: x=0.9235, y=0.7320, z=-2.0037, visibility=0.6839
#
# RIGHT_THUMB: x=0.1979, y=1.0997, z=-1.8716, visibility=0.4646
#
# LEFT_HIP: x=0.7311, y=2.0526, z=-0.0243, visibility=0.0026
#
# RIGHT_HIP: x=0.3758, y=2.0476, z=0.0310, visibility=0.0020
#
# LEFT_KNEE: x=0.7048, y=2.8739, z=-0.3402, visibility=0.0118
#
# RIGHT_KNEE: x=0.3719, y=2.8283, z=-0.4450, visibility=0.0035
#
# LEFT_ANKLE: x=0.7135, y=3.6196, z=0.1321, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3888, y=3.5989, z=-0.2170, visibility=0.0001
#
# LEFT_HEEL: x=0.7158, y=3.7351, z=0.1303, visibility=0.0004
#
# RIGHT_HEEL: x=0.3892, y=3.7220, z=-0.2268, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6700, y=3.8341, z=-0.6692, visibility=0.0008
#
# RIGHT_FOOT_INDEX: x=0.4302, y=3.8059, z=-1.0751, visibility=0.0008
#
# NOSE: x=0.6210, y=0.6557, z=-1.3463, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6531, y=0.5826, z=-1.2331, visibility=0.9997
#
# LEFT_EYE: x=0.6716, y=0.5835, z=-1.2335, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6896, y=0.5853, z=-1.2337, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5819, y=0.5845, z=-1.2605, visibility=0.9997
#
# RIGHT_EYE: x=0.5506, y=0.5874, z=-1.2603, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5218, y=0.5912, z=-1.2607, visibility=0.9997
#
# LEFT_EAR: x=0.7059, y=0.6207, z=-0.5704, visibility=0.9997
#
# RIGHT_EAR: x=0.4704, y=0.6297, z=-0.6937, visibility=0.9998
#
# MOUTH_LEFT: x=0.6501, y=0.7523, z=-1.0964, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5711, y=0.7515, z=-1.1342, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8389, y=0.9892, z=-0.2317, visibility=0.9864
#
# RIGHT_SHOULDER: x=0.2724, y=1.0133, z=-0.3558, visibility=0.9763
#
# LEFT_ELBOW: x=1.1188, y=1.2532, z=-1.0438, visibility=0.4727
#
# RIGHT_ELBOW: x=0.1296, y=1.4124, z=-0.9152, visibility=0.3335
#
# LEFT_WRIST: x=1.0361, y=0.8696, z=-1.9936, visibility=0.7035
#
# RIGHT_WRIST: x=0.1587, y=1.2058, z=-2.0573, visibility=0.3988
#
# LEFT_PINKY: x=1.0353, y=0.7292, z=-2.2014, visibility=0.6878
#
# RIGHT_PINKY: x=0.1745, y=1.3350, z=-2.2850, visibility=0.4089
#
# LEFT_INDEX: x=0.9406, y=0.6573, z=-2.1235, visibility=0.7322
#
# RIGHT_INDEX: x=0.1982, y=1.0918, z=-2.2655, visibility=0.4976
#
# LEFT_THUMB: x=0.9204, y=0.7347, z=-2.0023, visibility=0.6941
#
# RIGHT_THUMB: x=0.1988, y=1.0819, z=-2.0922, visibility=0.4547
#
# LEFT_HIP: x=0.7314, y=2.0523, z=-0.0268, visibility=0.0027
#
# RIGHT_HIP: x=0.3769, y=2.0476, z=0.0333, visibility=0.0020
#
# LEFT_KNEE: x=0.7051, y=2.8705, z=-0.3579, visibility=0.0120
#
# RIGHT_KNEE: x=0.3720, y=2.8222, z=-0.4456, visibility=0.0035
#
# LEFT_ANKLE: x=0.7135, y=3.6157, z=0.1236, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3892, y=3.5931, z=-0.2060, visibility=0.0001
#
# LEFT_HEEL: x=0.7159, y=3.7310, z=0.1233, visibility=0.0004
#
# RIGHT_HEEL: x=0.3900, y=3.7161, z=-0.2152, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6699, y=3.8291, z=-0.6705, visibility=0.0009
#
# RIGHT_FOOT_INDEX: x=0.4303, y=3.8003, z=-1.0598, visibility=0.0009
#
# NOSE: x=0.6209, y=0.6555, z=-1.3652, visibility=0.9997
#
# LEFT_EYE_INNER: x=0.6530, y=0.5823, z=-1.2507, visibility=0.9997
#
# LEFT_EYE: x=0.6716, y=0.5832, z=-1.2511, visibility=0.9997
#
# LEFT_EYE_OUTER: x=0.6896, y=0.5849, z=-1.2512, visibility=0.9997
#
# RIGHT_EYE_INNER: x=0.5808, y=0.5842, z=-1.2762, visibility=0.9997
#
# RIGHT_EYE: x=0.5498, y=0.5864, z=-1.2759, visibility=0.9997
#
# RIGHT_EYE_OUTER: x=0.5213, y=0.5897, z=-1.2763, visibility=0.9997
#
# LEFT_EAR: x=0.7066, y=0.6206, z=-0.5855, visibility=0.9998
#
# RIGHT_EAR: x=0.4702, y=0.6286, z=-0.7007, visibility=0.9998
#
# MOUTH_LEFT: x=0.6502, y=0.7520, z=-1.1152, visibility=0.9996
#
# MOUTH_RIGHT: x=0.5709, y=0.7514, z=-1.1500, visibility=0.9997
#
# LEFT_SHOULDER: x=0.8412, y=0.9889, z=-0.2446, visibility=0.9869
#
# RIGHT_SHOULDER: x=0.2698, y=1.0132, z=-0.3652, visibility=0.9764
#
# LEFT_ELBOW: x=1.1221, y=1.2659, z=-1.0701, visibility=0.4857
#
# RIGHT_ELBOW: x=0.1269, y=1.4143, z=-0.9850, visibility=0.3239
#
# LEFT_WRIST: x=1.0427, y=0.8731, z=-2.0521, visibility=0.7146
#
# RIGHT_WRIST: x=0.1730, y=1.3315, z=-2.1601, visibility=0.3858
#
# LEFT_PINKY: x=1.0434, y=0.7322, z=-2.2697, visibility=0.6987
#
# RIGHT_PINKY: x=0.1823, y=1.3608, z=-2.3954, visibility=0.3981
#
# LEFT_INDEX: x=0.9444, y=0.6667, z=-2.1937, visibility=0.7424
#
# RIGHT_INDEX: x=0.1973, y=1.1002, z=-2.3780, visibility=0.4872
#
# LEFT_THUMB: x=0.9678, y=0.7417, z=-2.0627, visibility=0.7036
#
# RIGHT_THUMB: x=0.2060, y=1.0854, z=-2.1968, visibility=0.4436
#
# LEFT_HIP: x=0.7318, y=2.0536, z=-0.0288, visibility=0.0027
#
# RIGHT_HIP: x=0.3755, y=2.0486, z=0.0356, visibility=0.0020
#
# LEFT_KNEE: x=0.7052, y=2.8757, z=-0.3822, visibility=0.0120
#
# RIGHT_KNEE: x=0.3721, y=2.8281, z=-0.4722, visibility=0.0034
#
# LEFT_ANKLE: x=0.7134, y=3.6248, z=0.0984, visibility=0.0007
#
# RIGHT_ANKLE: x=0.3890, y=3.6031, z=-0.2383, visibility=0.0001
#
# LEFT_HEEL: x=0.7156, y=3.7411, z=0.0974, visibility=0.0004
#
# RIGHT_HEEL: x=0.3899, y=3.7286, z=-0.2487, visibility=0.0002
#
# LEFT_FOOT_INDEX: x=0.6695, y=3.8402, z=-0.7119, visibility=0.0009
#
# RIGHT_FOOT_INDEX: x=0.4297, y=3.8095, z=-1.1097, visibility=0.0009

# %%
len(landmarks)   # total number of landmarks
# Out:
# 33

# %%
# name of all landmarks
for lndmrk in mp_pose.PoseLandmark:
    print(lndmrk)
# Out:
# PoseLandmark.NOSE
# PoseLandmark.LEFT_EYE_INNER
# PoseLandmark.LEFT_EYE
# PoseLandmark.LEFT_EYE_OUTER
# PoseLandmark.RIGHT_EYE_INNER
# PoseLandmark.RIGHT_EYE
# PoseLandmark.RIGHT_EYE_OUTER
# PoseLandmark.LEFT_EAR
# PoseLandmark.RIGHT_EAR
# PoseLandmark.MOUTH_LEFT
# PoseLandmark.MOUTH_RIGHT
# PoseLandmark.LEFT_SHOULDER
# PoseLandmark.RIGHT_SHOULDER
# PoseLandmark.LEFT_ELBOW
# PoseLandmark.RIGHT_ELBOW
# PoseLandmark.LEFT_WRIST
# PoseLandmark.RIGHT_WRIST
# PoseLandmark.LEFT_PINKY
# PoseLandmark.RIGHT_PINKY
# PoseLandmark.LEFT_INDEX
# PoseLandmark.RIGHT_INDEX
# PoseLandmark.LEFT_THUMB
# PoseLandmark.RIGHT_THUMB
# PoseLandmark.LEFT_HIP
# PoseLandmark.RIGHT_HIP
# PoseLandmark.LEFT_KNEE
# PoseLandmark.RIGHT_KNEE
# PoseLandmark.LEFT_ANKLE
# PoseLandmark.RIGHT_ANKLE
# PoseLandmark.LEFT_HEEL
# PoseLandmark.RIGHT_HEEL
# PoseLandmark.LEFT_FOOT_INDEX
# PoseLandmark.RIGHT_FOOT_INDEX

# %%
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]   # all values of left shoulder
# Out:
# x: 0.890171707
# y: 0.869838655
# z: -0.0732120797
# visibility: 0.995816171

# %%
landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value]   # all values of right shoulder
# Out:
# x: 0.371215105
# y: 0.814971149
# z: -0.29410705
# visibility: 0.997726202

# %%
mp_pose.PoseLandmark.LEFT_SHOULDER.value   # index of left shoulder
# Out:
# 11

# %%
mp_pose.PoseLandmark.RIGHT_SHOULDER.value   # index of right shoulder
# Out:
# 12

# %% [markdown]
# # Calculations

# %%
cap = cv2.VideoCapture(0)

# setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # recolor image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
      
        # make detection
        results = pose.process(image)
    
        # recolor image back to BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # extract landmarks
        try:
            landmarks = results.pose_landmarks.landmark

            # function to calculate mid point of shoulder
            def shldr_midpt(ls,rs):   # arguments are left shoulder and right shoulder
                 ls = np.array(ls)
                 rs = np.array(rs)
                 mids = (ls+rs)/2
                 return mids
            
            # function to calculate coordinate of chin
            def chin_coord(n,ll,rl):   # arguments are nose, left side of mouth and right side of mouth
                 n = np.array(n)
                 ll = np.array(ll)
                 rl = np.array(rl)
                 midm = (ll+rl)/2   # mid point of mouth

                 gap = abs(n[1] - midm[1])   # gap between nose and mouth

                 chin_pt = [midm[0], midm[1] + gap * 1.25]   # projecting downwards to estimate chin coordinate; scaling factor is 1.25
                 
                 return chin_pt
            
            # function to calculate angle
            def calculate_angle(a,b,c):
                 a = np.array(a)   # first
                 b = np.array(b)   # mid
                 c = np.array(c)   # end

                 radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])   # Y value - X value
                 angle = np.abs(radians*180.0/np.pi)

                 if angle > 180.0:
                      angle = 360-angle
                 
                 return angle
        
            # getting X and Y value; coordinates of landmark
            shoulderL = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            shoulderR = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            mouthL = [landmarks[mp_pose.PoseLandmark.MOUTH_LEFT.value].x, landmarks[mp_pose.PoseLandmark.MOUTH_LEFT.value].y]
            mouthR = [landmarks[mp_pose.PoseLandmark.MOUTH_RIGHT.value].x, landmarks[mp_pose.PoseLandmark.MOUTH_RIGHT.value].y]

            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x, landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            shoulderM = shldr_midpt(shoulderL,shoulderR)   # mid point of shoulder
            chin = chin_coord(nose,mouthL,mouthR)   # coordinate of chin

            angleL = calculate_angle(shoulderL, shoulderM, nose)   # left dirn
            angleR = calculate_angle(shoulderR, shoulderM, nose)   # right dirn

            # visulaising the chin and mid point of shoulder
            cv2.circle(image,tuple(np.multiply(chin,[640,480]).astype(int)),
                       5,(0,0,255),-1)
            cv2.circle(image,tuple(np.multiply(shoulderM,[640,480]).astype(int)),
                       5,(0,0,255),-1)
            cv2.line(image,tuple(np.multiply(chin,[640,480]).astype(int)),
                     tuple(np.multiply(shoulderM,[640,480]).astype(int)),
                     (0,255,255),2)
            
            if angleR > 80:
                dirn = 'Left'
            
            if angleL > 80:
                dirn = 'Right'

            # visualising angle
            cv2.putText(image, f"Direction: {dirn}",
                        (15,20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2, cv2.LINE_AA)

            for id, lm in enumerate(landmarks):
                landmark_name = mp_pose.PoseLandmark(id).name   # get landmark name
                print(f"{landmark_name}: "
                      f"x={lm.x:.4f}, y={lm.y:.4f}, z={lm.z:.4f}, visibility={lm.visibility:.4f} \n")

        except:
            pass
        
        # render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(0,0,255), thickness=2, circle_radius=2),   # color of dots
                                  mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2)   # color of lines
                                 )
        
        cv2.imshow('Camera Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('x'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cap = cv2.VideoCapture(0)
#       3 # setup mediapipe instance
#       4 with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#
# NameError: name 'cv2' is not defined
